# %%
import numpy as np
import pandas as pd
import sklearn
import scipy
from scipy.spatial import Delaunay
import networkx as nx
import matplotlib.pyplot as plt
import itertools
import collections
from collections import defaultdict
from Geometry3D import *
import copy
import ast
import random
import itertools
import statistics
from scipy.stats import truncnorm
from scipy.stats import bernoulli
from IPython.display import Image
import math
import shapely
from shapely.geometry import Point as pointpoint
from shapely.geometry.polygon import Polygon as polygonpolygon
from shapely.geometry import MultiPolygon
from itertools import permutations
import shapely.geometry as sg
import pandas as pd
import time
import json
epsilon = 10e-5
from sklearn.cluster import AgglomerativeClustering
from scipy.cluster.hierarchy import dendrogram
from sect.triangulation import Triangulation
from ground.base import get_context
#https://github.com/lycantropos/sect

# %%
with open('efficientset.json', 'r') as file:
    data = json.load(file)

# Преобразование данных в список списков
efficient_set = [[item[0], item[1]] for item in data]
efficient_set
# Out:
# [[4.040404040404041, 0.0],
#  [4.141414141414141, 0.0],
#  [4.242424242424242, 0.0],
#  [4.343434343434343, 0.0],
#  [4.444444444444445, 0.0],
#  [4.545454545454545, 0.0],
#  [4.646464646464646, 0.0],
#  [4.747474747474747, 0.0],
#  [4.848484848484849, 0.0],
#  [4.94949494949495, 0.0],
#  [5.05050505050505, 0.0],
#  [5.151515151515151, 0.0],
#  [5.252525252525253, 0.0],
#  [5.353535353535354, 0.0],
#  [5.454545454545454, 0.0],
#  [5.555555555555555, 0.0],
#  [5.656565656565657, 0.0],
#  [5.757575757575758, 0.0],
#  [5.858585858585858, 0.0],
#  [5.959595959595959, 0.0],
#  [4.040404040404041, 0.10101010101010101],
#  [4.141414141414141, 0.10101010101010101],
#  [4.242424242424242, 0.10101010101010101],
#  [4.343434343434343, 0.10101010101010101],
#  [4.444444444444445, 0.10101010101010101],
#  [4.545454545454545, 0.10101010101010101],
#  [4.646464646464646, 0.10101010101010101],
#  [4.747474747474747, 0.10101010101010101],
#  [4.848484848484849, 0.10101010101010101],
#  [4.94949494949495, 0.10101010101010101],
#  [5.05050505050505, 0.10101010101010101],
#  [5.151515151515151, 0.10101010101010101],
#  [5.252525252525253, 0.10101010101010101],
#  [5.353535353535354, 0.10101010101010101],
#  [5.454545454545454, 0.10101010101010101],
#  [5.555555555555555, 0.10101010101010101],
#  [5.656565656565657, 0.10101010101010101],
#  [5.757575757575758, 0.10101010101010101],
#  [5.858585858585858, 0.10101010101010101],
#  [5.959595959595959, 0.10101010101010101],
#  [4.040404040404041, 0.20202020202020202],
#  [4.141414141414141, 0.20202020202020202],
#  [4.242424242424242, 0.20202020202020202],
#  [4.343434343434343, 0.20202020202020202],
#  [4.444444444444445, 0.20202020202020202],
#  [4.545454545454545, 0.20202020202020202],
#  [4.646464646464646, 0.20202020202020202],
#  [4.747474747474747, 0.20202020202020202],
#  [4.848484848484849, 0.20202020202020202],
#  [4.94949494949495, 0.20202020202020202],
#  [5.05050505050505, 0.20202020202020202],
#  [5.151515151515151, 0.20202020202020202],
#  [5.252525252525253, 0.20202020202020202],
#  [5.353535353535354, 0.20202020202020202],
#  [5.454545454545454, 0.20202020202020202],
#  [5.555555555555555, 0.20202020202020202],
#  [5.656565656565657, 0.20202020202020202],
#  [5.757575757575758, 0.20202020202020202],
#  [5.858585858585858, 0.20202020202020202],
#  [5.959595959595959, 0.20202020202020202],
#  [4.040404040404041, 0.30303030303030304],
#  [4.141414141414141, 0.30303030303030304],
#  [4.242424242424242, 0.30303030303030304],
#  [4.343434343434343, 0.30303030303030304],
#  [4.444444444444445, 0.30303030303030304],
#  [4.545454545454545, 0.30303030303030304],
#  [4.646464646464646, 0.30303030303030304],
#  [4.747474747474747, 0.30303030303030304],
#  [4.848484848484849, 0.30303030303030304],
#  [4.94949494949495, 0.30303030303030304],
#  [5.05050505050505, 0.30303030303030304],
#  [5.151515151515151, 0.30303030303030304],
#  [5.252525252525253, 0.30303030303030304],
#  [5.353535353535354, 0.30303030303030304],
#  [5.454545454545454, 0.30303030303030304],
#  [5.555555555555555, 0.30303030303030304],
#  [5.656565656565657, 0.30303030303030304],
#  [5.757575757575758, 0.30303030303030304],
#  [5.858585858585858, 0.30303030303030304],
#  [5.959595959595959, 0.30303030303030304],
#  [4.040404040404041, 0.40404040404040403],
#  [4.141414141414141, 0.40404040404040403],
#  [4.242424242424242, 0.40404040404040403],
#  [4.343434343434343, 0.40404040404040403],
#  [4.444444444444445, 0.40404040404040403],
#  [4.545454545454545, 0.40404040404040403],
#  [4.646464646464646, 0.40404040404040403],
#  [4.747474747474747, 0.40404040404040403],
#  [4.848484848484849, 0.40404040404040403],
#  [4.94949494949495, 0.40404040404040403],
#  [5.05050505050505, 0.40404040404040403],
#  [5.151515151515151, 0.40404040404040403],
#  [5.252525252525253, 0.40404040404040403],
#  [5.353535353535354, 0.40404040404040403],
#  [5.454545454545454, 0.40404040404040403],
#  [5.555555555555555, 0.40404040404040403],
#  [5.656565656565657, 0.40404040404040403],
#  [5.757575757575758, 0.40404040404040403],
#  [5.858585858585858, 0.40404040404040403],
#  [5.959595959595959, 0.40404040404040403],
#  [4.040404040404041, 0.5050505050505051],
#  [4.141414141414141, 0.5050505050505051],
#  [4.242424242424242, 0.5050505050505051],
#  [4.343434343434343, 0.5050505050505051],
#  [4.444444444444445, 0.5050505050505051],
#  [4.545454545454545, 0.5050505050505051],
#  [4.646464646464646, 0.5050505050505051],
#  [4.747474747474747, 0.5050505050505051],
#  [4.848484848484849, 0.5050505050505051],
#  [4.94949494949495, 0.5050505050505051],
#  [5.05050505050505, 0.5050505050505051],
#  [5.151515151515151, 0.5050505050505051],
#  [5.252525252525253, 0.5050505050505051],
#  [5.353535353535354, 0.5050505050505051],
#  [5.454545454545454, 0.5050505050505051],
#  [5.555555555555555, 0.5050505050505051],
#  [5.656565656565657, 0.5050505050505051],
#  [5.757575757575758, 0.5050505050505051],
#  [5.858585858585858, 0.5050505050505051],
#  [5.959595959595959, 0.5050505050505051],
#  [4.040404040404041, 0.6060606060606061],
#  [4.141414141414141, 0.6060606060606061],
#  [4.242424242424242, 0.6060606060606061],
#  [4.343434343434343, 0.6060606060606061],
#  [4.444444444444445, 0.6060606060606061],
#  [4.545454545454545, 0.6060606060606061],
#  [4.646464646464646, 0.6060606060606061],
#  [4.747474747474747, 0.6060606060606061],
#  [4.848484848484849, 0.6060606060606061],
#  [4.94949494949495, 0.6060606060606061],
#  [5.05050505050505, 0.6060606060606061],
#  [5.151515151515151, 0.6060606060606061],
#  [5.252525252525253, 0.6060606060606061],
#  [5.353535353535354, 0.6060606060606061],
#  [5.454545454545454, 0.6060606060606061],
#  [5.555555555555555, 0.6060606060606061],
#  [5.656565656565657, 0.6060606060606061],
#  [5.757575757575758, 0.6060606060606061],
#  [5.858585858585858, 0.6060606060606061],
#  [5.959595959595959, 0.6060606060606061],
#  [4.040404040404041, 0.7070707070707071],
#  [4.141414141414141, 0.7070707070707071],
#  [4.242424242424242, 0.7070707070707071],
#  [4.343434343434343, 0.7070707070707071],
#  [4.444444444444445, 0.7070707070707071],
#  [4.545454545454545, 0.7070707070707071],
#  [4.646464646464646, 0.7070707070707071],
#  [4.747474747474747, 0.7070707070707071],
#  [4.848484848484849, 0.7070707070707071],
#  [4.94949494949495, 0.7070707070707071],
#  [5.05050505050505, 0.7070707070707071],
#  [5.151515151515151, 0.7070707070707071],
#  [5.252525252525253, 0.7070707070707071],
#  [5.353535353535354, 0.7070707070707071],
#  [5.454545454545454, 0.7070707070707071],
#  [5.555555555555555, 0.7070707070707071],
#  [5.656565656565657, 0.7070707070707071],
#  [5.757575757575758, 0.7070707070707071],
#  [5.858585858585858, 0.7070707070707071],
#  [5.959595959595959, 0.7070707070707071],
#  [4.040404040404041, 0.8080808080808081],
#  [4.141414141414141, 0.8080808080808081],
#  [4.242424242424242, 0.8080808080808081],
#  [4.343434343434343, 0.8080808080808081],
#  [4.444444444444445, 0.8080808080808081],
#  [4.545454545454545, 0.8080808080808081],
#  [4.646464646464646, 0.8080808080808081],
#  [4.747474747474747, 0.8080808080808081],
#  [4.848484848484849, 0.8080808080808081],
#  [4.94949494949495, 0.8080808080808081],
#  [5.05050505050505, 0.8080808080808081],
#  [5.151515151515151, 0.8080808080808081],
#  [5.252525252525253, 0.8080808080808081],
#  [5.353535353535354, 0.8080808080808081],
#  [5.454545454545454, 0.8080808080808081],
#  [5.555555555555555, 0.8080808080808081],
#  [5.656565656565657, 0.8080808080808081],
#  [5.757575757575758, 0.8080808080808081],
#  [5.858585858585858, 0.8080808080808081],
#  [5.959595959595959, 0.8080808080808081],
#  [4.040404040404041, 0.9090909090909091],
#  [4.141414141414141, 0.9090909090909091],
#  [4.242424242424242, 0.9090909090909091],
#  [4.343434343434343, 0.9090909090909091],
#  [4.444444444444445, 0.9090909090909091],
#  [4.545454545454545, 0.9090909090909091],
#  [4.646464646464646, 0.9090909090909091],
#  [4.747474747474747, 0.9090909090909091],
#  [4.848484848484849, 0.9090909090909091],
#  [4.94949494949495, 0.9090909090909091],
#  [5.05050505050505, 0.9090909090909091],
#  [5.151515151515151, 0.9090909090909091],
#  [5.252525252525253, 0.9090909090909091],
#  [5.353535353535354, 0.9090909090909091],
#  [5.454545454545454, 0.9090909090909091],
#  [5.555555555555555, 0.9090909090909091],
#  [5.656565656565657, 0.9090909090909091],
#  [5.757575757575758, 0.9090909090909091],
#  [5.858585858585858, 0.9090909090909091],
#  [5.959595959595959, 0.9090909090909091],
#  [4.040404040404041, 1.0101010101010102],
#  [4.141414141414141, 1.0101010101010102],
#  [4.242424242424242, 1.0101010101010102],
#  [4.343434343434343, 1.0101010101010102],
#  [4.444444444444445, 1.0101010101010102],
#  [4.545454545454545, 1.0101010101010102],
#  [4.646464646464646, 1.0101010101010102],
#  [4.747474747474747, 1.0101010101010102],
#  [4.848484848484849, 1.0101010101010102],
#  [4.94949494949495, 1.0101010101010102],
#  [5.05050505050505, 1.0101010101010102],
#  [5.151515151515151, 1.0101010101010102],
#  [5.252525252525253, 1.0101010101010102],
#  [5.353535353535354, 1.0101010101010102],
#  [5.454545454545454, 1.0101010101010102],
#  [5.555555555555555, 1.0101010101010102],
#  [5.656565656565657, 1.0101010101010102],
#  [5.757575757575758, 1.0101010101010102],
#  [5.858585858585858, 1.0101010101010102],
#  [5.959595959595959, 1.0101010101010102],
#  [4.040404040404041, 1.1111111111111112],
#  [4.141414141414141, 1.1111111111111112],
#  [4.242424242424242, 1.1111111111111112],
#  [4.343434343434343, 1.1111111111111112],
#  [4.444444444444445, 1.1111111111111112],
#  [4.545454545454545, 1.1111111111111112],
#  [4.646464646464646, 1.1111111111111112],
#  [4.747474747474747, 1.1111111111111112],
#  [4.848484848484849, 1.1111111111111112],
#  [4.94949494949495, 1.1111111111111112],
#  [5.05050505050505, 1.1111111111111112],
#  [5.151515151515151, 1.1111111111111112],
#  [5.252525252525253, 1.1111111111111112],
#  [5.353535353535354, 1.1111111111111112],
#  [5.454545454545454, 1.1111111111111112],
#  [5.555555555555555, 1.1111111111111112],
#  [5.656565656565657, 1.1111111111111112],
#  [5.757575757575758, 1.1111111111111112],
#  [5.858585858585858, 1.1111111111111112],
#  [5.959595959595959, 1.1111111111111112],
#  [4.040404040404041, 1.2121212121212122],
#  [4.141414141414141, 1.2121212121212122],
#  [4.242424242424242, 1.2121212121212122],
#  [4.343434343434343, 1.2121212121212122],
#  [4.444444444444445, 1.2121212121212122],
#  [4.545454545454545, 1.2121212121212122],
#  [4.646464646464646, 1.2121212121212122],
#  [4.747474747474747, 1.2121212121212122],
#  [4.848484848484849, 1.2121212121212122],
#  [4.94949494949495, 1.2121212121212122],
#  [5.05050505050505, 1.2121212121212122],
#  [5.151515151515151, 1.2121212121212122],
#  [5.252525252525253, 1.2121212121212122],
#  [5.353535353535354, 1.2121212121212122],
#  [5.454545454545454, 1.2121212121212122],
#  [5.555555555555555, 1.2121212121212122],
#  [5.656565656565657, 1.2121212121212122],
#  [5.757575757575758, 1.2121212121212122],
#  [5.858585858585858, 1.2121212121212122],
#  [5.959595959595959, 1.2121212121212122],
#  [4.040404040404041, 1.3131313131313131],
#  [4.141414141414141, 1.3131313131313131],
#  [4.242424242424242, 1.3131313131313131],
#  [4.343434343434343, 1.3131313131313131],
#  [4.444444444444445, 1.3131313131313131],
#  [4.545454545454545, 1.3131313131313131],
#  [4.646464646464646, 1.3131313131313131],
#  [4.747474747474747, 1.3131313131313131],
#  [4.848484848484849, 1.3131313131313131],
#  [4.94949494949495, 1.3131313131313131],
#  [5.05050505050505, 1.3131313131313131],
#  [5.151515151515151, 1.3131313131313131],
#  [5.252525252525253, 1.3131313131313131],
#  [5.353535353535354, 1.3131313131313131],
#  [5.454545454545454, 1.3131313131313131],
#  [5.555555555555555, 1.3131313131313131],
#  [5.656565656565657, 1.3131313131313131],
#  [5.757575757575758, 1.3131313131313131],
#  [5.858585858585858, 1.3131313131313131],
#  [5.959595959595959, 1.3131313131313131],
#  [4.040404040404041, 1.4141414141414141],
#  [4.141414141414141, 1.4141414141414141],
#  [4.242424242424242, 1.4141414141414141],
#  [4.343434343434343, 1.4141414141414141],
#  [4.444444444444445, 1.4141414141414141],
#  [4.545454545454545, 1.4141414141414141],
#  [4.646464646464646, 1.4141414141414141],
#  [4.747474747474747, 1.4141414141414141],
#  [4.848484848484849, 1.4141414141414141],
#  [4.94949494949495, 1.4141414141414141],
#  [5.05050505050505, 1.4141414141414141],
#  [5.151515151515151, 1.4141414141414141],
#  [5.252525252525253, 1.4141414141414141],
#  [5.353535353535354, 1.4141414141414141],
#  [5.454545454545454, 1.4141414141414141],
#  [5.555555555555555, 1.4141414141414141],
#  [5.656565656565657, 1.4141414141414141],
#  [5.757575757575758, 1.4141414141414141],
#  [5.858585858585858, 1.4141414141414141],
#  [5.959595959595959, 1.4141414141414141],
#  [4.040404040404041, 1.5151515151515151],
#  [4.141414141414141, 1.5151515151515151],
#  [4.242424242424242, 1.5151515151515151],
#  [4.343434343434343, 1.5151515151515151],
#  [4.444444444444445, 1.5151515151515151],
#  [4.545454545454545, 1.5151515151515151],
#  [4.646464646464646, 1.5151515151515151],
#  [4.747474747474747, 1.5151515151515151],
#  [4.848484848484849, 1.5151515151515151],
#  [4.94949494949495, 1.5151515151515151],
#  [5.05050505050505, 1.5151515151515151],
#  [5.151515151515151, 1.5151515151515151],
#  [5.252525252525253, 1.5151515151515151],
#  [5.353535353535354, 1.5151515151515151],
#  [5.454545454545454, 1.5151515151515151],
#  [5.555555555555555, 1.5151515151515151],
#  [5.656565656565657, 1.5151515151515151],
#  [5.757575757575758, 1.5151515151515151],
#  [5.858585858585858, 1.5151515151515151],
#  [5.959595959595959, 1.5151515151515151],
#  [1.1111111111111112, 1.6161616161616161],
#  [1.2121212121212122, 1.6161616161616161],
#  [4.040404040404041, 1.6161616161616161],
#  [4.141414141414141, 1.6161616161616161],
#  [4.242424242424242, 1.6161616161616161],
#  [4.343434343434343, 1.6161616161616161],
#  [4.444444444444445, 1.6161616161616161],
#  [4.545454545454545, 1.6161616161616161],
#  [4.646464646464646, 1.6161616161616161],
#  [4.747474747474747, 1.6161616161616161],
#  [4.848484848484849, 1.6161616161616161],
#  [4.94949494949495, 1.6161616161616161],
#  [5.05050505050505, 1.6161616161616161],
#  [5.151515151515151, 1.6161616161616161],
#  [5.252525252525253, 1.6161616161616161],
#  [5.353535353535354, 1.6161616161616161],
#  [5.454545454545454, 1.6161616161616161],
#  [5.555555555555555, 1.6161616161616161],
#  [5.656565656565657, 1.6161616161616161],
#  [5.757575757575758, 1.6161616161616161],
#  [5.858585858585858, 1.6161616161616161],
#  [5.959595959595959, 1.6161616161616161],
#  [1.1111111111111112, 1.7171717171717171],
#  [1.2121212121212122, 1.7171717171717171],
#  [1.3131313131313131, 1.7171717171717171],
#  [4.040404040404041, 1.7171717171717171],
#  [4.141414141414141, 1.7171717171717171],
#  [4.242424242424242, 1.7171717171717171],
#  [4.343434343434343, 1.7171717171717171],
#  [4.444444444444445, 1.7171717171717171],
#  [4.545454545454545, 1.7171717171717171],
#  [4.646464646464646, 1.7171717171717171],
#  [4.747474747474747, 1.7171717171717171],
#  [4.848484848484849, 1.7171717171717171],
#  [4.94949494949495, 1.7171717171717171],
#  [5.05050505050505, 1.7171717171717171],
#  [5.151515151515151, 1.7171717171717171],
#  [5.252525252525253, 1.7171717171717171],
#  [5.353535353535354, 1.7171717171717171],
#  [5.454545454545454, 1.7171717171717171],
#  [5.555555555555555, 1.7171717171717171],
#  [5.656565656565657, 1.7171717171717171],
#  [5.757575757575758, 1.7171717171717171],
#  [5.858585858585858, 1.7171717171717171],
#  [5.959595959595959, 1.7171717171717171],
#  [1.2121212121212122, 1.8181818181818181],
#  [1.3131313131313131, 1.8181818181818181],
#  [4.040404040404041, 1.8181818181818181],
#  [4.141414141414141, 1.8181818181818181],
#  [4.242424242424242, 1.8181818181818181],
#  [4.343434343434343, 1.8181818181818181],
#  [4.444444444444445, 1.8181818181818181],
#  [4.545454545454545, 1.8181818181818181],
#  [4.646464646464646, 1.8181818181818181],
#  [4.747474747474747, 1.8181818181818181],
#  [4.848484848484849, 1.8181818181818181],
#  [4.94949494949495, 1.8181818181818181],
#  [5.05050505050505, 1.8181818181818181],
#  [5.151515151515151, 1.8181818181818181],
#  [5.252525252525253, 1.8181818181818181],
#  [5.353535353535354, 1.8181818181818181],
#  [5.454545454545454, 1.8181818181818181],
#  [5.555555555555555, 1.8181818181818181],
#  [5.656565656565657, 1.8181818181818181],
#  [5.757575757575758, 1.8181818181818181],
#  [5.858585858585858, 1.8181818181818181],
#  [5.959595959595959, 1.8181818181818181],
#  [4.040404040404041, 1.9191919191919191],
#  [4.141414141414141, 1.9191919191919191],
#  [4.242424242424242, 1.9191919191919191],
#  [4.343434343434343, 1.9191919191919191],
#  [4.444444444444445, 1.9191919191919191],
#  [4.545454545454545, 1.9191919191919191],
#  [4.646464646464646, 1.9191919191919191],
#  [4.747474747474747, 1.9191919191919191],
#  [4.848484848484849, 1.9191919191919191],
#  [4.94949494949495, 1.9191919191919191],
#  [5.05050505050505, 1.9191919191919191],
#  [5.151515151515151, 1.9191919191919191],
#  [5.252525252525253, 1.9191919191919191],
#  [5.353535353535354, 1.9191919191919191],
#  [5.454545454545454, 1.9191919191919191],
#  [5.555555555555555, 1.9191919191919191],
#  [5.656565656565657, 1.9191919191919191],
#  [5.757575757575758, 1.9191919191919191],
#  [5.858585858585858, 1.9191919191919191],
#  [5.959595959595959, 1.9191919191919191],
#  [4.040404040404041, 2.0202020202020203],
#  [4.141414141414141, 2.0202020202020203],
#  [4.242424242424242, 2.0202020202020203],
#  [4.343434343434343, 2.0202020202020203],
#  [4.444444444444445, 2.0202020202020203],
#  [4.545454545454545, 2.0202020202020203],
#  [4.646464646464646, 2.0202020202020203],
#  [4.747474747474747, 2.0202020202020203],
#  [4.848484848484849, 2.0202020202020203],
#  [4.94949494949495, 2.0202020202020203],
#  [5.05050505050505, 2.0202020202020203],
#  [5.151515151515151, 2.0202020202020203],
#  [5.252525252525253, 2.0202020202020203],
#  [5.353535353535354, 2.0202020202020203],
#  [5.454545454545454, 2.0202020202020203],
#  [5.555555555555555, 2.0202020202020203],
#  [5.656565656565657, 2.0202020202020203],
#  [5.757575757575758, 2.0202020202020203],
#  [5.858585858585858, 2.0202020202020203],
#  [5.959595959595959, 2.0202020202020203],
#  [4.040404040404041, 2.121212121212121],
#  [4.141414141414141, 2.121212121212121],
#  [4.242424242424242, 2.121212121212121],
#  [4.343434343434343, 2.121212121212121],
#  [4.444444444444445, 2.121212121212121],
#  [4.545454545454545, 2.121212121212121],
#  [4.646464646464646, 2.121212121212121],
#  [4.747474747474747, 2.121212121212121],
#  [4.848484848484849, 2.121212121212121],
#  [4.94949494949495, 2.121212121212121],
#  [5.05050505050505, 2.121212121212121],
#  [5.151515151515151, 2.121212121212121],
#  [5.252525252525253, 2.121212121212121],
#  [5.353535353535354, 2.121212121212121],
#  [5.454545454545454, 2.121212121212121],
#  [5.555555555555555, 2.121212121212121],
#  [5.656565656565657, 2.121212121212121],
#  [5.757575757575758, 2.121212121212121],
#  [5.858585858585858, 2.121212121212121],
#  [5.959595959595959, 2.121212121212121],
#  [4.040404040404041, 2.2222222222222223],
#  [4.141414141414141, 2.2222222222222223],
#  [4.242424242424242, 2.2222222222222223],
#  [4.343434343434343, 2.2222222222222223],
#  [4.444444444444445, 2.2222222222222223],
#  [4.545454545454545, 2.2222222222222223],
#  [4.646464646464646, 2.2222222222222223],
#  [4.747474747474747, 2.2222222222222223],
#  [4.848484848484849, 2.2222222222222223],
#  [4.94949494949495, 2.2222222222222223],
#  [5.05050505050505, 2.2222222222222223],
#  [5.151515151515151, 2.2222222222222223],
#  [5.252525252525253, 2.2222222222222223],
#  [5.353535353535354, 2.2222222222222223],
#  [5.454545454545454, 2.2222222222222223],
#  [5.555555555555555, 2.2222222222222223],
#  [5.656565656565657, 2.2222222222222223],
#  [5.757575757575758, 2.2222222222222223],
#  [5.858585858585858, 2.2222222222222223],
#  [5.959595959595959, 2.2222222222222223],
#  [4.040404040404041, 2.323232323232323],
#  [4.141414141414141, 2.323232323232323],
#  [4.242424242424242, 2.323232323232323],
#  [4.343434343434343, 2.323232323232323],
#  [4.444444444444445, 2.323232323232323],
#  [4.545454545454545, 2.323232323232323],
#  [4.646464646464646, 2.323232323232323],
#  [4.747474747474747, 2.323232323232323],
#  [4.848484848484849, 2.323232323232323],
#  [4.94949494949495, 2.323232323232323],
#  [5.05050505050505, 2.323232323232323],
#  [5.151515151515151, 2.323232323232323],
#  [5.252525252525253, 2.323232323232323],
#  [5.353535353535354, 2.323232323232323],
#  [5.454545454545454, 2.323232323232323],
#  [5.555555555555555, 2.323232323232323],
#  [5.656565656565657, 2.323232323232323],
#  [5.757575757575758, 2.323232323232323],
#  [5.858585858585858, 2.323232323232323],
#  [5.959595959595959, 2.323232323232323],
#  [4.040404040404041, 2.4242424242424243],
#  [4.141414141414141, 2.4242424242424243],
#  [4.242424242424242, 2.4242424242424243],
#  [4.343434343434343, 2.4242424242424243],
#  [4.444444444444445, 2.4242424242424243],
#  [4.545454545454545, 2.4242424242424243],
#  [4.646464646464646, 2.4242424242424243],
#  [4.747474747474747, 2.4242424242424243],
#  [4.848484848484849, 2.4242424242424243],
#  [4.94949494949495, 2.4242424242424243],
#  [5.05050505050505, 2.4242424242424243],
#  [5.151515151515151, 2.4242424242424243],
#  [5.252525252525253, 2.4242424242424243],
#  [5.353535353535354, 2.4242424242424243],
#  [5.454545454545454, 2.4242424242424243],
#  [5.555555555555555, 2.4242424242424243],
#  [5.656565656565657, 2.4242424242424243],
#  [5.757575757575758, 2.4242424242424243],
#  [5.858585858585858, 2.4242424242424243],
#  [5.959595959595959, 2.4242424242424243],
#  [4.040404040404041, 2.525252525252525],
#  [4.141414141414141, 2.525252525252525],
#  [4.242424242424242, 2.525252525252525],
#  [4.343434343434343, 2.525252525252525],
#  [4.444444444444445, 2.525252525252525],
#  [4.545454545454545, 2.525252525252525],
#  [4.646464646464646, 2.525252525252525],
#  [4.747474747474747, 2.525252525252525],
#  [4.848484848484849, 2.525252525252525],
#  [4.94949494949495, 2.525252525252525],
#  [5.05050505050505, 2.525252525252525],
#  [5.151515151515151, 2.525252525252525],
#  [5.252525252525253, 2.525252525252525],
#  [5.353535353535354, 2.525252525252525],
#  [5.454545454545454, 2.525252525252525],
#  [5.555555555555555, 2.525252525252525],
#  [5.656565656565657, 2.525252525252525],
#  [5.757575757575758, 2.525252525252525],
#  [5.858585858585858, 2.525252525252525],
#  [5.959595959595959, 2.525252525252525],
#  [4.040404040404041, 2.6262626262626263],
#  [4.141414141414141, 2.6262626262626263],
#  [4.242424242424242, 2.6262626262626263],
#  [4.343434343434343, 2.6262626262626263],
#  [4.444444444444445, 2.6262626262626263],
#  [4.545454545454545, 2.6262626262626263],
#  [4.646464646464646, 2.6262626262626263],
#  [4.747474747474747, 2.6262626262626263],
#  [4.848484848484849, 2.6262626262626263],
#  [4.94949494949495, 2.6262626262626263],
#  [5.05050505050505, 2.6262626262626263],
#  [5.151515151515151, 2.6262626262626263],
#  [5.252525252525253, 2.6262626262626263],
#  [5.353535353535354, 2.6262626262626263],
#  [5.454545454545454, 2.6262626262626263],
#  [5.555555555555555, 2.6262626262626263],
#  [5.656565656565657, 2.6262626262626263],
#  [5.757575757575758, 2.6262626262626263],
#  [5.858585858585858, 2.6262626262626263],
#  [5.959595959595959, 2.6262626262626263],
#  [4.040404040404041, 2.727272727272727],
#  [4.141414141414141, 2.727272727272727],
#  [4.242424242424242, 2.727272727272727],
#  [4.343434343434343, 2.727272727272727],
#  [4.444444444444445, 2.727272727272727],
#  [4.545454545454545, 2.727272727272727],
#  [4.646464646464646, 2.727272727272727],
#  [4.747474747474747, 2.727272727272727],
#  [4.848484848484849, 2.727272727272727],
#  [4.94949494949495, 2.727272727272727],
#  [5.05050505050505, 2.727272727272727],
#  [5.151515151515151, 2.727272727272727],
#  [5.252525252525253, 2.727272727272727],
#  [5.353535353535354, 2.727272727272727],
#  [5.454545454545454, 2.727272727272727],
#  [5.555555555555555, 2.727272727272727],
#  [5.656565656565657, 2.727272727272727],
#  [5.757575757575758, 2.727272727272727],
#  [5.858585858585858, 2.727272727272727],
#  [5.959595959595959, 2.727272727272727],
#  [4.040404040404041, 2.8282828282828283],
#  [4.141414141414141, 2.8282828282828283],
#  [4.242424242424242, 2.8282828282828283],
#  [4.343434343434343, 2.8282828282828283],
#  [4.444444444444445, 2.8282828282828283],
#  [4.545454545454545, 2.8282828282828283],
#  [4.646464646464646, 2.8282828282828283],
#  [4.747474747474747, 2.8282828282828283],
#  [4.848484848484849, 2.8282828282828283],
#  [4.94949494949495, 2.8282828282828283],
#  [5.05050505050505, 2.8282828282828283],
#  [5.151515151515151, 2.8282828282828283],
#  [5.252525252525253, 2.8282828282828283],
#  [5.353535353535354, 2.8282828282828283],
#  [5.454545454545454, 2.8282828282828283],
#  [5.555555555555555, 2.8282828282828283],
#  [5.656565656565657, 2.8282828282828283],
#  [5.757575757575758, 2.8282828282828283],
#  [5.858585858585858, 2.8282828282828283],
#  [5.959595959595959, 2.8282828282828283],
#  [4.040404040404041, 2.929292929292929],
#  [4.141414141414141, 2.929292929292929],
#  [4.242424242424242, 2.929292929292929],
#  [4.343434343434343, 2.929292929292929],
#  [4.444444444444445, 2.929292929292929],
#  [4.545454545454545, 2.929292929292929],
#  [4.646464646464646, 2.929292929292929],
#  [4.747474747474747, 2.929292929292929],
#  [4.848484848484849, 2.929292929292929],
#  [4.94949494949495, 2.929292929292929],
#  [5.05050505050505, 2.929292929292929],
#  [5.151515151515151, 2.929292929292929],
#  [5.252525252525253, 2.929292929292929],
#  [5.353535353535354, 2.929292929292929],
#  [5.454545454545454, 2.929292929292929],
#  [5.555555555555555, 2.929292929292929],
#  [5.656565656565657, 2.929292929292929],
#  [5.757575757575758, 2.929292929292929],
#  [5.858585858585858, 2.929292929292929],
#  [5.959595959595959, 2.929292929292929],
#  [8.585858585858587, 2.929292929292929],
#  [4.040404040404041, 3.0303030303030303],
#  [4.141414141414141, 3.0303030303030303],
#  [4.242424242424242, 3.0303030303030303],
#  [4.343434343434343, 3.0303030303030303],
#  [4.444444444444445, 3.0303030303030303],
#  [4.545454545454545, 3.0303030303030303],
#  [4.646464646464646, 3.0303030303030303],
#  [4.747474747474747, 3.0303030303030303],
#  [4.848484848484849, 3.0303030303030303],
#  [4.94949494949495, 3.0303030303030303],
#  [5.05050505050505, 3.0303030303030303],
#  [5.151515151515151, 3.0303030303030303],
#  [5.252525252525253, 3.0303030303030303],
#  [5.353535353535354, 3.0303030303030303],
#  [5.454545454545454, 3.0303030303030303],
#  [5.555555555555555, 3.0303030303030303],
#  [5.656565656565657, 3.0303030303030303],
#  [5.757575757575758, 3.0303030303030303],
#  [5.858585858585858, 3.0303030303030303],
#  [5.959595959595959, 3.0303030303030303],
#  [8.484848484848484, 3.0303030303030303],
#  [8.585858585858587, 3.0303030303030303],
#  [8.686868686868687, 3.0303030303030303],
#  [4.040404040404041, 3.131313131313131],
#  [4.141414141414141, 3.131313131313131],
#  [4.242424242424242, 3.131313131313131],
#  [4.343434343434343, 3.131313131313131],
#  [4.444444444444445, 3.131313131313131],
#  [4.545454545454545, 3.131313131313131],
#  [4.646464646464646, 3.131313131313131],
#  [4.747474747474747, 3.131313131313131],
#  [4.848484848484849, 3.131313131313131],
#  [4.94949494949495, 3.131313131313131],
#  [5.05050505050505, 3.131313131313131],
#  [5.151515151515151, 3.131313131313131],
#  [5.252525252525253, 3.131313131313131],
#  [5.353535353535354, 3.131313131313131],
#  [5.454545454545454, 3.131313131313131],
#  [5.555555555555555, 3.131313131313131],
#  [5.656565656565657, 3.131313131313131],
#  [5.757575757575758, 3.131313131313131],
#  [5.858585858585858, 3.131313131313131],
#  [5.959595959595959, 3.131313131313131],
#  [8.484848484848484, 3.131313131313131],
#  [8.585858585858587, 3.131313131313131],
#  [8.686868686868687, 3.131313131313131],
#  [4.040404040404041, 3.2323232323232323],
#  [4.141414141414141, 3.2323232323232323],
#  [4.242424242424242, 3.2323232323232323],
#  [4.343434343434343, 3.2323232323232323],
#  [4.444444444444445, 3.2323232323232323],
#  [4.545454545454545, 3.2323232323232323],
#  [4.646464646464646, 3.2323232323232323],
#  [4.747474747474747, 3.2323232323232323],
#  [4.848484848484849, 3.2323232323232323],
#  [4.94949494949495, 3.2323232323232323],
#  [5.05050505050505, 3.2323232323232323],
#  [5.151515151515151, 3.2323232323232323],
#  [5.252525252525253, 3.2323232323232323],
#  [5.353535353535354, 3.2323232323232323],
#  [5.454545454545454, 3.2323232323232323],
#  [5.555555555555555, 3.2323232323232323],
#  [5.656565656565657, 3.2323232323232323],
#  [5.757575757575758, 3.2323232323232323],
#  [5.858585858585858, 3.2323232323232323],
#  [5.959595959595959, 3.2323232323232323],
#  [8.484848484848484, 3.2323232323232323],
#  [8.585858585858587, 3.2323232323232323],
#  [8.686868686868687, 3.2323232323232323],
#  [4.040404040404041, 3.3333333333333335],
#  [4.141414141414141, 3.3333333333333335],
#  [4.242424242424242, 3.3333333333333335],
#  [4.343434343434343, 3.3333333333333335],
#  [4.444444444444445, 3.3333333333333335],
#  [4.545454545454545, 3.3333333333333335],
#  [4.646464646464646, 3.3333333333333335],
#  [4.747474747474747, 3.3333333333333335],
#  [4.848484848484849, 3.3333333333333335],
#  [4.94949494949495, 3.3333333333333335],
#  [5.05050505050505, 3.3333333333333335],
#  [5.151515151515151, 3.3333333333333335],
#  [5.252525252525253, 3.3333333333333335],
#  [5.353535353535354, 3.3333333333333335],
#  [5.454545454545454, 3.3333333333333335],
#  [5.555555555555555, 3.3333333333333335],
#  [5.656565656565657, 3.3333333333333335],
#  [5.757575757575758, 3.3333333333333335],
#  [5.858585858585858, 3.3333333333333335],
#  [5.959595959595959, 3.3333333333333335],
#  [8.484848484848484, 3.3333333333333335],
#  [8.585858585858587, 3.3333333333333335],
#  [4.040404040404041, 3.4343434343434343],
#  [4.141414141414141, 3.4343434343434343],
#  [4.242424242424242, 3.4343434343434343],
#  [4.343434343434343, 3.4343434343434343],
#  [4.444444444444445, 3.4343434343434343],
#  [4.545454545454545, 3.4343434343434343],
#  [4.646464646464646, 3.4343434343434343],
#  [4.747474747474747, 3.4343434343434343],
#  [4.848484848484849, 3.4343434343434343],
#  [4.94949494949495, 3.4343434343434343],
#  [5.05050505050505, 3.4343434343434343],
#  [5.151515151515151, 3.4343434343434343],
#  [5.252525252525253, 3.4343434343434343],
#  [5.353535353535354, 3.4343434343434343],
#  [5.454545454545454, 3.4343434343434343],
#  [5.555555555555555, 3.4343434343434343],
#  [5.656565656565657, 3.4343434343434343],
#  [5.757575757575758, 3.4343434343434343],
#  [5.858585858585858, 3.4343434343434343],
#  [5.959595959595959, 3.4343434343434343],
#  [8.585858585858587, 3.4343434343434343],
#  [4.040404040404041, 3.5353535353535355],
#  [4.141414141414141, 3.5353535353535355],
#  [4.242424242424242, 3.5353535353535355],
#  [4.343434343434343, 3.5353535353535355],
#  [4.444444444444445, 3.5353535353535355],
#  [4.545454545454545, 3.5353535353535355],
#  [4.646464646464646, 3.5353535353535355],
#  [4.747474747474747, 3.5353535353535355],
#  [4.848484848484849, 3.5353535353535355],
#  [4.94949494949495, 3.5353535353535355],
#  [5.05050505050505, 3.5353535353535355],
#  [5.151515151515151, 3.5353535353535355],
#  [5.252525252525253, 3.5353535353535355],
#  [5.353535353535354, 3.5353535353535355],
#  [5.454545454545454, 3.5353535353535355],
#  [5.555555555555555, 3.5353535353535355],
#  [5.656565656565657, 3.5353535353535355],
#  [5.757575757575758, 3.5353535353535355],
#  [5.858585858585858, 3.5353535353535355],
#  [5.959595959595959, 3.5353535353535355],
#  [4.040404040404041, 3.6363636363636362],
#  [4.141414141414141, 3.6363636363636362],
#  [4.242424242424242, 3.6363636363636362],
#  [4.343434343434343, 3.6363636363636362],
#  [4.444444444444445, 3.6363636363636362],
#  [4.545454545454545, 3.6363636363636362],
#  [4.646464646464646, 3.6363636363636362],
#  [4.747474747474747, 3.6363636363636362],
#  [4.848484848484849, 3.6363636363636362],
#  [4.94949494949495, 3.6363636363636362],
#  [5.05050505050505, 3.6363636363636362],
#  [5.151515151515151, 3.6363636363636362],
#  [5.252525252525253, 3.6363636363636362],
#  [5.353535353535354, 3.6363636363636362],
#  [5.454545454545454, 3.6363636363636362],
#  [5.555555555555555, 3.6363636363636362],
#  [5.656565656565657, 3.6363636363636362],
#  [5.757575757575758, 3.6363636363636362],
#  [5.858585858585858, 3.6363636363636362],
#  [5.959595959595959, 3.6363636363636362],
#  [4.040404040404041, 3.7373737373737375],
#  [4.141414141414141, 3.7373737373737375],
#  [4.242424242424242, 3.7373737373737375],
#  [4.343434343434343, 3.7373737373737375],
#  [4.444444444444445, 3.7373737373737375],
#  [4.545454545454545, 3.7373737373737375],
#  [4.646464646464646, 3.7373737373737375],
#  [4.747474747474747, 3.7373737373737375],
#  [4.848484848484849, 3.7373737373737375],
#  [4.94949494949495, 3.7373737373737375],
#  [5.05050505050505, 3.7373737373737375],
#  [5.151515151515151, 3.7373737373737375],
#  [5.252525252525253, 3.7373737373737375],
#  [5.353535353535354, 3.7373737373737375],
#  [5.454545454545454, 3.7373737373737375],
#  [5.555555555555555, 3.7373737373737375],
#  [5.656565656565657, 3.7373737373737375],
#  [5.757575757575758, 3.7373737373737375],
#  [5.858585858585858, 3.7373737373737375],
#  [5.959595959595959, 3.7373737373737375],
#  [4.040404040404041, 3.8383838383838382],
#  [4.141414141414141, 3.8383838383838382],
#  [4.242424242424242, 3.8383838383838382],
#  [4.343434343434343, 3.8383838383838382],
#  [4.444444444444445, 3.8383838383838382],
#  [4.545454545454545, 3.8383838383838382],
#  [4.646464646464646, 3.8383838383838382],
#  [4.747474747474747, 3.8383838383838382],
#  [4.848484848484849, 3.8383838383838382],
#  [4.94949494949495, 3.8383838383838382],
#  [5.05050505050505, 3.8383838383838382],
#  [5.151515151515151, 3.8383838383838382],
#  [5.252525252525253, 3.8383838383838382],
#  [5.353535353535354, 3.8383838383838382],
#  [5.454545454545454, 3.8383838383838382],
#  [5.555555555555555, 3.8383838383838382],
#  [5.656565656565657, 3.8383838383838382],
#  [5.757575757575758, 3.8383838383838382],
#  [5.858585858585858, 3.8383838383838382],
#  [5.959595959595959, 3.8383838383838382],
#  [4.040404040404041, 3.9393939393939394],
#  [4.141414141414141, 3.9393939393939394],
#  [4.242424242424242, 3.9393939393939394],
#  [4.343434343434343, 3.9393939393939394],
#  [4.444444444444445, 3.9393939393939394],
#  [4.545454545454545, 3.9393939393939394],
#  [4.646464646464646, 3.9393939393939394],
#  [4.747474747474747, 3.9393939393939394],
#  [4.848484848484849, 3.9393939393939394],
#  [4.94949494949495, 3.9393939393939394],
#  [5.05050505050505, 3.9393939393939394],
#  [5.151515151515151, 3.9393939393939394],
#  [5.252525252525253, 3.9393939393939394],
#  [5.353535353535354, 3.9393939393939394],
#  [5.454545454545454, 3.9393939393939394],
#  [5.555555555555555, 3.9393939393939394],
#  [5.656565656565657, 3.9393939393939394],
#  [5.757575757575758, 3.9393939393939394],
#  [5.858585858585858, 3.9393939393939394],
#  [5.959595959595959, 3.9393939393939394],
#  [4.040404040404041, 4.040404040404041],
#  [4.141414141414141, 4.040404040404041],
#  [4.242424242424242, 4.040404040404041],
#  [4.343434343434343, 4.040404040404041],
#  [4.444444444444445, 4.040404040404041],
#  [4.545454545454545, 4.040404040404041],
#  [4.646464646464646, 4.040404040404041],
#  [4.747474747474747, 4.040404040404041],
#  [4.848484848484849, 4.040404040404041],
#  [4.94949494949495, 4.040404040404041],
#  [5.05050505050505, 4.040404040404041],
#  [5.151515151515151, 4.040404040404041],
#  [5.252525252525253, 4.040404040404041],
#  [5.353535353535354, 4.040404040404041],
#  [5.454545454545454, 4.040404040404041],
#  [5.555555555555555, 4.040404040404041],
#  [5.656565656565657, 4.040404040404041],
#  [5.757575757575758, 4.040404040404041],
#  [5.858585858585858, 4.040404040404041],
#  [5.959595959595959, 4.040404040404041],
#  [4.040404040404041, 4.141414141414141],
#  [4.141414141414141, 4.141414141414141],
#  [4.242424242424242, 4.141414141414141],
#  [4.343434343434343, 4.141414141414141],
#  [4.444444444444445, 4.141414141414141],
#  [4.545454545454545, 4.141414141414141],
#  [4.646464646464646, 4.141414141414141],
#  [4.747474747474747, 4.141414141414141],
#  [4.848484848484849, 4.141414141414141],
#  [4.94949494949495, 4.141414141414141],
#  [5.05050505050505, 4.141414141414141],
#  [5.151515151515151, 4.141414141414141],
#  [5.252525252525253, 4.141414141414141],
#  [5.353535353535354, 4.141414141414141],
#  [5.454545454545454, 4.141414141414141],
#  [5.555555555555555, 4.141414141414141],
#  [5.656565656565657, 4.141414141414141],
#  [5.757575757575758, 4.141414141414141],
#  [5.858585858585858, 4.141414141414141],
#  [5.959595959595959, 4.141414141414141],
#  [4.040404040404041, 4.242424242424242],
#  [4.141414141414141, 4.242424242424242],
#  [4.242424242424242, 4.242424242424242],
#  [4.343434343434343, 4.242424242424242],
#  [4.444444444444445, 4.242424242424242],
#  [4.545454545454545, 4.242424242424242],
#  [4.646464646464646, 4.242424242424242],
#  [4.747474747474747, 4.242424242424242],
#  [4.848484848484849, 4.242424242424242],
#  [4.94949494949495, 4.242424242424242],
#  [5.05050505050505, 4.242424242424242],
#  [5.151515151515151, 4.242424242424242],
#  [5.252525252525253, 4.242424242424242],
#  [5.353535353535354, 4.242424242424242],
#  [5.454545454545454, 4.242424242424242],
#  [5.555555555555555, 4.242424242424242],
#  [5.656565656565657, 4.242424242424242],
#  [5.757575757575758, 4.242424242424242],
#  [5.858585858585858, 4.242424242424242],
#  [5.959595959595959, 4.242424242424242],
#  [4.040404040404041, 4.343434343434343],
#  [4.141414141414141, 4.343434343434343],
#  [4.242424242424242, 4.343434343434343],
#  [4.343434343434343, 4.343434343434343],
#  [4.444444444444445, 4.343434343434343],
#  [4.545454545454545, 4.343434343434343],
#  [4.646464646464646, 4.343434343434343],
#  [4.747474747474747, 4.343434343434343],
#  [4.848484848484849, 4.343434343434343],
#  [4.94949494949495, 4.343434343434343],
#  [5.05050505050505, 4.343434343434343],
#  [5.151515151515151, 4.343434343434343],
#  [5.252525252525253, 4.343434343434343],
#  [5.353535353535354, 4.343434343434343],
#  [5.454545454545454, 4.343434343434343],
#  [5.555555555555555, 4.343434343434343],
#  [5.656565656565657, 4.343434343434343],
#  [5.757575757575758, 4.343434343434343],
#  [5.858585858585858, 4.343434343434343],
#  [5.959595959595959, 4.343434343434343],
#  [4.040404040404041, 4.444444444444445],
#  [4.141414141414141, 4.444444444444445],
#  [4.242424242424242, 4.444444444444445],
#  [4.343434343434343, 4.444444444444445],
#  [4.444444444444445, 4.444444444444445],
#  [4.545454545454545, 4.444444444444445],
#  [4.646464646464646, 4.444444444444445],
#  [4.747474747474747, 4.444444444444445],
#  [4.848484848484849, 4.444444444444445],
#  [4.94949494949495, 4.444444444444445],
#  [5.05050505050505, 4.444444444444445],
#  [5.151515151515151, 4.444444444444445],
#  [5.252525252525253, 4.444444444444445],
#  [5.353535353535354, 4.444444444444445],
#  [5.454545454545454, 4.444444444444445],
#  [5.555555555555555, 4.444444444444445],
#  [5.656565656565657, 4.444444444444445],
#  [5.757575757575758, 4.444444444444445],
#  [5.858585858585858, 4.444444444444445],
#  [5.959595959595959, 4.444444444444445],
#  [4.040404040404041, 4.545454545454545],
#  [4.141414141414141, 4.545454545454545],
#  [4.242424242424242, 4.545454545454545],
#  [4.343434343434343, 4.545454545454545],
#  [4.444444444444445, 4.545454545454545],
#  [4.545454545454545, 4.545454545454545],
#  [4.646464646464646, 4.545454545454545],
#  [4.747474747474747, 4.545454545454545],
#  [4.848484848484849, 4.545454545454545],
#  [4.94949494949495, 4.545454545454545],
#  [5.05050505050505, 4.545454545454545],
#  [5.151515151515151, 4.545454545454545],
#  [5.252525252525253, 4.545454545454545],
#  [5.353535353535354, 4.545454545454545],
#  [5.454545454545454, 4.545454545454545],
#  [5.555555555555555, 4.545454545454545],
#  [5.656565656565657, 4.545454545454545],
#  [5.757575757575758, 4.545454545454545],
#  [5.858585858585858, 4.545454545454545],
#  [5.959595959595959, 4.545454545454545],
#  [4.040404040404041, 4.646464646464646],
#  [4.141414141414141, 4.646464646464646],
#  [4.242424242424242, 4.646464646464646],
#  [4.343434343434343, 4.646464646464646],
#  [4.444444444444445, 4.646464646464646],
#  [4.545454545454545, 4.646464646464646],
#  [4.646464646464646, 4.646464646464646],
#  [4.747474747474747, 4.646464646464646],
#  [4.848484848484849, 4.646464646464646],
#  [4.94949494949495, 4.646464646464646],
#  [5.05050505050505, 4.646464646464646],
#  [5.151515151515151, 4.646464646464646],
#  [5.252525252525253, 4.646464646464646],
#  [5.353535353535354, 4.646464646464646],
#  [5.454545454545454, 4.646464646464646],
#  [5.555555555555555, 4.646464646464646],
#  [5.656565656565657, 4.646464646464646],
#  [5.757575757575758, 4.646464646464646],
#  [5.858585858585858, 4.646464646464646],
#  [5.959595959595959, 4.646464646464646],
#  [4.040404040404041, 4.747474747474747],
#  [4.141414141414141, 4.747474747474747],
#  [4.242424242424242, 4.747474747474747],
#  [4.343434343434343, 4.747474747474747],
#  [4.444444444444445, 4.747474747474747],
#  [4.545454545454545, 4.747474747474747],
#  [4.646464646464646, 4.747474747474747],
#  [4.747474747474747, 4.747474747474747],
#  [4.848484848484849, 4.747474747474747],
#  [4.94949494949495, 4.747474747474747],
#  [5.05050505050505, 4.747474747474747],
#  [5.151515151515151, 4.747474747474747],
#  [5.252525252525253, 4.747474747474747],
#  [5.353535353535354, 4.747474747474747],
#  [5.454545454545454, 4.747474747474747],
#  [5.555555555555555, 4.747474747474747],
#  [5.656565656565657, 4.747474747474747],
#  [5.757575757575758, 4.747474747474747],
#  [5.858585858585858, 4.747474747474747],
#  [5.959595959595959, 4.747474747474747],
#  [4.040404040404041, 4.848484848484849],
#  [4.141414141414141, 4.848484848484849],
#  [4.242424242424242, 4.848484848484849],
#  [4.343434343434343, 4.848484848484849],
#  [4.444444444444445, 4.848484848484849],
#  [4.545454545454545, 4.848484848484849],
#  [4.646464646464646, 4.848484848484849],
#  [4.747474747474747, 4.848484848484849],
#  [4.848484848484849, 4.848484848484849],
#  [4.94949494949495, 4.848484848484849],
#  [5.05050505050505, 4.848484848484849],
#  [5.151515151515151, 4.848484848484849],
#  [5.252525252525253, 4.848484848484849],
#  [5.353535353535354, 4.848484848484849],
#  [5.454545454545454, 4.848484848484849],
#  [5.555555555555555, 4.848484848484849],
#  [5.656565656565657, 4.848484848484849],
#  [5.757575757575758, 4.848484848484849],
#  [5.858585858585858, 4.848484848484849],
#  [5.959595959595959, 4.848484848484849],
#  ...]

# %%
#box 10x10

P_0 = [[9, 10], [8, 7], [5, 6], [3, 0], [0, 1], [5, 1], [2, 3], [0, 4], [7, 9], [3, 2], [8, 5], [10, 2], [7, 7], [7, 2], [8, 6], [9, 1], [9, 9], [1, 6], [2, 5], [2, 4], [0, 3], [4, 1], [5, 4], [6, 2], [7, 1], [10, 10], [8, 0], [2, 10], [10, 0], [1, 10], [2, 8], [9, 4], [1, 3], [6, 5], [8, 3], [10, 4], [3, 3], [3, 1], [6, 4], [5, 9], [1, 2], [3, 6], [6, 7], [1, 4], [9, 2], [6, 0], [8, 9], [1, 1], [4, 6], [5, 10]]

print(len(P_0))
# Out:
# 50

# %%
def vis_plot(P_0):
    x = [p[0] for p in P_0]
    y = [p[1] for p in P_0]
    plt.scatter(x=x, y=y, s = 5)
    plt.axis('scaled')
#     plt.grid()
    plt.xlim(-0.3, 10.3)
    plt.ylim(-0.3, 10.3)

    
vis_plot(P_0)

# %%
def my_distance(a, b):
    if (len(a)==2) and (len(b)==2):
        return np.sqrt((a[1]-b[1])**2 + (a[0]-b[0])**2)
    else:
        print(a, b)

my_distance(P_0[5], P_0[9])
# Out:
# 2.23606797749979

# %%
def my_euclidean_distance(p1, p2):
    p1 = np.array(p1)
    p2 = np.array(p2)
    return np.linalg.norm(p1 - p2)

def my_hausdorff_distance(A, B):
    A = np.array(A)
    B = np.array(B)
   
    # Calculate the bidirectional Hausdorff distance
    def my_directed_hausdorff(A, B):
        return np.max([np.min([my_euclidean_distance(a, b) for b in B]) for a in A])
    
    # Calculate the bidirectional Hausdorff distance
    d_AB = my_directed_hausdorff(A, B)
    d_BA = my_directed_hausdorff(B, A)
    
    return max(d_AB, d_BA)

# %%
def matrix_of_distances(P):
    M = np.zeros((len(P), len(P)))
    for i in range(len(P)):
        for j in range(len(P)):
            if (i<j):
                M[i][j] = my_distance(P[i], P[j])
                M[j][i] = M[i][j]
    return M

matrix_of_distances(P_0)
# Out:
# array([[ 0.        ,  3.16227766,  5.65685425, ..., 12.04159458,
#          6.40312424,  4.        ],
#        [ 3.16227766,  0.        ,  3.16227766, ...,  9.21954446,
#          4.12310563,  4.24264069],
#        [ 5.65685425,  3.16227766,  0.        , ...,  6.40312424,
#          1.        ,  4.        ],
#        ...,
#        [12.04159458,  9.21954446,  6.40312424, ...,  0.        ,
#          5.83095189,  9.8488578 ],
#        [ 6.40312424,  4.12310563,  1.        , ...,  5.83095189,
#          0.        ,  4.12310563],
#        [ 4.        ,  4.24264069,  4.        , ...,  9.8488578 ,
#          4.12310563,  0.        ]])

# %% [markdown]
# # Objectives

# %%
def obj1(a):
    return - (a[0]-5)**2/1000

# %%
def obj2(a):
    return -(((a[0]-5)**2 + (a[1]-5) - 11)**2 + ((a[0]-5) + (a[1]-5)**2 - 7)**2)/1000

# %% [markdown]
# # Mutation operator

# %%
def mutation(a, mutation_rate):
    angle = random.random()
    return [a[0] + np.cos(angle * 2 * math.pi)*mutation_rate*random.random(), a[1] + np.sin(angle * 2 * math.pi) * mutation_rate*random.random()]

# %% [markdown]
# # Useful functions for optimization

# %%
#Sort by values

def sort_by_values(list1, values):
    sorted_list = []
    while(len(sorted_list)!=len(list1)):
        if index_of(min(values),values) in list1:
            sorted_list.append(index_of(min(values),values))
        values[index_of(min(values),values)] = math.inf
    return sorted_list

# %%
#Function to find index of list

def index_of(a,list):
    for i in range(0,len(list)):
        if list[i] == a:
            return i
    return -1

# %%
#Sort solutions to Pareto front 

def fast_non_dominated_sort(values1, values2):
    S=[[] for i in range(0,len(values1))]
    front = [[]]
    n=[0 for i in range(0,len(values1))]
    rank = [0 for i in range(0, len(values1))]

    for p in range(0,len(values1)):
        S[p]=[]
        n[p]=0
        for q in range(0, len(values1)):
#             print(values2[q], values2[p])
            if ((values1[p] > values1[q]) and (values2[p] > values2[q])) or ((values1[p] >= values1[q]) and (values2[p] > values2[q])) or ((values1[p] > values1[q]) and (values2[p] >= values2[q])):
                if q not in S[p]:
                    S[p].append(q)
            elif ((values1[q] > values1[p]) and (values2[q] > values2[p])) or ((values1[q] >= values1[p]) and (values2[q] > values2[p])) or ((values1[q] > values1[p]) and (values2[q] >= values2[p])):
                n[p] = n[p] + 1
        if n[p]==0:
            rank[p] = 0
            if p not in front[0]:
                front[0].append(p)

    i = 0
    while(front[i] != []):
        Q=[]
        for p in front[i]:
            for q in S[p]:
                n[q] =n[q] - 1
                if( n[q]==0):
                    rank[q]=i+1
                    if q not in Q:
                        Q.append(q)
        i = i+1
        front.append(Q)

    del front[len(front)-1]
    return front

# %%
#Sort solutions to Pareto front with epsilon-dominance parameter НЕ СДЕЛАЛА!!!!валотжыоваи

def fast_non_dominated_sort_eps(values1, values2, eps):
    S=[[] for i in range(0,len(values1))]
    front = [[]]
    n=[0 for i in range(0,len(values1))]
    rank = [0 for i in range(0, len(values1))]

    for p in range(0,len(values1)):
        S[p]=[]
        n[p]=0
        for q in range(0, len(values1)):
#             print(values2[q], values2[p])
            if ((values1[p]*(1 + eps) > values1[q]) and (values2[p]*(1 + eps) > values2[q])) or ((values1[p]*(1 + eps) >= values1[q]) and (values2[p]*(1 + eps) > values2[q])) or ((values1[p]*(1 + eps) > values1[q]) and (values2[p]*(1 + eps) >= values2[q])):
                if q not in S[p]:
                    S[p].append(q)
            elif ((values1[q]*(1 + eps) > values1[p]) and (values2[q]*(1 + eps) > values2[p])) or ((values1[q]*(1 + eps) >= values1[p]) and (values2[q]*(1 + eps) > values2[p])) or ((values1[q]*(1 + eps) > values1[p]) and (values2[q]*(1 + eps) >= values2[p])):
                n[p] = n[p] + 1
        if n[p]==0:
            rank[p] = 0
            if p not in front[0]:
                front[0].append(p)

    i = 0
    while(front[i] != []):
        Q=[]
        for p in front[i]:
            for q in S[p]:
                n[q] =n[q] - 1
                if( n[q]==0):
                    rank[q]=i+1
                    if q not in Q:
                        Q.append(q)
        i = i+1
        front.append(Q)

    del front[len(front)-1]
    return front

# %%
#Function to calculate crowding distance

def crowding_distance(values1, values2, front):
    distance = [0 for i in range(0,len(front))]
    sorted1 = sort_by_values(front, values1[:])
    sorted2 = sort_by_values(front, values2[:])
    distance[0] = 4444444444444444
    distance[len(front) - 1] = 4444444444444444
    for k in range(1,len(front)-1):
        distance[k] = distance[k]+ (values1[sorted1[k+1]] - values2[sorted1[k-1]])/(max(values1)-min(values1))
    for k in range(1,len(front)-1):
        distance[k] = distance[k]+ (values1[sorted2[k+1]] - values2[sorted2[k-1]])/(max(values2)-min(values2))
    return distance

# %%
#Function to calculate hypervolumes

def hypervolumes(values1, values2, front):
    r = [0, 0]
    volumes = [0 for i in range(0,len(front))]
    sorted1 = sort_by_values(front, values1[:])
    sorted2 = sort_by_values(front, values2[:])
    for k in range(0,len(front)):
        volumes[k] = (values1[sorted1[k]] - r[0]) * (values2[sorted1[k]] - r[1])
    return volumes

# %%
#Class for working with json

class NpEncoder(json.JSONEncoder):
    def default(self, obj):
        if isinstance(obj, np.integer):
            return int(obj)
        if isinstance(obj, np.floating):
            return float(obj)
        if isinstance(obj, np.ndarray):
            return obj.tolist()
        return super(NpEncoder, self).default(obj)

# %%
#Vizualization of pareto fronts in population

def pareto_fronts(objjs, it, max_gen):
    with open(objjs, 'r') as f:
        data = f.readlines()
    dt = data[0]
    dt = dt[1:]
    df = []
    
    a = defaultdict()
    for k in range(it):
        n=0
        a[k] = ''
        for i in range(len(dt)):
            if (dt[i] == '}'):
                dt = dt[(n+3):]
                break
            else:
                a[k] = a[k] + dt[i]
            n += 1
        
        a[k] = a[k] + '}'
    for k in range(it):
        df.append(pd.DataFrame.from_dict(json.loads(a[k])))
            
    for k in range(it):
        df[k].columns = df[k].columns.astype(int)
        
    fig, axs = plt.subplots(nrows=6, ncols=5, figsize=(17, 17))
    plt.subplots_adjust(hspace=0.3)
    plt.subplots_adjust(wspace=0.3)
    fig.suptitle("Pareto fronts", fontsize=15, y=0.95)
    for q in range(it):
        ax = plt.subplot(6, 5, q + 1)
        function1 = [i*(-1) for i in non_dominated([x for y in [df[q][t][0] for t in range(1, max_gen)] for x in y], [x for y in [df[q][t][1] for t in range(1, max_gen)] for x in y])[0]]
        function2 = [j*(-1) for j in non_dominated([x for y in [df[q][t][0] for t in range(1, max_gen)] for x in y], [x for y in [df[q][t][1] for t in range(1, max_gen)] for x in y])[1]]
        plt.xlabel('Objective 1', fontsize=7)
        plt.ylabel('Objective 2', fontsize=7)
        plt.tick_params(axis='both', which='major', labelsize=5)
        plt.tick_params(axis='both', which='minor', labelsize=5)
        plt.scatter(function1, function2, s = 1)
    plt.show()

# %%
#Vizualization of pareto fronts in population

def pareto_fronts_eps(objjs, it, max_gen, eps):
    with open(objjs, 'r') as f:
        data = f.readlines()
    dt = data[0]
    dt = dt[1:]
    df = []
    
    a = defaultdict()
    for k in range(it):
        n=0
        a[k] = ''
        for i in range(len(dt)):
            if (dt[i] == '}'):
                dt = dt[(n+3):]
                break
            else:
                a[k] = a[k] + dt[i]
            n += 1
        
        a[k] = a[k] + '}'
    for k in range(it):
        df.append(pd.DataFrame.from_dict(json.loads(a[k])))
            
    for k in range(it):
        df[k].columns = df[k].columns.astype(int)
        
    fig, axs = plt.subplots(nrows=6, ncols=5, figsize=(17, 17))
    plt.subplots_adjust(hspace=0.3)
    plt.subplots_adjust(wspace=0.3)
    fig.suptitle("Pareto fronts", fontsize=15, y=0.95)
    for q in range(it):
        ax = plt.subplot(6, 5, q + 1)
        function1 = [i*(-1) for i in non_dominated_eps([x for y in [df[q][t][0] for t in range(1, max_gen)] for x in y], [x for y in [df[q][t][1] for t in range(1, max_gen)] for x in y], eps)[0]]
        function2 = [j*(-1) for j in non_dominated_eps([x for y in [df[q][t][0] for t in range(1, max_gen)] for x in y], [x for y in [df[q][t][1] for t in range(1, max_gen)] for x in y], eps)[1]]
        plt.xlabel('Objective 1', fontsize=7)
        plt.ylabel('Objective 2', fontsize=7)
        plt.tick_params(axis='both', which='major', labelsize=5)
        plt.tick_params(axis='both', which='minor', labelsize=5)
        plt.scatter(function1, function2, s = 1)
    plt.show()

# %%
#Total pareto fronts for all solutions among different iterations and generations

def one_pareto_front(js, it, max_gen):
    with open(js, 'r') as f:
        data = f.readlines()
    dt = data[0]
    dt = dt[1:]
    df = []
    
    a = defaultdict()
    for k in range(it):
        n=0
        a[k] = ''
        for i in range(len(dt)):
            if (dt[i] == '}'):
                dt = dt[(n+3):]
                break
            else:
                a[k] = a[k] + dt[i]
            n += 1
        
        a[k] = a[k] + '}'
    for k in range(it):
        df.append(pd.DataFrame.from_dict(json.loads(a[k])))
            
    for k in range(it):
        df[k].columns = df[k].columns.astype(int)
        
        
    X = []
    Y = []
    for q in range(it):
        X.append([i*(-1) for i in non_dominated([x for y in [df[q][t][0] for t in range(1, max_gen)] for x in y], [x for y in [df[q][t][1] for t in range(1, max_gen)] for x in y])[0]])
        Y.append([j*(-1) for j in non_dominated([x for y in [df[q][t][0] for t in range(1, max_gen)] for x in y], [x for y in [df[q][t][1] for t in range(1, max_gen)] for x in y])[1]])
    X = [x for y in X for x in y]
    Y = [x for y in Y for x in y]
    function1 = non_dominated(X, Y)[0]   
    function2 = non_dominated(X, Y)[1]
    plt.xlabel('Objective 1', fontsize=7)
    plt.ylabel('Objective 2', fontsize=7)
    plt.tick_params(axis='both', which='major', labelsize=5)
    plt.tick_params(axis='both', which='minor', labelsize=5)
    plt.scatter(function1, function2, s = 1)
    plt.show()
    return non_dominated(X, Y)

# %%
#Total pareto fronts for all solutions among different iterations and generations

def one_pareto_front_eps(js, it, max_gen, eps):
    with open(js, 'r') as f:
        data = f.readlines()
    dt = data[0]
    dt = dt[1:]
    df = []
    
    a = defaultdict()
    for k in range(it):
        n=0
        a[k] = ''
        for i in range(len(dt)):
            if (dt[i] == '}'):
                dt = dt[(n+3):]
                break
            else:
                a[k] = a[k] + dt[i]
            n += 1
        
        a[k] = a[k] + '}'
    for k in range(it):
        df.append(pd.DataFrame.from_dict(json.loads(a[k])))
            
    for k in range(it):
        df[k].columns = df[k].columns.astype(int)
        
        
    X = []
    Y = []
    for q in range(it):
        X.append([i*(-1) for i in non_dominated_eps([x for y in [df[q][t][0] for t in range(1, max_gen)] for x in y], [x for y in [df[q][t][1] for t in range(1, max_gen)] for x in y], eps)[0]])
        Y.append([j*(-1) for j in non_dominated_eps([x for y in [df[q][t][0] for t in range(1, max_gen)] for x in y], [x for y in [df[q][t][1] for t in range(1, max_gen)] for x in y], eps)[1]])
    X = [x for y in X for x in y]
    Y = [x for y in Y for x in y]
    function1 = non_dominated_eps(X, Y, eps)[0]   
    function2 = non_dominated_eps(X, Y, eps)[1]
    plt.xlabel('Objective 1', fontsize=7)
    plt.ylabel('Objective 2', fontsize=7)
    plt.tick_params(axis='both', which='major', labelsize=5)
    plt.tick_params(axis='both', which='minor', labelsize=5)
    plt.scatter(function1, function2, s = 1)
    plt.show()
    return non_dominated(X, Y)

# %%
# Non-dominated solutions

def non_dominated(values1, values2):
    M = []
    for q in range(0,len(values1)):
        for p in range(0,len(values1)):
            if (values1[p] > values1[q] and values2[p] > values2[q]) or (values1[p] >= values1[q] and values2[p] > values2[q]) or (values1[p] > values1[q] and values2[p] >= values2[q]):
                M.append(q)
            elif (values1[q] > values1[p] and values2[q] > values2[p]) or (values1[q] >= values1[p] and values2[q] > values2[p]) or (values1[q] > values1[p] and values2[q] >= values2[p]):
                M.append(p)
    return [np.delete(values1, M, axis = 0), np.delete(values2, M, axis = 0)]

# %%
# Non-dominated solutions with epsilon-dominance parameter

def non_dominated_eps(values1, values2, eps):
    M = []
    for q in range(0,len(values1)):
        for p in range(0,len(values1)):
            if (values1[p]*(1 + eps) > values1[q] and values2[p]*(1 + eps) > values2[q]) or (values1[p]*(1 + eps) >= values1[q] and values2[p]*(1 + eps) > values2[q]) or (values1[p]*(1 + eps) > values1[q] and values2[p]*(1 + eps) >= values2[q]):
                M.append(q)
            elif (values1[q]*(1 + eps) > values1[p] and values2[q]*(1 + eps) > values2[p]) or (values1[q]*(1 + eps) >= values1[p] and values2[q]*(1 + eps) > values2[p]) or (values1[q]*(1 + eps) > values1[p] and values2[q]*(1 + eps) >= values2[p]):
                M.append(p)
    return [np.delete(values1, M, axis = 0), np.delete(values2, M, axis = 0)]

# %%
# Transformation to dataframe

def df_correct_to_Andre(js, it):
    with open(js, 'r') as f:
        data = f.readlines()
    dt = data[0]
    dt = dt[1:]
    df = []
    
    a = defaultdict()
    for k in range(it):
        n=0
        a[k] = ''
        for i in range(len(dt)):
            if (dt[i] == '}'):
                dt = dt[(n+3):]
                break
            else:
                a[k] = a[k] + dt[i]
            n += 1
        
        a[k] = a[k] + '}'
    for k in range(it):
        df.append(pd.DataFrame.from_dict(json.loads(a[k])))
            
    for k in range(it):
        df[k].columns = df[k].columns.astype(int)
        
    return df

# %%
# For solution vizualization

def sol(js, it):
    with open(js, 'r') as f:
        data = f.readlines()
    dt = data[0]
    dt = dt[1:]
    
    df = []
    a = defaultdict()
    for k in range(it):
        n=0
        a[k] = ''
        for i in dt:
            if i != '}':
                a[k] = a[k] + i
            else:
                dt = dt[(n+3):]
                break
            n += 1
        
        a[k] = a[k] + '}'
    for k in range(it):
        df.append(pd.DataFrame.from_dict(json.loads(a[k])))
            
    for k in range(it):
        df[k].columns = df[k].columns.astype(int)
        
    return df

# %% [markdown]
# # NOAH basic functions (sample, reflectpoint, objopt, boundchange)

# %%
#box 10x10

#unformly distributed sample
# P_0 = [[0, 1], [5, 1], [2, 3], [0, 4], [7, 9], [3, 2], [8, 5], [10, 2], [7, 7], [7, 2], [8, 6], [9, 1], [5, 4], [6, 2], [7, 1], [10, 10], [2, 2], [0, 6], [4, 6], [5, 10]]

#not uniformly distributed sample
P_0 = [[0, 1], [0, 0.5], [2, 4], [2, 4.2], [1.97, 4], [1.9, 2.1], [6.9, 7], [9, 4], [7, 7], [7, 8], [7, 7.03], [9.05, 1], [6.5, 7], [2, 2.04], [7.3, 7], [9.03, 10], [2, 2], [0, 6], [0.1, 0.3], [2, 1.98]]

print(len(P_0))
vis_plot(P_0)
# Out:
# 20

# %%
def reflect_point(x, y, box_border):
    # Отражаем по оси x
    if x < 0:
        x = -x
    elif x > box_border:
        x = 2 * box_border - x
    
    # Отражаем по оси y
    if y < 0:
        y = -y
    elif y > box_border:
        y = 2 * box_border - y
    
    return x, y

reflect_point(-5, 12, 10)
# Out:
# (5, 8)

# %%
def objOpt(P_0, mutation_rate, it, max_gen, pop_size, b, box_border):
#     
#     print("pbjopt", P_0, mutation_rate, it, max_gen, pop_size, b, box_border)
    start_time = time.time()

    a_fp = open('./obj_evolution_with_b_simple_' + str(mutation_rate) + '.json', 'w')
    b_fp = open('./sol_evolution_with_b_simple_' + str(mutation_rate) + '.json', 'w')
    iteration = 0
    B = []
    D = []
    for iteration in range(it):
        print("iteration", iteration)
        
        #Main program starts here

        #Initialization
        min_x=-55
        max_x=55
        A = defaultdict()
        C = defaultdict()
        solution = P_0

        gen_no=0
        while(gen_no<max_gen):
#             print("GENERATION", gen_no)
            function1_values = [obj1(solution[i]) for i in range(0,pop_size)]
            function2_values = [obj2(solution[i]) for i in range(0,pop_size)]
            non_dominated_sorted_solution = fast_non_dominated_sort(function1_values[:],function2_values[:])

            solution2 = solution[:]
            
            
#             for i in range(len(solution)):
#                 print(-obj1(solution[i]), -obj2(solution[i]))
            
#             print("offsprings")

            #Generating offsprings
            while(len(solution2)!=2*pop_size):
                
                s = 0
                while s == 0:
                    a1 = random.randint(0,pop_size-1)
                    app = mutation(solution[a1], mutation_rate) 
                    if (app[0]<0) or (app[1]<0) or (app[0]>box_border) or (app[1]>box_border):
                        app = reflect_point(app[0], app[1], box_border)
                    if (-obj1(app)<b[0]) and (-obj2(app)<b[1]) and (my_distance(app, solution[a1]) > epsilon) and (app[0]<=box_border) and (app[1]<=box_border) :
                        solution2.append(app)
#                         print(app)
#                         print(-obj1(app), -obj2(app))
                        s = 1
                    else:
                        pass
                    
            
            function1_values2 = [obj1(solution2[i]) for i in range(0,2*pop_size)]
            function2_values2 = [obj2(solution2[i]) for i in range(0,2*pop_size)]

            A[gen_no] = [function1_values, function2_values]
            non_dominated_sorted_solution2 = fast_non_dominated_sort(function1_values2[:],function2_values2[:])
            crowding_distance_values2=[]

            for i in range(0,len(non_dominated_sorted_solution2)):
                crowding_distance_values2.append(crowding_distance(function1_values2[:],function2_values2[:],non_dominated_sorted_solution2[i][:]))


            new_solution= []
            for i in range(0,len(non_dominated_sorted_solution2)):
                non_dominated_sorted_solution2_1 = [index_of(non_dominated_sorted_solution2[i][j],non_dominated_sorted_solution2[i] ) for j in range(0,len(non_dominated_sorted_solution2[i]))]
                front22 = sort_by_values(non_dominated_sorted_solution2_1[:], crowding_distance_values2[i][:])
                front = [non_dominated_sorted_solution2[i][front22[j]] for j in range(0,len(non_dominated_sorted_solution2[i]))]
                front.reverse()
                for value in front:
                    new_solution.append(value)
                    if(len(new_solution)==pop_size):
                        break
                if (len(new_solution) == pop_size):
                    break
            solution = [solution2[i] for i in new_solution] 
#             vis_plot(solution)
            C[gen_no] = solution
            gen_no = gen_no + 1
        B.append(A)   
        D.append(C)
        iteration +=1  
        
        print(A[max_gen-1])
        for i in range(len(A[max_gen-1][0])):
            if (-A[max_gen-1][0][i]>=b[0]) or (-A[max_gen-1][1][i]>=b[1]):
                print('objopt final generation contains solutions >= b for iteration ', iteration)
        
    json.dump(B, a_fp)
    json.dump(D, b_fp, cls=NpEncoder)            
    a_fp.close()
    b_fp.close()

    print("--- %s seconds ---" % (time.time() - start_time))
    
    return D[-1][max_gen-1]

# objOpt_minmax(P_0, mutation_rate, it, max_gen, pop_size, b, box_border=10)

# %%
def boundChange(P, b, r_number, global_bound):
    
    bound = copy.deepcopy(b)
    print("b", b)
    #Делаем маленький шаг по 2 координатам
    
    step0 = bound[0]/10000
    step1 = bound[1]/10000
    
    #Будущее значение финальной популяции из r элементов и значении b при котором это так
    fitting_conditions = [P, bound]
    
#     Пока стартовое щначение порога не уменьшится до v делаем то что делаем
#     Нам нужно найти минимальное b при котором в выборку попадает r элементов с меньше чем b обджективами
    while (bound[0]>global_bound[0]) and (bound[1]>global_bound[1]):
#         print("a")
        satisfying_sol = []
        
#       Проходимся по каждому значению популяции 
        for i in range(len(P)):
#             print(-obj1(P, i, heights), bound[0])
        
        
#         Если обджективы меньше b, добавляем их в список
            if (-obj1(P[i])<bound[0]) and (-obj2(P[i])<bound[1]):
                
                satisfying_sol.append(P[i])
#         print(satisfying_sol)
            
#             Если в списоке уже r элементов, то попробуем уменьшить b еще сильнее
        if len(satisfying_sol)>=r_number:
#         Но запомним значение при котором было r элемнтов подходящих, если вдруг при следующем уменьшении b уже не будет r, выходим из функции
            fitting_conditions = [satisfying_sol, bound]
            if random.random()<0.5:
                bound[0]-=step0
            else:
                bound[1]-=step1
        else:
            return fitting_conditions
        
    return fitting_conditions

# boundChange(P_0, heights, b, r_number, global_bound)[0]

# %% [markdown]
# # NOAH with min-max

# %%
def Diversity_minmax(P):
    M = matrix_of_distances(P)
    
    indices = []
    for i in range(len(P)):
        indices.append(i)
        
    diversity = 1000
    for i in range(len(indices)):
        for j in range(len(indices)):
            if i<j:
                if M[indices[i]][indices[j]]<diversity:
                    diversity = M[indices[i]][indices[j]]
#                     print([i, j, indices[i], indices[j]])
    return diversity

# %%
def SelectDiv_minmax(P, n):
#     print("P", P)
    M = matrix_of_distances(P)
    
    indices = []
    
    all_indices = []
    for i in range(len(P)):
        all_indices.append(i)
        
    #n^2 - первый элемент
    index_max_sum = -1
    max_sum = -1
    for i in range(len(P)):
        column_sum = 0
        for j in range(len(P)):
            column_sum = column_sum + M[i][j]
        if column_sum>max_sum:
            max_sum = column_sum
            index_max_sum = i
    
    indices.append(index_max_sum)
    
    
    #n^3
    for i in range(n-1):
        
#         print("i", i)
        #не выбранные индексы из всех индексов
        rest = [x for x in all_indices if x not in indices]
#         print(rest)
        
        best_index = -1000
        max_dist = -1000
        best_summa = -1000
        
    
        #цикл по еще не выбранным точкам
        for j in range(len(rest)):
            
            #находим минимальное расстояние от не выбранной точки j до всех выбранных точек
            minim_dist = 10000
            summa = 0
            sum_picked_dist = 0
            for k in range(len(indices)):
#                 print("indices", indices[k], rest[j])
                summa+=M[rest[j]][indices[k]]
                if M[rest[j]][indices[k]]< minim_dist:
                    minim_dist = M[rest[j]][indices[k]]
#                     print("minim dist", minim_dist)
#             print("final", minim_dist) 
                for q in range(len(indices)):
                    if k<q:
                        sum_picked_dist+=M[indices[k], indices[q]]
                        
            #нашли самое большое из таких 
            if minim_dist >max_dist:
                max_dist = minim_dist
                best_index = rest[j]
                    
#         print(best_index, best_summa, max_dist)
        if best_index>-1000:
            indices.append(best_index)
        
#     print("final indices", indices) 
#     print("indices", indices)
    diversity = 1000
    for i in range(len(indices)):
        for j in range(len(indices)):
            if i<j:
                if M[indices[i]][indices[j]]<diversity:
                    diversity = M[indices[i]][indices[j]]
#                     print([i, j, indices[i], indices[j]])
    
#     print("indices", [P_0[i] for i in indices])
#     vis_plot([P[i] for i in indices])
    
    
    contributions = []
    #Исключает элемент с индексом i
#     print(indices)
    exc = lambda s, i: s[:i] + s[i+1:]
    #Element for which we calculate the contribution
    for k in range(len(indices)):
        diversity_dropout = 1000 
        indices_dropout = exc(indices, k)
#         print(indices_dropout)
        for i in range(len(indices_dropout)):
            for j in range(len(indices_dropout)):
                if i<j:
                    if M[indices_dropout[i]][indices_dropout[j]]<diversity_dropout:
                        diversity_dropout = M[indices_dropout[i]][indices_dropout[j]]
#                     print([i, j, indices[i], indices[j]])
#         print(diversity_dropout)
        contributions.append(diversity - diversity_dropout)
#         print(diversity, diversity_dropout, indices)
    
#     print([indices[i] for i in list(np.nonzero(contributions)[0])], contributions)
    best = [indices[i] for i in list(np.nonzero(contributions)[0])]
    return [diversity, indices, best, [P[i] for i in best]]
    
SelectDiv_minmax(P_0, 15)
# Out:
# [2.23606797749979,
#  [25, 4, 28, 29, 33, 5, 39, 17, 35, 1, 6, 3, 7, 13, 30],
#  [],
#  []]

# %%
#WITH B and counter - РАБОТАЕТ ЛУЧШЕ, СТОИТ ОСТАВИТЬ


#c - параметр схождения, если c раз подряд значение diversity не меняется, значит, все
# На входе будет r элементов популяции, на выходе надо n = pop_size

def divOpt_simple_minmax(P, it, pop_size, b, c, mutation_rate, box_border):
    
    start_time = time.time()

    a_fp = open('./obj_div_simple_minmax_' + str(mutation_rate) + '.json', 'w')
    b_fp = open('./sol_div_simple_minmax_' + str(mutation_rate) + '.json', 'w')
    c_fp = open('./0.9statistic_div_simple_minmax_' + str(mutation_rate) + '.json', 'w')
    iteration = 0
    A = []
    B = []
    S = []
    for iteration in range(it):
        print("iteration", iteration)
        
        #Main program starts here

        #Initialization
        min_x=-55
        max_x=55
        A = defaultdict()
        C = defaultdict()
        solution = P
        diversity = []
        
        iteration_no_change = 0

        
        selec = SelectDiv_minmax(solution, len(solution))
        diversity.append(selec[0])

        gen_no=0
        
        while(len(solution)!=pop_size):
                
                #Поменяла на len(P)=r, было pop_size
                #здесь надо выбирать только из элементов с индексами solution
#                 a1 = random.randint(0,len(P)-1)
                 
    
            s = 0
            while s == 0:
                a1 = random.randint(0,len(P)-2)
                app = mutation(solution[a1], mutation_rate)
                if (app[0]<0) or (app[1]<0) or (app[0]>box_border) or (app[1]>box_border):
                    app = reflect_point(app[0], app[1], box_border)
                
                min_distance_from_new = 1000
                for z in range(len(solution)):
                    if my_distance(solution[z], app)<min_distance_from_new:
                        min_distance_from_new = my_distance(solution[z], app)
                            
                if (-obj1(app)<b[0]) and (-obj2(app)<b[1]) and (my_distance(app, solution[a1]) > epsilon) and (min_distance_from_new>=diversity[-1]) and (app[0]>=0) and (app[1]>=0) and (app[0]<=box_border) and (app[1]<=box_border) :
                    solution.append(app)
                    
                    s = 1
                else:
                    pass
        
        while(iteration_no_change < c):
        #and (diversity[-1]<1.9):
#             print("GENERATION", gen_no)
            
            solution2 = solution[:]
            
            #Just printing
            
#             for i in range(len(solution)):
#                 print(-obj1(solution[i]), -obj2(solution[i]))
        
#             Generating offsprings
#             print("offsprings")

            while(len(solution2)!=pop_size+1):
                
                #Поменяла на len(P)=r, было pop_size
                #здесь надо выбирать только из элементов с индексами solution
#                 a1 = random.randint(0,len(P)-1)
                 
                s = 0
                counter = 0
                while (s == 0) and (counter < 700):
                    a1 = random.randint(0,len(P)-1)
                    app = mutation(solution[a1], mutation_rate)
                    if (app[0]<0) or (app[1]<0) or (app[0]>box_border) or (app[1]>box_border):
                        app = reflect_point(app[0], app[1], box_border)
                    min_distance_from_new = 1000
                    for z in range(len(solution)):
                        if my_distance(solution[z], app)<min_distance_from_new:
                            min_distance_from_new = my_distance(solution[z], app)
    #                 print(min_distance_from_new)    
    #УБРАЛА  (-obj1(app)<b[0]) and (-obj2(app)<b[1]) and
                    if (-obj1(app)<b[0]) and (-obj2(app)<b[1]) and (my_distance(app, solution[a1]) > epsilon) and (min_distance_from_new>=diversity[-1]) and (app[0]>=0) and (app[1]>=0) and (app[0]<=box_border) and (app[1]<=box_border) :
                        solution2.append(app)
#                         print(-obj1(app), -obj2(app))
                        s = 1
                    else:
                        counter += 1
#                 print("counter", counter)
                
                if counter>=700:
                    solution2.append(solution2[random.randint(0,len(P)-2)])
                    break 
#             print("offsprings are ready")
            
            # When it is [0, 2, .., 9] it is not supposed to chenge, but it's getting lower
            
            solution = []
            
            select_div = SelectDiv_minmax(solution2, pop_size) 
#             print("select_div", select_div)
            #не забыть все нужные параметры вставить
    
    
    
    
            if np.abs(select_div[0]-diversity[-1])<epsilon:
                iteration_no_change+=1
            else:
                iteration_no_change = 0
#             print(iteration_no_change)
            diversity.append(select_div[0])  
            indices = select_div[1]
            
#             print(indices)
            
            for i in range(2*pop_size):
                if i in indices:
                    solution.append(solution2[i])
                         
#             print(heights)
            
#             save = select_div[0]
            
             
            
#             print("len solution", len(solution), len(solution[0]))
#             print(solution)
            C[gen_no] = solution
            gen_no = gen_no + 1
            max_reached_gen = gen_no
#             print(solution)
            
#         print(max_reached_gen)
        print("diversity", diversity[-1])
        S.append(max_reached_gen)
        B.append(C)
        iteration +=1  
#         print(solution)
        
    json.dump(B, b_fp, cls=NpEncoder)  
    json.dump(S, c_fp, cls=NpEncoder)            

    a_fp.close()
    b_fp.close()
    c_fp.close()

    print("--- %s seconds ---" % (time.time() - start_time))
    
    return solution

# divOpt_simple_minmax(P_0, 100, pop_size, b, 20, 10, 10)

# %%
def NOAH_minmax(P, it, max_global_iteration, max_gen, pop_size, global_bound, b, r_number, c, mutation_rate, mutation_rate_div, box_border):
    
    global_iteration = 0
    dfhaudorf = []
    combined_rows = []

    all_diversities_minmax = []
    count = 1
    plt.subplots(figsize=(15, 60))
    plt.subplots_adjust(left=None, bottom=None, right=None, top=None, wspace=None, hspace=0.4)
    
    while (b[0]>global_bound[0]) and (b[1]>global_bound[1]) and (global_iteration<max_global_iteration):
        
        print("Global_iteration: ", global_iteration, "b is ", b)
        
        #Генерим из популяции размера 10 еще 10 дополнительных потомков, но таких, чтобы были меньше b, выбираем из 20 всего 10 лучших
        #И так делаем итерации и поколения
        #На выходе новая популяция 
        print("OBJOPT", P)
        plt.subplot(max_global_iteration,6,count).set_title(f'Global iteration: {round((count-1)//6.)} \n Starting set \n Diversity: {round(Diversity_minmax(P), 5)}', size=8)
        vis_plot(P)
        plt.xticks(fontsize=7)
        plt.yticks(fontsize=7, rotation = 90)
        count+=1
        
        all_diversities_minmax.append(
            {
                'SP diversity': SP_diversity(P, theta)/10,
                'Min-max diversity': Diversity_minmax(P),
                'S-energy diversity': s_energy(P, s)/100,
                'Average Himmelblaus function (obj1)': statistics.mean([-obj1(p) for p in P]),
                'Average x**2 function (obj1)': statistics.mean([-obj2(p) for p in P])
            }
        )
        
        plt.subplot(max_global_iteration,6,count).set_title(f'Objectives \n Average objectives: \n {round(statistics.mean([-obj1(p) for p in P]), 5)}, {round(statistics.mean([-obj2(p) for p in P]), 5)}', size=8)
        x_obj = [-obj1(p) for p in P]
        y_obj = [-obj2(p) for p in P]
        plt.scatter(x=x_obj, y=y_obj, s = 5)
        plt.axis('scaled')
        plt.xlim(-0.003, 0.1)
        plt.ylim(-0.003, 0.1)
        plt.xticks(fontsize=7)
        plt.yticks(fontsize=7, rotation = 90)
        count+=1


        P0 = objOpt(P, mutation_rate, it, max_gen, pop_size, b, box_border)
        
        dfhaudorf.append(
            {
                'Optimization': my_hausdorff_distance(P0, efficient_set)
            }
        )
        
        plt.subplot(max_global_iteration,6,count).set_title(f'After optimization \n Diversity: {round(Diversity_minmax(P0), 5)}', size=8)
        vis_plot(P0)
        plt.xticks(fontsize=7)
        plt.yticks(fontsize=7, rotation = 90)
        count+=1
        
        plt.subplot(max_global_iteration,6,count).set_title(f'Objectives \n Average objectives: \n {round(statistics.mean([-obj1(p) for p in P0]), 5)}, {round(statistics.mean([-obj2(p) for p in P0]), 5)}', size=8)
        x_obj = [-obj1(p) for p in P0]
        y_obj = [-obj2(p) for p in P0]
        plt.scatter(x=x_obj, y=y_obj, s = 5)
        plt.axis('scaled')
        plt.xlim(-0.003, 0.1)
        plt.ylim(-0.003, 0.1)
        plt.xticks(fontsize=7)
        plt.yticks(fontsize=7, rotation = 90)
        count+=1

        
        print("objopt for global iteration ", global_iteration, " is ready")
        
        print("b before boundchange: ", b)
        
        #Опускаем b до мнимального значения, при котором итоговая популяция содержит r элементов с обдж меньше b
        #P содержит r элементов, надо проверить что все меньше нового b 
        bound_fun = boundChange(P0, b, r_number, global_bound)
        P1 = bound_fun[0]
        b = bound_fun[1]
        print("b after boundchange: ", b)
        print(P1)
        print(" and size of P is", len(P1))
        print("DIVOPT")
        print("parameters for divopt", P1, pop_size, b, c, mutation_rate_div, box_border)
        #Сейчас популяция размера r должна быть, достраиваем ее до 20 так чтобы все были меньше нового b 
        #Из них выбираем 10 самых разнообразных, повторяем это max_gen раз 
        P2 = divOpt_simple_minmax(P1, it, pop_size, b, c, mutation_rate_div, box_border)
        dfhaudorf.append(
            {
                'Diversity Optimization': my_hausdorff_distance(P2, efficient_set)
            }
        )
        plt.subplot(max_global_iteration,6,count).set_title(f'After diversity optimization \n Diversity: {round(Diversity_minmax(P2), 5)}', size=8)
        vis_plot(P2)
        plt.xticks(fontsize=7)
        plt.yticks(fontsize=7, rotation = 90)
        count+=1
        
        plt.subplot(max_global_iteration,6,count).set_title(f'Objectives \n Average objectives: \n {round(statistics.mean([-obj1(p) for p in P2]), 5)}, {round(statistics.mean([-obj2(p) for p in P2]), 5)}', size=8)
        x_obj = [-obj1(p) for p in P2]
        y_obj = [-obj2(p) for p in P2]
        plt.scatter(x=x_obj, y=y_obj, s = 5)
        plt.axis('scaled')
        plt.xlim(-0.003, 0.1)
        plt.ylim(-0.003, 0.1)
        plt.xticks(fontsize=7)
        plt.yticks(fontsize=7, rotation = 90)
        count+=1

        
        P = P2
        
        
        global_iteration+=1
        
#     print(all_diversities_minmax)
    df = pd.DataFrame(all_diversities_minmax) 
    df2 = pd.DataFrame(dfhaudorf)
    
    for i in range(0, len(df2), 2):
        optimization_val = df2['Optimization'].iloc[i] if not pd.isna(df2['Optimization'].iloc[i]) else df2['Optimization'].iloc[i + 1]
        diversity_val = df2['Diversity Optimization'].iloc[i + 1] if not pd.isna(df2['Diversity Optimization'].iloc[i + 1]) else df2['Diversity Optimization'].iloc[i]
        combined_rows.append([optimization_val, diversity_val])

# Create a new DataFrame with combined values
    combined_df = pd.DataFrame(combined_rows, columns=['Optimization', 'Diversity Optimization'])
    
    plt.savefig('minmaxiterations.png')
    
    
    lines = df.plot.line(xlim = (1, 15), ylim = (0, 2.1))
    plt.show()
    return [P, df, combined_df]

# %%
def NOAH_minmax_noplots(P, it, max_global_iteration, max_gen, pop_size, global_bound, b, r_number, c, mutation_rate, mutation_rate_div, box_border):
    
    dfhaudorf = []
    combined_rows = []
    
    global_iteration = 0
    
    all_diversities_minmax = []
        
    while (b[0]>global_bound[0]) and (b[1]>global_bound[1]) and (global_iteration<max_global_iteration):
        
        print("Global_iteration: ", global_iteration, "b is ", b)
        
        #Генерим из популяции размера 10 еще 10 дополнительных потомков, но таких, чтобы были меньше b, выбираем из 20 всего 10 лучших
        #И так делаем итерации и поколения
        #На выходе новая популяция 
#         print("OBJOPT", P)
        
        all_diversities_minmax.append(
            {
                'SP diversity': SP_diversity(P, theta)/10,
                'Min-max diversity': Diversity_minmax(P),
                'S-energy diversity': s_energy(P, s)/100,
                'Average Himmelblaus function (obj1)': statistics.mean([-obj1(p) for p in P]),
                'Average x**2 function (obj1)': statistics.mean([-obj2(p) for p in P])
            }
        )

        P0 = objOpt(P, mutation_rate, it, max_gen, pop_size, b, box_border)
        
#         print("objopt for global iteration ", global_iteration, " is ready")
        
#         print("b before boundchange: ", b)

        dfhaudorf.append(
            {
                'Optimization': my_hausdorff_distance(P0, efficient_set)
            }
        )
        
        #Опускаем b до мнимального значения, при котором итоговая популяция содержит r элементов с обдж меньше b
        #P содержит r элементов, надо проверить что все меньше нового b 
        bound_fun = boundChange(P0, b, r_number, global_bound)
        P1 = bound_fun[0]
        b = bound_fun[1]
#         print("b after boundchange: ", b)
#         print(P1)
#         print(" and size of P is", len(P1))
#         print("DIVOPT")
#         print("parameters for divopt", P1, pop_size, b, c, mutation_rate_div, mutation_rate, box_border)
        #Сейчас популяция размера r должна быть, достраиваем ее до 20 так чтобы все были меньше нового b 
        #Из них выбираем 10 самых разнообразных, повторяем это max_gen раз 
        P2 = divOpt_simple_minmax(P1, it, pop_size, b, c, mutation_rate_div, box_border)
        
        dfhaudorf.append(
            {
                'Diversity Optimization': my_hausdorff_distance(P2, efficient_set)
            }
        )

        P = P2
        
        global_iteration+=1
    df = pd.DataFrame(all_diversities_minmax)  
    df2 = pd.DataFrame(dfhaudorf)
    
    for i in range(0, len(df2), 2):
        optimization_val = df2['Optimization'].iloc[i] if not pd.isna(df2['Optimization'].iloc[i]) else df2['Optimization'].iloc[i + 1]
        diversity_val = df2['Diversity Optimization'].iloc[i + 1] if not pd.isna(df2['Diversity Optimization'].iloc[i + 1]) else df2['Diversity Optimization'].iloc[i]
        combined_rows.append([optimization_val, diversity_val])

# Create a new DataFrame with combined values
    combined_df = pd.DataFrame(combined_rows, columns=['Optimization', 'Diversity Optimization'])

    
    return [P, df, combined_df]
# NOAH_minmax_noplots(P_0, it, max_global_iteration, max_gen, pop_size, global_bound, b, r_number, c, mutation_rate, mutation_rate_div, box_border)

# %%
def NOAH_minmax_repeats(P, repeats, it, max_global_iteration, max_gen, pop_size, global_bound, b, r_number, c, mutation_rate, mutation_rate_div, box_border):
    all_diversities_minmax = []
    list_of_dfs = []
    
    list_of_hausdorfs = []
    
    b_initial = copy.deepcopy(b)

    for repeat in range(repeats):
        
        print("REPEAT: ", repeat)
        b = b_initial
        
        res = NOAH_minmax_noplots(P_0, it, max_global_iteration, max_gen, pop_size, global_bound, b, r_number, c, mutation_rate, mutation_rate_div, box_border)

        list_of_dfs.append(res[1])
        list_of_hausdorfs.append(res[2])

    df_concat = pd.concat(list_of_dfs)
    by_row_index = df_concat.groupby(df_concat.index)
    finaldf = by_row_index.mean()
    finaldfsem = by_row_index.sem()
    df_add = finaldf + finaldfsem
    df_sub = finaldf - finaldfsem
    
    hdf_concat = pd.concat(list_of_hausdorfs)
    hby_row_index = hdf_concat.groupby(hdf_concat.index)
    hfinaldf = hby_row_index.mean()
    
    ax = finaldf.plot(xlim = (1, max_global_iteration-1), ylim = (0, 2.1), color = ['pink', 'cyan', 'orange', 'purple', 'blue'], linestyle = '-') 
    dashlines1 = df_sub.plot.line(ax = ax, xlim = (1, max_global_iteration-1), ylim = (0, 2), color = ['pink', 'cyan', 'orange', 'purple', 'blue'], linestyle = '--')
    dashlines2 = df_add.plot.line(ax = ax, xlim = (1, max_global_iteration-1), ylim = (0, 2), color = ['pink', 'cyan', 'orange', 'purple', 'blue'], linestyle = '--')
    ax.legend(['SP', 'Max-min', 's-Energy/100', 'Himmelblaus', 'x**2'], loc='upper right', fontsize = 12)
    
    plt.savefig('minmaxrepeats.png')
    
    ax2 = hfinaldf.plot(xlim = (1, max_global_iteration-1), ylim = (0, 10), color = ['pink', 'cyan', 'orange', 'purple', 'blue'], linestyle = '-')
    
    return [finaldf, hfinaldf]

# %% [markdown]
# # NOAH with s-energy

# %%
#calculation of s-energy in N^2

def s_energy(P, s):
    sum_of_k = 0
    if s==0:
        for i in range(len(P)):
            for j in range(len(P)):
                if (i!=j):
                    sum_of_k+= -np.log(my_distance(P[i], P[j]))
    else:
        for i in range(len(P)):
            for j in range(len(P)):
                if (i!=j):
                    sum_of_k+=(my_distance(P[i], P[j]))**(-s)
#                     print((my_distance(P[i], P[j]))**(-s))
    return sum_of_k
                
s_energy(P_0, 2)  
#Число такое большое потому что в знаменателе что-то около 0 в степени s
# Out:
# 228.23317193239745

# %%
#subset selection based on s-energy, delte elements one by one which contribute the most
def SelectDiv_senergy(P, n, s):
    
    # dissimilarity matrix
    M = np.zeros((len(P), len(P)))
    # memoization structure
    r = []
    for i in range(len(P)):
        summa = 0
        for j in range(len(P)):
            if i!=j:
                if s==0:
                    M[i][j] = -np.log(my_distance(P[i], P[j]))
                    summa += M[i][j]
                else:
                    M[i][j] = (my_distance(P[i], P[j]))**(-s)
                    summa += M[i][j]
                    
        r.append(summa) 
#     print("M", M)
#     print(r)
    
    P_new = copy.deepcopy(P)
    indices_new = list(range(len(P)))
    r_new = copy.deepcopy(r)
#     print(indices_new)
    #number of deletions
    
#     print("initial P", P_new)

    for i in range(len(P)-n):
        
        #calculate all contributions j = 0, len(P_new)-1
        contribution = np.zeros(len(P_new))
        max_contrib = -1000
        arg_max = -1
        
        for j in range(len(P_new)):
    
            r_new_temp = r_new - M[:, j] #вычли из столбца сумм столбец соответствующий элементу j 
            energy_without_j = np.sum(r_new_temp)- r_new_temp[j] # теперь вычли строчку j 
#             print(energy_without_j, "energy_without_j") 
            contribution[j] = np.sum(r_new) - energy_without_j #
#             print(contribution[j], "contribution[j]", r_new_temp[j])
            if contribution[j]>max_contrib:
                max_contrib = contribution[j]
                arg_max = j
        
        P_new.pop(arg_max)
        indices_new.pop(arg_max)
        
#         print("new P", P_new, indices_new)
    return [s_energy(P_new, s), indices_new]

SelectDiv_senergy(P_0, 9, 3)
# Out:
# [0.8409904128688451, [0, 1, 2, 3, 4, 5, 29, 30, 31]]

# %%
#c - параметр схождения, если c раз подряд значение diversity не меняется, значит, все
# На входе будет r элементов популяции, на выходе надо n = pop_size

def divOpt_simple_senergy(P, it, pop_size, b, c, mutation_rate, box_border, s_par):
    
    start_time = time.time()

    a_fp = open('./obj_div_simple_senergy_' + str(mutation_rate) + '.json', 'w')
    b_fp = open('./sol_div_simple_senergy_' + str(mutation_rate) + '.json', 'w')
    c_fp = open('./statistic_div_simple_senergy_' + str(mutation_rate) + '.json', 'w')
    iteration = 0
    A = []
    B = []
    S = []
    for iteration in range(it):
        print("iteration", iteration)
        
        #Main program starts here

        #Initialization
        min_x=-55
        max_x=55
        A = defaultdict()
        C = defaultdict()
        solution = P
        energies = []
        
        iteration_no_change = 0

        
        selec = SelectDiv_senergy(solution, len(solution), s_par)
        energies.append(selec[0])
        
#         print(selec)

        gen_no=0
    
        
        while(len(solution)!=pop_size):
                
                #Поменяла на len(P)=r, было pop_size
                #здесь надо выбирать только из элементов с индексами solution
#                 a1 = random.randint(0,len(P)-1)
                 
    
            s = 0
            while s == 0:
                a1 = random.randint(0,len(P)-2)
                app = mutation(solution[a1], mutation_rate)
                if (app[0]<0) or (app[1]<0) or (app[0]>box_border) or (app[1]>box_border):
                    app = reflect_point(app[0], app[1], box_border)
                        
                new_set = copy.deepcopy(solution)
                new_set.pop(a1)
                new_set.append(app)
    
    
                if (-obj1(app)<b[0]) and (-obj2(app)<b[1]) and (my_distance(app, solution[a1]) > epsilon) and (s_energy(new_set, s_par)<=energies[-1]) and (app[0]>=0) and (app[1]>=0) and (app[0]<=box_border) and (app[1]<=box_border) :
                    solution.append(app)
#                         print(-obj1(app), -obj2(app))
                    s = 1
                else:
                    pass
        
        while(iteration_no_change < c):
            print("GENERATION", gen_no)
            
            solution2 = solution[:]
            
            #Just printing
            
#             for i in range(len(solution)):
#                 print(-obj1(solution[i]), -obj2(solution[i]))
        
#             Generating offsprings
#             print("offsprings")

            while(len(solution2)!=pop_size+1):
                
                #Поменяла на len(P)=r, было pop_size
                #здесь надо выбирать только из элементов с индексами solution
#                 a1 = random.randint(0,len(P)-1)
                 
    
                s = 0
                counter = 0
                while (s == 0) and (counter < 700):
                    a1 = random.randint(0,len(P)-1)
                    app = mutation(solution[a1], mutation_rate)
                    if (app[0]<0) or (app[1]<0) or (app[0]>box_border) or (app[1]>box_border):
                        app = reflect_point(app[0], app[1], box_border)
                        
                        
                        
#                     min_distance_from_new = 1000
#                     for z in range(len(solution)):
#                         if my_distance(solution[z], app)<min_distance_from_new:
#                             min_distance_from_new = my_distance(solution[z], app)
                    
                    new_set = copy.deepcopy(solution)
                    new_set.pop(a1)
                    new_set.append(app)
                    
    
                    if (-obj1(app)<b[0]) and (-obj2(app)<b[1]) and (my_distance(app, solution[a1]) > epsilon) and (s_energy(new_set, s_par)<=energies[-1]) and (app[0]>=0) and (app[1]>=0) and (app[0]<=box_border) and (app[1]<=box_border) :
                        solution2.append(app)
#                         print(-obj1(app), -obj2(app))
                        s = 1
                    else:
                        counter += 1
#                 print("counter", counter)
                if counter >= 700:
#                     solution2.append(solution2[random.randint(0,len(P)-2)])
                    break
#             print("offsprings are ready")
            
            # When it is [0, 2, .., 9] it is not supposed to chenge, but it's getting lower
            
            solution = []
            
            select_div = SelectDiv_senergy(solution2, pop_size, s_par) 
#             print("select_div", select_div)
            #не забыть все нужные параметры вставить
    
    
    
    
            if np.abs(select_div[0]-energies[-1])<epsilon:
                iteration_no_change+=1
            else:
                iteration_no_change = 0
#             print(iteration_no_change)
            energies.append(select_div[0])  
            
            indices = select_div[1]
            
            for i in range(2*pop_size):
                if i in indices:
                    solution.append(solution2[i])
                 
            C[gen_no] = solution
            gen_no = gen_no + 1
            max_reached_gen = gen_no
#             print(solution)
            
#         print(max_reached_gen)
#         print("diversity", diversity[-1])
        S.append(max_reached_gen)
        B.append(C)
        iteration +=1  
#         print(solution)
    print("all energies", energies, solution)    
    json.dump(B, b_fp, cls=NpEncoder)  
    json.dump(S, c_fp, cls=NpEncoder)            

    a_fp.close()
    b_fp.close()
    c_fp.close()

    print("--- %s seconds ---" % (time.time() - start_time))
    
    return solution

# divOpt_simple_senergy(P_0, 5, pop_size, b, c, 10, 10, 3)

# %%
def NOAH_senergy(P, it, max_global_iteration, max_gen, pop_size, global_bound, b, r_number, c, mutation_rate, mutation_rate_div, box_border, s):
    
    global_iteration = 0
    dfhaudorf = []
    combined_rows = []
    
    all_diversities_senergy = []
    
    count = 1
    plt.subplots(figsize=(15, 60))
    plt.subplots_adjust(left=None, bottom=None, right=None, top=None, wspace=None, hspace=0.4)
    
    
    while (b[0]>global_bound[0]) and (b[1]>global_bound[1]) and (global_iteration<max_global_iteration):
        
        print("Global_iteration: ", global_iteration, "b is ", b)
        
        #Генерим из популяции размера 10 еще 10 дополнительных потомков, но таких, чтобы были меньше b, выбираем из 20 всего 10 лучших
        #И так делаем итерации и поколения
        #На выходе новая популяция 
        print("OBJOPT", P)
        plt.subplot(max_global_iteration,6,count).set_title(f'Global iteration: {round((count-1)//6.)} \n Starting set \n Diversity: {round(s_energy(P, s), 5)}', size=8)
        vis_plot(P)
        plt.xticks(fontsize=7)
        plt.yticks(fontsize=7, rotation = 90)
        count+=1
        
        all_diversities_senergy.append(
            {
                'SP diversity': SP_diversity(P, theta)/10,
                'Min-max diversity': Diversity_minmax(P),
                'S-energy diversity': s_energy(P, s)/1000,
                'Average Himmelblaus function (obj1)': statistics.mean([-obj1(p) for p in P]),
                'Average x**2 function (obj1)': statistics.mean([-obj2(p) for p in P])
            }
        )
        
        plt.subplot(max_global_iteration,6,count).set_title(f'Objectives \n Average objectives: \n {round(statistics.mean([-obj1(p) for p in P]), 5)}, {round(statistics.mean([-obj2(p) for p in P]), 5)}', size=8)
        x_obj = [-obj1(p) for p in P]
        y_obj = [-obj2(p) for p in P]
        plt.scatter(x=x_obj, y=y_obj, s = 5)
        plt.axis('scaled')
        plt.xlim(-0.003, 0.1)
        plt.ylim(-0.003, 0.1)
        plt.xticks(fontsize=7)
        plt.yticks(fontsize=7, rotation = 90)
        count+=1


        P0 = objOpt(P, mutation_rate, it, max_gen, pop_size, b, box_border)
        dfhaudorf.append(
            {
                'Optimization': my_hausdorff_distance(P0, efficient_set)
            }
        )
        plt.subplot(max_global_iteration,6,count).set_title(f'After optimization \n Diversity: {round(s_energy(P0, s), 5)}', size=8)
        vis_plot(P0)
        plt.xticks(fontsize=7)
        plt.yticks(fontsize=7, rotation = 90)
        count+=1
        
        plt.subplot(max_global_iteration,6,count).set_title(f'Objectives \n Average objectives: \n {round(statistics.mean([-obj1(p) for p in P0]), 5)}, {round(statistics.mean([-obj2(p) for p in P0]), 5)}', size=8)
        x_obj = [-obj1(p) for p in P0]
        y_obj = [-obj2(p) for p in P0]
        plt.scatter(x=x_obj, y=y_obj, s = 5)
        plt.axis('scaled')
        plt.xlim(-0.003, 0.1)
        plt.ylim(-0.003, 0.1)
        plt.xticks(fontsize=7)
        plt.yticks(fontsize=7, rotation = 90)
        count+=1

        
        print("objopt for global iteration ", global_iteration, " is ready")
        
        print("b before boundchange: ", b)
        
        #Опускаем b до мнимального значения, при котором итоговая популяция содержит r элементов с обдж меньше b
        #P содержит r элементов, надо проверить что все меньше нового b 
        bound_fun = boundChange(P0, b, r_number, global_bound)
        P1 = bound_fun[0]
        b = bound_fun[1]
        print("b after boundchange: ", b)
        print(P1)
        print(" and size of P is", len(P1))
        print("DIVOPT")
        print("parameters for divopt", P1, pop_size, b, c, mutation_rate_div, box_border, s)
        #Сейчас популяция размера r должна быть, достраиваем ее до 20 так чтобы все были меньше нового b 
        #Из них выбираем 10 самых разнообразных, повторяем это max_gen раз 
        P2 = divOpt_simple_senergy(P1, it, pop_size, b, c, mutation_rate_div, box_border, s)
        dfhaudorf.append(
            {
                'Diversity Optimization': my_hausdorff_distance(P2, efficient_set)
            }
        )
        
        plt.subplot(max_global_iteration,6,count).set_title(f'After diversity optimization \n Diversity: {round(s_energy(P2, s), 5)}', size=8)
        vis_plot(P2)
        plt.xticks(fontsize=7)
        plt.yticks(fontsize=7, rotation = 90)
        count+=1
        
        plt.subplot(max_global_iteration,6,count).set_title(f'Objectives \n Average objectives: \n {round(statistics.mean([-obj1(p) for p in P2]), 5)}, {round(statistics.mean([-obj2(p) for p in P2]), 5)}', size=8)
        x_obj = [-obj1(p) for p in P2]
        y_obj = [-obj2(p) for p in P2]
        plt.scatter(x=x_obj, y=y_obj, s = 5)
        plt.axis('scaled')
        plt.xlim(-0.003, 0.1)
        plt.ylim(-0.003, 0.1)
        plt.xticks(fontsize=7)
        plt.yticks(fontsize=7, rotation = 90)
        count+=1

        
        P = P2
        
        global_iteration+=1
        
    df = pd.DataFrame(all_diversities_senergy)
    df2 = pd.DataFrame(dfhaudorf)
    
    for i in range(0, len(df2), 2):
        optimization_val = df2['Optimization'].iloc[i] if not pd.isna(df2['Optimization'].iloc[i]) else df2['Optimization'].iloc[i + 1]
        diversity_val = df2['Diversity Optimization'].iloc[i + 1] if not pd.isna(df2['Diversity Optimization'].iloc[i + 1]) else df2['Diversity Optimization'].iloc[i]
        combined_rows.append([optimization_val, diversity_val])

# Create a new DataFrame with combined values
    combined_df = pd.DataFrame(combined_rows, columns=['Optimization', 'Diversity Optimization'])
    
    plt.savefig('senergyiterations.png')
    plt.show()
    lines = df.plot.line(xlim = (1, 15), ylim = (0, 2.1))
    return [P, df, combined_df]

# %%
def NOAH_senergy_noplots(P, it, max_global_iteration, max_gen, pop_size, global_bound, b, r_number, c, mutation_rate, mutation_rate_div, box_border, s):
    
    global_iteration = 0
    dfhaudorf = []
    combined_rows = []
    
    all_diversities_senergy = []
   
    while (b[0]>global_bound[0]) and (b[1]>global_bound[1]) and (global_iteration<max_global_iteration):
        
        print("Global_iteration: ", global_iteration, "b is ", b)
        
        #Генерим из популяции размера 10 еще 10 дополнительных потомков, но таких, чтобы были меньше b, выбираем из 20 всего 10 лучших
        #И так делаем итерации и поколения
        #На выходе новая популяция 

        
        all_diversities_senergy.append(
            {
                'SP diversity': SP_diversity(P, theta)/10,
                'Min-max diversity': Diversity_minmax(P),
                'S-energy diversity': s_energy(P, s)/1000,
                'Average Himmelblaus function (obj1)': statistics.mean([-obj1(p) for p in P]),
                'Average x**2 function (obj1)': statistics.mean([-obj2(p) for p in P])
            }
        )

        P0 = objOpt(P, mutation_rate, it, max_gen, pop_size, b, box_border)
        
        dfhaudorf.append(
            {
                'Optimization': my_hausdorff_distance(P0, efficient_set)
            }
        )
        
        #Опускаем b до мнимального значения, при котором итоговая популяция содержит r элементов с обдж меньше b
        #P содержит r элементов, надо проверить что все меньше нового b 
        bound_fun = boundChange(P0, b, r_number, global_bound)
        P1 = bound_fun[0]
        b = bound_fun[1]
        #Сейчас популяция размера r должна быть, достраиваем ее до 20 так чтобы все были меньше нового b 
        #Из них выбираем 10 самых разнообразных, повторяем это max_gen раз 
        P2 = divOpt_simple_senergy(P1, it, pop_size, b, c, mutation_rate_div, box_border, s)
        
        dfhaudorf.append(
            {
                'Diversity Optimization': my_hausdorff_distance(P2, efficient_set)
            }
        )
        
        P = P2
        
        global_iteration+=1
        
    df = pd.DataFrame(all_diversities_senergy)
    df2 = pd.DataFrame(dfhaudorf)
    
    for i in range(0, len(df2), 2):
        optimization_val = df2['Optimization'].iloc[i] if not pd.isna(df2['Optimization'].iloc[i]) else df2['Optimization'].iloc[i + 1]
        diversity_val = df2['Diversity Optimization'].iloc[i + 1] if not pd.isna(df2['Diversity Optimization'].iloc[i + 1]) else df2['Diversity Optimization'].iloc[i]
        combined_rows.append([optimization_val, diversity_val])

# Create a new DataFrame with combined values
    combined_df = pd.DataFrame(combined_rows, columns=['Optimization', 'Diversity Optimization'])
    
    return [P, df, combined_df]

# %%
def NOAH_senergy_repeats(P, repeats, it, max_global_iteration, max_gen, pop_size, global_bound, b, r_number, c, mutation_rate, mutation_rate_div, box_border, s):
    all_diversities_minmax = []
    list_of_dfs = []
    list_of_hausdorfs = []
    
    b_initial = copy.deepcopy(b)

    for repeat in range(repeats):
        
        print("REPEAT: ", repeat)
        b = b_initial
        
        res = NOAH_senergy_noplots(P, it, max_global_iteration, max_gen, pop_size, global_bound, b, r_number, c, mutation_rate, mutation_rate_div, box_border, s)
        list_of_dfs.append(res[1])
        list_of_hausdorfs.append(res[2])
        
    df_concat = pd.concat(list_of_dfs)
    by_row_index = df_concat.groupby(df_concat.index)
    finaldf = by_row_index.mean()
    finaldfsem = by_row_index.sem()
    df_add = finaldf + finaldfsem
    df_sub = finaldf - finaldfsem
    
    hdf_concat = pd.concat(list_of_hausdorfs)
    hby_row_index = hdf_concat.groupby(hdf_concat.index)
    hfinaldf = hby_row_index.mean()
    
    ax = finaldf.plot(xlim = (1, max_global_iteration-1), ylim = (0, 2.1), color = ['pink', 'cyan', 'orange', 'purple', 'blue'], linestyle = '-') 
    dashlines1 = df_sub.plot.line(ax = ax, xlim = (1, max_global_iteration-1), ylim = (0, 2.1), color = ['pink', 'cyan', 'orange', 'purple', 'blue'], linestyle = '--')
    dashlines2 = df_add.plot.line(ax = ax, xlim = (1, max_global_iteration-1), ylim = (0, 2.1), color = ['pink', 'cyan', 'orange', 'purple', 'blue'], linestyle = '--')
    ax.legend(['SP/10', 'Max-min', 's-Energy/1000', 'Himmelblaus', 'x**2'], loc='upper left', fontsize = 12)
    plt.savefig('senergyrepeats.png')
    
    ax2 = hfinaldf.plot(xlim = (1, max_global_iteration-1), ylim = (0, 10), color = ['pink', 'cyan', 'orange', 'purple', 'blue'], linestyle = '-')
    
    return [finaldf, hfinaldf]

# %% [markdown]
# # NOAH with S-P

# %%
def SelectDiv_SP(P, n, theta):
    
    if (n>len(P)) or (n<1):
        print("wrong n", len(P), n)
        return -1
    
#     print(len(P))
    indices = []
    #Создаем матрицу
    M = np.exp(-matrix_of_distances(P) * theta)
#     print("M is calculated")
#     print("M", M)
    #     Берем обратную матрицу
    Dp = np.linalg.inv(M)
#     print(np.sum(Dp), M, Dp)

#   Делаем список [0, 1, 2, ...]
    all_indices = list(range(len(P)))

#     Считаем сумму квадратов элементов по столбцам, деленную на диагональный элемент
    for k in range(len(P) - n):
        
        lis = []
        for i in range(len(Dp)):
            a = 0
            for j in range(len(Dp)):
                a+=Dp[i][j]
            a = (a**2)/Dp[i][i]
            lis.append(a)
            
#         print("optimal", b)
        
#         contributions = []
#         for i in range(len(Dp)):
#             A = np.delete(np.delete(M, i, 0), i, 1)
#             B = np.linalg.inv(A)
#             contributions.append(np.sum(Dp) - np.sum(B)) 
#         print("non-optimal", contributions)
        
#         minarg_cont = contributions.index(min(contributions))
            
# #      Находим номер столбца, при котором сумма столбца минимальна            
        minarg = lis.index(min(lis))
        
#       Записываем в список индексов
        indices.append(minarg)
          
#         print("before deletion", Dp)
#         print("what to subtract", np.outer(np.delete(b, minarg, 0), np.delete(b, minarg, 0))/Dp[minarg, minarg])
# #         Новая обратная матрица считается как старая обратная матрица без строки и столбца - произведение этого столбца на строку/диагональный элемент
#         Dp = np.delete(np.delete(Dp, minarg, 0), minarg, 1) - np.outer(np.delete(b, minarg, 0), np.delete(b, minarg, 0))/Dp[minarg, minarg]
#         print("after deletion", np.sum(Dp), Dp)
        
        
        Dp = np.linalg.inv(np.delete(np.delete(np.linalg.inv(Dp), minarg, 0), minarg, 1))
        
#         print(Dp, Dp_cont)
        #Проверить не оптимальным способом!!!!
#     print(indices)    
#     Удаляем все индексы из списка всех индексов, 
    for i in indices:
        del all_indices[i]
#     print(all_indices)    
#     Выводим финальное дайверсити после всех удалений и список оставшихся индексов
    return [np.sum(Dp), all_indices]

# SelectDiv_SP(P_0,5, 1)

# %%
def SP_diversity(P, theta):
    M = np.exp(-matrix_of_distances(P) * theta)
    Dp = np.linalg.inv(M)
    return np.sum(Dp)

# SP_diversity(P_0, 1)

# %%
#c - параметр схождения, если c раз подряд значение diversity не меняется, значит, все
# На входе будет r элементов популяции, на выходе надо n = pop_size

def divOpt_simple_SP(P, it, pop_size, b, c, mutation_rate, box_border, theta):
    
    start_time = time.time()

    a_fp = open('./obj_div_simple_SP_' + str(mutation_rate) + '.json', 'w')
    b_fp = open('./sol_div_simple_SP_' + str(mutation_rate) + '.json', 'w')
    c_fp = open('./statistic_div_simple_SP_' + str(mutation_rate) + '.json', 'w')
    iteration = 0
    A = []
    B = []
    S = []
    for iteration in range(it):
        print("iteration", iteration)
        
        #Main program starts here

        #Initialization
        min_x=-55
        max_x=55
        A = defaultdict()
        C = defaultdict()
        solution = P
        diversity = []
        
        iteration_no_change = 0

        
        selec = SelectDiv_SP(solution, len(solution), theta)
        diversity.append(selec[0])
        
#         print(selec)

        gen_no=0
    
    
    
        while(len(solution)!=pop_size):
                
                #Поменяла на len(P)=r, было pop_size
                #здесь надо выбирать только из элементов с индексами solution
#                 a1 = random.randint(0,len(P)-1)
                 
    
            s = 0
            counter = 0
            while s == 0:
                a1 = random.randint(0,len(P)-2)
                app = mutation(solution[a1], mutation_rate)
                if (app[0]<0) or (app[1]<0) or (app[0]>box_border) or (app[1]>box_border):
                    app = reflect_point(app[0], app[1], box_border)
                        
                new_set = copy.deepcopy(solution)
                new_set.append(app)
    
    
                if (-obj1(app)<b[0]) and (-obj2(app)<b[1]) and (my_distance(app, solution[a1]) > epsilon) and (SP_diversity(new_set, theta)>=diversity[-1]) and (app[0]>=0) and (app[1]>=0) and (app[0]<=box_border) and (app[1]<=box_border) :
                    solution.append(app)
#                         print(-obj1(app), -obj2(app))
                    s = 1
                else:
                    pass
    
    
    
    
    
    
        while(iteration_no_change < c):
            print("GENERATION", gen_no)
            
            solution2 = solution[:]
            
            #Just printing
            
#             for i in range(len(solution)):
#                 print(-obj1(solution[i]), -obj2(solution[i]))
        
#             Generating offsprings
#             print("offsprings")
#             print("before while (len(solution2)!=pop_size+1)", len(solution2), pop_size+1)
            while(len(solution2)!=pop_size+1):
                
                #Поменяла на len(P)=r, было pop_size
                #здесь надо выбирать только из элементов с индексами solution
#                 a1 = random.randint(0,len(P)-1)
                 
    
                s = 0
                counter = 0
                while (s == 0) and (counter < 700):
                    a1 = random.randint(0,len(P)-1)
                    app = mutation(solution[a1], mutation_rate)
                    if (app[0]<0) or (app[1]<0) or (app[0]>box_border) or (app[1]>box_border):
                        app = reflect_point(app[0], app[1], box_border)
                        
                    new_set = copy.deepcopy(solution)
                    new_set.append(app)
    
    
                    if (-obj1(app)<b[0]) and (-obj2(app)<b[1]) and (my_distance(app, solution[a1]) > epsilon) and (SP_diversity(new_set, theta)>=diversity[-1]) and (app[0]>=0) and (app[1]>=0) and (app[0]<=box_border) and (app[1]<=box_border) :
                        solution2.append(app)
#                         print(-obj1(app), -obj2(app))
                        s = 1
                    else:
                        counter += 1
#                 print("counter", counter)
                if counter>= 700:
#                     solution2.append(solution2[random.randint(0,len(P)-2)])
                    break
#             print("offsprings are ready")
            
            # When it is [0, 2, .., 9] it is not supposed to chenge, but it's getting lower
            
            solution = []
            
#             print("before the error in SelectDiv_SP(solution2, pop_size, theta)", len(solution2), pop_size)
            select_div = SelectDiv_SP(solution2, pop_size, theta) 
#             print("select_div", select_div)
            #не забыть все нужные параметры вставить
    
    
    
    
            if np.abs(select_div[0]-diversity[-1])<epsilon:
                iteration_no_change+=1
            else:
                iteration_no_change = 0
#             print(iteration_no_change)
            diversity.append(select_div[0])  
            
            indices = select_div[1]
            
            for i in range(2*pop_size):
                if i in indices:
                    solution.append(solution2[i])
                 
            C[gen_no] = solution
            gen_no = gen_no + 1
            max_reached_gen = gen_no
#             print(solution)
            
#         print(max_reached_gen)
#         print("diversity", diversity[-1])
        S.append(max_reached_gen)
        B.append(C)
        iteration +=1  
        print(solution)
    print("all diversities", diversity)    
    json.dump(B, b_fp, cls=NpEncoder)  
    json.dump(S, c_fp, cls=NpEncoder)            

    a_fp.close()
    b_fp.close()
    c_fp.close()

    print("--- %s seconds ---" % (time.time() - start_time))
    
    return solution

# divOpt_simple_SP(P_0, 5, pop_size, b, c, 10, 10, 1)

# %%
###
def NOAH_SP(P, it, max_global_iteration, max_gen, pop_size, global_bound, b, r_number, c, mutation_rate, mutation_rate_div, box_border, theta):
    
    all_diversities_SP = []
    dfhaudorf = []
    combined_rows = []
    global_iteration = 0
    
    count = 1
    plt.subplots(figsize=(15, 60))
    plt.subplots_adjust(left=None, bottom=None, right=None, top=None, wspace=None, hspace=0.4)
    #len P = 20
    while (b[0]>global_bound[0]) and (b[1]>global_bound[1]) and (global_iteration<max_global_iteration):
        
        
        
        print("Global_iteration: ", global_iteration, "b is ", b)
        
        #Генерим из популяции размера 10 еще 10 дополнительных потомков, но таких, чтобы были меньше b, выбираем из 20 всего 10 лучших
        #И так делаем итерации и поколения
        #На выходе новая популяция 
        print("OBJOPT", P)
        plt.subplot(max_global_iteration,6,count).set_title(f'Global iteration: {round((count-1)//6.)} \n Starting set \n Diversity: {round(SP_diversity(P, theta), 5)}', size=8)
        vis_plot(P)
        plt.xticks(fontsize=7)
        plt.yticks(fontsize=7, rotation = 90)
        count+=1
        
        all_diversities_SP.append(
            {
                'SP diversity': SP_diversity(P, theta)/10,
                'Min-max diversity': Diversity_minmax(P),
                'S-energy diversity': s_energy(P, s)/10000,
                'Average Himmelblaus function (obj1)': statistics.mean([-obj1(p) for p in P]),
                'Average x**2 function (obj1)': statistics.mean([-obj2(p) for p in P])
            }
        )
        
        plt.subplot(max_global_iteration,6,count).set_title(f'Objectives \n Average objectives: \n {round(statistics.mean([-obj1(p) for p in P]), 5)}, {round(statistics.mean([-obj2(p) for p in P]), 5)}', size=8)
        x_obj = [-obj1(p) for p in P]
        y_obj = [-obj2(p) for p in P]
        plt.scatter(x=x_obj, y=y_obj, s = 5)
        plt.axis('scaled')
        plt.xlim(-0.003, 0.1)
        plt.ylim(-0.003, 0.1)
        plt.xticks(fontsize=7)
        plt.yticks(fontsize=7, rotation = 90)
        count+=1


        P0 = objOpt(P, mutation_rate, it, max_gen, pop_size, b, box_border)
        dfhaudorf.append(
            {
                'Optimization': my_hausdorff_distance(P0, efficient_set)
            }
        )
        # len P0 20
        plt.subplot(max_global_iteration,6,count).set_title(f'After optimization \n Diversity: {round(SP_diversity(P0, theta), 5)}', size=8)
        vis_plot(P0)
        plt.xticks(fontsize=7)
        plt.yticks(fontsize=7, rotation = 90)
        count+=1
        
        plt.subplot(max_global_iteration,6,count).set_title(f'Objectives \n Average objectives: \n {round(statistics.mean([-obj1(p) for p in P0]), 5)}, {round(statistics.mean([-obj2(p) for p in P0]), 5)}', size=8)
        x_obj = [-obj1(p) for p in P0]
        y_obj = [-obj2(p) for p in P0]
        plt.scatter(x=x_obj, y=y_obj, s = 5)
        plt.axis('scaled')
        plt.xlim(-0.003, 0.1)
        plt.ylim(-0.003, 0.1)
        plt.xticks(fontsize=7)
        plt.yticks(fontsize=7, rotation = 90)
        count+=1

        
        print("objopt for global iteration ", global_iteration, " is ready")
        
        print("b before boundchange: ", b)
        
        #Опускаем b до мнимального значения, при котором итоговая популяция содержит r элементов с обдж меньше b
        #P содержит r элементов, надо проверить что все меньше нового b 
        bound_fun = boundChange(P0, b, r_number, global_bound)
        #len P1 19 = r
        P1 = bound_fun[0]
        b = bound_fun[1]
        print("b after boundchange: ", b)
        print(P1)
        print(" and size of P is", len(P1))
        print("DIVOPT")
        print("parameters for divopt", P1, pop_size, b, c, mutation_rate_div, box_border, theta)
        #Сейчас популяция размера r должна быть, достраиваем ее до 20 так чтобы все были меньше нового b 
        #Из них выбираем 10 самых разнообразных, повторяем это max_gen раз 
        P2 = divOpt_simple_SP(P1, it, pop_size, b, c, mutation_rate_div, box_border, theta)
        dfhaudorf.append(
            {
                'Diversity Optimization': my_hausdorff_distance(P2, efficient_set)
            }
        )
        #len P2 20
        plt.subplot(max_global_iteration,6,count).set_title(f'After diversity optimization \n Diversity: {round(SP_diversity(P2, theta), 5)}', size=8)
        vis_plot(P2)
        plt.xticks(fontsize=7)
        plt.yticks(fontsize=7, rotation = 90)
        count+=1
        
        plt.subplot(max_global_iteration,6,count).set_title(f'Objectives \n Average objectives: \n {round(statistics.mean([-obj1(p) for p in P2]), 5)}, {round(statistics.mean([-obj2(p) for p in P2]), 5)}', size=8)
        x_obj = [-obj1(p) for p in P2]
        y_obj = [-obj2(p) for p in P2]
        plt.scatter(x=x_obj, y=y_obj, s = 5)
        plt.axis('scaled')
        plt.xlim(-0.003, 0.1)
        plt.ylim(-0.003, 0.1)
        plt.xticks(fontsize=7)
        plt.yticks(fontsize=7, rotation = 90)
        count+=1

        
        P = P2
        
        global_iteration+=1
        
    df = pd.DataFrame(all_diversities_SP)
    df2 = pd.DataFrame(dfhaudorf)
    
    for i in range(0, len(df2), 2):
        optimization_val = df2['Optimization'].iloc[i] if not pd.isna(df2['Optimization'].iloc[i]) else df2['Optimization'].iloc[i + 1]
        diversity_val = df2['Diversity Optimization'].iloc[i + 1] if not pd.isna(df2['Diversity Optimization'].iloc[i + 1]) else df2['Diversity Optimization'].iloc[i]
        combined_rows.append([optimization_val, diversity_val])

# Create a new DataFrame with combined values
    combined_df = pd.DataFrame(combined_rows, columns=['Optimization', 'Diversity Optimization'])
    
    
    
    plt.savefig('spiterations.png')
      
    plt.show()
    
    lines = df.plot.line(xlim = (1, 15), ylim = (0, 2.1))

    return [P, df, combined_df]

# %%
###
def NOAH_SP_noplots(P, it, max_global_iteration, max_gen, pop_size, global_bound, b, r_number, c, mutation_rate, mutation_rate_div, box_border, theta):
    
    all_diversities_SP = []
    dfhaudorf = []
    combined_rows = []
    global_iteration = 0
    
    #len P = 20
    while (b[0]>global_bound[0]) and (b[1]>global_bound[1]) and (global_iteration<max_global_iteration):
        
        
        
        print("Global_iteration: ", global_iteration, "b is ", b)
        
        #Генерим из популяции размера 10 еще 10 дополнительных потомков, но таких, чтобы были меньше b, выбираем из 20 всего 10 лучших
        #И так делаем итерации и поколения
        #На выходе новая популяция 
#         print("OBJOPT", P)
        all_diversities_SP.append(
            {
                'SP diversity': SP_diversity(P, theta)/10,
                'Min-max diversity': Diversity_minmax(P),
                'S-energy diversity': s_energy(P, s)/10000,
                'Average Himmelblaus function (obj1)': statistics.mean([-obj1(p) for p in P]),
                'Average x**2 function (obj1)': statistics.mean([-obj2(p) for p in P])
            }
        )
        

        P0 = objOpt(P, mutation_rate, it, max_gen, pop_size, b, box_border)
        
        dfhaudorf.append(
            {
                'Optimization': my_hausdorff_distance(P0, efficient_set)
            }
        )
        
        #Опускаем b до мнимального значения, при котором итоговая популяция содержит r элементов с обдж меньше b
        #P содержит r элементов, надо проверить что все меньше нового b 
        bound_fun = boundChange(P0, b, r_number, global_bound)
        #len P1 19 = r
        P1 = bound_fun[0]
        b = bound_fun[1]
        #Сейчас популяция размера r должна быть, достраиваем ее до 20 так чтобы все были меньше нового b 
        #Из них выбираем 10 самых разнообразных, повторяем это max_gen раз 
        P2 = divOpt_simple_SP(P1, it, pop_size, b, c, mutation_rate_div, box_border, theta)
        
        dfhaudorf.append(
            {
                'Diversity Optimization': my_hausdorff_distance(P2, efficient_set)
            }
        )
        #len P2 20
        
        P = P2
        
        global_iteration+=1
        
    df = pd.DataFrame(all_diversities_SP)
    df2 = pd.DataFrame(dfhaudorf)
    
    for i in range(0, len(df2), 2):
        optimization_val = df2['Optimization'].iloc[i] if not pd.isna(df2['Optimization'].iloc[i]) else df2['Optimization'].iloc[i + 1]
        diversity_val = df2['Diversity Optimization'].iloc[i + 1] if not pd.isna(df2['Diversity Optimization'].iloc[i + 1]) else df2['Diversity Optimization'].iloc[i]
        combined_rows.append([optimization_val, diversity_val])

# Create a new DataFrame with combined values
    combined_df = pd.DataFrame(combined_rows, columns=['Optimization', 'Diversity Optimization'])
    

    return [P, df, combined_df]

# %%
def NOAH_SP_repeats(P, repeats, it, max_global_iteration, max_gen, pop_size, global_bound, b, r_number, c, mutation_rate, mutation_rate_div, box_border, theta):
    all_diversities_minmax = []
    list_of_dfs = []
    list_of_hausdorfs = []
    
    b_initial = copy.deepcopy(b)

    for repeat in range(repeats):
        
        print("REPEAT: ", repeat)
        b = b_initial
        
        res = NOAH_SP_noplots(P, it, max_global_iteration, max_gen, pop_size, global_bound, b, r_number, c, mutation_rate, mutation_rate_div, box_border, theta)
        list_of_dfs.append(res[1])
        list_of_hausdorfs.append(res[2])
    
    df_concat = pd.concat(list_of_dfs)
    by_row_index = df_concat.groupby(df_concat.index)
    finaldf = by_row_index.mean()
    finaldfsem = by_row_index.sem()
    df_add = finaldf + finaldfsem
    df_sub = finaldf - finaldfsem
    
    hdf_concat = pd.concat(list_of_hausdorfs)
    hby_row_index = hdf_concat.groupby(hdf_concat.index)
    hfinaldf = hby_row_index.mean()
    
    ax = finaldf.plot(xlim = (1, max_global_iteration-1), ylim = (0, 2.1), color = ['pink', 'cyan', 'orange', 'purple', 'blue'], linestyle = '-') 
    dashlines1 = df_sub.plot.line(ax = ax, xlim = (1, max_global_iteration-1), ylim = (0, 2.1), color = ['pink', 'cyan', 'orange', 'purple', 'blue'], linestyle = '--')
    dashlines2 = df_add.plot.line(ax = ax, xlim = (1, max_global_iteration-1), ylim = (0, 2.1), color = ['pink', 'cyan', 'orange', 'purple', 'blue'], linestyle = '--')
    ax.legend(['SP/10', 'Max-min', 's-Energy/10000', 'Himmelblaus', 'x**2'], loc='upper left', fontsize = 12)
    plt.savefig('sprepeats.png')
    
    
    ax2 = hfinaldf.plot(xlim = (1, max_global_iteration-1), ylim = (0, 10), color = ['pink', 'cyan', 'orange', 'purple', 'blue'], linestyle = '-')
    
    return [finaldf, hfinaldf]

# %% [markdown]
# # Results

# %%
#not uniformly distributed sample
P_0 = [[0, 1], [0, 0.5], [2, 4], [2, 4.2], [1.97, 4], [1.9, 2.1], [6.9, 7], [9, 4], [7, 7], [7, 8], [7, 7.03], [9.05, 1], [6.5, 7], [2, 2.04], [7.3, 7], [9.03, 10], [2, 2], [0, 6], [0.1, 0.3], [2, 1.98]]

print(len(P_0))
vis_plot(P_0)
# Out:
# 20

# %%
it = 1
max_gen = 10
pop_size = 20
b = [3, 3]
c = 3
global_bound = [0, 0]
r_number = 19
mutation_rate_div = 10
box_border = 10
max_global_iteration = 16
mutation_rate = 0.7
theta = 5
s = 3

random.seed(11)
NOAH_minmax(P_0, it, max_global_iteration, max_gen, pop_size, global_bound, b, r_number, c, mutation_rate, mutation_rate_div, box_border=10)
# Out:
# Global_iteration:  0 b is  [3, 3]
# OBJOPT [[0, 1], [0, 0.5], [2, 4], [2, 4.2], [1.97, 4], [1.9, 2.1], [6.9, 7], [9, 4], [7, 7], [7, 8], [7, 7.03], [9.05, 1], [6.5, 7], [2, 2.04], [7.3, 7], [9.03, 10], [2, 2], [0, 6], [0.1, 0.3], [2, 1.98]]
# iteration 0
# [[-0.001699252906733198, -5.342067399359091e-05, -0.003782545575348038, -0.00013226164619971402, -0.004066701648199818, -0.0005548048667095957, -0.0011441849039889485, -0.001566202321737674, -0.002435817027549024, -0.004653469285370135, -3.2358939655525174e-05, -0.004583676487935035, -0.0019519783068977802, -0.0034310327393066303, -0.0038556037050964174, -0.005612941629634243, -0.0007581452142273761, -0.0017890372481342031, -0.0036504907155413806, -0.002271697934141637], [-0.046459332512507355, -0.08934162699924386, -0.024314632845150026, -0.07926809399458855, -0.021533096877854846, -0.06427048876653971, -0.05795759200423153, -0.04772118411714311, -0.03729708104820508, -0.016580334869570494, -0.10159090462752537, -0.01709484050388366, -0.04291869669999058, -0.026983694353253717, -0.023680184428350244, -0.010038775477223216, -0.06047793903837967, -0.04499274363686893, -0.025515658323673945, -0.04029577326666754]]
# --- 0.04574298858642578 seconds ---
# objopt for global iteration  0  is ready
# b before boundchange:  [3, 3]
# b [3, 3]
# b after boundchange:  [0.13019999999951865, 0.07949999999951954]
# [[5.3277700680549485, 7.780640103355604], [6.3035539523676025, 7.75840523786436], [6.601409489829543, 7.545879747674812], [5.627454051048486, 7.76917206527866], [7.3960877978160084, 7.184896258754236], [6.778358435246158, 7.332353742013111], [5.701661987402619, 7.673890191911587], [6.84786589202274, 7.673515234188576], [5.128230362075682, 7.247457942778371], [7.215872626578103, 7.261122604444598], [6.796503962508839, 7.415470514057023], [6.725830626755194, 7.699432963039638], [6.507215291237996, 7.38315075180047], [6.910625739264857, 7.619636853059834], [6.337548970368638, 7.688282971839404], [5.870715346268444, 7.465270481076791], [7.3691647535860065, 7.357973743919229], [6.96356912409429, 7.281020881815075], [6.85230471016694, 7.429538943399523]]
#  and size of P is 19
# DIVOPT
# parameters for divopt [[5.3277700680549485, 7.780640103355604], [6.3035539523676025, 7.75840523786436], [6.601409489829543, 7.545879747674812], [5.627454051048486, 7.76917206527866], [7.3960877978160084, 7.184896258754236], [6.778358435246158, 7.332353742013111], [5.701661987402619, 7.673890191911587], [6.84786589202274, 7.673515234188576], [5.128230362075682, 7.247457942778371], [7.215872626578103, 7.261122604444598], [6.796503962508839, 7.415470514057023], [6.725830626755194, 7.699432963039638], [6.507215291237996, 7.38315075180047], [6.910625739264857, 7.619636853059834], [6.337548970368638, 7.688282971839404], [5.870715346268444, 7.465270481076791], [7.3691647535860065, 7.357973743919229], [6.96356912409429, 7.281020881815075], [6.85230471016694, 7.429538943399523]] 20 [0.13019999999951865, 0.07949999999951954] 3 10 10
# iteration 0
# diversity 1.2789543026545567
# --- 0.16148781776428223 seconds ---
# Global_iteration:  1 b is  [0.13019999999951865, 0.07949999999951954]
# OBJOPT [[5.128230362075682, 7.247457942778371], [7.215872626578103, 7.261122604444598], [9.108162869333423, 6.555262176618028], [7.451147851346471, 3.9008024989913217], [2.05311447487993, 3.4141728500843618], [8.22603371714565, 1.8664662092642939], (8.865596832014319, 3.7502122170547985), [1.1515057931000277, 7.147754038459203], (2.3984378432925944, 6.209330063057233), (3.0370326347751533, 8.110498700032528), (8.798302201339956, 5.21403958236748), [9.598370221560797, 2.481338781670765], (1.5849914202979978, 9.06654840419765), [1.1987583134440225, 0.6402526356431748], [6.753496405465625, 5.5841435348270565], (0.20919933975082117, 1.5004447879252196), [2.0417675043016583, 1.8361288034683259], (6.57835603322224, 8.551762912576725), (4.285430110431831, 8.38839769436795), (8.483072747989471, 8.343509780510482)]
# iteration 0
# [[-0.00234579338990672, -7.712308342171006e-05, -0.005089074213876908, -0.0038994915672845402, -0.0013536582362178601, -0.004961537116007821, -0.000813997033267493, -0.007021689912884433, -4.5823663846339216e-06, -0.002656749041886462, -0.0033313713675368287, -0.0034717196987872575, -0.00047153332723947684, -0.0006953253120886518, -0.004828703544746256, -0.006252200564075652, -0.0011278647438956264, -0.002196071979470142, -0.006272411693379251, -0.0006912125068094542], [-0.03198812763939862, -0.06568452357185844, -0.008475967672239688, -0.01736215126483198, -0.044821269938658134, -0.008981523331997693, -0.05402777904698623, -0.0010609164633996052, -0.07702816458021494, -0.028683133990001174, -0.02153291654410205, -0.02122686524637256, -0.05840209828497135, -0.05478399256853671, -0.00974611030896425, -0.0029207917939232312, -0.048535471134115035, -0.03395997045236346, -0.0027353987509769803, -0.055744397043869284]]
# --- 0.06285309791564941 seconds ---
# objopt for global iteration  1  is ready
# b before boundchange:  [0.13019999999951865, 0.07949999999951954]
# b [0.13019999999951865, 0.07949999999951954]
# b after boundchange:  [0.11063093999959836, 0.06755114999959311]
# [[3.143602578584062, 8.226334459775082], [3.4684016878088695, 8.085577713816056], [3.563905056224766, 7.984611606926792], [3.0752150318204556, 7.91444844743283], [2.7401588643457844, 8.200848322050465], [4.418167776834542, 7.866530129537181], [3.7429564865056877, 7.931543634900468], [2.5704775524823993, 8.245797885824249], [3.2726382569019647, 7.974059686940599], [3.887946324808379, 8.083304787114272], [4.9194750626390675, 7.996733792512289], [4.168608090724083, 8.159893393725758], [2.4955216724077545, 8.173290369145422], [3.5180850296086006, 7.998899641990506], [3.937990233615704, 7.921468064880423], [2.499559925917909, 8.196487789626872], [2.802568875994914, 8.172714678391849], [4.166138313574336, 8.049046923568248], [4.3133171567313795, 7.99923562324679]]
#  and size of P is 19
# DIVOPT
# parameters for divopt [[3.143602578584062, 8.226334459775082], [3.4684016878088695, 8.085577713816056], [3.563905056224766, 7.984611606926792], [3.0752150318204556, 7.91444844743283], [2.7401588643457844, 8.200848322050465], [4.418167776834542, 7.866530129537181], [3.7429564865056877, 7.931543634900468], [2.5704775524823993, 8.245797885824249], [3.2726382569019647, 7.974059686940599], [3.887946324808379, 8.083304787114272], [4.9194750626390675, 7.996733792512289], [4.168608090724083, 8.159893393725758], [2.4955216724077545, 8.173290369145422], [3.5180850296086006, 7.998899641990506], [3.937990233615704, 7.921468064880423], [2.499559925917909, 8.196487789626872], [2.802568875994914, 8.172714678391849], [4.166138313574336, 8.049046923568248], [4.3133171567313795, 7.99923562324679]] 20 [0.11063093999959836, 0.06755114999959311] 3 10 10
# iteration 0
# diversity 1.242386667816993
# --- 0.3061399459838867 seconds ---
# Global_iteration:  2 b is  [0.11063093999959836, 0.06755114999959311]
# OBJOPT [[4.418167776834542, 7.866530129537181], [2.802568875994914, 8.172714678391849], [6.725501973653493, 6.500404943367873], [7.066875952084566, 7.749477726235025], (5.777365932653039, 7.625372416812155), [8.534519643963087, 6.264916768443729], [8.666199915281176, 8.024261824493239], [2.244316722471773, 6.820944950898438], [7.717515145755131, 4.149650435840967], (1.398793220657865, 9.025782061321877), (0.4224965234313738, 0.8414086802977812), [9.349570060827737, 4.78650582518779], [1.545185154458001, 3.395275218364315], (9.322231565110163, 3.421797361508304), [8.741291733780972, 1.9638387549100873], (2.4639182048374257, 2.380351893551371), [0.8158171981813083, 2.2012842136535635], [7.524636318434906, 2.2153824542517766], (2.0958894643763797, 1.13979383360345), [1.1383756976630528, 7.672164693835266]]
# iteration 0
# [[-0.0006441307412967524, -0.0022686508523923387, -0.0020688737868087954, -0.003996741813767731, -0.00017304777654888527, -0.004772092007281402, -0.0028785572535046226, -0.0025843406477365927, -3.82410143929278e-05, -0.00016239154884170774, -0.0005053659033659567, -2.196609406371307e-05, -0.006046228523257417, -0.0012074149746445545, -0.0054696844370737754, -0.00026276372535719396, -0.007052876588163436, -0.004828703544746256, -0.002900890334204024, -0.003155432459076201], [-0.05614693779298915, -0.03348253843765029, -0.04062076680688173, -0.01588584873278665, -0.06388949537071849, -0.009998588037261665, -0.02813659838093685, -0.029385728203016635, -0.0668098499659422, -0.063904462511464, -0.05784378178115029, -0.06684724126937207, -0.0040221633609377905, -0.04706170307464477, -0.006408269540008021, -0.06249771643386556, -0.0006977374610681817, -0.00974611030896425, -0.026764732846062265, -0.02339954229445885]]
# --- 0.051664113998413086 seconds ---
# objopt for global iteration  2  is ready
# b before boundchange:  [0.11063093999959836, 0.06755114999959311]
# b [0.11063093999959836, 0.06755114999959311]
# b after boundchange:  [0.10232255640562375, 0.06249156886461929]
# [[3.940037416645811, 8.19246611918377], [4.197422439077224, 8.12578256117236], [4.317982161439314, 8.04402780220334], [4.127190271689316, 8.111882540264185], [3.337249402564483, 8.129139283150868], [3.983927883581897, 7.757201263108086], [3.101210119435822, 8.004488383764583], [2.98225862936642, 8.173262121746005], [3.2019081681051547, 7.979313166307721], [2.870581884647077, 8.009258407044543], [4.17398117540685, 7.94273611105928], [2.394118731079477, 8.077652798015887], [3.2236463023721313, 8.158649979580632], [3.296799972344991, 8.235033501918965], [2.802568875994914, 8.172714678391849], [2.3442747528851116, 8.144221627661356], [4.487395156716995, 7.859756219401742], [2.6612643507497955, 8.01257306164638], [3.901175639765593, 7.971467939244348]]
#  and size of P is 19
# DIVOPT
# parameters for divopt [[3.940037416645811, 8.19246611918377], [4.197422439077224, 8.12578256117236], [4.317982161439314, 8.04402780220334], [4.127190271689316, 8.111882540264185], [3.337249402564483, 8.129139283150868], [3.983927883581897, 7.757201263108086], [3.101210119435822, 8.004488383764583], [2.98225862936642, 8.173262121746005], [3.2019081681051547, 7.979313166307721], [2.870581884647077, 8.009258407044543], [4.17398117540685, 7.94273611105928], [2.394118731079477, 8.077652798015887], [3.2236463023721313, 8.158649979580632], [3.296799972344991, 8.235033501918965], [2.802568875994914, 8.172714678391849], [2.3442747528851116, 8.144221627661356], [4.487395156716995, 7.859756219401742], [2.6612643507497955, 8.01257306164638], [3.901175639765593, 7.971467939244348]] 20 [0.10232255640562375, 0.06249156886461929] 3 10 10
# iteration 0
# diversity 1.157561931436156
# --- 0.2469501495361328 seconds ---
# Global_iteration:  3 b is  [0.10232255640562375, 0.06249156886461929]
# OBJOPT [[4.487395156716995, 7.859756219401742], [8.179209136315425, 2.2661585788375564], (1.917301243625798, 2.7648293579765504), (2.816860159230127, 7.196613884785195), (9.017559231444647, 5.247848458708992), (0.9700887016411421, 0.8306868375343335), (6.677990401913858, 6.691239728367616), [8.436348445274977, 7.734655317800358], (1.3175694982652417, 8.16433218953695), (3.4265141327060324, 8.867512081584678), (7.422441488243608, 4.449227327547284), [6.455712960073487, 8.293320182688113], [0.6439669964498242, 2.4954306589759065], [9.100408601256104, 3.601003006543898], [1.643148949747272, 6.829140619986515], (7.329761448968236, 3.255565008272143), [1.9508397191434173, 1.6077533899562315], (9.485082215855034, 2.4362361177420793), [1.9971818632037461, 9.187881621839619], (8.583449206932123, 6.511297450495324)]
# iteration 0
# [[-0.0012411711007155365, -0.006409978440717023, -0.0011378871120964838, -0.0020976216321455412, -0.004052525586274624, -0.006447557250089656, -0.003663629163237501, -0.008181079237866555, -0.0030281384686982526, -0.003261152326523843, -0.0044669733470112365, -0.004516948951893098, -0.00035202983877829537, -0.007340586539165492, -0.0029103774321094437, -0.00026276372535719396, -0.000866915927294957, -0.0032290910308250126, -0.007586043661965334, -0.004107452504250621], [-0.046937268785746306, -0.00652373826679896, -0.04989169787639093, -0.04190260314688888, -0.021481817788635314, -0.005661178291570127, -0.025799957435257224, -0.001020922515111072, -0.030919375052095164, -0.02856519183253827, -0.017895185609286154, -0.01752087500599895, -0.060698491393537043, -0.0033547745420595314, -0.032388342811109236, -0.06249771643386556, -0.05213844999416098, -0.028924399921440188, -0.0018402892261451711, -0.021130152378497122]]
# objopt final generation contains solutions >= b for iteration  1
# --- 0.07170701026916504 seconds ---
# objopt for global iteration  3  is ready
# b before boundchange:  [0.10232255640562375, 0.06249156886461929]
# b [0.10232255640562375, 0.06249156886461929]
# b after boundchange:  [0.09937566678114156, 0.06044809456274622]
# [[7.393992467150171, 7.268724455808481], [3.8859214117866117, 7.920262176900376], [7.392726242083081, 7.1369956936305945], [7.490254007079565, 7.550581056486531], [4.1571181198893274, 8.24208184616514], [7.154198170141601, 7.34306846061366], [7.009183638286123, 7.204552451605886], [6.685120829664334, 7.786138259942772], [7.73551949495028, 7.216845501215717], [7.501972008428022, 7.554334713886526], [4.376875703115192, 8.107818762059063], [6.965026067454735, 7.512511596845806], [7.024117942039356, 7.344394711429853], [4.155459061337818, 7.978269962066388], [3.7222118813456695, 8.347725608869089], [7.754277339333375, 7.0574427362475545], [6.796967175778404, 7.541356930670506], [4.068916798940633, 7.960992821296669], [6.7059828346467745, 7.433048054517612]]
#  and size of P is 19
# DIVOPT
# parameters for divopt [[7.393992467150171, 7.268724455808481], [3.8859214117866117, 7.920262176900376], [7.392726242083081, 7.1369956936305945], [7.490254007079565, 7.550581056486531], [4.1571181198893274, 8.24208184616514], [7.154198170141601, 7.34306846061366], [7.009183638286123, 7.204552451605886], [6.685120829664334, 7.786138259942772], [7.73551949495028, 7.216845501215717], [7.501972008428022, 7.554334713886526], [4.376875703115192, 8.107818762059063], [6.965026067454735, 7.512511596845806], [7.024117942039356, 7.344394711429853], [4.155459061337818, 7.978269962066388], [3.7222118813456695, 8.347725608869089], [7.754277339333375, 7.0574427362475545], [6.796967175778404, 7.541356930670506], [4.068916798940633, 7.960992821296669], [6.7059828346467745, 7.433048054517612]] 20 [0.09937566678114156, 0.06044809456274622] 3 10 10
# iteration 0
# diversity 1.1356652948745132
# --- 0.1531050205230713 seconds ---
# Global_iteration:  4 b is  [0.09937566678114156, 0.06044809456274622]
# OBJOPT [[4.376875703115192, 8.107818762059063], (8.133140901493713, 5.599989299541091), (6.620937623724536, 7.771347416227595), [8.64521872256547, 7.072246837554982], [6.777210055805675, 6.227757534738542], (2.0734491231608496, 8.549365165198573), (3.0533218775478694, 7.944368026359481), [2.3456039411927616, 2.685501898166563], [2.5570746805044644, 6.8015914043496775], (9.023653329187434, 2.1616457053125293), [0.5728672435471882, 2.1328387250902754], (1.2739624613351044, 7.438921815048014), (9.041179237894964, 3.7576183045652756), [7.983698846659743, 4.437868287723193], [9.256411882597078, 5.026627562249525], [7.655082053279904, 2.475457143520994], [0.8626240195174706, 0.906627957926849], (1.9199346540423805, 1.6069029682322393), (7.267340481132271, 3.5428802719995263), [8.082420966096272, 8.170181741525653]]
# iteration 0
# [[-0.005733320474616791, -0.004478745640711108, -0.002371569777383373, -0.002416497359883646, -0.006113094249739187, -0.001702699177269438, -0.006085638375685209, -0.0032097544446297896, -0.0014257854943465725, -0.0018354064125394567, -0.00393723811664202, -0.006736780521072588, -0.0025859451481107477, -0.0009907800217438313, -0.0048509165732485105, -0.003763210885585291, -0.004800257187760585, -0.002513628550055074, -0.0036512525869876605, -0.006422992321979932], [-0.0073221414950892716, -0.012332292302043068, -0.03241079709741345, -0.03182293219593781, -0.003191228061088933, -0.04262167735346743, -0.0032997078088316096, -0.025624211842769324, -0.04423637978127695, -0.04130955758492481, -0.01650787833642427, -0.0014799040322802887, -0.030786655862821376, -0.05036594013034021, -0.009482331109711575, -0.01968431017854467, -0.010234881930758697, -0.03114616752335655, -0.02119191895022957, -0.002652329497343855]]
# --- 0.03073287010192871 seconds ---
# objopt for global iteration  4  is ready
# b before boundchange:  [0.09937566678114156, 0.06044809456274622]
# b [0.09937566678114156, 0.06044809456274622]
# b after boundchange:  [0.051267906492409275, 0.031142858318717805]
# [[3.3659779354040067, 7.897880119356741], [2.6055646856478267, 7.8571166559930345], [2.136725246693415, 7.985000578451156], [2.7231869832871074, 8.287070572682543], [2.880847105254818, 8.081964785613211], [3.1281516313566318, 8.241262408594666], [2.422543494319441, 8.275697424603244], [2.5539388645446315, 8.401243552458613], [3.207803391575877, 7.96229780648987], [2.9160423248309124, 8.323638809700528], [3.050460228593124, 7.865306317194663], [2.465637689283568, 8.013220799724555], [3.414557301554208, 8.237559627980763], [2.8090510759580485, 8.216645670974197], [3.0601002898125658, 7.862882068025808], [2.797520358039941, 8.08748952137096], [3.391912580700058, 7.875784062826368], [2.4044691253863713, 8.064254012396294], [3.0157525062024093, 8.201194419755595]]
#  and size of P is 19
# DIVOPT
# parameters for divopt [[3.3659779354040067, 7.897880119356741], [2.6055646856478267, 7.8571166559930345], [2.136725246693415, 7.985000578451156], [2.7231869832871074, 8.287070572682543], [2.880847105254818, 8.081964785613211], [3.1281516313566318, 8.241262408594666], [2.422543494319441, 8.275697424603244], [2.5539388645446315, 8.401243552458613], [3.207803391575877, 7.96229780648987], [2.9160423248309124, 8.323638809700528], [3.050460228593124, 7.865306317194663], [2.465637689283568, 8.013220799724555], [3.414557301554208, 8.237559627980763], [2.8090510759580485, 8.216645670974197], [3.0601002898125658, 7.862882068025808], [2.797520358039941, 8.08748952137096], [3.391912580700058, 7.875784062826368], [2.4044691253863713, 8.064254012396294], [3.0157525062024093, 8.201194419755595]] 20 [0.051267906492409275, 0.031142858318717805] 3 10 10
# iteration 0
# diversity 0.79734240753917
# --- 0.20771002769470215 seconds ---
# Global_iteration:  5 b is  [0.051267906492409275, 0.031142858318717805]
# OBJOPT [[3.391912580700058, 7.875784062826368], [2.4044691253863713, 8.064254012396294], [8.460577991852098, 7.2911348496798905], [1.6353658598120484, 8.523474993156578], [7.20744302679909, 7.954594774980753], (7.7512903058603975, 6.116060819053556), [1.9816056481604676, 7.166449541108106], (8.819492388941617, 5.840558554331042), [0.8051189670061181, 1.3876745656041196], [1.5072645817698647, 2.383564734278142], (8.641547674498023, 2.231578142966825), (8.959053795529147, 4.982942224909037), [2.92589746406016, 8.667468238429013], [8.93844570366772, 3.676367187451641], [7.765177430671778, 3.6813430070412414], [8.152327354319503, 5.345641118752484], [1.8014201488536103, 1.3915598493915553], [6.926702840843255, 7.143288821305891], (8.092902478611022, 8.01916848745889), [7.899592031116231, 2.724134797096656]]
# iteration 0
# [[-0.007233975264284221, -0.003197073556586369, -0.00505721220929714, -0.002755114787225264, -0.0075849670916224195, -0.006217746830769712, -0.004516583798135559, -0.002581544116310668, -0.006036781880435931, -0.004289408866219468, -0.006105885984693031, -0.002605557030635635, -0.007790284506147996, -0.004908856697833217, -0.0041111154442783834, -0.006736780521072588, -0.007109512934086645, -0.0024692212405992447, -0.002943235482640313, -0.004430260326955669], [-0.0006944813467557295, -0.022859184121303902, -0.008510271302082003, -0.02742610367522867, -0.00020318627708430903, -0.0028670376280466553, -0.011894655901503523, -0.030345408175231316, -0.003987236673945096, -0.013340299130893494, -0.0033144210933218616, -0.029507197179806096, -5.24507038894214e-05, -0.009123191459370657, -0.014703859160020672, -0.0014799040322802887, -0.0009348494068756572, -0.030650102738468826, -0.02551113461452402, -0.012386830585220289]]
# --- 0.038057804107666016 seconds ---
# objopt for global iteration  5  is ready
# b before boundchange:  [0.051267906492409275, 0.031142858318717805]
# b [0.051267906492409275, 0.031142858318717805]
# b after boundchange:  [0.04886344167791494, 0.029504743971153886]
# [[2.6546088877907885, 8.306829821100708], [2.310394961284423, 8.044964531945253], [3.344333998199437, 8.087739075288221], [3.2719936176695117, 8.122170003573666], [3.0675110716896183, 7.929759424037266], [2.2715884326082287, 8.0419199694893], [2.777623927340747, 8.055791345590572], [2.8417812615031055, 8.088141055546835], [3.1377700116579375, 8.124911083558468], [2.8951816403889694, 8.059588916528977], [3.2844139535889454, 8.145809724694963], [2.3336330083638814, 8.219013593576065], [2.4044691253863713, 8.064254012396294], [2.972411421348408, 8.0888411879609], [2.2088918856217705, 8.09704960940613], [2.784406016926112, 8.087125017681192], [3.3858262080446124, 7.965343097073877], [2.5289908974888355, 8.171991528500875], [2.928911188234684, 8.125938935814757]]
#  and size of P is 19
# DIVOPT
# parameters for divopt [[2.6546088877907885, 8.306829821100708], [2.310394961284423, 8.044964531945253], [3.344333998199437, 8.087739075288221], [3.2719936176695117, 8.122170003573666], [3.0675110716896183, 7.929759424037266], [2.2715884326082287, 8.0419199694893], [2.777623927340747, 8.055791345590572], [2.8417812615031055, 8.088141055546835], [3.1377700116579375, 8.124911083558468], [2.8951816403889694, 8.059588916528977], [3.2844139535889454, 8.145809724694963], [2.3336330083638814, 8.219013593576065], [2.4044691253863713, 8.064254012396294], [2.972411421348408, 8.0888411879609], [2.2088918856217705, 8.09704960940613], [2.784406016926112, 8.087125017681192], [3.3858262080446124, 7.965343097073877], [2.5289908974888355, 8.171991528500875], [2.928911188234684, 8.125938935814757]] 20 [0.04886344167791494, 0.029504743971153886] 3 10 10
# iteration 0
# diversity 0.8148662112048998
# --- 0.2640848159790039 seconds ---
# Global_iteration:  6 b is  [0.04886344167791494, 0.029504743971153886]
# OBJOPT [[3.344333998199437, 8.087739075288221], (7.32726599131893, 7.485632725441189), (8.041841637638537, 7.982705434066023), (1.4788514193692812, 7.889576660270993), (7.387752258523605, 6.592714635251195), [7.701827958723425, 5.62643209310553], (9.106176744294398, 3.8697933123912573), (8.835605817951661, 5.3884597622931665), [1.812899105962988, 2.1374870664060284], [8.805890701049284, 6.757234014862362], [7.894494116742144, 4.563541932017751], (1.291534485301524, 1.0992818243809008), (0.7503446525019488, 2.0669983797163365), (7.982747585112663, 3.393056066570419), [8.767283364022347, 2.137672807353258], (2.6435493072392138, 8.710774214302347), (2.27459977483449, 7.49962633682415), (1.8235388531090315, 8.640790819578996), (8.018781293453717, 2.4597777475791127), (9.151929476249183, 3.039485615966395)]
# iteration 0
# [[-0.003769654403643024, -0.005799791073945376, -0.0028325523501305824, -0.005050676697608424, -0.005986442399737647, -0.006523043978087144, -0.005629055525614538, -0.004307950447616993, -0.0037478180992926323, -0.004181294621580097, -0.002741229909518262, -0.003816468609392992, -0.007206978256893912, -0.007661090907417851, -0.006057320969184537, -0.0033823591720114547, -0.005151528157779975, -0.004184728926782799, -0.0030223691554422216, -0.005413225389496203], [-0.01761228549953297, -0.0044336121909539054, -0.026528370138041286, -0.008387768958403907, -0.0036889603505135976, -0.0030161348663677065, -0.006027774967607544, -0.01414652710582573, -0.017836708562968148, -0.014511538328902505, -0.027511265319083086, -0.017525113299246668, -0.0005052141282459897, -0.0001300548776057405, -0.003471208585655127, -0.021969024723226246, -0.00782898043784458, -0.014325597196247741, -0.024642755788393242, -0.006785526156338069]]
# --- 0.03236794471740723 seconds ---
# objopt for global iteration  6  is ready
# b before boundchange:  [0.04886344167791494, 0.029504743971153886]
# b [0.04886344167791494, 0.029504743971153886]
# b after boundchange:  [0.04073256498270565, 0.02464236216470523]
# [[2.843827423080332, 8.159700931353575], [3.05844021373458, 8.048329687319606], [2.5572834298947025, 8.140790737641991], [2.3948705977689535, 7.916199525880181], [2.378779484223953, 8.087996340860721], [3.0246821670153836, 8.219758505365984], [2.7953937392750516, 7.989395609738871], [3.2360304638845623, 8.142884733617223], [3.141034447175041, 8.100425495303845], [2.2541104542189307, 8.155919892593603], [2.6733660817618508, 8.001389690430193], [3.2615037660546338, 8.13603714859643], [2.954339000033779, 8.175488254820705], [2.73030218800388, 8.050684685603366], [3.1608808706308733, 7.935724344166109], [2.538837476072631, 8.079708539769431], [2.232132425960763, 8.176449775201679], [2.3154184205180295, 8.092556532853452], [3.046421588624354, 8.200201038804204]]
#  and size of P is 19
# DIVOPT
# parameters for divopt [[2.843827423080332, 8.159700931353575], [3.05844021373458, 8.048329687319606], [2.5572834298947025, 8.140790737641991], [2.3948705977689535, 7.916199525880181], [2.378779484223953, 8.087996340860721], [3.0246821670153836, 8.219758505365984], [2.7953937392750516, 7.989395609738871], [3.2360304638845623, 8.142884733617223], [3.141034447175041, 8.100425495303845], [2.2541104542189307, 8.155919892593603], [2.6733660817618508, 8.001389690430193], [3.2615037660546338, 8.13603714859643], [2.954339000033779, 8.175488254820705], [2.73030218800388, 8.050684685603366], [3.1608808706308733, 7.935724344166109], [2.538837476072631, 8.079708539769431], [2.232132425960763, 8.176449775201679], [2.3154184205180295, 8.092556532853452], [3.046421588624354, 8.200201038804204]] 20 [0.04073256498270565, 0.02464236216470523] 3 10 10
# iteration 0
# diversity 0.7478306032367231
# --- 0.23695611953735352 seconds ---
# Global_iteration:  7 b is  [0.04073256498270565, 0.02464236216470523]
# OBJOPT [[3.2615037660546338, 8.13603714859643], [8.632780381910612, 6.9717135067669735], [8.79677051614201, 5.122114760313485], (1.2547470275458539, 2.3105638607815493), [8.258925857433958, 2.3272230567976733], (6.966802907741503, 7.395812507467323), [8.394643663283507, 6.255313218039037], [8.077125590355275, 4.792377477227886], (9.086356601624221, 3.627784578591818), [7.587091732933427, 5.983566835704844], [7.862219333068116, 7.758027231087871], [0.8810831223611466, 1.0661409904273658], [1.601337029298726, 8.54380247384875], (8.999562955271006, 2.4306991431409237), (2.563593919373768, 8.720523178663678), [8.079827825104328, 3.1682488091198993], (1.7943909784929204, 1.662666233019059), [2.013360105254749, 7.753216778598125], (7.582805885987247, 6.804583014056017), [8.42802235867787, 3.985449313933637]]
# iteration 0
# [[-0.005557614896026191, -0.003167709070434244, -0.004747805155897398, -0.004298305231056216, -0.004299568571656189, -0.004262115461373948, -0.005454752036674576, -0.004746569625610442, -0.007105891969194538, -0.004325836179325023, -0.007779503674694771, -0.0030223691554422216, -0.0037495859881324857, -0.005936742659036506, -0.00620172526651533, -0.006999556474425433, -0.005112535574864513, -0.0035628138379296724, -0.007058841289315149, -0.004874841111972909], [-0.005885579680276061, -0.023095904390126293, -0.010519578955518576, -0.013319238577670358, -0.013265361626205287, -0.015646273749145935, -0.006438470118339551, -0.011208147385245695, -0.0006414580648214256, -0.013117346761801594, -7.261976215377275e-05, -0.024642755788393242, -0.01772357478978145, -0.003972701113997825, -0.002933592580727823, -0.0009373925397208612, -0.007909954237489287, -0.020536476143645073, -0.0007081332914652235, -0.009376762003086592]]
# objopt final generation contains solutions >= b for iteration  1
# --- 0.027598142623901367 seconds ---
# objopt for global iteration  7  is ready
# b before boundchange:  [0.04073256498270565, 0.02464236216470523]
# b [0.04073256498270565, 0.02464236216470523]
# b after boundchange:  [0.03444345694938088, 0.020817867556742815]
# [[2.6425405844370955, 8.210764908386107], [2.345855842237162, 8.17719220218037], [2.9958316212841942, 8.209339391500478], [2.322312333358845, 8.156020711641954], [2.6492999470582568, 8.040399258514714], [2.834204282120302, 8.161504203786345], [3.138235631193812, 8.21426260911841], [2.8420126432144697, 8.146389417236737], [2.7920957647640354, 8.154485223437124], [2.8582889029189844, 8.111222603959476], [3.041812014385614, 8.190176418799052], [2.343152001089421, 8.155802071304953], [3.112458255314688, 8.264114998737766], [2.738908322322044, 8.141525150454763], [2.3543325087181812, 8.065178981144184], [2.5096736626467346, 8.161429995818752], [2.5634568218403135, 8.17323103343255], [3.0636152272514416, 8.132016038434593], [2.2108238358442165, 8.090787252043897]]
#  and size of P is 19
# DIVOPT
# parameters for divopt [[2.6425405844370955, 8.210764908386107], [2.345855842237162, 8.17719220218037], [2.9958316212841942, 8.209339391500478], [2.322312333358845, 8.156020711641954], [2.6492999470582568, 8.040399258514714], [2.834204282120302, 8.161504203786345], [3.138235631193812, 8.21426260911841], [2.8420126432144697, 8.146389417236737], [2.7920957647640354, 8.154485223437124], [2.8582889029189844, 8.111222603959476], [3.041812014385614, 8.190176418799052], [2.343152001089421, 8.155802071304953], [3.112458255314688, 8.264114998737766], [2.738908322322044, 8.141525150454763], [2.3543325087181812, 8.065178981144184], [2.5096736626467346, 8.161429995818752], [2.5634568218403135, 8.17323103343255], [3.0636152272514416, 8.132016038434593], [2.2108238358442165, 8.090787252043897]] 20 [0.03444345694938088, 0.020817867556742815] 3 10 10
# iteration 0
# diversity 0.7435489015447824
# --- 0.2594878673553467 seconds ---
# Global_iteration:  8 b is  [0.03444345694938088, 0.020817867556742815]
# OBJOPT [[3.138235631193812, 8.21426260911841], (7.615169063544078, 6.247898177163551), [8.063310759439082, 5.178629327256492], [8.121659774715823, 3.543292788898505], [9.008416030045769, 3.93474438064551], (2.7361882802974398, 7.5585145497412745), [8.683892753677455, 5.616851216791028], (7.418739947676832, 7.166209294727787), [0.7721874023999766, 1.319893548134461], [1.3814000818046823, 2.4335188074215885], (1.9104468278872893, 7.510664835297542), [2.4294053205191, 8.737265090904032], (8.208258350504806, 2.7021365623091285), [9.160982739066093, 3.0570933990234113], (1.5371761660837375, 1.5883007555625783), (1.7797308254662123, 8.242633615847303), (8.485098105296379, 7.376330591142126), (8.862201438427324, 2.2729945897112365), [8.772271606868795, 4.809346460104191], (8.61194760113785, 6.378727970318089)]
# iteration 0
# [[-0.005194149300762446, -0.00509051018195441, -0.004498889307579097, -0.004936939276824744, -0.005495579922267005, -0.004646539750550477, -0.003564502827074828, -0.00588122922895707, -0.006711067272860502, -0.0050260593458176525, -0.006379625119327794, -0.004358821634995335, -0.006007409996094906, -0.004813899231978912, -0.006381141178721455, -0.003593903882588109, -0.007606754687768613, -0.014448001294537606, -0.007371109306687331, -0.00631447961568821], [-0.0076649018397796235, -0.00801908457143879, -0.011803618052126685, -0.009628362718087478, -0.006448759042849171, -0.01125741361608624, -0.01960240938143948, -0.005447994372881544, -0.0017381994155594251, -0.008710834361029414, -0.0031593696915693586, -0.012817495402758797, -0.003875203872257796, -0.009716649446055076, -0.0023026086342130773, -0.019299065963419477, -8.766849410931491e-05, -3.607892065561788e-05, -0.0010183710067578693, -0.003175281628187638]]
# --- 0.03199577331542969 seconds ---
# objopt for global iteration  8  is ready
# b before boundchange:  [0.03444345694938088, 0.020817867556742815]
# b [0.03444345694938088, 0.020817867556742815]
# b after boundchange:  [0.02806452872235576, 0.017174740734310696]
# [[2.202234988952966, 8.108181650419835], [2.720932361520956, 8.0377654626671], [3.03829707268856, 8.190679106380127], [2.429899034574736, 8.19759702161228], [2.6845394041016646, 8.067942957973347], [2.4811952239655524, 8.217238457763452], [2.3067812384906845, 8.11682642428757], [2.9601473499977473, 8.122387668230246], [2.786589720750984, 8.027822061888644], [2.487137167355088, 8.251184401920403], [2.2419654302803576, 8.109965887872677], [2.4739079235464407, 8.143197792412604], [2.805940011763828, 8.13768519995028], [2.5489981648120077, 8.037141669339098], [2.878941465310517, 8.106085308604088], [2.743784101209636, 8.130945734692695], [2.912220884529368, 8.094239571452151], [2.655734673236196, 7.993793805673123], [2.8444166101608417, 8.001465732957021]]
#  and size of P is 19
# DIVOPT
# parameters for divopt [[2.202234988952966, 8.108181650419835], [2.720932361520956, 8.0377654626671], [3.03829707268856, 8.190679106380127], [2.429899034574736, 8.19759702161228], [2.6845394041016646, 8.067942957973347], [2.4811952239655524, 8.217238457763452], [2.3067812384906845, 8.11682642428757], [2.9601473499977473, 8.122387668230246], [2.786589720750984, 8.027822061888644], [2.487137167355088, 8.251184401920403], [2.2419654302803576, 8.109965887872677], [2.4739079235464407, 8.143197792412604], [2.805940011763828, 8.13768519995028], [2.5489981648120077, 8.037141669339098], [2.878941465310517, 8.106085308604088], [2.743784101209636, 8.130945734692695], [2.912220884529368, 8.094239571452151], [2.655734673236196, 7.993793805673123], [2.8444166101608417, 8.001465732957021]] 20 [0.02806452872235576, 0.017174740734310696] 3 10 10
# iteration 0
# diversity 0.6275858476636055
# --- 0.22742319107055664 seconds ---
# Global_iteration:  9 b is  [0.02806452872235576, 0.017174740734310696]
# OBJOPT [[3.03829707268856, 8.190679106380127], (8.794618719897525, 4.028710140515676), [8.29179440922486, 7.514141686498371], (1.6507585224190264, 7.776494185413583), (2.3064029760564537, 8.504668714629451), [8.830358618170246, 2.9549471233437643], (0.9568490080037781, 1.2123218476843611), [7.908388055658443, 6.4582350102423325], [8.496682593081497, 5.994181276230623], (8.311048612864479, 3.4993923719269167), (8.257921346424794, 2.5105210594543284), (7.294736480401863, 7.3913097550860645), [7.996703293635718, 5.54016162350872], (1.7935511774398334, 1.8038368998406857), (1.260543250758551, 2.3559481870881775), (8.507426660446116, 6.64536263022849), [2.6575463309717753, 7.615727018754541], (8.163925270742663, 4.109912171106661), (8.500525744815004, 5.154651298669403), (7.732176943382235, 7.867724044357601)]
# iteration 0
# [[-0.005955307015889379, -0.0043548736040253866, -0.006527321292893663, -0.00738422896627457, -0.00781559834328486, -0.004020186623750109, -0.004623704866291609, -0.0057881416874909115, -0.004551608073302468, -0.007924435049762089, -0.004246740402137529, -0.006434063309613565, -0.0059083540911503895, -0.00665415893730528, -0.0070109407003722465, -0.004723045348141838, -0.007037248694294449, -0.005059716915187076, -0.00537081212329103, -0.004620143613804756], [-0.004179358859966517, -0.012839391352047615, -0.0019028987917987159, -0.000822173389462678, -0.0007012977855692594, -0.015419067326050596, -0.011263132672159993, -0.004490668024906983, -0.011965272559196018, -7.451326864366682e-05, -0.013994963118646647, -0.0021633049410360616, -0.004210567589957153, -0.0015544541315873964, -0.001050140961175849, -0.010448216399037159, -0.0008327761882916321, -0.00861967838910464, -0.006489286073500671, -0.011897611218495583]]
# --- 0.03318190574645996 seconds ---
# objopt for global iteration  9  is ready
# b before boundchange:  [0.02806452872235576, 0.017174740734310696]
# b [0.02806452872235576, 0.017174740734310696]
# b after boundchange:  [0.022836107021377727, 0.01399397875031539]
# [[2.6947996706342168, 8.089166141490965], [2.559650226731959, 8.218614150859716], [2.8378526613220587, 8.091785607564002], [2.3288063408391944, 8.151416198748176], [2.9342392754371542, 8.122302361207135], [2.850548066644719, 8.258394046512928], [2.7319003579182266, 8.01539009960222], [2.7506185483144314, 8.010333205245889], [2.6824987328393908, 8.095674554712554], [2.3472186870579685, 8.073635485508891], [2.8267431472230813, 8.04635721169845], [2.3521818981712044, 8.211799595249374], [2.4204343510378963, 8.153298465443056], [2.5692893855601837, 8.045561713197712], [2.4634544534715004, 8.095905055371032], [2.939237907438724, 8.012298572879649], [2.18496269123088, 8.173311760616516], [2.866550194332553, 8.221852173542011], [2.594144292046817, 8.13403146042411]]
#  and size of P is 19
# DIVOPT
# parameters for divopt [[2.6947996706342168, 8.089166141490965], [2.559650226731959, 8.218614150859716], [2.8378526613220587, 8.091785607564002], [2.3288063408391944, 8.151416198748176], [2.9342392754371542, 8.122302361207135], [2.850548066644719, 8.258394046512928], [2.7319003579182266, 8.01539009960222], [2.7506185483144314, 8.010333205245889], [2.6824987328393908, 8.095674554712554], [2.3472186870579685, 8.073635485508891], [2.8267431472230813, 8.04635721169845], [2.3521818981712044, 8.211799595249374], [2.4204343510378963, 8.153298465443056], [2.5692893855601837, 8.045561713197712], [2.4634544534715004, 8.095905055371032], [2.939237907438724, 8.012298572879649], [2.18496269123088, 8.173311760616516], [2.866550194332553, 8.221852173542011], [2.594144292046817, 8.13403146042411]] 20 [0.022836107021377727, 0.01399397875031539] 3 10 10
# iteration 0
# diversity 0.5821339746694012
# --- 0.26871609687805176 seconds ---
# Global_iteration:  10 b is  [0.022836107021377727, 0.01399397875031539]
# OBJOPT [[2.939237907438724, 8.012298572879649], [8.357007051692094, 4.950739175561849], [2.3785202548407285, 8.274814151864783], [0.8614012020672004, 1.8991604776430142], [7.782845309301607, 6.300687145548221], (9.005318388245058, 2.8503710866598393), (1.73472540186512, 8.175184918478477), [8.607530017884212, 3.7197402936651516], (8.086293622632986, 7.377860690173477), (7.336950941064462, 7.262658010762075), [8.30085324840972, 2.6440946857148457], (8.607322672300041, 6.279456507652039), (1.4839315946799878, 2.2798954625283425), [7.685619352900151, 7.800164010120708], (8.655680921064558, 4.346939447499474), (8.480448399376407, 5.6228949381971765), [8.131180566418307, 4.068888861957649], [0.9991566080129279, 1.2005969713379376], [2.2750360305939687, 7.642385086535518], (8.04571235388629, 3.4275382689714853)]
# iteration 0
# [[-0.006003188376442476, -0.004394073969365083, -0.004675802996751414, -0.005046070576309696, -0.004904258224256999, -0.007583386260167212, -0.006860788280752317, -0.0075176648982823975, -0.00526538841119299, -0.007175390342700125, -0.004322538249457128, -0.005097348518387774, -0.007245350987452084, -0.00571062540944267, -0.004246740402137529, -0.006192085668393345, -0.006473105930639875, -0.0045256404044104566, -0.004936042529513732, -0.0074998358252414766], [-0.004183303775743992, -0.012800951447830512, -0.01090074013168615, -0.008377856275252022, -0.009716097412236984, -0.0001142405911372687, -0.0010695428932079797, -0.00028466231943069433, -0.007079644878488358, -0.0006542076014408517, -0.01334437613497136, -0.008053277433521477, -0.0004080656540904863, -0.00499071374043302, -0.013994963118646647, -0.0033901804343529776, -0.0020147199133322287, -0.012135886633331356, -0.009252460638213531, -0.00037519891412367436]]
# objopt final generation contains solutions >= b for iteration  1
# --- 0.0611567497253418 seconds ---
# objopt for global iteration  10  is ready
# b before boundchange:  [0.022836107021377727, 0.01399397875031539]
# b [0.022836107021377727, 0.01399397875031539]
# b after boundchange:  [0.021803914984011838, 0.013343258738426123]
# [[2.2820961385703313, 8.137066475751435], [2.5498595190392703, 8.23997467782435], [2.512107945299878, 7.986817058937599], [2.89466960954221, 8.151913197929707], [2.626782390343029, 7.9769160690380785], [2.48713603452892, 8.225858702746654], [2.5453904030735575, 8.031507329801352], [2.8665741856161047, 8.1289317156328], [2.778279376358555, 8.20180292358548], [2.872644739492142, 8.22050934759246], [2.4557700711924886, 8.122284449271978], [2.5116098239236386, 8.230909785515518], [2.610308511660413, 8.055961499584956], [2.3082810348307006, 8.142158654252349], [2.7422691660900376, 8.160361035581863], [2.920928512663134, 8.02518977246596], [2.3213080911198234, 8.190794923042207], [2.7053565829974824, 8.081414111273821], [2.3806893500861115, 8.105292364901626]]
#  and size of P is 19
# DIVOPT
# parameters for divopt [[2.2820961385703313, 8.137066475751435], [2.5498595190392703, 8.23997467782435], [2.512107945299878, 7.986817058937599], [2.89466960954221, 8.151913197929707], [2.626782390343029, 7.9769160690380785], [2.48713603452892, 8.225858702746654], [2.5453904030735575, 8.031507329801352], [2.8665741856161047, 8.1289317156328], [2.778279376358555, 8.20180292358548], [2.872644739492142, 8.22050934759246], [2.4557700711924886, 8.122284449271978], [2.5116098239236386, 8.230909785515518], [2.610308511660413, 8.055961499584956], [2.3082810348307006, 8.142158654252349], [2.7422691660900376, 8.160361035581863], [2.920928512663134, 8.02518977246596], [2.3213080911198234, 8.190794923042207], [2.7053565829974824, 8.081414111273821], [2.3806893500861115, 8.105292364901626]] 20 [0.021803914984011838, 0.013343258738426123] 3 10 10
# iteration 0
# diversity 0.513143721482182
# --- 0.19504570960998535 seconds ---
# Global_iteration:  11 b is  [0.021803914984011838, 0.013343258738426123]
# OBJOPT [[2.920928512663134, 8.02518977246596], (1.7142422248611877, 8.11228883319861), (2.1160251641371306, 8.583601279950079), (7.5629131988729466, 7.603676053718071), [2.1140951355308615, 7.596706490736173], (8.142846613631328, 3.5088524146495965), [1.0247226985457496, 2.0730789487413483], [7.690369533488424, 6.900003647150097], [0.9901117819117029, 1.3627868546826978], [8.357754164905042, 6.3383893476635995], [8.563917423598852, 6.917487439553805], [8.387467014125043, 7.399339835929613], [8.6169757546589, 2.6705586404138515], [1.695987636920251, 2.0336602244282744], (8.687036977401634, 4.371123706647281), [8.974989406268522, 3.3782882546392616], (8.453303158479233, 5.414874242931781), [7.901785364307908, 6.032883046911115], [8.145099920167851, 4.084489841366803], [8.377440832492256, 4.893959640509104]]
# iteration 0
# [[-0.004603303266621418, -0.004735411437804059, -0.005928968157103224, -0.0067911641799119835, -0.0077459931883712965, -0.00618720403663517, -0.007813661351021059, -0.0043479678724407155, -0.0053886502411755735, -0.007752412037390476, -0.004534387640680458, -0.0068146222183333004, -0.004322538249457128, -0.0053278929103950665, -0.006334323803145892, -0.007381718569268982, -0.004459469116174739, -0.004941297377391325, -0.006951689452017458, -0.005486941451341591], [-0.011103171311043531, -0.010203278105482223, -0.0039002036553672827, -0.002440407111086828, -0.00026748821149499553, -0.003134259567238572, -6.040792694018479e-05, -0.0132152946271384, -0.006414321246230412, -9.004318987856424e-05, -0.011557432347048488, -0.0021449302503484344, -0.01334437613497136, -0.006701398440073646, -0.002509896527064432, -0.0002678595615020076, -0.012085944602322303, -0.008901643615427439, -0.0008781306072854648, -0.005917950165941779]]
# objopt final generation contains solutions >= b for iteration  1
# --- 0.03843498229980469 seconds ---
# objopt for global iteration  11  is ready
# b before boundchange:  [0.021803914984011838, 0.013343258738426123]
# b [0.021803914984011838, 0.013343258738426123]
# b after boundchange:  [0.01967367249007445, 0.012084989439392924]
# [[2.6740252605342283, 8.10134294301141], [2.85446900124435, 8.086165866261943], [2.72811090586751, 8.28173932758433], [2.2475635105135403, 8.07869756405104], [2.2395876577703824, 8.123137844656366], [2.601309955954367, 8.249189965914802], [2.318141802878237, 8.105137269142363], [2.657577866536095, 8.08813518979576], [2.28306816992605, 8.105700470599539], [2.4831917428723553, 8.081548344899694], [2.8882544859347425, 8.117880509864], [2.3633943313385943, 8.112676513548378], [2.7770970832284814, 8.102050188528828], [2.691777109897082, 8.130272347580904], [2.870589837377388, 8.117782981169283], [2.6786533560935855, 8.147931272747806], [2.3895168611283273, 8.280565541985464], [2.565052740385693, 8.111878231431461], [2.2047072870589997, 8.168664809572299]]
#  and size of P is 19
# DIVOPT
# parameters for divopt [[2.6740252605342283, 8.10134294301141], [2.85446900124435, 8.086165866261943], [2.72811090586751, 8.28173932758433], [2.2475635105135403, 8.07869756405104], [2.2395876577703824, 8.123137844656366], [2.601309955954367, 8.249189965914802], [2.318141802878237, 8.105137269142363], [2.657577866536095, 8.08813518979576], [2.28306816992605, 8.105700470599539], [2.4831917428723553, 8.081548344899694], [2.8882544859347425, 8.117880509864], [2.3633943313385943, 8.112676513548378], [2.7770970832284814, 8.102050188528828], [2.691777109897082, 8.130272347580904], [2.870589837377388, 8.117782981169283], [2.6786533560935855, 8.147931272747806], [2.3895168611283273, 8.280565541985464], [2.565052740385693, 8.111878231431461], [2.2047072870589997, 8.168664809572299]] 20 [0.01967367249007445, 0.012084989439392924] 3 10 10
# iteration 0
# diversity 0.46761574402054434
# --- 0.43413496017456055 seconds ---
# Global_iteration:  12 b is  [0.01967367249007445, 0.012084989439392924]
# OBJOPT [[2.8882544859347425, 8.117880509864], [2.3895168611283273, 8.280565541985464], [7.666829497395777, 6.404341339023171], [8.806639656327437, 3.721637843226428], [8.69598051278201, 2.7261191541728644], [1.460670483516861, 2.1905895536093576], (1.665507812844072, 8.159380858850362), (8.20631030870564, 6.649176817644845), (8.421941521153819, 7.163771492728955), [1.0670363086786412, 1.5614127061546146], (2.062416132485549, 7.606795545494199), (8.353804382142648, 5.948635793324068), (8.37330643429107, 4.1877521369264095), (7.444112895362185, 6.831213428581101), (7.472821563241865, 7.664092507442649), (8.332954755225035, 3.3980861605234978), [2.541347026182015, 7.645322443310833], [1.542303749505182, 1.6419439709833323], [7.674432512661941, 7.238174554418424], (8.092418965629777, 2.9894050160956045)]
# iteration 0
# [[-0.005156553381743522, -0.0067057533619812515, -0.006904729166754212, -0.005498146375198312, -0.005640485536922833, -0.004506594250705345, -0.005431942743499345, -0.0059133694246092505, -0.0073588928975488665, -0.005102382080865402, -0.006986720294657588, -0.006095564805510564, -0.007829189518373818, -0.00690138134847241, -0.006526667813953572, -0.0047924061621592426, -0.007225717192611224, -0.0053999341867649086, -0.005023909871444468, -0.004574478170259774], [-0.007926480870720584, -0.0014109242178338686, -0.0009627121015561534, -0.005825778203313809, -0.0055162259327618725, -0.011762860067060243, -0.006354357455376343, -0.003961925210099633, -0.0003261884884470571, -0.008395397210166272, -0.0008083886429847934, -0.0032697639845707047, -7.057142177891174e-05, -0.0010943941198046925, -0.0019820185618604816, -0.00982812761384528, -0.0004288883930410315, -0.006374782437409367, -0.008688411801159425, -0.011423656717563808]]
# --- 0.04417991638183594 seconds ---
# objopt for global iteration  12  is ready
# b before boundchange:  [0.01967367249007445, 0.012084989439392924]
# b [0.01967367249007445, 0.012084989439392924]
# b after boundchange:  [0.015959283123948224, 0.00982751341211477]
# [[2.277863543671308, 8.130744831530068], [2.729195432948154, 8.199905977499162], [2.210830417486827, 8.124143840731504], [2.5258013350215123, 8.15780220958011], [2.4460780461829628, 8.236863387474397], [2.4803009014813475, 8.026265380321208], [2.595408609036454, 8.091572237717186], [2.7442348886645904, 8.055481774349117], [2.374289855828942, 8.112219985645822], [2.4012719072818776, 8.109083404744565], [2.758591989073728, 8.029203134086913], [2.676224153072223, 8.154745031827192], [2.311930582627892, 8.136075816600187], [2.8108435044156295, 8.111578164490608], [2.445265607944033, 8.070957707456488], [2.53108023510067, 8.10356651617635], [2.3723148653702415, 8.119728666170396], [2.4104530585484163, 8.108798675690704], [2.6693471422154382, 8.047632018162357]]
#  and size of P is 19
# DIVOPT
# ...
# iteration 0
# diversity 0.4041211939421733
# --- 0.22980976104736328 seconds ---
# Global_iteration:  13 b is  [0.015959283123948224, 0.00982751341211477]
# OBJOPT [[2.8108435044156295, 8.111578164490608], (2.2040713498738778, 7.875981444742095), (2.258310202940184, 8.475539025857133), (8.304279065266314, 5.878255084473448), (8.337155448784532, 3.216751858118986), (7.617858051182816, 7.448154081492665), [8.793997706889385, 2.9971860724664356], (8.229244769829332, 7.366241138866021), (1.7514045531397475, 8.229655870877172), [8.690798323566032, 3.7253324569271244], (1.17111009128595, 1.9942524531113754), [7.776608841651702, 6.7203950970492885], (8.312124307023154, 2.731914697076256), (1.1467155271941532, 1.590868213662164), (8.238823280129514, 3.611826149668918), [7.860202158438189, 6.286712834315031], (8.739583982844266, 2.5301757937879876), (8.457321813814241, 4.161088534579363), [7.415195528645734, 7.064495535817688], [8.335462723003522, 6.700829250634261]]
# iteration 0
# [[-0.006480381542943325, -0.007095165351143633, -0.005677321255730048, -0.0076128939042652, -0.007468229741853339, -0.007442243022689396, -0.005604635567418363, -0.005837454057084548, -0.005367446690414536, -0.006803587114151876, -0.0061462942130914265, -0.0075103458580361845, -0.004844843938473407, -0.006280204094612872, -0.005804534549751344, -0.006589147579348547, -0.006855358214244948, -0.006438313454747064, -0.005253593405302885, -0.006040534876750549], [-0.002128336787915936, -0.0007932612998010297, -0.004981116475714864, -6.796353431795491e-05, -0.00034504989088907225, -0.0005262008271201934, -0.005315086974432641, -0.004277539415092412, -0.007046927688606538, -0.00119519687229652, -0.003261040659299161, -0.00013272501453359944, -0.009776619049205435, -0.002831862141508476, -0.004483354057713414, -0.001765905492422511, -0.001082321735077513, -0.0026085848106386996, -0.007190501022340831, -0.003527492678237925]]
# --- 0.03438615798950195 seconds ---
# objopt for global iteration  13  is ready
# b before boundchange:  [0.015959283123948224, 0.00982751341211477]
# b [0.015959283123948224, 0.00982751341211477]
# b after boundchange:  [0.011726881239478874, 0.00718980881230301]
# [[2.455948113686833, 8.004306854403241], [2.4543406467197295, 8.067245914565415], [2.20737858452825, 8.159932238455298], [2.661386103298937, 8.115367305086917], [2.39275097717024, 8.087957402608833], [2.4025741143008656, 8.027782075151151], [2.6572009371541276, 8.153555813476942], [2.7079281413308864, 8.067459698005374], [2.5422500377885164, 8.163357636250863], [2.336324841287205, 8.19373778578435], [2.462616809634961, 8.013083775225073], [2.3817261002246255, 8.150245902473602], [2.6172869967765635, 8.131959327605028], [2.4330665027413456, 8.168284980563058], [2.2671937972382055, 8.062577759548672], [2.590739833527449, 8.079331829139464], [2.632588846985306, 8.128399466967606], [2.493966461794082, 8.197335675942277], [2.5208279178138064, 8.191318900282498]]
#  and size of P is 19
# DIVOPT
# parameters for divopt [[2.455948113686833, 8.004306854403241], [2.4543406467197295, 8.067245914565415], [2.20737858452825, 8.159932238455298], [2.661386103298937, 8.115367305086917], [2.39275097717024, 8.087957402608833], [2.4025741143008656, 8.027782075151151], [2.6572009371541276, 8.153555813476942], [2.7079281413308864, 8.067459698005374], [2.5422500377885164, 8.163357636250863], [2.336324841287205, 8.19373778578435], [2.462616809634961, 8.013083775225073], [2.3817261002246255, 8.150245902473602], [2.6172869967765635, 8.131959327605028], [2.4330665027413456, 8.168284980563058], [2.2671937972382055, 8.062577759548672], [2.590739833527449, 8.079331829139464], [2.632588846985306, 8.128399466967606], [2.493966461794082, 8.197335675942277], [2.5208279178138064, 8.191318900282498]] 20 [0.011726881239478874, 0.00718980881230301] 3 10 10
# iteration 0
# diversity 0.2725525291268556
# --- 0.21822428703308105 seconds ---
# Global_iteration:  14 b is  [0.011726881239478874, 0.00718980881230301]
# OBJOPT [[2.20737858452825, 8.159932238455298], [2.7079281413308864, 8.067459698005374], [8.351159583819909, 3.3845818728037402], (2.0465153553378697, 7.827730289543094), (2.1429110475671234, 8.424832762151869), (2.378251576148158, 7.817078915248466), (8.358394791052476, 3.816215287903467), [8.136768189374953, 6.200048624169422], [8.405222636442936, 2.7067088250725098], [8.00270180026655, 6.650807486897803], [7.7099287738406135, 7.408359942754005], (8.322731009224997, 7.045861183353901), (1.871628133056645, 8.366417839829467), (7.653934786032856, 6.850611515180468), [8.05067436040915, 7.0120811786845945], [8.098221472882567, 7.343880405433524], [8.233484243078829, 2.958637468961407], [2.608744706847996, 8.333492228858182], (8.293804379128748, 6.474909234422551), [7.5611306794287705, 7.180009317108158]]
# iteration 0
# [[-0.006875713010779402, -0.006558223166308067, -0.006107012667366347, -0.005388898572692405, -0.0059206955129964016, -0.006950360669467113, -0.005425537285410501, -0.007823388998057861, -0.00779873437015144, -0.006790355699236692, -0.005294654610840263, -0.006447360126072087, -0.0059713816032125715, -0.005625473994108943, -0.005253593405302885, -0.005481757899531609, -0.005949884267126134, -0.006263908346506791, -0.007623243583243147, -0.005582628108121918], [-0.001031531315539803, -0.002146455101148995, -0.0032354136120318283, -0.006582153549877301, -0.004255372747895932, -0.0008714601153349639, -0.0062045854100243195, -2.7921412579441444e-06, -3.878408119838043e-05, -0.001249137407462974, -0.006878550817438349, -0.0023389662874836866, -0.0037560442692757346, -0.005224147013444104, -0.007190501022340831, -0.005911556762202179, -0.003816027128546586, -0.0029349610373555894, -0.00013695083157387223, -0.00546128596454068]]
# objopt final generation contains solutions >= b for iteration  1
# --- 0.04929089546203613 seconds ---
# objopt for global iteration  14  is ready
# b before boundchange:  [0.011726881239478874, 0.00718980881230301]
# b [0.011726881239478874, 0.00718980881230301]
# b after boundchange:  [0.011183926638091235, 0.006878490090730138]
# [[2.6544761489919755, 8.09697477695692], [2.377841917278937, 8.145166981099765], [2.238977801023116, 8.173354698607207], [2.4972198765159592, 8.04153300130401], [2.411258735464911, 8.100334253691944], [2.5607615395115357, 8.112549970453006], [2.2945997542620162, 8.033750766051023], [2.6372414198395306, 8.152662288408557], [2.65868457923081, 8.130318044254917], [2.6281918302466063, 8.10424845993142], [2.4608347580214307, 8.045861936094859], [2.5563589455051767, 8.14889310895723], [2.3941689043154213, 8.161149470746471], [2.6989883505639822, 8.130226477892275], [2.20737858452825, 8.159932238455298], [2.6707217243509738, 8.138094176588531], [2.2029678231994074, 8.135274810729396], [2.363646330731191, 8.12967300431265], [2.5667520650380897, 8.210360660706465]]
#  and size of P is 19
# DIVOPT
# parameters for divopt [[2.6544761489919755, 8.09697477695692], [2.377841917278937, 8.145166981099765], [2.238977801023116, 8.173354698607207], [2.4972198765159592, 8.04153300130401], [2.411258735464911, 8.100334253691944], [2.5607615395115357, 8.112549970453006], [2.2945997542620162, 8.033750766051023], [2.6372414198395306, 8.152662288408557], [2.65868457923081, 8.130318044254917], [2.6281918302466063, 8.10424845993142], [2.4608347580214307, 8.045861936094859], [2.5563589455051767, 8.14889310895723], [2.3941689043154213, 8.161149470746471], [2.6989883505639822, 8.130226477892275], [2.20737858452825, 8.159932238455298], [2.6707217243509738, 8.138094176588531], [2.2029678231994074, 8.135274810729396], [2.363646330731191, 8.12967300431265], [2.5667520650380897, 8.210360660706465]] 20 [0.011183926638091235, 0.006878490090730138] 3 10 10
# iteration 0
# diversity 0.25313398492727646
# --- 0.41446900367736816 seconds ---
# Global_iteration:  15 b is  [0.011183926638091235, 0.006878490090730138]
# OBJOPT [[2.6989883505639822, 8.130226477892275], (2.1249958787341816, 7.833256641214309), (8.258688843822215, 7.059170407742158), [8.296205971274729, 2.8235894484841877], (1.910600934235811, 8.34290302176081), (8.190711174367333, 6.18484967466288), [7.833484389165174, 7.478171903430796], [8.224808218565745, 3.5073344944554847], (1.8382766171870117, 8.052973654600398), (8.256546112802521, 6.67610816403724), [7.955544388832959, 6.738388699952385], [2.3317133968269985, 8.350965784482723], (7.886622676499158, 7.009112112498363), (7.626561919030898, 6.891072361101601), [8.037890219995722, 7.273698182049855], (7.887262550886524, 6.44067482015942), [2.528512936986542, 7.84097769120901], [7.540020870689326, 7.364832793033241], [2.3175415062929834, 8.049058578658922], (8.307952441047139, 3.0764507440061566)]
# iteration 0
# [[-0.006776728066349177, -0.007431766057568959, -0.0061402099281730885, -0.006078637498407156, -0.006228827332773269, -0.005590330966997623, -0.007035298524409623, -0.0058903843045393115, -0.0076281798031429884, -0.007259453251755812, -0.007365488614317061, -0.006588875742553307, -0.0066991694546694154, -0.006813645381821539, -0.00900084235469733, -0.006196655316498427, -0.009006435681383445, -0.005922314917514924, -0.007141696846045204, -0.007696001595967676], [-0.0014776807482832944, -0.0002299056431186308, -0.0030953884305480787, -0.0033738838801630417, -0.0028477501863105816, -0.005662052534226283, -0.0007752375855093437, -0.00446242809813224, -0.0001804510857983489, -0.000543974379509178, -0.00027467622574288983, -0.0023869495274134395, -0.001532188770735725, -0.0011898079513295815, -1.0512593085667275e-05, -0.0029203732389565824, -1.6531938905725587e-06, -0.003951121016135565, -0.0005774892390586045, -0.00015799149996687805]]
# --- 0.055542945861816406 seconds ---
# objopt for global iteration  15  is ready
# b before boundchange:  [0.011183926638091235, 0.006878490090730138]
# b [0.011183926638091235, 0.006878490090730138]
# b after boundchange:  [0.009000824158335951, 0.005523427542855938]
# [[2.474685052185552, 8.160196735379138], [2.396785051835101, 8.04824310055952], [2.6029176023519036, 8.152468651179792], [2.4975174934476145, 8.180978801532902], [2.411921986369061, 8.027064820837163], [2.2258331708479253, 8.074074591915041], [2.3276046613486985, 8.100630145251484], [2.566419321757562, 8.095500324434443], [2.510691799616121, 8.149611055563316], [8.000140389164702, 6.974902271221104], [2.389703966631076, 8.095877509598822], [2.273873433318079, 8.158296571163879], [2.286056630230273, 8.111446074093623], [2.4117246176904947, 8.18027520214123], [2.5345106979734924, 8.160316786710766], [2.3056627435015096, 8.06549011726135], [2.2380840340185966, 8.184863979504199], [2.5220553016313927, 8.132353226867489], [2.572988606425732, 8.019756237150855]]
#  and size of P is 19
# DIVOPT
# parameters for divopt [[2.474685052185552, 8.160196735379138], [2.396785051835101, 8.04824310055952], [2.6029176023519036, 8.152468651179792], [2.4975174934476145, 8.180978801532902], [2.411921986369061, 8.027064820837163], [2.2258331708479253, 8.074074591915041], [2.3276046613486985, 8.100630145251484], [2.566419321757562, 8.095500324434443], [2.510691799616121, 8.149611055563316], [8.000140389164702, 6.974902271221104], [2.389703966631076, 8.095877509598822], [2.273873433318079, 8.158296571163879], [2.286056630230273, 8.111446074093623], [2.4117246176904947, 8.18027520214123], [2.5345106979734924, 8.160316786710766], [2.3056627435015096, 8.06549011726135], [2.2380840340185966, 8.184863979504199], [2.5220553016313927, 8.132353226867489], [2.572988606425732, 8.019756237150855]] 20 [0.009000824158335951, 0.005523427542855938] 3 10 10
# iteration 0
# diversity 0.15886743939557335
# --- 0.2513620853424072 seconds ---
# [[[2.4975174934476145, 8.180978801532902],
#   [8.000140389164702, 6.974902271221104],
#   [2.3056627435015096, 8.06549011726135],
#   [2.572988606425732, 8.019756237150855],
#   (7.568272516495251, 7.191061126201688),
#   (2.2680659949198123, 7.757974426732266),
#   [2.4969495401683566, 8.339845225704842],
#   [2.076452784603246, 7.977078565448407],
#   [7.900826387432056, 6.712876959245637],
#   (7.838164010947188, 7.525083943130806),
#   (7.840273177140799, 7.19847845495295),
#   [7.7949101920758395, 6.985433137919811],
#   (7.7308348104940725, 7.369707356073242),
#   (2.138157586360923, 8.351333003976006),
#   (7.957869779892498, 6.468688697019978),
#   [2.267328982065293, 8.46314196525066],
#   (7.606450271323956, 6.953227109250033),
#   (7.731512596207434, 6.7915648462147775),
#   (7.891671038667444, 7.369615943658573),
#   (2.0284902822512305, 8.179191992947722)],
#      SP diversity  Min-max diversity  S-energy diversity  \
#  0       1.289199           0.020000         4458.612694
#  1       1.997760           1.278954            0.167527
#  2       1.996438           1.242387            0.199342
#  3       1.994717           1.157562            0.227442
#  4       1.992566           1.135665            0.275156
#  5       1.960415           0.797342            0.637183
#  6       1.965298           0.814866            0.598670
#  7       1.945791           0.747831            0.811030
#  8       1.934600           0.743549            0.918304
#  9       1.887856           0.627586            1.377137
#  10      1.855292           0.582134            1.704419
#  11      1.852851           0.513144            1.784108
#  12      1.763445           0.467616            2.826623
#  13      1.681302           0.404121            4.075532
#  14      1.322194           0.272553           14.794733
#  15      1.250338           0.253134           18.158760
#
#      Average Himmelblaus function (obj1)  Average x**2 function (obj1)
#  0                              0.011730                      0.106289
#  1                              0.009944                      0.055940
#  2                              0.010252                      0.048277
#  3                              0.009971                      0.043617
#  4                              0.009798                      0.037635
#  5                              0.009840                      0.021368
#  6                              0.010586                      0.021788
#  7                              0.010464                      0.016766
#  8                              0.011074                      0.015672
#  9                              0.010343                      0.011991
#  10                             0.010672                      0.010465
#  11                             0.010891                      0.010090
#  12                             0.009841                      0.007856
#  13                             0.010389                      0.005917
#  14                             0.008874                      0.004406
#  15                             0.008657                      0.004150  ,
#      Optimization  Diversity Optimization
#  0       6.436722                3.596715
#  1       7.642121                3.246479
#  2       7.988476                3.672329
#  3       7.792254                3.520758
#  4       8.283778                3.728715
#  5       8.370841                3.855019
#  6       8.414780                3.801896
#  7       8.584278                4.004735
#  8       8.586489                3.901068
#  9       8.562680                4.189988
#  10      8.562680                4.184905
#  11      8.581210                4.057305
#  12      8.643757                4.215499
#  13      8.698118                6.281605
#  14      8.698118                6.299225
#  15      8.020522                7.562438]

# %%
repeats = 50

random.seed(12)

# NOAH_minmax_repeats(P_0, repeats, it, max_global_iteration, max_gen, pop_size, global_bound, b, r_number, c, mutation_rate, mutation_rate_div, box_border)

# %%
it = 1
max_gen = 10
pop_size = 20
b = [3, 3]
c = 3
global_bound = [0, 0]
r_number = 19
mutation_rate_div = 10
box_border = 10
max_global_iteration = 16
s = 3
theta = 5

random.seed(20)

NOAH_senergy(P_0, it, max_global_iteration, max_gen, pop_size, global_bound, b, r_number, c, mutation_rate, mutation_rate_div, box_border, s)
# Out:
# Global_iteration:  0 b is  [3, 3]
# OBJOPT [[0, 1], [0, 0.5], [2, 4], [2, 4.2], [1.97, 4], [1.9, 2.1], [6.9, 7], [9, 4], [7, 7], [7, 8], [7, 7.03], [9.05, 1], [6.5, 7], [2, 2.04], [7.3, 7], [9.03, 10], [2, 2], [0, 6], [0.1, 0.3], [2, 1.98]]
# iteration 0
# [[-0.005368488022462698, -0.0022282698488373877, -0.0014131401767003204, -0.0005053583622946214, -0.0007824930484146643, -0.006857873243061191, -0.003359574807328254, -0.0060778811013146705, -0.0023600251176638383, -0.0070036733212655525, -0.0038776764193740377, -0.004756667997547062, -0.004041789256707121, -0.007833023114280135, -0.0007033864655125641, -0.0053223352253439484, -0.009211354419026407, -0.003566968588106103, -0.0028556440821181158, -0.0057634980040518384], [-0.011801660865779185, -0.04056640596873267, -0.054979539564773056, -0.062290634749322775, -0.05794434731046297, -0.004629529173936855, -0.030509900086419378, -0.00801261656149655, -0.038823844607766105, -0.003939411262451769, -0.023021631739819498, -0.016130886587046978, -0.02199311038271279, -0.0013719299733182834, -0.05897675269584607, -0.012608970242230096, -4.649312911210143e-05, -0.025620224484736945, -0.03355949652368629, -0.010030127806891642]]
# --- 0.023618221282958984 seconds ---
# objopt for global iteration  0  is ready
# b before boundchange:  [3, 3]
# b [3, 3]
# b after boundchange:  [0.007799999999519578, 0.07109999999951969]
# [[7.164059713336913, 7.403068582009399], [7.316999789051069, 7.199683402068869], [6.271018933980771, 7.260447451292167], [6.272053975124664, 7.493513680918879], [7.6069577683928085, 7.33449360042126], [6.616896202465637, 7.605115053002604], [6.818675598074178, 7.452604042706521], [7.051122330503341, 7.213875855619709], [7.629726323983893, 7.218169679079357], [6.19335667654243, 7.256207734502913], [6.560452906472551, 7.696799962246619], [7.400728640236509, 7.482595748272622], [6.6898651076692826, 7.356371658256569], [6.8886419957488245, 7.491312957065329], [7.307018687688496, 7.509185740814987], [5.838681384980354, 7.78804703782756], [7.798753850248381, 7.207501312754632], [7.010420169195266, 7.271639592875534], [6.969181662359783, 7.349027841236235]]
#  and size of P is 19
# DIVOPT
# parameters for divopt [[7.164059713336913, 7.403068582009399], [7.316999789051069, 7.199683402068869], [6.271018933980771, 7.260447451292167], [6.272053975124664, 7.493513680918879], [7.6069577683928085, 7.33449360042126], [6.616896202465637, 7.605115053002604], [6.818675598074178, 7.452604042706521], [7.051122330503341, 7.213875855619709], [7.629726323983893, 7.218169679079357], [6.19335667654243, 7.256207734502913], [6.560452906472551, 7.696799962246619], [7.400728640236509, 7.482595748272622], [6.6898651076692826, 7.356371658256569], [6.8886419957488245, 7.491312957065329], [7.307018687688496, 7.509185740814987], [5.838681384980354, 7.78804703782756], [7.798753850248381, 7.207501312754632], [7.010420169195266, 7.271639592875534], [6.969181662359783, 7.349027841236235]] 20 [0.007799999999519578, 0.07109999999951969] 3 10 10 3
# iteration 0
# GENERATION 0
# GENERATION 1
# GENERATION 2
# GENERATION 3
# GENERATION 4
# GENERATION 5
# GENERATION 6
# GENERATION 7
# GENERATION 8
# GENERATION 9
# GENERATION 10
# GENERATION 11
# GENERATION 12
# GENERATION 13
# GENERATION 14
# GENERATION 15
# GENERATION 16
# GENERATION 17
# GENERATION 18
# GENERATION 19
# GENERATION 20
# GENERATION 21
# GENERATION 22
# GENERATION 23
# GENERATION 24
# GENERATION 25
# GENERATION 26
# GENERATION 27
# GENERATION 28
# GENERATION 29
# GENERATION 30
# GENERATION 31
# GENERATION 32
# GENERATION 33
# GENERATION 34
# GENERATION 35
# GENERATION 36
# GENERATION 37
# GENERATION 38
# GENERATION 39
# GENERATION 40
# GENERATION 41
# GENERATION 42
# GENERATION 43
# GENERATION 44
# GENERATION 45
# GENERATION 46
# GENERATION 47
# GENERATION 48
# GENERATION 49
# GENERATION 50
# GENERATION 51
# GENERATION 52
# GENERATION 53
# GENERATION 54
# GENERATION 55
# GENERATION 56
# all energies [28623.868182533948, 19374.549955769508, 17140.18370034826, 12645.29123759134, 9650.468282730391, 7021.471026849439, 5121.609833866818, 3415.4357957029147, 2017.152186763873, 1437.9271146432468, 1093.661160952419, 823.0617005834971, 596.780003697291, 382.83349678069027, 292.65180224314247, 229.60742496297266, 195.69711314448946, 187.94099135965362, 166.6905875855493, 158.31116360735766, 154.69144738463976, 132.64235864667694, 117.58030067594514, 116.72206509449015, 114.97000579919286, 104.22734788035481, 96.14479788981507, 79.19039251176011, 78.84750546642974, 76.66063900814848, 74.09239368156733, 59.50941585658764, 59.439241553315696, 56.53290724142578, 56.14774128279325, 54.53781731286747, 54.512412617843225, 54.242846508796504, 54.09841614261886, 53.69270865754862, 53.41384419499794, 52.33598155293404, 51.46849637094964, 51.35930768523881, 51.100061626897016, 50.847585057572005, 50.33848611923604, 50.184115304066594, 50.13229566945786, 48.08657640971563, 47.961163402536364, 47.5795240810157, 47.098605343598834, 47.098605343598834, 46.99589973134701, 46.99589973134701, 46.99589973134701, 46.99589973134701] [[7.798753850248381, 7.207501312754632], [7.168905098783639, 4.115363314086336], [6.881313807549147, 5.692635386269248], [2.2123662160733204, 7.512414025603878], [7.755034716126955, 1.9886894165574462], [5.832270422789471, 8.241982866673567], (4.692405047023901, 7.559205513097375), [2.305586431275331, 1.650836594400754], [7.711701323697412, 6.393680720623077], [3.8573841927435177, 8.69029772975374], (2.2739916245881555, 3.091158838326469), (6.746965446476505, 7.738427894201198), [2.77870292939844, 6.503882601297686], [7.6787175173481925, 4.90888989749699], [7.710774870065808, 3.1351289267807303], (3.5504138584446716, 7.069704815717413), [7.550562781527823, 8.568301811137417], [3.0804098109251528, 8.000099199898063], (2.3961135872696175, 9.071279003858917), (6.264421189878366, 6.630977005937533)]
# --- 1.0565671920776367 seconds ---
# Global_iteration:  1 b is  [0.007799999999519578, 0.07109999999951969]
# OBJOPT [[7.798753850248381, 7.207501312754632], [7.168905098783639, 4.115363314086336], [6.881313807549147, 5.692635386269248], [2.2123662160733204, 7.512414025603878], [7.755034716126955, 1.9886894165574462], [5.832270422789471, 8.241982866673567], (4.692405047023901, 7.559205513097375), [2.305586431275331, 1.650836594400754], [7.711701323697412, 6.393680720623077], [3.8573841927435177, 8.69029772975374], (2.2739916245881555, 3.091158838326469), (6.746965446476505, 7.738427894201198), [2.77870292939844, 6.503882601297686], [7.6787175173481925, 4.90888989749699], [7.710774870065808, 3.1351289267807303], (3.5504138584446716, 7.069704815717413), [7.550562781527823, 8.568301811137417], [3.0804098109251528, 8.000099199898063], (2.3961135872696175, 9.071279003858917), (6.264421189878366, 6.630977005937533)]
# iteration 0
# [[-0.000109183752083867, -0.0004219500232913797, -0.001284575559518127, -0.004975192101468965, -4.4648839055197294e-05, -0.00607494417102092, -0.0030551287933561545, -0.0020794845218884703, -0.0025056221242580235, -0.003793479217669559, -0.0060971070074107726, -0.0005233129454561368, -0.0033066075024877177, -0.00225583364468927, -0.005066792901948436, -0.0036848264939924077, -0.000853118848418729, -0.0052659057011446, -0.002849614712182453, -0.0004998401589405972], [-0.06616933367735725, -0.06006607422059986, -0.048321051825098604, -0.009495348582737591, -0.0664448560220443, -0.0037828278471269457, -0.025820548968612606, -0.041015178943474395, -0.030238695909465776, -0.017609641656089595, -0.003364717885440814, -0.05782657837845738, -0.0238082579335709, -0.03477092825909878, -0.009252330970665421, -0.01862642808053681, -0.05541773973886728, -0.007030387274692038, -0.02784160457296182, -0.05798078663289431]]
# --- 0.08766603469848633 seconds ---
# objopt for global iteration  1  is ready
# b before boundchange:  [0.007799999999519578, 0.07109999999951969]
# b [0.007799999999519578, 0.07109999999951969]
# b after boundchange:  [0.006939659999572523, 0.06319367999957629]
# [[4.3504231967724065, 8.128458778242438], [3.285843762466312, 7.862166871145232], [3.1505386324822293, 8.275385250456008], [3.590509877191619, 8.17233583015898], [3.0942114203176434, 7.991075113532663], [3.1987464030259516, 8.118460210922905], [4.407115799743332, 8.234475351187157], [4.128856119182225, 7.770347370699849], [2.644547247773459, 7.942065099045352], [4.293006252544906, 8.031703762199076], [3.3119198146466937, 8.270251393376828], [2.7052438689166554, 8.106872432179292], [4.076355669958003, 7.720813142008035], [3.0804098109251528, 8.000099199898063], [2.749046223942296, 7.945866547378377], [3.498056710561524, 8.270233607142949], [2.5307679316413427, 8.069232083937386], [4.276596277687116, 8.081067558670899], [3.0523143945519444, 8.011978641097144]]
#  and size of P is 19
# DIVOPT
# parameters for divopt [[4.3504231967724065, 8.128458778242438], [3.285843762466312, 7.862166871145232], [3.1505386324822293, 8.275385250456008], [3.590509877191619, 8.17233583015898], [3.0942114203176434, 7.991075113532663], [3.1987464030259516, 8.118460210922905], [4.407115799743332, 8.234475351187157], [4.128856119182225, 7.770347370699849], [2.644547247773459, 7.942065099045352], [4.293006252544906, 8.031703762199076], [3.3119198146466937, 8.270251393376828], [2.7052438689166554, 8.106872432179292], [4.076355669958003, 7.720813142008035], [3.0804098109251528, 8.000099199898063], [2.749046223942296, 7.945866547378377], [3.498056710561524, 8.270233607142949], [2.5307679316413427, 8.069232083937386], [4.276596277687116, 8.081067558670899], [3.0523143945519444, 8.011978641097144]] 20 [0.006939659999572523, 0.06319367999957629] 3 10 10 3
# iteration 0
# GENERATION 0
# GENERATION 1
# GENERATION 2
# GENERATION 3
# GENERATION 4
# GENERATION 5
# GENERATION 6
# GENERATION 7
# GENERATION 8
# GENERATION 9
# GENERATION 10
# GENERATION 11
# GENERATION 12
# GENERATION 13
# GENERATION 14
# GENERATION 15
# GENERATION 16
# GENERATION 17
# GENERATION 18
# GENERATION 19
# GENERATION 20
# GENERATION 21
# GENERATION 22
# GENERATION 23
# GENERATION 24
# GENERATION 25
# GENERATION 26
# GENERATION 27
# GENERATION 28
# GENERATION 29
# GENERATION 30
# GENERATION 31
# GENERATION 32
# GENERATION 33
# GENERATION 34
# GENERATION 35
# GENERATION 36
# all energies [570660.8314986968, 53483.64675266475, 33104.30818898702, 15608.19200366877, 10276.116529818031, 8836.070910527584, 6459.1734002390185, 5143.474591690927, 3849.9760780155134, 2557.097698367997, 1887.2442914576436, 1304.3049387890464, 1025.5585396802985, 759.6881656575679, 536.0919011162601, 499.1787539772115, 496.2750335476932, 455.5970468420555, 381.6102448113296, 282.41718155270274, 228.51126593205242, 224.21304945409116, 180.29444659018853, 149.78306324029742, 137.5338673571335, 123.57672575999203, 123.19075991495383, 122.42010485162578, 118.17026111635452, 115.86951032789962, 91.03853583845007, 89.64881716011577, 87.80098943178456, 87.80098943178456, 86.2369825453019, 86.2369825453019, 86.2369825453019, 86.2369825453019] [[4.407115799743332, 8.234475351187157], [3.482281167766752, 8.661204526867232], (2.408985348644916, 8.038332370122351), [2.706909910707231, 6.600092281636217], [7.562734709133986, 4.322527692053718], [2.587578207995247, 8.904480825035915], [6.380482546407493, 8.289992445003675], [7.454227771493015, 2.603245478093384], (5.680779391848803, 7.91425345074893), [7.443264652617589, 5.051236796256804], [7.576249695261918, 7.393321377830459], (7.337185492137496, 8.430987643197755), (6.699799641395311, 6.660844191008389), [3.7746276514194244, 7.277022009356556], (7.607884664011868, 6.178691736692077), (6.983781049130688, 5.874009772082275), (2.489246759643275, 1.88130411854862), (3.0314990766765346, 7.58110529588739), (6.268050430549943, 7.2436225963922745), [7.366493555164884, 3.4409661061843995]]
# --- 0.4447019100189209 seconds ---
# Global_iteration:  2 b is  [0.006939659999572523, 0.06319367999957629]
# OBJOPT [[4.407115799743332, 8.234475351187157], [3.482281167766752, 8.661204526867232], (2.408985348644916, 8.038332370122351), [2.706909910707231, 6.600092281636217], [7.562734709133986, 4.322527692053718], [2.587578207995247, 8.904480825035915], [6.380482546407493, 8.289992445003675], [7.454227771493015, 2.603245478093384], (5.680779391848803, 7.91425345074893), [7.443264652617589, 5.051236796256804], [7.576249695261918, 7.393321377830459], (7.337185492137496, 8.430987643197755), (6.699799641395311, 6.660844191008389), [3.7746276514194244, 7.277022009356556], (7.607884664011868, 6.178691736692077), (6.983781049130688, 5.874009772082275), (2.489246759643275, 1.88130411854862), (3.0314990766765346, 7.58110529588739), (6.268050430549943, 7.2436225963922745), [7.366493555164884, 3.4409661061843995]]
# iteration 0
# [[-0.004788973795278197, -0.0019927168695186817, -0.002332675073062985, -0.002123927862160808, -0.0027959432290177826, -0.0009037675540537272, -0.0026758006348371836, -0.0027601366531142075, -0.001321216239580176, -0.006390533394548932, -0.006713356923536707, -0.0004945050623059815, -0.002047873538044326, -0.0034170186262814785, -0.0009293102263683835, -0.0015555124137363113, -0.000730130899067568, -0.0011090792627270671, -0.00451654581424919, -0.0021701445791779544], [-0.011037236137189394, -0.03807480934542378, -0.032143094329097566, -0.03469475803239609, -0.027056695854771606, -0.05268738258338701, -0.028916718125974402, -0.028001138510098115, -0.04631707627634926, -0.0023392396426802384, -0.0016875565843282056, -0.05807316623935533, -0.03570734683684654, -0.020694382875691975, -0.051074271456467896, -0.042505882688124205, -0.05460079139804223, -0.04835198832705781, -0.01270891469507394, -0.034092940476495824]]
# --- 0.044634103775024414 seconds ---
# objopt for global iteration  2  is ready
# b before boundchange:  [0.006939659999572523, 0.06319367999957629]
# b [0.006939659999572523, 0.06319367999957629]
# b after boundchange:  [0.006408776009605033, 0.05806867255161312]
# [[3.2713406454043827, 7.964907245399749], [2.8116275921867877, 7.936871503937157], [3.8535657162285535, 7.858088559013045], [3.7066325333888743, 7.929480964924859], [3.4217006605297042, 8.232057982057041], [3.2988563142054006, 8.049275747238935], [2.9865657115467505, 8.408905382076137], [3.608140422164973, 8.149877597673465], [3.99717377751377, 8.069404127776986], [3.414885558520829, 7.9798897289094315], [3.526858941181139, 8.051164412759277], [2.8747833488678878, 7.946312555427976], [3.9468716779389763, 8.044692142584868], [4.145523026016752, 8.113936595902404], [3.7527981663995553, 7.935258822616338], [4.035992621206464, 8.046566092229526], [3.151482045994284, 8.1155761834174], [3.5689606790712123, 8.009362704131973], [4.29678946089668, 8.032158414140092]]
#  and size of P is 19
# DIVOPT
# parameters for divopt [[3.2713406454043827, 7.964907245399749], [2.8116275921867877, 7.936871503937157], [3.8535657162285535, 7.858088559013045], [3.7066325333888743, 7.929480964924859], [3.4217006605297042, 8.232057982057041], [3.2988563142054006, 8.049275747238935], [2.9865657115467505, 8.408905382076137], [3.608140422164973, 8.149877597673465], [3.99717377751377, 8.069404127776986], [3.414885558520829, 7.9798897289094315], [3.526858941181139, 8.051164412759277], [2.8747833488678878, 7.946312555427976], [3.9468716779389763, 8.044692142584868], [4.145523026016752, 8.113936595902404], [3.7527981663995553, 7.935258822616338], [4.035992621206464, 8.046566092229526], [3.151482045994284, 8.1155761834174], [3.5689606790712123, 8.009362704131973], [4.29678946089668, 8.032158414140092]] 20 [0.006408776009605033, 0.05806867255161312] 3 10 10 3
# iteration 0
# GENERATION 0
# GENERATION 1
# GENERATION 2
# GENERATION 3
# GENERATION 4
# GENERATION 5
# GENERATION 6
# GENERATION 7
# GENERATION 8
# GENERATION 9
# GENERATION 10
# GENERATION 11
# GENERATION 12
# GENERATION 13
# GENERATION 14
# GENERATION 15
# GENERATION 16
# GENERATION 17
# GENERATION 18
# GENERATION 19
# GENERATION 20
# GENERATION 21
# GENERATION 22
# GENERATION 23
# GENERATION 24
# GENERATION 25
# GENERATION 26
# GENERATION 27
# GENERATION 28
# GENERATION 29
# GENERATION 30
# GENERATION 31
# GENERATION 32
# GENERATION 33
# GENERATION 34
# GENERATION 35
# GENERATION 36
# GENERATION 37
# GENERATION 38
# GENERATION 39
# GENERATION 40
# GENERATION 41
# GENERATION 42
# GENERATION 43
# GENERATION 44
# GENERATION 45
# GENERATION 46
# GENERATION 47
# GENERATION 48
# GENERATION 49
# GENERATION 50
# GENERATION 51
# GENERATION 52
# GENERATION 53
# GENERATION 54
# GENERATION 55
# GENERATION 56
# GENERATION 57
# GENERATION 58
# GENERATION 59
# GENERATION 60
# GENERATION 61
# GENERATION 62
# GENERATION 63
# GENERATION 64
# GENERATION 65
# all energies [90652.0513578186, 56427.37466605789, 34767.9276288015, 22585.949198943996, 15289.37399073982, 11298.921812253298, 7523.72656485873, 5638.86989066147, 4251.8495799130515, 3326.742254074917, 2645.0309201164996, 2448.3001898982197, 1982.6331302668905, 1555.293418962424, 1206.0556836132278, 904.030193241156, 889.3287508543918, 726.3090389081673, 630.9009048317903, 619.696842181068, 500.40517002067105, 464.7565573967649, 412.69483584863065, 400.21110054477015, 390.7257544768998, 362.64138878576847, 356.7935380148105, 303.76993213399214, 250.81982554861256, 236.78206892454668, 203.10496541610047, 201.1576143264042, 187.27813946992893, 163.07868755168738, 161.62048850083625, 160.73037843072714, 160.59207414158067, 158.68234350641848, 157.76281059229535, 154.69829770995514, 154.69829770995514, 154.06440019702936, 154.06440019702936, 153.92050302000246, 153.00263919608076, 151.4361238989602, 147.05776093900934, 145.34877425612535, 141.07072410169852, 138.9539274787751, 138.9539274787751, 138.9539274787751, 136.33672477767252, 134.58705512524617, 129.48999477407523, 129.0701505456054, 126.29940402809974, 126.29940402809974, 126.0456513492837, 125.95209546300747, 125.15672197714576, 125.15672197714576, 125.15672197714576, 122.36090142770873, 122.36090142770873, 122.36090142770873, 122.36090142770873] [[4.29678946089668, 8.032158414140092], [7.437805962918844, 6.595858547926548], (7.33276195552179, 7.315112545332164), [2.5375949277707885, 7.907199320941354], [2.5117317370314507, 6.668454671225072], [6.670810921963685, 6.450603847373887], (7.458949739640654, 8.442694093421366), [3.6760836347181183, 8.336633420897504], [7.480030026860682, 5.238641479913153], [3.0580204668203836, 7.137285593241852], (3.795808094076677, 7.459389389926864), (7.458871227536346, 2.578553596462382), (6.254908218571439, 7.162864458387452), (2.481409570130721, 8.54006223551378), [6.075326676061775, 7.914651841997921], (3.0221460269550096, 8.989130548194346), [7.439067710296948, 4.312585851175499], [7.3412012998265155, 3.3980591139092646], (7.106644510814612, 5.712690996025335), (6.704011983429823, 8.349475091457869)]
# --- 1.1252610683441162 seconds ---
# Global_iteration:  3 b is  [0.006408776009605033, 0.05806867255161312]
# OBJOPT [[4.29678946089668, 8.032158414140092], [7.437805962918844, 6.595858547926548], (7.33276195552179, 7.315112545332164), [2.5375949277707885, 7.907199320941354], [2.5117317370314507, 6.668454671225072], [6.670810921963685, 6.450603847373887], (7.458949739640654, 8.442694093421366), [3.6760836347181183, 8.336633420897504], [7.480030026860682, 5.238641479913153], [3.0580204668203836, 7.137285593241852], (3.795808094076677, 7.459389389926864), (7.458871227536346, 2.578553596462382), (6.254908218571439, 7.162864458387452), (2.481409570130721, 8.54006223551378), [6.075326676061775, 7.914651841997921], (3.0221460269550096, 8.989130548194346), [7.439067710296948, 4.312585851175499], [7.3412012998265155, 3.3980591139092646], (7.106644510814612, 5.712690996025335), (6.704011983429823, 8.349475091457869)]
# iteration 0
# [[-0.0016132042116868018, -0.005635103041945754, -0.004476850224234502, -0.003109129995182897, -0.006152477552546143, -0.006082153966825362, -0.0014980058651139574, -0.005247054620743612, -0.0018901847741993934, -0.0027304558906074265, -0.0004945050623059815, -0.0012706417265827806, -0.005503314098104665, -0.0017111156675067077, -0.00253695999361442, -0.004213723687649038, -0.0023682054954896436, -0.00563414787983328, -0.0026561788644571217, -0.0008738725465689864], [-0.041228098283489494, -0.0051695754934295846, -0.012068045776354428, -0.023875097548182792, -0.0034133516365536694, -0.003582560365870088, -0.04281382254626337, -0.007143463672517457, -0.0377372906320826, -0.02772381423225095, -0.05807316623935533, -0.04600274712037597, -0.0068387595185159696, -0.03992221007084769, -0.029775570844224213, -0.01418956770723831, -0.03253877292591292, -0.005186774873209651, -0.02936275455834324, -0.05260216795517021]]
# objopt final generation contains solutions >= b for iteration  1
# --- 0.01838207244873047 seconds ---
# objopt for global iteration  3  is ready
# b before boundchange:  [0.006408776009605033, 0.05806867255161312]
# b [0.006408776009605033, 0.05806867255161312]
# b after boundchange:  [0.0062370208125476665, 0.056599535136057484]
# [[2.8858904718059484, 8.045655253571397], [3.729880237266264, 8.064447464264891], [4.159295515843764, 8.072247667564874], [3.1718987572860997, 8.110530367073382], [2.810283713136051, 8.19371280760019], [2.5025969939592145, 8.04781290140907], [3.777896654544945, 8.227777518252674], [3.6281206967449275, 8.010301546631226], [3.2683725476513117, 7.952625818776328], [3.0134943230070075, 8.246529267216172], [4.065188496771148, 7.883272837916097], [3.37022122223379, 8.226932058236835], [2.6263639959266545, 8.137546711868396], [3.461102506503554, 7.927607472829568], [2.9472643405326058, 8.019977370032686], [3.407216275317198, 8.079561163654066], [3.6919038003622564, 8.070338643915887], [2.6540856584042407, 8.27494641833081], [3.8727725488692264, 8.056212786991379]]
#  and size of P is 19
# DIVOPT
# parameters for divopt [[2.8858904718059484, 8.045655253571397], [3.729880237266264, 8.064447464264891], [4.159295515843764, 8.072247667564874], [3.1718987572860997, 8.110530367073382], [2.810283713136051, 8.19371280760019], [2.5025969939592145, 8.04781290140907], [3.777896654544945, 8.227777518252674], [3.6281206967449275, 8.010301546631226], [3.2683725476513117, 7.952625818776328], [3.0134943230070075, 8.246529267216172], [4.065188496771148, 7.883272837916097], [3.37022122223379, 8.226932058236835], [2.6263639959266545, 8.137546711868396], [3.461102506503554, 7.927607472829568], [2.9472643405326058, 8.019977370032686], [3.407216275317198, 8.079561163654066], [3.6919038003622564, 8.070338643915887], [2.6540856584042407, 8.27494641833081], [3.8727725488692264, 8.056212786991379]] 20 [0.0062370208125476665, 0.056599535136057484] 3 10 10 3
# iteration 0
# GENERATION 0
# GENERATION 1
# GENERATION 2
# GENERATION 3
# GENERATION 4
# GENERATION 5
# GENERATION 6
# GENERATION 7
# GENERATION 8
# GENERATION 9
# GENERATION 10
# GENERATION 11
# GENERATION 12
# GENERATION 13
# GENERATION 14
# GENERATION 15
# GENERATION 16
# GENERATION 17
# GENERATION 18
# GENERATION 19
# GENERATION 20
# GENERATION 21
# GENERATION 22
# GENERATION 23
# GENERATION 24
# GENERATION 25
# GENERATION 26
# GENERATION 27
# GENERATION 28
# GENERATION 29
# GENERATION 30
# GENERATION 31
# GENERATION 32
# GENERATION 33
# GENERATION 34
# GENERATION 35
# GENERATION 36
# GENERATION 37
# GENERATION 38
# GENERATION 39
# GENERATION 40
# GENERATION 41
# GENERATION 42
# GENERATION 43
# GENERATION 44
# GENERATION 45
# GENERATION 46
# GENERATION 47
# GENERATION 48
# GENERATION 49
# GENERATION 50
# GENERATION 51
# all energies [57507.33682423034, 19293.32950103008, 11550.126198847376, 9105.409931997749, 7330.437878114972, 5642.0109727124145, 5096.358387426039, 4261.276613596882, 3399.6650855573644, 2736.0367934726964, 2083.1578589787396, 1576.9186249948675, 1279.3832603716173, 962.1239257671108, 705.1999022617728, 575.5018225447008, 568.2305741728331, 453.0239452205468, 381.10430878848473, 374.8201786807703, 370.50632735450574, 368.4422579078412, 366.05157564761765, 322.81215538311505, 309.8396113559913, 302.885839270341, 286.4710322628093, 279.7024450677413, 262.4453701978549, 256.229077074909, 239.13642259971107, 220.92667201887923, 190.55354580998076, 189.82191983177336, 185.95192804371055, 185.95192804371055, 185.9044433240242, 185.9044433240242, 183.7428574172956, 180.83626754428968, 180.83626754428968, 180.0423682830211, 180.0423682830211, 172.7444538437421, 171.2942108724214, 170.9314937247932, 170.9314937247932, 168.43220514523608, 168.43220514523608, 167.10581730614066, 167.10581730614066, 167.10581730614066, 167.10581730614066] [[2.5025969939592145, 8.04781290140907], (3.909409925966364, 8.454828381042764), [7.470661494029182, 2.9321484297770595], (7.341074932092901, 5.5174196045911525), (7.230127871935771, 6.774800747391846), (6.490021582558936, 8.217961304617381), [3.646782840233798, 7.3311511035446815], (2.785114402073869, 7.3732092468217285), (4.158265533184581, 7.881361622733012), [6.052814950253955, 7.772836392235714], [6.243210472325865, 7.153305513590049], (3.4198838704107324, 8.089284838891217), (7.006571665443708, 6.090590872712397), (7.424653015671128, 4.180432120220473), [7.449954318458473, 4.869724116121317], (3.2528394280272352, 8.878355062322893), (7.457094147999079, 8.148732637555764), [2.517147436306852, 6.874793153492148], (7.378076581798311, 7.499787502705413), (2.635393206949665, 8.828999737319945)]
# --- 0.866422176361084 seconds ---
# Global_iteration:  4 b is  [0.0062370208125476665, 0.056599535136057484]
# OBJOPT [[2.5025969939592145, 8.04781290140907], (3.909409925966364, 8.454828381042764), [7.470661494029182, 2.9321484297770595], (7.341074932092901, 5.5174196045911525), (7.230127871935771, 6.774800747391846), (6.490021582558936, 8.217961304617381), [3.646782840233798, 7.3311511035446815], (2.785114402073869, 7.3732092468217285), (4.158265533184581, 7.881361622733012), [6.052814950253955, 7.772836392235714], [6.243210472325865, 7.153305513590049], (3.4198838704107324, 8.089284838891217), (7.006571665443708, 6.090590872712397), (7.424653015671128, 4.180432120220473), [7.449954318458473, 4.869724116121317], (3.2528394280272352, 8.878355062322893), (7.457094147999079, 8.148732637555764), [2.517147436306852, 6.874793153492148], (7.378076581798311, 7.499787502705413), (2.635393206949665, 8.828999737319945)]
# iteration 0
# [[-0.0011183744647837762, -0.005405753020464418, -0.003546371996093304, -0.0029757674736739835, -0.0014752122160209852, -0.0012857276125132632, -0.0018382156546704852, -0.000992465248628052, -0.0024967669829881675, -0.0033307706501752524, -0.0010565573441063993, -0.0012349759924272037, -0.004522133907691331, -0.0007419137586456466, -0.003860883944435596, -0.004110452468955897, -0.0022318997105123238, -0.0024279382149652987, -0.002063412336555263, -0.003459128489668938], [-0.048800220340393594, -0.006919258315918327, -0.019498674773218105, -0.025139793751967923, -0.04326313017112956, -0.046078424593521856, -0.03949511753280983, -0.05009136106989388, -0.03023929177989396, -0.021527442434033997, -0.049199426574965864, -0.047768436081578144, -0.011715289117725718, -0.05399900831906373, -0.016731654495371957, -0.014706480285661764, -0.033540537273905005, -0.031339945645243485, -0.03680727849388371, -0.020322758184678325]]
# --- 0.021842002868652344 seconds ---
# objopt for global iteration  4  is ready
# b before boundchange:  [0.0062370208125476665, 0.056599535136057484]
# b [0.0062370208125476665, 0.056599535136057484]
# b after boundchange:  [0.005417476277778524, 0.0491963159402602]
# [[3.116898139557101, 8.159242126555405], [3.942467747638978, 8.150728397838579], [3.8718876512233753, 8.024575445851061], [3.7262720996415055, 8.014716271324996], [2.9578884496338147, 8.200213564646377], [2.673238473875052, 8.206000355549325], [3.0837092700056834, 8.126628727060341], [3.1455338933494863, 8.040666852753045], [3.3560602764878533, 8.141001740794401], [3.227820976013349, 8.23230892866514], [2.7423476391820367, 7.83781675192797], [3.140126754407995, 8.125968400984956], [3.5635417386658035, 7.872512660255212], [3.441815731383063, 7.984891956792561], [3.5060456129746385, 7.997574745197248], [2.972574916561429, 8.117619913754789], [3.0350867845027873, 8.0957786275508], [2.8734690437966037, 8.152032021157167], [3.9721102471050704, 7.98470913663392]]
#  and size of P is 19
# DIVOPT
# parameters for divopt [[3.116898139557101, 8.159242126555405], [3.942467747638978, 8.150728397838579], [3.8718876512233753, 8.024575445851061], [3.7262720996415055, 8.014716271324996], [2.9578884496338147, 8.200213564646377], [2.673238473875052, 8.206000355549325], [3.0837092700056834, 8.126628727060341], [3.1455338933494863, 8.040666852753045], [3.3560602764878533, 8.141001740794401], [3.227820976013349, 8.23230892866514], [2.7423476391820367, 7.83781675192797], [3.140126754407995, 8.125968400984956], [3.5635417386658035, 7.872512660255212], [3.441815731383063, 7.984891956792561], [3.5060456129746385, 7.997574745197248], [2.972574916561429, 8.117619913754789], [3.0350867845027873, 8.0957786275508], [2.8734690437966037, 8.152032021157167], [3.9721102471050704, 7.98470913663392]] 20 [0.005417476277778524, 0.0491963159402602] 3 10 10 3
# iteration 0
# GENERATION 0
# GENERATION 1
# GENERATION 2
# GENERATION 3
# GENERATION 4
# GENERATION 5
# GENERATION 6
# GENERATION 7
# GENERATION 8
# GENERATION 9
# GENERATION 10
# GENERATION 11
# GENERATION 12
# GENERATION 13
# GENERATION 14
# GENERATION 15
# GENERATION 16
# GENERATION 17
# GENERATION 18
# GENERATION 19
# GENERATION 20
# GENERATION 21
# GENERATION 22
# GENERATION 23
# GENERATION 24
# GENERATION 25
# GENERATION 26
# GENERATION 27
# GENERATION 28
# GENERATION 29
# GENERATION 30
# GENERATION 31
# GENERATION 32
# GENERATION 33
# GENERATION 34
# GENERATION 35
# GENERATION 36
# GENERATION 37
# GENERATION 38
# GENERATION 39
# GENERATION 40
# GENERATION 41
# GENERATION 42
# GENERATION 43
# GENERATION 44
# GENERATION 45
# GENERATION 46
# GENERATION 47
# GENERATION 48
# GENERATION 49
# GENERATION 50
# GENERATION 51
# GENERATION 52
# GENERATION 53
# GENERATION 54
# GENERATION 55
# GENERATION 56
# GENERATION 57
# GENERATION 58
# GENERATION 59
# all energies [120807.54728256265, 66037.39476264178, 44091.61462782134, 31451.447369006506, 23380.968429343415, 16376.575843423836, 12584.730216145816, 9290.49007611109, 8682.712477715579, 6089.9302481148525, 4425.192816298649, 3496.7163900561645, 2901.981924619082, 2268.185273047941, 1714.1827944656468, 1473.6182722365686, 1437.657573863189, 1411.5647325422733, 1258.8678486868278, 1113.34020790185, 955.2706009579751, 832.2659664769234, 799.7962636703172, 799.7962636703172, 720.5529604105692, 637.2349470567261, 637.2349470567261, 619.1122296845681, 616.7635189011085, 543.7644631953264, 519.8040223512072, 516.8269666651422, 513.9260145992928, 513.9260145992928, 513.2272376512421, 513.2272376512421, 508.69405310108687, 508.69405310108687, 508.69405310108687, 506.3114264912176, 492.6863397963092, 467.66342764510114, 467.66342764510114, 467.66342764510114, 453.60780763084676, 450.32664981827696, 450.32664981827696, 443.45377294803126, 440.1064695598871, 440.1064695598871, 436.93058942492513, 436.93058942492513, 435.3493791936679, 435.3493791936679, 430.62957278192147, 430.62957278192147, 428.970492062792, 426.8941448797664, 426.8941448797664, 426.8941448797664, 426.8941448797664] [[3.942467747638978, 8.150728397838579], [2.673238473875052, 8.206000355549325], [7.20025746797885, 7.831844402630776], [7.295198357110504, 6.535194150584962], [6.267410601069335, 7.840462606114673], [3.218449835374571, 8.312383697614967], (2.6940562946107858, 8.979845588829171), [7.2686227462546205, 5.734561826512575], (6.899819445323682, 6.364134353759791), (3.0920400250610047, 7.157538750632151), [2.754300744060059, 6.902216530269721], (6.645223423223822, 6.853027657199793), [7.26587554995704, 8.335303681521241], (3.6622888366423707, 8.46175022702671), [7.32177959049559, 7.17192887542725], (3.6906650173900752, 7.659583786326728), (6.440240968729466, 7.329812042518596), (6.617411600543764, 8.125335761986216), [2.801348390179068, 7.541429682900255], (3.0395652913545255, 8.743176913635144)]
# --- 1.2004179954528809 seconds ---
# Global_iteration:  5 b is  [0.005417476277778524, 0.0491963159402602]
# OBJOPT [[3.942467747638978, 8.150728397838579], [2.673238473875052, 8.206000355549325], [7.20025746797885, 7.831844402630776], [7.295198357110504, 6.535194150584962], [6.267410601069335, 7.840462606114673], [3.218449835374571, 8.312383697614967], (2.6940562946107858, 8.979845588829171), [7.2686227462546205, 5.734561826512575], (6.899819445323682, 6.364134353759791), (3.0920400250610047, 7.157538750632151), [2.754300744060059, 6.902216530269721], (6.645223423223822, 6.853027657199793), [7.26587554995704, 8.335303681521241], (3.6622888366423707, 8.46175022702671), [7.32177959049559, 7.17192887542725], (3.6906650173900752, 7.659583786326728), (6.440240968729466, 7.329812042518596), (6.617411600543764, 8.125335761986216), [2.801348390179068, 7.541429682900255], (3.0395652913545255, 8.743176913635144)]
# iteration 0
# [[-0.003039132899894265, -0.0018820693085630973, -0.001243551552591586, -0.002021274680766315, -0.002943016943302003, -0.0025813236362190717, -0.002915396559267283, -0.003053515301695372, -0.004283733035769583, -0.0024041734485571796, -0.0016378284042665794, -0.0021275064145044025, -0.0019860055486184847, -0.004598521927853857, -0.003512972132520202, -0.003020677235975199, -0.0013086432312006038, -0.0013812659049407404, -0.0014692912094785876, -0.0017161335769431876], [-0.024540117661619162, -0.03881369028089915, -0.04715486662028867, -0.03594143211797086, -0.02546137311059272, -0.029276201357088787, -0.02634399195890456, -0.024494666809789456, -0.014206405492505658, -0.03410476334639639, -0.04107882237233722, -0.03484445215866934, -0.03657721938172927, -0.012018574874167054, -0.020140986225231628, -0.02458882674929436, -0.04551382244358073, -0.04469172629213713, -0.04336201332067598, -0.040209143124220637]]
# --- 0.026072025299072266 seconds ---
# objopt for global iteration  5  is ready
# b before boundchange:  [0.005417476277778524, 0.0491963159402602]
# b [0.005417476277778524, 0.0491963159402602]
# b after boundchange:  [0.004894689816972756, 0.044689933400132255]
# [[3.505037961918422, 8.105334023186073], [3.25668909832633, 8.022728065746298], [3.5014102467966475, 8.046197554982744], [3.7843436467859575, 8.059569196215497], [3.1832326468185816, 8.276809501977294], [3.2335335559845397, 8.114058753433044], [3.6801549855845184, 8.070475705250496], [3.2951580916063934, 8.197716552989377], [3.172310356216567, 8.014376123784539], [3.4282980817513384, 8.232690310242019], [3.6899871844355157, 8.148080552237122], [3.787856770229447, 8.11093987039474], [3.824727306136682, 8.124113362478406], [3.261990438468419, 8.112990124406195], [3.125707564834078, 8.001109239717081], [2.8555835460774284, 8.256105992398412], [3.590742908969948, 7.988796085466666], [3.5414025865563854, 8.14321511423452], [3.720223299060895, 8.119679469375706]]
#  and size of P is 19
# DIVOPT
# parameters for divopt [[3.505037961918422, 8.105334023186073], [3.25668909832633, 8.022728065746298], [3.5014102467966475, 8.046197554982744], [3.7843436467859575, 8.059569196215497], [3.1832326468185816, 8.276809501977294], [3.2335335559845397, 8.114058753433044], [3.6801549855845184, 8.070475705250496], [3.2951580916063934, 8.197716552989377], [3.172310356216567, 8.014376123784539], [3.4282980817513384, 8.232690310242019], [3.6899871844355157, 8.148080552237122], [3.787856770229447, 8.11093987039474], [3.824727306136682, 8.124113362478406], [3.261990438468419, 8.112990124406195], [3.125707564834078, 8.001109239717081], [2.8555835460774284, 8.256105992398412], [3.590742908969948, 7.988796085466666], [3.5414025865563854, 8.14321511423452], [3.720223299060895, 8.119679469375706]] 20 [0.004894689816972756, 0.044689933400132255] 3 10 10 3
# iteration 0
# GENERATION 0
# GENERATION 1
# GENERATION 2
# GENERATION 3
# GENERATION 4
# GENERATION 5
# GENERATION 6
# GENERATION 7
# GENERATION 8
# GENERATION 9
# GENERATION 10
# GENERATION 11
# GENERATION 12
# GENERATION 13
# GENERATION 14
# GENERATION 15
# GENERATION 16
# GENERATION 17
# GENERATION 18
# GENERATION 19
# GENERATION 20
# GENERATION 21
# GENERATION 22
# GENERATION 23
# GENERATION 24
# GENERATION 25
# GENERATION 26
# GENERATION 27
# GENERATION 28
# GENERATION 29
# GENERATION 30
# GENERATION 31
# GENERATION 32
# GENERATION 33
# GENERATION 34
# GENERATION 35
# GENERATION 36
# all energies [274136.95512747683, 181462.24888553607, 124784.80065873018, 107539.33818101336, 81616.95098961194, 59082.663946364846, 35791.308762062785, 28555.21415995286, 23352.93934008239, 17555.94374475422, 14171.569603775966, 11912.610451011951, 10519.65542003754, 8984.38940142927, 7354.568310379108, 6350.0879168762, 5163.503661243131, 4044.301332835372, 3524.6248433947744, 3195.4752265444313, 2816.5583905638987, 2730.566600804836, 2343.847803215925, 2341.0698297168233, 2304.2332198363442, 2056.191296061166, 1725.257609174796, 1561.0103897288038, 1395.032869293298, 1394.3870847635988, 1114.276759701444, 1015.1609770707489, 1015.1609770707489, 984.6075648624812, 977.6072412714583, 977.6072412714583, 977.6072412714583, 977.6072412714583] [[3.25668909832633, 8.022728065746298], [3.824727306136682, 8.124113362478406], (3.7539562388886023, 7.871812924198974), (3.4750965825561138, 7.483854503343521), (3.144988817768359, 7.315938264722246), (2.9289393143688724, 7.857555930805299), (6.452254775331238, 7.824297467227517), [7.183863798992515, 6.24773716823668], (3.156876159483308, 8.513473305444414), [6.748553317449911, 6.727123778904205], [2.904105577488072, 7.12768453572967], (2.8173150010128967, 8.204116974631182), (7.190358733988276, 6.710762715038069), [2.8414739087157295, 8.893197859297427], [6.378949066988909, 7.515684590672481], [3.526895769983401, 8.540246621040152], (7.104870911742166, 7.264141059624601), (6.962061856233687, 8.168392836340187), (6.717823095707706, 7.354232505727932), [6.925776646387144, 7.689691437816929]]
# --- 0.38170909881591797 seconds ---
# Global_iteration:  6 b is  [0.004894689816972756, 0.044689933400132255]
# OBJOPT [[3.25668909832633, 8.022728065746298], [3.824727306136682, 8.124113362478406], (3.7539562388886023, 7.871812924198974), (3.4750965825561138, 7.483854503343521), (3.144988817768359, 7.315938264722246), (2.9289393143688724, 7.857555930805299), (6.452254775331238, 7.824297467227517), [7.183863798992515, 6.24773716823668], (3.156876159483308, 8.513473305444414), [6.748553317449911, 6.727123778904205], [2.904105577488072, 7.12768453572967], (2.8173150010128967, 8.204116974631182), (7.190358733988276, 6.710762715038069), [2.8414739087157295, 8.893197859297427], [6.378949066988909, 7.515684590672481], [3.526895769983401, 8.540246621040152], (7.104870911742166, 7.264141059624601), (6.962061856233687, 8.168392836340187), (6.717823095707706, 7.354232505727932), [6.925776646387144, 7.689691437816929]]
# iteration 0
# [[-0.0026724457206861968, -0.0015670906517945636, -0.0027479120817296794, -0.0019453513771226553, -0.0017006844530481366, -0.002724156935349427, -0.004726083477169089, -0.002229419418721888, -0.001486621103471166, -0.0034297459869775324, -0.003918019276860506, -0.00253093830567793, -0.003564510851381128, -0.003039132899894265, -0.0017752688587707344, -0.0016628436933549358, -0.0025176837015516884, -0.0028110945551397854, -0.002179325387254498, -0.0029979694800323707], [-0.029013944328175518, -0.04184929406460567, -0.027580331660949232, -0.03783177216627401, -0.04005196475559753, -0.0277178123269094, -0.010289431533514934, -0.03346083296075653, -0.04410904463344465, -0.021599559914481432, -0.016455695926081645, -0.029986903163571582, -0.019339552650861895, -0.024540117661619162, -0.03907246130512392, -0.04139716037598475, -0.03017768552867725, -0.027453400971480937, -0.03432896052257814, -0.025556483318648494]]
# --- 0.026559829711914062 seconds ---
# objopt for global iteration  6  is ready
# b before boundchange:  [0.004894689816972756, 0.044689933400132255]
# b [0.004894689816972756, 0.044689933400132255]
# b after boundchange:  [0.0045021356936514045, 0.041114738728120305]
# [[3.068762553929384, 8.05391423101313], [3.3652383290870205, 8.213338094852954], [3.722603781939218, 8.08909421258629], [3.5692030307342257, 8.178349521336512], [3.351468034747399, 7.950042884430178], [3.726675924654427, 8.03777173660104], [3.220299441001156, 8.06533378609715], [3.3356182832242416, 8.023717450936415], [3.6291345810444193, 7.959085140697702], [3.2685354522738934, 7.946908750415456], [3.5237461643557033, 7.972692557895018], [3.413278946521573, 8.14314834773826], [3.6676078434744768, 8.068233162183656], [3.25668909832633, 8.022728065746298], [3.112008778786001, 8.119843295976098], [3.409107701421014, 8.016915567405244], [3.0206012840105947, 8.03061269531201], [3.148042660594599, 7.9302997594920726], [3.5068759533374703, 8.020465785608511]]
#  and size of P is 19
# DIVOPT
# parameters for divopt [[3.068762553929384, 8.05391423101313], [3.3652383290870205, 8.213338094852954], [3.722603781939218, 8.08909421258629], [3.5692030307342257, 8.178349521336512], [3.351468034747399, 7.950042884430178], [3.726675924654427, 8.03777173660104], [3.220299441001156, 8.06533378609715], [3.3356182832242416, 8.023717450936415], [3.6291345810444193, 7.959085140697702], [3.2685354522738934, 7.946908750415456], [3.5237461643557033, 7.972692557895018], [3.413278946521573, 8.14314834773826], [3.6676078434744768, 8.068233162183656], [3.25668909832633, 8.022728065746298], [3.112008778786001, 8.119843295976098], [3.409107701421014, 8.016915567405244], [3.0206012840105947, 8.03061269531201], [3.148042660594599, 7.9302997594920726], [3.5068759533374703, 8.020465785608511]] 20 [0.0045021356936514045, 0.041114738728120305] 3 10 10 3
# iteration 0
# GENERATION 0
# GENERATION 1
# GENERATION 2
# GENERATION 3
# GENERATION 4
# GENERATION 5
# GENERATION 6
# GENERATION 7
# GENERATION 8
# GENERATION 9
# GENERATION 10
# GENERATION 11
# GENERATION 12
# GENERATION 13
# GENERATION 14
# GENERATION 15
# GENERATION 16
# GENERATION 17
# GENERATION 18
# GENERATION 19
# GENERATION 20
# GENERATION 21
# GENERATION 22
# GENERATION 23
# GENERATION 24
# GENERATION 25
# GENERATION 26
# GENERATION 27
# GENERATION 28
# all energies [141241.16274636905, 120785.64618346315, 96650.85135316692, 75530.96582286553, 56491.62717139196, 41807.62984615784, 41807.628744244954, 36384.777390191375, 28174.715168388386, 21004.495618249188, 16272.20259412687, 13360.450512065614, 12166.386755135221, 9702.619578918155, 7393.081848207042, 5422.411684129856, 4168.602791725959, 3610.71007894329, 3081.386694675183, 2669.8136093210906, 2420.4233686431967, 2312.639151560974, 2291.608797990555, 2201.0213341825743, 2201.0213341825743, 2065.3313497310996, 2065.215311420628, 2065.215311420628, 2065.215311420628, 2065.215311420628] [[3.726675924654427, 8.03777173660104], [3.112008778786001, 8.119843295976098], [3.409107701421014, 8.016915567405244], (2.9882159687621748, 7.7160139852266125), (6.512151429823165, 7.707117100177488), (6.758982622239674, 7.48311344230838), [7.0899257139788725, 6.350076194847076], (6.9281341276661355, 7.962827310452959), [6.930837987808545, 7.718178716889757], (3.2048502249961586, 7.367327704654105), [2.901340165538706, 8.385270152877434], [6.564232224135512, 7.195389936992428], [6.600895153613114, 7.916447400473707], [7.071925063228722, 6.561122230973679], [7.0301022145098075, 7.402484442520015], [6.833722201468275, 6.724051520883406], (3.556107157197787, 8.376518457384043), [7.039993696690439, 7.102180203326849], (3.5413735182612776, 7.759321910350632), [3.0890918371062495, 8.695003351648047]]
# --- 0.29091477394104004 seconds ---
# Global_iteration:  7 b is  [0.0045021356936514045, 0.041114738728120305]
# OBJOPT [[3.726675924654427, 8.03777173660104], [3.112008778786001, 8.119843295976098], [3.409107701421014, 8.016915567405244], (2.9882159687621748, 7.7160139852266125), (6.512151429823165, 7.707117100177488), (6.758982622239674, 7.48311344230838), [7.0899257139788725, 6.350076194847076], (6.9281341276661355, 7.962827310452959), [6.930837987808545, 7.718178716889757], (3.2048502249961586, 7.367327704654105), [2.901340165538706, 8.385270152877434], [6.564232224135512, 7.195389936992428], [6.600895153613114, 7.916447400473707], [7.071925063228722, 6.561122230973679], [7.0301022145098075, 7.402484442520015], [6.833722201468275, 6.724051520883406], (3.556107157197787, 8.376518457384043), [7.039993696690439, 7.102180203326849], (3.5413735182612776, 7.759321910350632), [3.0890918371062495, 8.695003351648047]]
# iteration 0
# [[-0.003599063993312052, -0.0017020755344941776, -0.0029940815686493806, -0.0017211446012762456, -0.002443404179234122, -0.0035487978997741794, -0.0016797946086905692, -0.00302071471468305, -0.0037435677077635983, -0.004325840892881835, -0.003470216779681415, -0.003816948417485494, -0.001640818600093323, -0.003313941122152204, -0.0018382599683115942, -0.00253093830567793, -0.003564510851381128, -0.0036379179270297707, -0.0021175535976854115, -0.0016649286571241296], [-0.019020360896683786, -0.04030995764739074, -0.025417827546680323, -0.03978503243816674, -0.03107662223118662, -0.019545649839076886, -0.04044032329876666, -0.02458806837249133, -0.017791627802953798, -0.013164940488745282, -0.02020299429504058, -0.017156826812867374, -0.040856258506274626, -0.02188513378271316, -0.03856596694433131, -0.029986903163571582, -0.019339552650861895, -0.01901810549638978, -0.034724636377541376, -0.04065126877908861]]
# --- 0.03953981399536133 seconds ---
# objopt for global iteration  7  is ready
# b before boundchange:  [0.0045021356936514045, 0.041114738728120305]
# b [0.0045021356936514045, 0.041114738728120305]
# b after boundchange:  [0.004454413055298688, 0.04065014218049276]
# [[3.181505998412851, 8.210559531948046], [3.102880079353956, 8.078197061134407], [3.5222107300438665, 7.98273213835611], [3.4746902144872434, 8.182430919318385], [3.380173199036679, 8.21313094623575], [3.151527990189793, 8.067661259251162], [3.5852188203100583, 8.182949665196922], [3.293497320221615, 8.26104251095753], [3.4216488812692187, 8.055704084595375], [3.709678855042618, 8.107945571974263], [3.544818362648356, 8.064056607276363], [3.0926673265972267, 8.190262970467533], [3.112008778786001, 8.119843295976098], [3.409107701421014, 8.016915567405244], [3.6441755392708117, 8.146087192665135], [3.179576664027786, 8.016066522762586], [3.046298790120277, 8.063474579857242], [3.1371482131738406, 8.118604428028043], [2.9201344050920417, 8.158918930565283]]
#  and size of P is 19
# DIVOPT
# parameters for divopt [[3.181505998412851, 8.210559531948046], [3.102880079353956, 8.078197061134407], [3.5222107300438665, 7.98273213835611], [3.4746902144872434, 8.182430919318385], [3.380173199036679, 8.21313094623575], [3.151527990189793, 8.067661259251162], [3.5852188203100583, 8.182949665196922], [3.293497320221615, 8.26104251095753], [3.4216488812692187, 8.055704084595375], [3.709678855042618, 8.107945571974263], [3.544818362648356, 8.064056607276363], [3.0926673265972267, 8.190262970467533], [3.112008778786001, 8.119843295976098], [3.409107701421014, 8.016915567405244], [3.6441755392708117, 8.146087192665135], [3.179576664027786, 8.016066522762586], [3.046298790120277, 8.063474579857242], [3.1371482131738406, 8.118604428028043], [2.9201344050920417, 8.158918930565283]] 20 [0.004454413055298688, 0.04065014218049276] 3 10 10 3
# iteration 0
# GENERATION 0
# GENERATION 1
# GENERATION 2
# GENERATION 3
# GENERATION 4
# GENERATION 5
# GENERATION 6
# GENERATION 7
# GENERATION 8
# GENERATION 9
# GENERATION 10
# GENERATION 11
# GENERATION 12
# GENERATION 13
# GENERATION 14
# GENERATION 15
# GENERATION 16
# GENERATION 17
# GENERATION 18
# GENERATION 19
# GENERATION 20
# GENERATION 21
# GENERATION 22
# GENERATION 23
# GENERATION 24
# GENERATION 25
# GENERATION 26
# GENERATION 27
# GENERATION 28
# GENERATION 29
# GENERATION 30
# GENERATION 31
# GENERATION 32
# GENERATION 33
# GENERATION 34
# GENERATION 35
# GENERATION 36
# GENERATION 37
# GENERATION 38
# GENERATION 39
# GENERATION 40
# GENERATION 41
# GENERATION 42
# ...
# GENERATION 19
# GENERATION 20
# GENERATION 21
# all energies [611006.9480529167, 341703.503710259, 244618.75253397567, 171946.23046400992, 129903.75936273202, 103919.15655637375, 79642.87835101254, 69815.5557266062, 55022.48100567883, 41400.14045139868, 30550.515738818765, 23127.160965327563, 17748.40366921025, 13015.935852667668, 10464.833158546096, 8110.908503481334, 8110.908503481334, 7744.995868324405, 7197.964883258542, 6358.19636377943, 6358.19636377943, 6358.19636377943, 6358.19636377943] [[3.225056186309575, 7.92151289901027], [3.3818647834186515, 8.199772832667975], [3.5481407613096843, 7.994270947939488], [3.108388202613223, 8.099979517977424], [3.1298741404059074, 8.643827426021943], [3.416303682081797, 8.40134004189523], [6.6923512711988336, 7.520308803246918], [3.102595630544669, 8.40057604657652], (3.1155671808870222, 7.5216293728902315), [3.3481677980266675, 7.64318712046358], (3.0723426416955477, 7.75874609761226), (6.9041461436165115, 7.146490806968475), (6.93129827234457, 7.974521307822524), [6.77756542082232, 7.057131499797856], (6.8986771032971, 6.920215309231601), (6.815583924686752, 7.901487297191521), [6.958492601926327, 7.581716793690318], [3.464697436175254, 7.824076267297838], (3.2781809056140636, 8.540899672774756), (6.9558222118172095, 7.372803148704705)]
# --- 0.3311018943786621 seconds ---
# Global_iteration:  14 b is  [0.0038359221327714825, 0.03504720318524895]
# OBJOPT [[3.225056186309575, 7.92151289901027], [3.3818647834186515, 8.199772832667975], [3.5481407613096843, 7.994270947939488], [3.108388202613223, 8.099979517977424], [3.1298741404059074, 8.643827426021943], [3.416303682081797, 8.40134004189523], [6.6923512711988336, 7.520308803246918], [3.102595630544669, 8.40057604657652], (3.1155671808870222, 7.5216293728902315), [3.3481677980266675, 7.64318712046358], (3.0723426416955477, 7.75874609761226), (6.9041461436165115, 7.146490806968475), (6.93129827234457, 7.974521307822524), [6.77756542082232, 7.057131499797856], (6.8986771032971, 6.920215309231601), (6.815583924686752, 7.901487297191521), [6.958492601926327, 7.581716793690318], [3.464697436175254, 7.824076267297838], (3.2781809056140636, 8.540899672774756), (6.9558222118172095, 7.372803148704705)]
# iteration 0
# [[-0.002160248484232745, -0.0022683289361223827, -0.0027769410084249055, -0.003242233152727882, -0.0024780555864705725, -0.0022884423419905217, -0.002619702054689913, -0.0027664437655990056, -0.00285162186773608, -0.0032286022177590674, -0.00212966491001768, -0.0035781951920128337, -0.002411289878977166, -0.002107895248970423, -0.0024395281329456582, -0.0026850676847138895, -0.0033653729453493727, -0.0023921357825814294, -0.0026257463755211623, -0.003199744298341774], [-0.034452321003509805, -0.03304658723352935, -0.027186598241751826, -0.022602876417593763, -0.030795202109494893, -0.0326815414403141, -0.030378797373748802, -0.027404146926484203, -0.02632619416534455, -0.022621809829617555, -0.03457760067067873, -0.019194073009612417, -0.031470379648722915, -0.03504843325973592, -0.030985695911823243, -0.028133594510875565, -0.02185331717980806, -0.03149057944988162, -0.030258443152087127, -0.02278285219645318]]
# objopt final generation contains solutions >= b for iteration  1
# --- 0.08209872245788574 seconds ---
# objopt for global iteration  14  is ready
# b before boundchange:  [0.0038359221327714825, 0.03504720318524895]
# b [0.0038359221327714825, 0.03504720318524895]
# b after boundchange:  [0.003832469802851988, 0.03500164182110817]
# [[3.299968057405173, 8.073764991469963], [3.530221620708501, 8.145335808787381], [3.1594304663896704, 8.224169361421817], [3.220027377732332, 8.134850649583681], [3.298607566916845, 8.072751583483209], [3.1411597448392397, 8.224544673318173], [3.0442342705477454, 7.94468830338698], [3.3418074755744396, 8.19507951045086], [3.38947648032287, 7.900509111613044], [3.2112170902141943, 8.11240361144491], [3.0422351806521593, 8.196678082021787], [3.379584505282314, 7.88236386617894], [3.4533469094262186, 8.109136895288668], [3.1655047164548575, 8.221049767225935], [3.3613823860601615, 8.09622524937506], [3.4381011130852106, 8.025599196094246], [3.4471671439020986, 7.993918587826586], [3.108388202613223, 8.099979517977424], [3.5406628525191035, 8.060154675227851]]
#  and size of P is 19
# DIVOPT
# parameters for divopt [[3.299968057405173, 8.073764991469963], [3.530221620708501, 8.145335808787381], [3.1594304663896704, 8.224169361421817], [3.220027377732332, 8.134850649583681], [3.298607566916845, 8.072751583483209], [3.1411597448392397, 8.224544673318173], [3.0442342705477454, 7.94468830338698], [3.3418074755744396, 8.19507951045086], [3.38947648032287, 7.900509111613044], [3.2112170902141943, 8.11240361144491], [3.0422351806521593, 8.196678082021787], [3.379584505282314, 7.88236386617894], [3.4533469094262186, 8.109136895288668], [3.1655047164548575, 8.221049767225935], [3.3613823860601615, 8.09622524937506], [3.4381011130852106, 8.025599196094246], [3.4471671439020986, 7.993918587826586], [3.108388202613223, 8.099979517977424], [3.5406628525191035, 8.060154675227851]] 20 [0.003832469802851988, 0.03500164182110817] 3 10 10 3
# iteration 0
# GENERATION 0
# GENERATION 1
# GENERATION 2
# GENERATION 3
# GENERATION 4
# GENERATION 5
# GENERATION 6
# GENERATION 7
# GENERATION 8
# GENERATION 9
# GENERATION 10
# GENERATION 11
# GENERATION 12
# GENERATION 13
# GENERATION 14
# GENERATION 15
# GENERATION 16
# GENERATION 17
# GENERATION 18
# GENERATION 19
# GENERATION 20
# GENERATION 21
# GENERATION 22
# GENERATION 23
# all energies [416905400.9240471, 7243442.658927026, 628753.6710492836, 399902.7837270364, 252175.593951917, 113810.55134581027, 49526.77608419932, 42879.42588768392, 31605.25670319349, 24866.5163063097, 22448.13708725186, 20197.141785107546, 16759.223031380378, 14652.012507801564, 12581.783394317647, 11539.845505612086, 10947.604910103124, 9149.807167407782, 9062.844612070214, 8336.774963304912, 8336.774963304912, 7188.848545621059, 7188.848545621059, 7188.848545621059, 7188.848545621059] [[3.0442342705477454, 7.94468830338698], [3.3418074755744396, 8.19507951045086], [3.108388202613223, 8.099979517977424], [3.5406628525191035, 8.060154675227851], (3.1738057932519994, 7.499929494985788), (3.4327897022809757, 7.759577523939718), [3.4815443036554425, 8.251752868846987], (3.100353329321355, 7.657193575331626), (3.26842188051543, 8.496397825184737), (6.863877946757324, 7.793931406749609), (6.751238169905477, 7.248791665301978), (3.0471044674930012, 8.307817948048902), [6.916435849513084, 7.925943090543244], [6.876997445046552, 7.597520246231461], [6.657386669775388, 7.462709319238687], (3.2979503325418094, 7.673429685205675), [6.948397567146724, 7.146793977614895], (3.3608833456630838, 7.962105092865674), (3.043375405980545, 8.629945397579522), [6.897691609160847, 6.929693525111761]]
# --- 0.3699681758880615 seconds ---
# Global_iteration:  15 b is  [0.003832469802851988, 0.03500164182110817]
# OBJOPT [[3.0442342705477454, 7.94468830338698], [3.3418074755744396, 8.19507951045086], [3.108388202613223, 8.099979517977424], [3.5406628525191035, 8.060154675227851], (3.1738057932519994, 7.499929494985788), (3.4327897022809757, 7.759577523939718), [3.4815443036554425, 8.251752868846987], (3.100353329321355, 7.657193575331626), (3.26842188051543, 8.496397825184737), (6.863877946757324, 7.793931406749609), (6.751238169905477, 7.248791665301978), (3.0471044674930012, 8.307817948048902), [6.916435849513084, 7.925943090543244], [6.876997445046552, 7.597520246231461], [6.657386669775388, 7.462709319238687], (3.2979503325418094, 7.673429685205675), [6.948397567146724, 7.146793977614895], (3.3608833456630838, 7.962105092865674), (3.043375405980545, 8.629945397579522), [6.897691609160847, 6.929693525111761]]
# iteration 0
# [[-0.002660582122645036, -0.0028100781372039025, -0.003532226394971365, -0.0029966497273027754, -0.0036154481208527057, -0.003502321844069752, -0.0028944159223014206, -0.003750254748256273, -0.002591364364104147, -0.003721976976824455, -0.002905567993086382, -0.0037690537768798192, -0.0031136291327869357, -0.002267516167410523, -0.002481201779344783, -0.0023235807519888865, -0.0024489945071245194, -0.0024720924521137735, -0.0022319081174388172, -0.003244567966630569], [-0.028693578028890675, -0.02680105481069049, -0.01979380465945864, -0.02508303924591847, -0.01924011930733249, -0.019925689109712715, -0.02610500023093379, -0.017981902246222682, -0.02926225515295421, -0.018256144845235227, -0.025952431695603878, -0.017741170993625092, -0.023630348580612224, -0.03290947006553062, -0.0304202782434197, -0.03242488976665443, -0.031153301058078803, -0.030595169044354803, -0.033933610821541754, -0.02243358967782213]]
# --- 0.01983499526977539 seconds ---
# objopt for global iteration  15  is ready
# b before boundchange:  [0.003832469802851988, 0.03500164182110817]
# b [0.003832469802851988, 0.03500164182110817]
# b after boundchange:  [0.0037688508041246365, 0.03437861259669278]
# [[3.1306756941428437, 7.942173626468862], [3.368870905585632, 8.164682096629232], [3.0910436218418393, 8.030139636517344], [3.512912848626962, 8.11441398373949], [3.389541403874193, 8.030526061750571], [3.2180721612117478, 8.019080134150041], [3.24012367457398, 8.116482052000583], [3.5060367955506395, 8.063777708863595], [3.344582391271431, 7.996833052986727], [3.1987315673030383, 8.142707883159126], [3.4277110786774037, 8.030619081343715], [3.4350736416289362, 8.169489953126982], [3.4756703926024115, 8.138221958665865], [3.4248169060884437, 8.059843744221618], [3.494172597071456, 8.075590591844701], [3.2354521449428084, 8.072190039721047], [3.058594896246582, 8.173834212398601], [3.295427328305894, 8.153854726732808], [3.0707574085085994, 8.006752324409991]]
#  and size of P is 19
# DIVOPT
# parameters for divopt [[3.1306756941428437, 7.942173626468862], [3.368870905585632, 8.164682096629232], [3.0910436218418393, 8.030139636517344], [3.512912848626962, 8.11441398373949], [3.389541403874193, 8.030526061750571], [3.2180721612117478, 8.019080134150041], [3.24012367457398, 8.116482052000583], [3.5060367955506395, 8.063777708863595], [3.344582391271431, 7.996833052986727], [3.1987315673030383, 8.142707883159126], [3.4277110786774037, 8.030619081343715], [3.4350736416289362, 8.169489953126982], [3.4756703926024115, 8.138221958665865], [3.4248169060884437, 8.059843744221618], [3.494172597071456, 8.075590591844701], [3.2354521449428084, 8.072190039721047], [3.058594896246582, 8.173834212398601], [3.295427328305894, 8.153854726732808], [3.0707574085085994, 8.006752324409991]] 20 [0.0037688508041246365, 0.03437861259669278] 3 10 10 3
# iteration 0
# GENERATION 0
# GENERATION 1
# GENERATION 2
# GENERATION 3
# GENERATION 4
# GENERATION 5
# GENERATION 6
# GENERATION 7
# GENERATION 8
# GENERATION 9
# GENERATION 10
# GENERATION 11
# GENERATION 12
# GENERATION 13
# GENERATION 14
# GENERATION 15
# GENERATION 16
# GENERATION 17
# GENERATION 18
# GENERATION 19
# GENERATION 20
# GENERATION 21
# GENERATION 22
# all energies [887007.1523052198, 442437.0623482759, 316673.5844527058, 243068.543830031, 190524.47846804894, 142709.61333054697, 106078.12897484502, 83601.71973170491, 65079.43801759323, 47004.19546440386, 34633.52688039908, 31379.077118764242, 29362.08608169665, 24301.487145657324, 21759.291424434512, 20322.709684691166, 19579.28780934803, 16656.526633430538, 14281.766123767153, 12232.74072791749, 10177.76151449703, 10177.76151449703, 10177.76151449703, 10177.76151449703] [[3.512912848626962, 8.11441398373949], [3.058594896246582, 8.173834212398601], [3.0707574085085994, 8.006752324409991], (3.1845677917530897, 8.574625009295612), [3.366497260184003, 7.765989213876334], (6.93262808953506, 7.822646159204722), (3.077085937208917, 7.602860951787438), [6.844504730088674, 7.197702063011828], [3.0952564424278526, 7.823712192024843], (3.324900688659835, 8.365112968413715), (3.5143953894898377, 7.968455408250682), [3.1859322973007025, 7.6841333216024275], [3.2714411631762603, 7.912298778152559], [6.658774942821448, 7.669880507511565], (3.154854653954151, 8.326757686519727), (3.3066091945482956, 8.23500175806434), (6.871617468564937, 7.370361518029833), [6.905482980556171, 7.998881623255398], (6.869114902022443, 7.551316563898791), (6.9052266672688605, 7.030011374164472)]
# --- 0.3041861057281494 seconds ---
# [[[3.512912848626962, 8.11441398373949],
#   [3.058594896246582, 8.173834212398601],
#   [3.0707574085085994, 8.006752324409991],
#   (3.1845677917530897, 8.574625009295612),
#   [3.366497260184003, 7.765989213876334],
#   (6.93262808953506, 7.822646159204722),
#   (3.077085937208917, 7.602860951787438),
#   [6.844504730088674, 7.197702063011828],
#   [3.0952564424278526, 7.823712192024843],
#   (3.324900688659835, 8.365112968413715),
#   (3.5143953894898377, 7.968455408250682),
#   [3.1859322973007025, 7.6841333216024275],
#   [3.2714411631762603, 7.912298778152559],
#   [6.658774942821448, 7.669880507511565],
#   (3.154854653954151, 8.326757686519727),
#   (3.3066091945482956, 8.23500175806434),
#   (6.871617468564937, 7.370361518029833),
#   [6.905482980556171, 7.998881623255398],
#   (6.869114902022443, 7.551316563898791),
#   (6.9052266672688605, 7.030011374164472)],
#      SP diversity  Min-max diversity  S-energy diversity  \
#  0       1.289199           0.020000          445.861269
#  1       1.980102           0.818463            0.046996
#  2       1.944350           0.694504            0.086237
#  3       1.909718           0.603440            0.122361
#  4       1.868096           0.565884            0.167106
#  5       1.679268           0.418611            0.426894
#  6       1.445354           0.262038            0.977607
#  7       1.214420           0.211812            2.065215
#  8       1.330658           0.263146            1.400569
#  9       1.243406           0.270575            1.782164
#  10      1.092961           0.207337            2.912163
#  11      0.969974           0.194866            4.403952
#  12      0.932459           0.162802            5.354232
#  13      0.878485           0.154161            8.053072
#  14      0.893196           0.136835            6.358196
#  15      0.874242           0.142089            7.188849
#
#      Average Himmelblaus function (obj1)  Average x**2 function (obj1)
#  0                              0.011730                      0.106289
#  1                              0.004938                      0.049297
#  2                              0.004299                      0.045781
#  3                              0.004195                      0.044466
#  4                              0.004060                      0.041109
#  5                              0.003714                      0.037357
#  6                              0.003349                      0.034285
#  7                              0.003270                      0.032111
#  8                              0.003466                      0.032270
#  9                              0.003446                      0.030988
#  10                             0.003262                      0.030597
#  11                             0.003158                      0.030784
#  12                             0.003186                      0.029861
#  13                             0.003184                      0.029842
#  14                             0.003216                      0.029823
#  15                             0.003205                      0.029042  ,
#      Optimization  Diversity Optimization
#  0       7.592058                3.276156
#  1       7.947172                3.345115
#  2       7.952119                5.242843
#  3       8.107698                5.443358
#  4       8.228346                6.580775
#  5       8.332606                6.993966
#  6       8.293255                7.044363
#  7       8.345070                7.140245
#  8       8.320748                7.052329
#  9       8.262684                7.243584
#  10      8.339838                7.447856
#  11      8.331406                7.383274
#  12      8.377759                7.426697
#  13      8.326120                7.487263
#  14      8.293860                7.495648
#  15      8.413539                7.591329]

# %%
repeats = 50

random.seed(14)


# NOAH_senergy_repeats(P_0, repeats, it, max_global_iteration, max_gen, pop_size, global_bound, b, r_number, c, mutation_rate, mutation_rate_div, box_border, s)

# %%
it = 1
max_gen = 10
pop_size = 20
b = [3, 3]
c = 3
global_bound = [0, 0]
r_number = 19
mutation_rate_div = 10
box_border = 10
max_global_iteration = 16
theta = 5
s = 3

random.seed(15)

NOAH_SP(P_0, it, max_global_iteration, max_gen, pop_size, global_bound, b, r_number, c, mutation_rate, mutation_rate_div, box_border, theta)
# Out:
# Global_iteration:  0 b is  [3, 3]
# OBJOPT [[0, 1], [0, 0.5], [2, 4], [2, 4.2], [1.97, 4], [1.9, 2.1], [6.9, 7], [9, 4], [7, 7], [7, 8], [7, 7.03], [9.05, 1], [6.5, 7], [2, 2.04], [7.3, 7], [9.03, 10], [2, 2], [0, 6], [0.1, 0.3], [2, 1.98]]
# iteration 0
# [[-0.004515817164048172, -0.0034717049572181263, -0.004254363837717766, -0.005972734014873347, -0.0038052576529833083, -0.0048644070416099874, -0.002281929336962428, -0.006433005653255137, -0.008737018457220148, -0.006218113821142207, -0.00301109114686502, -0.0032837037721681586, -0.00439394065445195, -0.003223410704262293, -0.005619700245857962, -0.001720316414539356, -0.004181780118578853, -0.0030732915934399054, -0.002663168372413536, -0.00238515507462635], [-0.017467720630332244, -0.026835656658938844, -0.019555149875824848, -0.008448845777788655, -0.024113435016523424, -0.015002064202441165, -0.03903740442762103, -0.006578917686360969, -0.00035780675060557185, -0.008033612445323975, -0.03249024328925258, -0.02854162836561411, -0.018697382166183964, -0.029213966726734944, -0.01009729870873567, -0.0457467428978355, -0.020674439157100072, -0.03195738261121202, -0.03479522929660634, -0.03786384845076069]]
# --- 0.05080699920654297 seconds ---
# objopt for global iteration  0  is ready
# b before boundchange:  [3, 3]
# b [3, 3]
# b after boundchange:  [0.02549999999951963, 0.05309999999951978]
# [[6.471789546641034, 7.589330872390356], [7.125045214589132, 7.407429759803421], [6.962353062714291, 7.506974004906378], [7.448602347649879, 7.383603576434109], [6.455295461789258, 7.563537341913496], [6.989748330043978, 7.272106851664574], [6.840321790541895, 7.279450183345494], [6.5322117234545525, 7.4774581489213885], [7.864426738054252, 7.373068671717225], [6.136867933096721, 7.402134301845597], [6.936945314948371, 7.549341497041601], [6.544394727596009, 7.5638384306804305], [6.63192168084548, 7.576635236667136], [6.75308060095362, 7.274123570883114], [6.311608331225201, 7.610411613390268], [7.0449401259153905, 7.5582914395143606], [7.37059069555627, 7.38606028870362], [6.795385948553205, 7.599598049570242], [7.096172858915016, 7.298799726046273]]
#  and size of P is 19
# DIVOPT
# parameters for divopt [[6.471789546641034, 7.589330872390356], [7.125045214589132, 7.407429759803421], [6.962353062714291, 7.506974004906378], [7.448602347649879, 7.383603576434109], [6.455295461789258, 7.563537341913496], [6.989748330043978, 7.272106851664574], [6.840321790541895, 7.279450183345494], [6.5322117234545525, 7.4774581489213885], [7.864426738054252, 7.373068671717225], [6.136867933096721, 7.402134301845597], [6.936945314948371, 7.549341497041601], [6.544394727596009, 7.5638384306804305], [6.63192168084548, 7.576635236667136], [6.75308060095362, 7.274123570883114], [6.311608331225201, 7.610411613390268], [7.0449401259153905, 7.5582914395143606], [7.37059069555627, 7.38606028870362], [6.795385948553205, 7.599598049570242], [7.096172858915016, 7.298799726046273]] 20 [0.02549999999951963, 0.05309999999951978] 3 10 10 5
# iteration 0
# GENERATION 0
# GENERATION 1
# GENERATION 2
# GENERATION 3
# GENERATION 4
# GENERATION 5
# GENERATION 6
# GENERATION 7
# GENERATION 8
# GENERATION 9
# GENERATION 10
# GENERATION 11
# GENERATION 12
# GENERATION 13
# GENERATION 14
# GENERATION 15
# GENERATION 16
# GENERATION 17
# GENERATION 18
# GENERATION 19
# GENERATION 20
# GENERATION 21
# GENERATION 22
# GENERATION 23
# GENERATION 24
# GENERATION 25
# GENERATION 26
# GENERATION 27
# GENERATION 28
# GENERATION 29
# GENERATION 30
# GENERATION 31
# GENERATION 32
# GENERATION 33
# GENERATION 34
# GENERATION 35
# GENERATION 36
# GENERATION 37
# GENERATION 38
# GENERATION 39
# GENERATION 40
# GENERATION 41
# GENERATION 42
# GENERATION 43
# GENERATION 44
# GENERATION 45
# GENERATION 46
# [[6.136867933096721, 7.402134301845597], (2.4756999145773078, 9.08487469572745), [2.690300434495581, 7.529787126771767], (3.838804504450822, 8.277939185989474), [8.808789372008851, 7.63133752852094], [8.971932855620718, 6.661596284363081], (9.407197523923172, 3.521610547257083), [7.168982186289009, 7.874052375932644], [7.89590678709794, 5.894902691411252], (6.705329496596093, 6.8695604544928734), [2.213050816318157, 1.8612676935443293], (3.5385667889435792, 7.473904804669072), (7.738234141754588, 2.5615349676108803), (8.512808775514893, 4.031278262467587), (1.7063608055657116, 2.74452006361851), [1.78514400007667, 8.288234096485054], (8.728675120604887, 1.9891860730972182), [9.08554579727457, 4.615475516816857], (1.448940193785083, 7.533027398531708), (7.682422958001432, 4.705793875614788)]
# all diversities [5.698283091297775, 7.6981050244109435, 8.687145977282771, 9.67323755268406, 10.660489921857053, 11.626583012486714, 12.316514370385402, 13.280525000738061, 14.208544009130033, 14.830843111465176, 15.646620273117042, 16.15884269183624, 16.28619391652962, 16.508189934460162, 16.99458591657412, 17.349477080322018, 17.581802687709462, 18.012338701764083, 18.24510501265489, 18.404048933966536, 18.679567418266707, 18.909745377641972, 18.919094054585848, 19.00234444755395, 19.002344447553952, 19.194696779245124, 19.33165338531685, 19.446549639678686, 19.446549639678686, 19.446549639678686, 19.45834249964078, 19.531519008542748, 19.634718723157196, 19.634718723157196, 19.640841290262035, 19.65087470433963, 19.65087470433963, 19.675980399985413, 19.675980399985413, 19.675980399985413, 19.69412074086303, 19.69412074086303, 19.724452743053334, 19.724452743053334, 19.730233567703475, 19.730233567703472, 19.73023356770348, 19.730233567703472]
# --- 0.43871116638183594 seconds ---
# Global_iteration:  1 b is  [0.02549999999951963, 0.05309999999951978]
# OBJOPT [[6.136867933096721, 7.402134301845597], (2.4756999145773078, 9.08487469572745), [2.690300434495581, 7.529787126771767], (3.838804504450822, 8.277939185989474), [8.808789372008851, 7.63133752852094], [8.971932855620718, 6.661596284363081], (9.407197523923172, 3.521610547257083), [7.168982186289009, 7.874052375932644], [7.89590678709794, 5.894902691411252], (6.705329496596093, 6.8695604544928734), [2.213050816318157, 1.8612676935443293], (3.5385667889435792, 7.473904804669072), (7.738234141754588, 2.5615349676108803), (8.512808775514893, 4.031278262467587), (1.7063608055657116, 2.74452006361851), [1.78514400007667, 8.288234096485054], (8.728675120604887, 1.9891860730972182), [9.08554579727457, 4.615475516816857], (1.448940193785083, 7.533027398531708), (7.682422958001432, 4.705793875614788)]
# iteration 0
# [[-0.007159836688995352, -0.007593355130878819, -0.003931194159862553, -0.0038159970264966155, -0.0023610097958747444, -0.005249368089690923, -0.004463083186550814, -0.0033111705579393826, -0.002984432519690726, -0.0021028964926360816, -0.006525998754766132, -0.0021937700884229363, -0.005359926323016187, -0.0048824328925309276, -0.0010279764405514153, -0.0012081882201123704, -0.0038398389887567283, -0.0032119736612154534, -0.002950998827034251, -0.0012042545149897664], [-0.0029674907665168653, -0.00014070252943066119, -0.0186791641773372, -0.02475551323808196, -0.03395457171080465, -0.012474782563559618, -0.018011064689155042, -0.028137885843662176, -0.031912774813749475, -0.04159140665270888, -0.003603515829533368, -0.03402719818931498, -0.01007404054000525, -0.014789669261628224, -0.04974220365949952, -0.04731479396641177, -0.02312176775782633, -0.02940995873572274, -0.0320121440268627, -0.048317946690619715]]
# --- 0.027797937393188477 seconds ---
# objopt for global iteration  1  is ready
# b before boundchange:  [0.02549999999951963, 0.05309999999951978]
# b [0.02549999999951963, 0.05309999999951978]
# b after boundchange:  [0.023074949999565376, 0.04831568999956226]
# [[3.2664712018443, 8.11629978194478], [7.675787115783943, 7.2079227682099285], [7.421925205831377, 7.380568880407532], [3.645302617205021, 8.092447722268803], [3.5329916615225327, 7.793180041682261], [3.7467671034816847, 8.135988294487543], [2.8686074290523886, 8.300997343168905], [7.307869813251368, 7.163222746119959], [3.902614691646655, 7.844636421182065], [3.282152851085333, 7.650391938099785], [3.900823844821782, 8.136428148513641], [6.959550710942875, 7.429934376616428], [2.684848531301637, 7.8076468665668015], [3.5188618942100853, 7.991973716669471], [2.445396556260418, 8.326704224831952], [7.112601047654482, 7.324374652536378], [6.7275510179704465, 7.65753593338003], [7.291149949193837, 7.227842162389841], [3.4634422250124324, 8.295590835644546]]
#  and size of P is 19
# DIVOPT
# parameters for divopt [[3.2664712018443, 8.11629978194478], [7.675787115783943, 7.2079227682099285], [7.421925205831377, 7.380568880407532], [3.645302617205021, 8.092447722268803], [3.5329916615225327, 7.793180041682261], [3.7467671034816847, 8.135988294487543], [2.8686074290523886, 8.300997343168905], [7.307869813251368, 7.163222746119959], [3.902614691646655, 7.844636421182065], [3.282152851085333, 7.650391938099785], [3.900823844821782, 8.136428148513641], [6.959550710942875, 7.429934376616428], [2.684848531301637, 7.8076468665668015], [3.5188618942100853, 7.991973716669471], [2.445396556260418, 8.326704224831952], [7.112601047654482, 7.324374652536378], [6.7275510179704465, 7.65753593338003], [7.291149949193837, 7.227842162389841], [3.4634422250124324, 8.295590835644546]] 20 [0.023074949999565376, 0.04831568999956226] 3 10 10 5
# iteration 0
# GENERATION 0
# GENERATION 1
# GENERATION 2
# GENERATION 3
# GENERATION 4
# GENERATION 5
# GENERATION 6
# GENERATION 7
# GENERATION 8
# GENERATION 9
# GENERATION 10
# GENERATION 11
# GENERATION 12
# GENERATION 13
# GENERATION 14
# GENERATION 15
# GENERATION 16
# GENERATION 17
# GENERATION 18
# GENERATION 19
# GENERATION 20
# GENERATION 21
# GENERATION 22
# GENERATION 23
# GENERATION 24
# GENERATION 25
# GENERATION 26
# GENERATION 27
# GENERATION 28
# GENERATION 29
# GENERATION 30
# GENERATION 31
# GENERATION 32
# GENERATION 33
# GENERATION 34
# GENERATION 35
# [[3.902614691646655, 7.844636421182065], [2.445396556260418, 8.326704224831952], [6.7275510179704465, 7.65753593338003], (8.06867209267532, 6.66361184437453), (1.479058247788588, 7.6044546440445835), [7.20725515795009, 6.231724078038548], (2.0908214664626987, 7.086949900625161), [8.608373720729467, 5.597615052709039], [1.5297679431506541, 8.773722856406055], [8.676643002777816, 6.904228023122106], (3.484955093137108, 8.421311656255694), [7.998926937337847, 2.697411170637756], [7.981063390735212, 8.135948445379526], [7.41796413087075, 7.5688856928962], (7.850397678220217, 5.87825494072866), (8.947666593622424, 2.9166597666158385), (8.496069628421267, 4.052475466857792), [9.100308447559005, 4.846104187967706], (3.316944707133686, 7.278490963305826), (7.916787148151833, 4.171000561536873)]
# all diversities [9.952184932327, 11.859736314945835, 12.804621117357037, 13.711955858863291, 14.070284821732244, 14.844475084476212, 15.592646846834619, 16.058201108289673, 16.058201108289676, 16.058201108289676, 16.67000545333886, 16.749690055273597, 17.227158887762094, 17.22715888776209, 17.726928390476168, 18.220441048295324, 18.22044104829532, 18.552687567016772, 18.552687567016772, 18.603881332503775, 18.603881332503775, 18.603881332503775, 18.613229513498176, 18.613229513498176, 18.76988708814124, 18.769887088141235, 19.025581885991848, 19.0269384162186, 19.0269384162186, 19.218488842076155, 19.21848884207616, 19.268773623711503, 19.26877362371151, 19.340466900982626, 19.340466900982623, 19.340466900982626, 19.340466900982626]
# --- 0.152069091796875 seconds ---
# Global_iteration:  2 b is  [0.023074949999565376, 0.04831568999956226]
# OBJOPT [[3.902614691646655, 7.844636421182065], [2.445396556260418, 8.326704224831952], [6.7275510179704465, 7.65753593338003], (8.06867209267532, 6.66361184437453), (1.479058247788588, 7.6044546440445835), [7.20725515795009, 6.231724078038548], (2.0908214664626987, 7.086949900625161), [8.608373720729467, 5.597615052709039], [1.5297679431506541, 8.773722856406055], [8.676643002777816, 6.904228023122106], (3.484955093137108, 8.421311656255694), [7.998926937337847, 2.697411170637756], [7.981063390735212, 8.135948445379526], [7.41796413087075, 7.5688856928962], (7.850397678220217, 5.87825494072866), (8.947666593622424, 2.9166597666158385), (8.496069628421267, 4.052475466857792), [9.100308447559005, 4.846104187967706], (3.316944707133686, 7.278490963305826), (7.916787148151833, 4.171000561536873)]
# iteration 0
# [[-0.004708405822051797, -0.0022039146443296564, -0.0016743076555032512, -0.004009001642621525, -0.0031406609038870125, -0.002094184484338172, -0.0026837201048702944, -0.009583496947672335, -0.0012042545149897664, -0.002797160374093332, -0.0055463083764110905, -0.006494200609488945, -0.0015108622962127438, -0.003876488399856772, -0.0034716197667605765, -0.006312421038244205, -0.006476939581572886, -0.005956435008790837, -0.0030522823111114165, -0.005530698255666547], [-0.010549463880159262, -0.033900754920725064, -0.04040127180065864, -0.015512406172158284, -0.02343347566133071, -0.03539786112533945, -0.028704088650542317, -0.0004302077691715907, -0.048317946690619715, -0.027198072940614125, -0.005874762686206217, -0.0019615190806953216, -0.04344269843424319, -0.01701869894529091, -0.020266104372444783, -0.0041330616160732084, -0.0031379398044122046, -0.004385085234197833, -0.025316616305702387, -0.009051178754148716]]
# objopt final generation contains solutions >= b for iteration  1
# --- 0.04181790351867676 seconds ---
# objopt for global iteration  2  is ready
# b before boundchange:  [0.023074949999565376, 0.04831568999956226]
# b [0.023074949999565376, 0.04831568999956226]
# b after boundchange:  [0.021332791274597317, 0.04489493914759407]
# [[3.3668890005703145, 7.853716410271534], [2.830113868874268, 8.045256182682397], [3.1373331057312295, 7.859488978549992], [3.797954793997274, 7.854584659332927], [3.5963077981862996, 8.000052256097453], [3.35761631547081, 8.115820402203513], [3.2745773376168974, 8.028142205459218], [2.6482563371688346, 7.816497276811651], [2.55941912471829, 7.998428995243985], [2.4550167816716577, 7.953575497610313], [2.4875468087456425, 7.917592819533641], [3.136771681526771, 8.14395986257325], [3.031120013851334, 8.201063621742112], [3.7708286139790173, 8.18777915904268], [2.45162785106081, 8.111728504177696], [2.644939835925398, 8.201814438932365], [3.327528662699019, 8.166409639066423], [8.095722362821371, 6.846297235488367], [3.361793631781913, 7.960094251499081]]
#  and size of P is 19
# DIVOPT
# parameters for divopt [[3.3668890005703145, 7.853716410271534], [2.830113868874268, 8.045256182682397], [3.1373331057312295, 7.859488978549992], [3.797954793997274, 7.854584659332927], [3.5963077981862996, 8.000052256097453], [3.35761631547081, 8.115820402203513], [3.2745773376168974, 8.028142205459218], [2.6482563371688346, 7.816497276811651], [2.55941912471829, 7.998428995243985], [2.4550167816716577, 7.953575497610313], [2.4875468087456425, 7.917592819533641], [3.136771681526771, 8.14395986257325], [3.031120013851334, 8.201063621742112], [3.7708286139790173, 8.18777915904268], [2.45162785106081, 8.111728504177696], [2.644939835925398, 8.201814438932365], [3.327528662699019, 8.166409639066423], [8.095722362821371, 6.846297235488367], [3.361793631781913, 7.960094251499081]] 20 [0.021332791274597317, 0.04489493914759407] 3 10 10 5
# iteration 0
# GENERATION 0
# GENERATION 1
# GENERATION 2
# GENERATION 3
# GENERATION 4
# GENERATION 5
# GENERATION 6
# GENERATION 7
# GENERATION 8
# GENERATION 9
# GENERATION 10
# GENERATION 11
# GENERATION 12
# GENERATION 13
# GENERATION 14
# GENERATION 15
# GENERATION 16
# GENERATION 17
# GENERATION 18
# GENERATION 19
# GENERATION 20
# GENERATION 21
# GENERATION 22
# GENERATION 23
# GENERATION 24
# GENERATION 25
# GENERATION 26
# GENERATION 27
# GENERATION 28
# GENERATION 29
# GENERATION 30
# GENERATION 31
# GENERATION 32
# GENERATION 33
# GENERATION 34
# GENERATION 35
# GENERATION 36
# GENERATION 37
# GENERATION 38
# GENERATION 39
# GENERATION 40
# GENERATION 41
# GENERATION 42
# [[3.797954793997274, 7.854584659332927], [2.45162785106081, 8.111728504177696], (7.332263515250796, 5.601883105945095), (1.9066957962325577, 2.059903726127418), (6.973618489627398, 7.645029350746458), (1.5450129250172453, 7.311375566632049), [8.23623211168147, 8.116767131803828], (7.745482579578179, 4.901435653928392), [8.984753536296541, 4.361089995948173], [7.57880873605683, 3.7747358178684483], (8.805155371551923, 7.094411451105726), [2.9208478896541177, 8.782335495870083], [8.95277346775504, 2.94855473615444], [3.1323181256851855, 7.466108866343253], (8.654602934626382, 5.933883168978742), (9.118698465247967, 2.0291100933981827), [8.102114907590806, 6.709309882808723], (6.8581866945174745, 6.537950565813389), (8.220908354034966, 2.3970146977194), [1.504748250583587, 8.130673786687694]]
# all diversities [6.823545069726045, 8.789791350881067, 9.781609947604064, 10.77662041347167, 11.760831382981966, 11.822593689662343, 12.678172980610519, 13.006496869580989, 13.423793898579447, 14.306339268755305, 15.184427928395365, 15.925397550148007, 16.55805225753976, 16.558052257539757, 17.042511568861876, 17.689047161050947, 18.260275505962852, 18.354215954878455, 18.35421595487846, 18.354215954878455, 18.43940778417131, 18.736591325943706, 18.73659132594371, 18.81682882650317, 18.86084626868907, 19.14903706777976, 19.221108966225323, 19.238709771172054, 19.23870977117205, 19.307200644893555, 19.35944243255669, 19.371395792853665, 19.371395792853665, 19.49093918915356, 19.49093918915356, 19.49093918915356, 19.51294222952532, 19.538108793404923, 19.610953324780084, 19.61095332478008, 19.645515182541253, 19.645515182541253, 19.645515182541253, 19.645515182541253]
# --- 0.12983202934265137 seconds ---
# Global_iteration:  3 b is  [0.021332791274597317, 0.04489493914759407]
# OBJOPT [[3.797954793997274, 7.854584659332927], [2.45162785106081, 8.111728504177696], (7.332263515250796, 5.601883105945095), (1.9066957962325577, 2.059903726127418), (6.973618489627398, 7.645029350746458), (1.5450129250172453, 7.311375566632049), [8.23623211168147, 8.116767131803828], (7.745482579578179, 4.901435653928392), [8.984753536296541, 4.361089995948173], [7.57880873605683, 3.7747358178684483], (8.805155371551923, 7.094411451105726), [2.9208478896541177, 8.782335495870083], [8.95277346775504, 2.94855473615444], [3.1323181256851855, 7.466108866343253], (8.654602934626382, 5.933883168978742), (9.118698465247967, 2.0291100933981827), [8.102114907590806, 6.709309882808723], (6.8581866945174745, 6.537950565813389), (8.220908354034966, 2.3970146977194), [1.504748250583587, 8.130673786687694]]
# iteration 0
# [[-0.0015126197583265877, -0.0037483188631544525, -0.0059482582132688545, -0.0025017589932803358, -0.0078077303901029965, -0.002534205058421947, -0.0018426922561701373, -0.002931625003377117, -0.0020265352788868983, -0.0017692820182076258, -0.008052180969983391, -0.006021785623448028, -0.006438950852878753, -0.004412792809717867, -0.001444912677274136, -0.006494200609488945, -0.0026928764532765295, -0.0014681557532836658, -0.0025052009543381245, -0.005606095107880509], [-0.042921364707138206, -0.017693871789906012, -0.0038192370140478172, -0.03416285417354733, -0.00016530604762546284, -0.029835566263489065, -0.03825319444742542, -0.0254970056525823, -0.03606462133682771, -0.03945612066538326, -5.328642509664069e-05, -0.0036950081651218923, -0.0021287721770260246, -0.012871346040400378, -0.04489958660815149, -0.0019615190806953216, -0.029361058899973813, -0.04336595586421309, -0.030313400535450643, -0.00530858898586347]]
# objopt final generation contains solutions >= b for iteration  1
# --- 0.037895917892456055 seconds ---
# objopt for global iteration  3  is ready
# b before boundchange:  [0.021332791274597317, 0.04489493914759407]
# b [0.021332791274597317, 0.04489493914759407]
# b after boundchange:  [0.020594676696496627, 0.043364021722661024]
# [[3.742906546642715, 7.884360970579879], [3.770113924655382, 8.136879011019053], [3.2283526702255867, 8.042699361811765], [3.17316860920265, 8.08028232339372], [2.9617534255294093, 8.091834766996914], [3.4696269076069854, 7.846869415959075], [2.423914185808808, 8.181866674439723], [2.8210342213012876, 8.057040183778167], [2.2388948077516604, 8.110083724322601], [2.632280610401539, 8.110365419743145], [3.41721733824946, 8.009513834267233], [3.7883252279247266, 7.981557228737573], [3.3590013853520384, 7.894827223397753], [2.45162785106081, 8.111728504177696], [2.899335150549268, 8.000819277300067], [2.4624912112706383, 8.106283875878042], [2.546067314809139, 8.05853905748568], [2.162363488749239, 8.110242603097404], [3.669856391885588, 7.967249032234609]]
#  and size of P is 19
# DIVOPT
# parameters for divopt [[3.742906546642715, 7.884360970579879], [3.770113924655382, 8.136879011019053], [3.2283526702255867, 8.042699361811765], [3.17316860920265, 8.08028232339372], [2.9617534255294093, 8.091834766996914], [3.4696269076069854, 7.846869415959075], [2.423914185808808, 8.181866674439723], [2.8210342213012876, 8.057040183778167], [2.2388948077516604, 8.110083724322601], [2.632280610401539, 8.110365419743145], [3.41721733824946, 8.009513834267233], [3.7883252279247266, 7.981557228737573], [3.3590013853520384, 7.894827223397753], [2.45162785106081, 8.111728504177696], [2.899335150549268, 8.000819277300067], [2.4624912112706383, 8.106283875878042], [2.546067314809139, 8.05853905748568], [2.162363488749239, 8.110242603097404], [3.669856391885588, 7.967249032234609]] 20 [0.020594676696496627, 0.043364021722661024] 3 10 10 5
# iteration 0
# GENERATION 0
# GENERATION 1
# GENERATION 2
# GENERATION 3
# GENERATION 4
# GENERATION 5
# GENERATION 6
# GENERATION 7
# GENERATION 8
# GENERATION 9
# GENERATION 10
# GENERATION 11
# GENERATION 12
# GENERATION 13
# GENERATION 14
# GENERATION 15
# GENERATION 16
# GENERATION 17
# GENERATION 18
# GENERATION 19
# GENERATION 20
# GENERATION 21
# GENERATION 22
# GENERATION 23
# GENERATION 24
# GENERATION 25
# GENERATION 26
# GENERATION 27
# GENERATION 28
# GENERATION 29
# GENERATION 30
# GENERATION 31
# GENERATION 32
# GENERATION 33
# GENERATION 34
# GENERATION 35
# GENERATION 36
# GENERATION 37
# GENERATION 38
# GENERATION 39
# GENERATION 40
# [[3.770113924655382, 8.136879011019053], [2.162363488749239, 8.110242603097404], [7.69692458408521, 5.967474415581444], (1.3627331327274477, 1.0042755571483486), (2.9328084865532795, 7.67893849552334), (8.208371090988004, 7.819071748768126), (6.731361076445116, 7.142702510255031), [7.815645614715948, 4.721863474361421], (8.74751070045166, 6.348890840464616), (7.037087853778516, 8.166288030529566), (8.622087674813537, 4.600442126826588), (9.026402591443535, 5.4437457276968875), [1.7184017888226502, 2.938740161651735], [8.745930205775204, 7.488170507100616], [8.94845131902276, 4.000150704641417], [1.8262485526557082, 8.786961778069443], [8.65287618973006, 2.064961312645773], (1.59102521905821, 7.108587064417218), [7.939709585522026, 3.4436209978402825], (1.10113528926083, 2.294461103201815)]
# all diversities [5.5152467739398405, 6.94136861173064, 7.9379499894713454, 8.932269579625682, 9.52054413103119, 10.489362246083212, 11.462785111818244, 11.903525428448702, 12.868064437257514, 13.806529965728272, 14.65645057295759, 14.934390125182698, 15.682100454586394, 15.946638623127992, 16.609628065811098, 17.22003952798611, 17.43554839294726, 17.43554839294726, 17.9153327506275, 18.36481661174354, 18.71970607980285, 18.719706079802855, 18.719706079802855, 18.726094510666293, 18.731141931841545, 18.974369522904027, 19.20285005497757, 19.20285005497757, 19.202850054977574, 19.460026043102268, 19.460026043102268, 19.460026043102268, 19.462498766307576, 19.462498766307576, 19.462498766307576, 19.591336272074436, 19.593619863225314, 19.593619863225314, 19.61342204530262, 19.61342204530262, 19.613422045302624, 19.61342204530262]
# --- 0.11949396133422852 seconds ---
# Global_iteration:  4 b is  [0.020594676696496627, 0.043364021722661024]
# OBJOPT [[3.770113924655382, 8.136879011019053], [2.162363488749239, 8.110242603097404], [7.69692458408521, 5.967474415581444], (1.3627331327274477, 1.0042755571483486), (2.9328084865532795, 7.67893849552334), (8.208371090988004, 7.819071748768126), (6.731361076445116, 7.142702510255031), [7.815645614715948, 4.721863474361421], (8.74751070045166, 6.348890840464616), (7.037087853778516, 8.166288030529566), (8.622087674813537, 4.600442126826588), (9.026402591443535, 5.4437457276968875), [1.7184017888226502, 2.938740161651735], [8.745930205775204, 7.488170507100616], [8.94845131902276, 4.000150704641417], [1.8262485526557082, 8.786961778069443], [8.65287618973006, 2.064961312645773], (1.59102521905821, 7.108587064417218), [7.939709585522026, 3.4436209978402825], (1.10113528926083, 2.294461103201815)]
# iteration 0
# [[-0.0030028873014230585, -0.002418471290206462, -0.001762842483287621, -0.0037458663020450487, -0.0022225107086551034, -0.0036617435405896567, -0.005977722820994044, -0.007163603984783469, -0.006589691643845338, -0.001689014888119028, -0.0055909357510381405, -0.0026086010942550824, -0.004610753853564579, -0.004460751924507546, -0.003358030612044642, -0.007968629575175884, -0.0024723436910515967, -0.001854522166049199, -0.004904646223717147, -0.0017474629506907579], [-0.025332653650893287, -0.031383711634994954, -0.03935783054667351, -0.020560635668558667, -0.0343563349643576, -0.02258396913453334, -0.003977346349828938, -0.0008880371502825126, -0.002945357042537473, -0.04025774055364897, -0.00537671062730308, -0.029457639889728167, -0.011122474552110212, -0.01253658903209684, -0.022863344157359432, -0.00042042122533383035, -0.03091128110470638, -0.039029100230663374, -0.009926881621712489, -0.0395441254435858]]
# --- 0.035215139389038086 seconds ---
# objopt for global iteration  4  is ready
# b before boundchange:  [0.020594676696496627, 0.043364021722661024]
# b [0.020594676696496627, 0.043364021722661024]
# b after boundchange:  [0.018403403095990905, 0.039027619550392696]
# [[3.1171670728766823, 8.204791646466193], [3.267115900753008, 7.9642455288547085], [2.3440565861903004, 8.16222034358517], [2.634403308592532, 8.104318872647653], [3.143282574895057, 7.911315388733552], [2.977936938424, 8.30223085231973], [2.805221939373677, 8.038608108265423], [2.8358734207114877, 8.173629877524014], [3.4618167268039812, 7.828711183409772], [2.3646700014425877, 8.205223195329994], [2.9027717949298006, 8.035926973195217], [2.523514380559665, 8.160326200869706], [3.6381915824723365, 8.212029114205539], [3.42763118478787, 7.974761304317807], [2.1771238824248975, 8.028940689291716], [2.887950776021651, 8.213600205222484], [3.1675069953626993, 8.287538842122897], [2.8527333995135633, 8.157936115424457], [2.6354840345140107, 8.12102143449946]]
#  and size of P is 19
# DIVOPT
# parameters for divopt [[3.1171670728766823, 8.204791646466193], [3.267115900753008, 7.9642455288547085], [2.3440565861903004, 8.16222034358517], [2.634403308592532, 8.104318872647653], [3.143282574895057, 7.911315388733552], [2.977936938424, 8.30223085231973], [2.805221939373677, 8.038608108265423], [2.8358734207114877, 8.173629877524014], [3.4618167268039812, 7.828711183409772], [2.3646700014425877, 8.205223195329994], [2.9027717949298006, 8.035926973195217], [2.523514380559665, 8.160326200869706], [3.6381915824723365, 8.212029114205539], [3.42763118478787, 7.974761304317807], [2.1771238824248975, 8.028940689291716], [2.887950776021651, 8.213600205222484], [3.1675069953626993, 8.287538842122897], [2.8527333995135633, 8.157936115424457], [2.6354840345140107, 8.12102143449946]] 20 [0.018403403095990905, 0.039027619550392696] 3 10 10 5
# iteration 0
# GENERATION 0
# GENERATION 1
# GENERATION 2
# GENERATION 3
# GENERATION 4
# GENERATION 5
# GENERATION 6
# GENERATION 7
# GENERATION 8
# GENERATION 9
# GENERATION 10
# GENERATION 11
# GENERATION 12
# GENERATION 13
# GENERATION 14
# GENERATION 15
# GENERATION 16
# GENERATION 17
# GENERATION 18
# GENERATION 19
# GENERATION 20
# GENERATION 21
# GENERATION 22
# GENERATION 23
# GENERATION 24
# GENERATION 25
# GENERATION 26
# GENERATION 27
# GENERATION 28
# GENERATION 29
# GENERATION 30
# GENERATION 31
# GENERATION 32
# GENERATION 33
# GENERATION 34
# GENERATION 35
# GENERATION 36
# GENERATION 37
# GENERATION 38
# GENERATION 39
# GENERATION 40
# GENERATION 41
# GENERATION 42
# GENERATION 43
# GENERATION 44
# GENERATION 45
# GENERATION 46
# GENERATION 47
# GENERATION 48
# GENERATION 49
# GENERATION 50
# [[3.6381915824723365, 8.212029114205539], [0.883955590051654, 1.3585063404145847], [6.87506542711225, 7.013010988309128], (1.4502597760351927, 1.5638773055715425), [9.202419608205735, 2.306751255778872], (7.645379719681829, 4.4386249889430225), (2.6602346359672007, 8.726750550742413), (3.01146972877152, 7.3135101028089995), [7.830148216540254, 3.372839271976903], [8.986456184664787, 5.410971957783135], (1.5643919845135574, 7.5351227194822155), (7.582920898664661, 5.451788886034051), [8.705481688788446, 6.738253431099336], [1.7691264215295632, 8.602133252032228], (2.0755552809534414, 7.09173922612443), [9.230347114123939, 3.5725950811806775], [7.917256209242615, 7.987868786254668], (7.885200347973109, 6.698905835864375), [8.350499061011718, 2.4986683361564728], (6.584507770372525, 7.781245381024318)]
# all diversities [5.588846984514631, 7.588599140090064, 8.586568733969523, 8.915375997638563, 9.749752819600188, 10.711297467466704, 11.689522338612898, 12.116548804551353, 12.853973006401212, 12.881965836150002, 13.746970181834307, 14.393980209009495, 15.112378978087529, 15.228335903189592, 15.807484327481827, 15.807484327481829, 16.521398683769103, 17.18001367057808, 17.768498030522817, 18.19204255759127, 18.406363459937054, 18.406363459937054, 18.608827916391782, 18.820563979624318, 18.9348661066341, 18.97932074148007, 18.98392813237823, 18.98392813237823, 19.112843167374287, 19.12990509871808, 19.12990509871808, 19.260761003146698, 19.2607610031467, 19.27400654141475, 19.32679035605245, 19.380571946272013, 19.380571946272013, 19.380571946272013, 19.40136131478836, 19.42500885827837, 19.42500885827837, 19.452457983274005, 19.452457983274, 19.46772167114863, 19.46772167114863, 19.518529788316204, 19.518529788316204, 19.542190840280234, 19.61505470057014, 19.61505470057014, 19.61505470057014, 19.61505470057014]
# --- 0.16089701652526855 seconds ---
# Global_iteration:  5 b is  [0.018403403095990905, 0.039027619550392696]
# OBJOPT [[3.6381915824723365, 8.212029114205539], [0.883955590051654, 1.3585063404145847], [6.87506542711225, 7.013010988309128], (1.4502597760351927, 1.5638773055715425), [9.202419608205735, 2.306751255778872], (7.645379719681829, 4.4386249889430225), (2.6602346359672007, 8.726750550742413), (3.01146972877152, 7.3135101028089995), [7.830148216540254, 3.372839271976903], [8.986456184664787, 5.410971957783135], (1.5643919845135574, 7.5351227194822155), (7.582920898664661, 5.451788886034051), [8.705481688788446, 6.738253431099336], [1.7691264215295632, 8.602133252032228], (2.0755552809534414, 7.09173922612443), [9.230347114123939, 3.5725950811806775], [7.917256209242615, 7.987868786254668], (7.885200347973109, 6.698905835864375), [8.350499061011718, 2.4986683361564728], (6.584507770372525, 7.781245381024318)]
# iteration 0
# [[-0.0037309030491775035, -0.002062827428169421, -0.008468081738312717, -0.0031168755168513684, -0.004331854121350105, -0.004084994572018856, -0.005919835485025916, -0.001988446248684431, -0.0018560798793185805, -0.0023221591618678102, -0.0019718683179791143, -0.008990535507685518, -0.0028065549769159797, -0.008020000662580384, -0.0036101149725421638, -0.0030971957281135045, -0.001854522166049199, -0.0035072847275223963, -0.00355275621744041, -0.0033643157009124614], [-0.017851059703686993, -0.035400763071763396, -0.0007850638430957792, -0.02371966974622099, -0.013043096148903569, -0.014953931604279463, -0.003948409170765159, -0.03641874125294918, -0.03809157903668177, -0.03335388166453595, -0.03781422399413662, -7.83555867427481e-08, -0.02732761531824528, -0.0009195562709802138, -0.018983801799807964, -0.02383563388269846, -0.039029100230663374, -0.02042351577084895, -0.019435169721087952, -0.021188825627918174]]
# objopt final generation contains solutions >= b for iteration  1
# --- 0.035063982009887695 seconds ---
# objopt for global iteration  5  is ready
# b before boundchange:  [0.018403403095990905, 0.039027619550392696]
# b [0.018403403095990905, 0.039027619550392696]
# b after boundchange:  [0.014047317583169065, 0.0300746836255291]
# [[3.267567786579918, 8.1830926365645], [3.0684454319959005, 8.083836077081504], [2.735687571904209, 7.919677819939621], [2.7124572612210542, 8.11329903986033], [2.8390184641590324, 8.037403075705832], [3.3605773583028995, 8.294204634450223], [7.893094741923918, 7.177665829632109], [2.95220420778034, 8.113311190936717], [3.3134642204803577, 8.148695002622397], [2.8670088335478296, 8.146630125224998], [7.724305740344853, 7.131828332360951], [3.165792895850509, 8.073178963727132], [3.1151243496080676, 8.113026662401294], [3.127225393294111, 8.21332963914465], [3.2401148537153044, 8.123891252763656], [3.099969744308748, 8.140421523744202], [7.831960568683891, 7.159845933126785], [3.3247224179509893, 7.967498778150975], [7.998422169689505, 7.001160740379025]]
#  and size of P is 19
# DIVOPT
# parameters for divopt [[3.267567786579918, 8.1830926365645], [3.0684454319959005, 8.083836077081504], [2.735687571904209, 7.919677819939621], [2.7124572612210542, 8.11329903986033], [2.8390184641590324, 8.037403075705832], [3.3605773583028995, 8.294204634450223], [7.893094741923918, 7.177665829632109], [2.95220420778034, 8.113311190936717], [3.3134642204803577, 8.148695002622397], [2.8670088335478296, 8.146630125224998], [7.724305740344853, 7.131828332360951], [3.165792895850509, 8.073178963727132], [3.1151243496080676, 8.113026662401294], [3.127225393294111, 8.21332963914465], [3.2401148537153044, 8.123891252763656], [3.099969744308748, 8.140421523744202], [7.831960568683891, 7.159845933126785], [3.3247224179509893, 7.967498778150975], [7.998422169689505, 7.001160740379025]] 20 [0.014047317583169065, 0.0300746836255291] 3 10 10 5
# iteration 0
# GENERATION 0
# GENERATION 1
# GENERATION 2
# GENERATION 3
# GENERATION 4
# GENERATION 5
# GENERATION 6
# GENERATION 7
# GENERATION 8
# GENERATION 9
# GENERATION 10
# GENERATION 11
# GENERATION 12
# GENERATION 13
# GENERATION 14
# GENERATION 15
# GENERATION 16
# GENERATION 17
# GENERATION 18
# GENERATION 19
# GENERATION 20
# GENERATION 21
# GENERATION 22
# GENERATION 23
# GENERATION 24
# GENERATION 25
# GENERATION 26
# GENERATION 27
# GENERATION 28
# [[2.735687571904209, 7.919677819939621], [3.3605773583028995, 8.294204634450223], [7.893094741923918, 7.177665829632109], [3.3247224179509893, 7.967498778150975], [8.492860932663712, 5.908814635582288], [8.38913319204114, 6.929111502645039], (8.659882840800051, 4.843806804336568), (8.04461917525109, 6.52035718034924), [7.731392211719864, 3.3392171652643583], [1.9942284675677202, 8.367834599750239], (7.111465783136786, 7.896080889828654), [1.8522147142703087, 7.646777425526964], [7.386490614585485, 6.590786687311722], (1.3703030902825066, 8.219725556165157), [8.496969505256159, 5.104345345228681], (8.203221150146176, 4.12623958011153), [7.291643061414335, 7.094153337938089], (8.041677852796937, 6.069403656383454), [2.0240523927047107, 7.207781239492345], [1.7866707183040416, 8.753472059447743]]
# all diversities [5.233397027689179, 6.3444489294908415, 7.339210582060278, 7.400343241065661, 7.405672630516041, 8.258353592835414, 8.995050997236802, 9.463469127080874, 10.448068664292258, 11.36798866404903, 12.02157778163265, 12.994039895634653, 13.43913363961594, 14.32910237042508, 14.776190836806617, 15.312939526477658, 15.423644858614743, 15.423644858614745, 15.782231725656892, 16.468077100462885, 16.682852043971724, 16.682852043971724, 16.982860653758124, 17.07333102964326, 17.109300737715845, 17.109300737715845, 17.36572346786523, 17.36572346786523, 17.36572346786523, 17.36572346786523]
# --- 0.09819579124450684 seconds ---
# Global_iteration:  6 b is  [0.014047317583169065, 0.0300746836255291]
# OBJOPT [[2.735687571904209, 7.919677819939621], [3.3605773583028995, 8.294204634450223], [7.893094741923918, 7.177665829632109], [3.3247224179509893, 7.967498778150975], [8.492860932663712, 5.908814635582288], [8.38913319204114, 6.929111502645039], (8.659882840800051, 4.843806804336568), (8.04461917525109, 6.52035718034924), [7.731392211719864, 3.3392171652643583], [1.9942284675677202, 8.367834599750239], (7.111465783136786, 7.896080889828654), [1.8522147142703087, 7.646777425526964], [7.386490614585485, 6.590786687311722], (1.3703030902825066, 8.219725556165157), [8.496969505256159, 5.104345345228681], (8.203221150146176, 4.12623958011153), [7.291643061414335, 7.094153337938089], (8.041677852796937, 6.069403656383454), [2.0240523927047107, 7.207781239492345], [1.7866707183040416, 8.753472059447743]]
# iteration 0
# [[-0.0035430196756885274, -0.0055282166152896915, -0.005236574806139756, -0.004732300219248037, -0.007022446693431355, -0.004593835801610634, -0.0027768187866562, -0.002825069604747404, -0.008285494672320752, -0.005893320804308909, -0.0064525069707763345, -0.008771284592684952, -0.0030028935710563606, -0.004330005277133831, -0.0025522231433242914, -0.004443069780513002, -0.003917276456811247, -0.005653139347212416, -0.005009983342825644, -0.0028065017466270695], [-0.01998954550947073, -0.006952378741802565, -0.007309778206896363, -0.01140040278696269, -0.00256449214645558, -0.011699813186387346, -0.027984666283169545, -0.027002809909875285, -0.0004950668421091623, -0.00475861870758202, -0.0034327920647335215, -4.557255077389063e-05, -0.02486669162141756, -0.01424072460922668, -0.029701191680687414, -0.012942937008178097, -0.01673403919023848, -0.0067649550896119945, -0.008724378014381902, -0.02704287339943886]]
# --- 0.020462989807128906 seconds ---
# objopt for global iteration  6  is ready
# b before boundchange:  [0.014047317583169065, 0.0300746836255291]
# b [0.014047317583169065, 0.0300746836255291]
# b after boundchange:  [0.0138450362099714, 0.029698750080209984]
# [[2.860972382465852, 8.047827912270952], [3.117708929073793, 8.202703275632567], [3.1299672215288012, 8.277882814408349], [2.3901235963868857, 8.228249498421963], [2.922835951334398, 7.850256622635986], [2.7192555556073073, 8.22845327575733], [2.3291119423050657, 8.127087495114973], [2.391815943941582, 8.264227502251988], [3.324738305031996, 8.00557424401077], [2.7617007923814914, 8.19075235703957], [2.622366860255263, 7.910037859324181], [3.0207889307071754, 7.992084306634891], [2.892140948613261, 8.240834926341776], [3.402432116207799, 8.126218118486802], [2.919133527317567, 7.929460505688037], [2.4598214687198983, 8.303520850402727], [3.267114091737035, 8.03138658376897], [7.961635459114601, 7.026575821050349], [2.5723837197141495, 7.986020508831961]]
#  and size of P is 19
# DIVOPT
# parameters for divopt [[2.860972382465852, 8.047827912270952], [3.117708929073793, 8.202703275632567], [3.1299672215288012, 8.277882814408349], [2.3901235963868857, 8.228249498421963], [2.922835951334398, 7.850256622635986], [2.7192555556073073, 8.22845327575733], [2.3291119423050657, 8.127087495114973], [2.391815943941582, 8.264227502251988], [3.324738305031996, 8.00557424401077], [2.7617007923814914, 8.19075235703957], [2.622366860255263, 7.910037859324181], [3.0207889307071754, 7.992084306634891], [2.892140948613261, 8.240834926341776], [3.402432116207799, 8.126218118486802], [2.919133527317567, 7.929460505688037], [2.4598214687198983, 8.303520850402727], [3.267114091737035, 8.03138658376897], [7.961635459114601, 7.026575821050349], [2.5723837197141495, 7.986020508831961]] 20 [0.0138450362099714, 0.029698750080209984] 3 10 10 5
# iteration 0
# GENERATION 0
# GENERATION 1
# GENERATION 2
# GENERATION 3
# GENERATION 4
# GENERATION 5
# GENERATION 6
# GENERATION 7
# GENERATION 8
# GENERATION 9
# GENERATION 10
# GENERATION 11
# GENERATION 12
# GENERATION 13
# GENERATION 14
# GENERATION 15
# GENERATION 16
# GENERATION 17
# GENERATION 18
# GENERATION 19
# GENERATION 20
# GENERATION 21
# GENERATION 22
# GENERATION 23
# GENERATION 24
# GENERATION 25
# GENERATION 26
# GENERATION 27
# GENERATION 28
# GENERATION 29
# GENERATION 30
# GENERATION 31
# GENERATION 32
# GENERATION 33
# GENERATION 34
# [[2.3291119423050657, 8.127087495114973], [3.402432116207799, 8.126218118486802], [1.720754762146141, 7.523426699818052], [8.26625898002385, 4.836010333334952], [8.259428470150526, 6.945959826671736], (7.765261614748271, 7.188792865208675), [7.438285187090843, 6.332745024756843], [8.462734298666335, 2.4328064497161717], (2.678280671851807, 7.3254520254427495), [8.612984685717313, 6.476519853124284], [7.06713060731985, 7.542545489052001], [1.836174706225925, 8.568212371026295], [7.091393453938614, 6.9290834644497], (2.613344832893481, 8.71826993384537), (8.596577786131096, 5.543212550499114), (8.17768268810094, 6.069875937826929), (7.755767978144966, 7.910719415680244), [8.064822723653288, 4.380683686300472], [8.316320528032552, 3.304731824755217], (1.6406469423743764, 2.563517215905275)]
# all diversities [5.753528247310355, 7.716899490275732, 8.692597627038854, 9.201956571068209, 9.354309931561348, 10.283198882759848, 10.689319744410863, 11.514422548911742, 12.42941555427036, 13.377585433220295, 14.210285893796108, 14.45566271407193, 15.096541559777625, 15.116268897068354, 15.174544603324005, 15.394070395168793, 15.394070395168796, 15.838704237590782, 15.871303214447236, 15.871303214447234, 16.343845476271024, 16.80741076588489, 16.808384225666508, 16.816948276602467, 17.46818878288076, 17.684707479502645, 17.876828784191314, 17.929387973566868, 18.253338864483787, 18.406089766762125, 18.40608976676213, 18.40608976676213, 18.66692116894864, 18.66692116894864, 18.66692116894864, 18.666921169005718]
# --- 0.15149712562561035 seconds ---
# Global_iteration:  7 b is  [0.0138450362099714, 0.029698750080209984]
# OBJOPT [[2.3291119423050657, 8.127087495114973], [3.402432116207799, 8.126218118486802], [1.720754762146141, 7.523426699818052], [8.26625898002385, 4.836010333334952], [8.259428470150526, 6.945959826671736], (7.765261614748271, 7.188792865208675), [7.438285187090843, 6.332745024756843], [8.462734298666335, 2.4328064497161717], (2.678280671851807, 7.3254520254427495), [8.612984685717313, 6.476519853124284], [7.06713060731985, 7.542545489052001], [1.836174706225925, 8.568212371026295], [7.091393453938614, 6.9290834644497], (2.613344832893481, 8.71826993384537), (8.596577786131096, 5.543212550499114), (8.17768268810094, 6.069875937826929), (7.755767978144966, 7.910719415680244), [8.064822723653288, 4.380683686300472], [8.316320528032552, 3.304731824755217], (1.6406469423743764, 2.563517215905275)]
# iteration 0
# [[-0.0049271637948920385, -0.0062743881078645035, -0.005243463521332791, -0.004270175212944106, -0.004415812717578785, -0.005751752598488219, -0.0025522231433242914, -0.005972859255377206, -0.005997463547818042, -0.004474892051189431, -0.0077971498848413215, -0.002898296239561784, -0.006498580593445173, -0.00345849585923652, -0.007133643016737419, -0.0047220077769328395, -0.006833390055317384, -0.0036849727106675017, -0.004026855211525919, -0.0031028036116090727], [-0.009842676439751142, -0.0027552929978721884, -0.00715920963723468, -0.013939400302915851, -0.012402770865030513, -0.004737162458436773, -0.029701191680687414, -0.003929792056909354, -0.0038285466141670063, -0.012088480139433805, -0.0003936315276692724, -0.02586943917325759, -0.00205290125682635, -0.020991710053605454, -0.0005581376601812717, -0.010373920065328912, -0.0014074846801007304, -0.01838894051342449, -0.017886118964268116, -0.02378152571640827]]
# objopt final generation contains solutions >= b for iteration  1
# --- 0.03989124298095703 seconds ---
# objopt for global iteration  7  is ready
# b before boundchange:  [0.0138450362099714, 0.029698750080209984]
# b [0.0138450362099714, 0.029698750080209984]
# b after boundchange:  [0.012018875933875772, 0.025867611319864956]
# [[2.533550766476179, 8.139983201821027], [2.7802784420355695, 8.255894732494244], [2.279988711750438, 8.145949988309653], [2.184587653426868, 8.081675737788634], [2.8096383015764457, 7.998152936077791], [3.087991321099151, 8.109315142600014], [2.7551523038698296, 8.033710325347167], [3.238522321569452, 8.052157551185775], [2.9932974282355844, 8.34317649983114], [3.0803717259147536, 8.038001608710484], [2.8269818737679984, 8.06455283706882], [2.3859246270779826, 8.21230558570153], [2.3291119423050657, 8.127087495114973], [3.1402968357190657, 7.960786138956119], [2.45076862692984, 8.072687352208908], [3.297561678191605, 8.053937815254908], [2.551028063080746, 8.050938045857583], [2.884605934774934, 8.16167490108804], [2.5560566178044946, 8.049876806273215]]
#  and size of P is 19
# DIVOPT
# parameters for divopt [[2.533550766476179, 8.139983201821027], [2.7802784420355695, 8.255894732494244], [2.279988711750438, 8.145949988309653], [2.184587653426868, 8.081675737788634], [2.8096383015764457, 7.998152936077791], [3.087991321099151, 8.109315142600014], [2.7551523038698296, 8.033710325347167], [3.238522321569452, 8.052157551185775], [2.9932974282355844, 8.34317649983114], [3.0803717259147536, 8.038001608710484], [2.8269818737679984, 8.06455283706882], [2.3859246270779826, 8.21230558570153], [2.3291119423050657, 8.127087495114973], [3.1402968357190657, 7.960786138956119], [2.45076862692984, 8.072687352208908], [3.297561678191605, 8.053937815254908], [2.551028063080746, 8.050938045857583], [2.884605934774934, 8.16167490108804], [2.5560566178044946, 8.049876806273215]] 20 [0.012018875933875772, 0.025867611319864956] 3 10 10 5
# iteration 0
# GENERATION 0
# GENERATION 1
# GENERATION 2
# GENERATION 3
# GENERATION 4
# GENERATION 5
# GENERATION 6
# GENERATION 7
# GENERATION 8
# GENERATION 9
# GENERATION 10
# GENERATION 11
# GENERATION 12
# GENERATION 13
# GENERATION 14
# GENERATION 15
# GENERATION 16
# GENERATION 17
# GENERATION 18
# GENERATION 19
# GENERATION 20
# GENERATION 21
# GENERATION 22
# GENERATION 23
# GENERATION 24
# GENERATION 25
# GENERATION 26
# GENERATION 27
# GENERATION 28
# GENERATION 29
# GENERATION 30
# GENERATION 31
# GENERATION 32
# GENERATION 33
# GENERATION 34
# GENERATION 35
# GENERATION 36
# [[2.8096383015764457, 7.998152936077791], [3.297561678191605, 8.053937815254908], (2.1531168526405815, 8.767919322120493), [7.723565995183649, 7.756616348314426], [7.500017570815595, 6.322777001910934], (2.766560028629485, 8.690599966566632), [2.6262808605312586, 7.433769627229091], [7.914143190942244, 6.1210016877251965], [2.1552446908379195, 7.575688518469796], (1.6043670188596053, 8.44193363030432), (8.352041071471442, 5.799544067990766), (7.976691294780206, 6.633873934754215), (1.589133556845272, 7.5409734422347725), (7.395081976622197, 7.043594376215623), (1.7415596157361755, 7.9905493655099935), [1.8063223690333228, 2.426923328469756], (7.122828528933644, 7.834923223315631), [7.932116867955869, 4.491276067254729], (8.460938380590314, 5.22782813031233), [8.27922715260401, 7.458860431170737]]
# all diversities [4.397351753652506, 5.21036629975707, 5.926567571316644, 6.924661000614961, 7.784108504606736, 8.764544754425456, 8.971695875379982, 9.066173336628797, 9.778330404956169, 10.203866927599808, 10.971034099780335, 10.971034099780335, 11.745661019270965, 12.190667573072815, 12.661537838829595, 12.847277657911206, 12.847277657911206, 13.025522482687432, 13.534835075683604, 14.2085099598896, 14.541363192531172, 14.541363192531174, 14.97175081545346, 14.982809016901987, 15.077420889094203, 15.602650888306613, 15.668393119654837, 15.738915896974945, 16.316066365614468, 16.545221002258064, 17.042248987162054, 17.398170068354926, 17.398170068354926, 17.398170068354926, 17.67466142813749, 17.67466142813749, 17.67466142813749, 17.67466142813749]
# --- 0.35517311096191406 seconds ---
# Global_iteration:  8 b is  [0.012018875933875772, 0.025867611319864956]
# OBJOPT [[2.8096383015764457, 7.998152936077791], [3.297561678191605, 8.053937815254908], (2.1531168526405815, 8.767919322120493), [7.723565995183649, 7.756616348314426], [7.500017570815595, 6.322777001910934], (2.766560028629485, 8.690599966566632), [2.6262808605312586, 7.433769627229091], [7.914143190942244, 6.1210016877251965], [2.1552446908379195, 7.575688518469796], (1.6043670188596053, 8.44193363030432), (8.352041071471442, 5.799544067990766), (7.976691294780206, 6.633873934754215), (1.589133556845272, 7.5409734422347725), (7.395081976622197, 7.043594376215623), (1.7415596157361755, 7.9905493655099935), [1.8063223690333228, 2.426923328469756], (7.122828528933644, 7.834923223315631), [7.932116867955869, 4.491276067254729], (8.460938380590314, 5.22782813031233), [8.27922715260401, 7.458860431170737]]
# iteration 0
# ...
# iteration 0
# [[-0.0048454054505602355, -0.006945137624905132, -0.006505662225670716, -0.004959668813573613, -0.006479560830597265, -0.0062402100338386345, -0.004028491386380371, -0.0051030529398191525, -0.0055378168204469015, -0.004294586347820699, -0.004098314859110222, -0.004143659202154234, -0.007249090411079398, -0.004209023566941574, -0.006498305881659544, -0.006392015124170787, -0.0053241456773226925, -0.0054062663153513916, -0.006361697366293782, -0.004146036724748574], [-0.009507346798821705, -0.0009237378017852182, -0.0019501411774212798, -0.008806817202804422, -0.0021744479168226637, -0.002758142683478014, -0.015370376229099232, -0.007936907900936612, -0.00564257596690756, -0.013518635287022945, -0.015281971823496644, -0.01457001273056428, -0.0005880265893237792, -0.014311762753737198, -0.0020682806932620554, -0.0024490460576719196, -0.0070095405535620095, -0.006372638647602637, -0.0024558048539026706, -0.014422584333198799]]
# --- 0.02601027488708496 seconds ---
# objopt for global iteration  14  is ready
# b before boundchange:  [0.00732437059796237, 0.015585780591573756]
# b [0.00732437059796237, 0.015585780591573756]
# b after boundchange:  [0.007188869741900081, 0.015302119384807262]
# [[2.983308780727394, 8.022849331644352], [2.7987718313268304, 8.092719090597553], [2.6115976757116757, 8.129640964798238], [2.8310818766395864, 8.165725622066493], [2.840431900424552, 8.248384480706546], [2.6073282098402326, 8.16493716389284], [2.552284431976224, 8.17096625122111], [2.6962203749704474, 8.159827003732913], [2.7241241999564956, 8.131234604242213], [2.9638181012619293, 8.111865429202195], [2.4777594551086564, 8.073145180972093], [2.674862086810464, 8.071743367797682], [2.4717565140653903, 8.193344940066224], [2.450822508796309, 8.180917950074019], [2.9484095031070225, 8.200538130772246], [2.9755704855169145, 7.993029506441622], [2.964402003794896, 8.04762923500247], [2.927661623233141, 8.18134126463827], [2.6467433585673446, 8.135895987178897]]
#  and size of P is 19
# DIVOPT
# parameters for divopt [[2.983308780727394, 8.022849331644352], [2.7987718313268304, 8.092719090597553], [2.6115976757116757, 8.129640964798238], [2.8310818766395864, 8.165725622066493], [2.840431900424552, 8.248384480706546], [2.6073282098402326, 8.16493716389284], [2.552284431976224, 8.17096625122111], [2.6962203749704474, 8.159827003732913], [2.7241241999564956, 8.131234604242213], [2.9638181012619293, 8.111865429202195], [2.4777594551086564, 8.073145180972093], [2.674862086810464, 8.071743367797682], [2.4717565140653903, 8.193344940066224], [2.450822508796309, 8.180917950074019], [2.9484095031070225, 8.200538130772246], [2.9755704855169145, 7.993029506441622], [2.964402003794896, 8.04762923500247], [2.927661623233141, 8.18134126463827], [2.6467433585673446, 8.135895987178897]] 20 [0.007188869741900081, 0.015302119384807262] 3 10 10 5
# iteration 0
# GENERATION 0
# GENERATION 1
# GENERATION 2
# GENERATION 3
# GENERATION 4
# GENERATION 5
# GENERATION 6
# GENERATION 7
# GENERATION 8
# GENERATION 9
# GENERATION 10
# GENERATION 11
# GENERATION 12
# GENERATION 13
# GENERATION 14
# GENERATION 15
# GENERATION 16
# GENERATION 17
# GENERATION 18
# GENERATION 19
# GENERATION 20
# GENERATION 21
# GENERATION 22
# GENERATION 23
# GENERATION 24
# GENERATION 25
# GENERATION 26
# GENERATION 27
# GENERATION 28
# GENERATION 29
# GENERATION 30
# GENERATION 31
# GENERATION 32
# GENERATION 33
# GENERATION 34
# GENERATION 35
# GENERATION 36
# GENERATION 37
# GENERATION 38
# GENERATION 39
# GENERATION 40
# GENERATION 41
# GENERATION 42
# GENERATION 43
# GENERATION 44
# GENERATION 45
# GENERATION 46
# GENERATION 47
# GENERATION 48
# GENERATION 49
# GENERATION 50
# GENERATION 51
# GENERATION 52
# GENERATION 53
# GENERATION 54
# [[2.9484095031070225, 8.200538130772246], [2.9755704855169145, 7.993029506441622], (2.6433105169643656, 7.612433173921071), (2.4649909392946694, 7.8129437256536285), [2.3209629758412436, 8.24540426106693], (2.403855886621225, 7.541374597742248), [2.639764911144506, 8.46386235727821], [7.308242596888846, 7.025775351212462], (7.569496071592837, 6.831720355573781), [2.4974650681852615, 8.605414089948047], [7.3682772708923014, 7.597549130028304], [7.345940752307634, 7.257364033101638], [2.8036650480475256, 7.828505613793632], (7.613868185290283, 7.577967851858135), [2.3720620868714626, 7.975060896915066], (2.781859712744664, 8.359458757263381), (2.3882658963056422, 8.485601918189062), [2.6752050557166758, 8.09749454657754], [7.2809791414139395, 7.39115794411071], (7.5026467920952555, 7.138246890948082)]
# all diversities [2.78622172102491, 3.1093991378462196, 3.6214111128660686, 3.915532603722224, 3.9503728694668423, 4.264406463120018, 4.283773462971937, 4.471434193558469, 4.4718204515850175, 4.555455895088126, 4.9426634875299005, 4.942663487529899, 4.942663487529904, 4.951446763970832, 4.96232881663593, 4.962328816635931, 5.08726514726907, 5.088464586213609, 6.086819166860906, 6.757269160021116, 6.761981235814037, 6.761981235814035, 6.765047364259237, 7.394060606391134, 7.394060606391134, 7.394060606391136, 7.634611020133877, 7.634611020133882, 7.63461102013388, 7.636156365415314, 7.636156365415314, 7.636156365415313, 8.176111795690627, 8.176111795690627, 8.180094650220664, 8.180094650220664, 8.236114085163988, 8.237353434087154, 8.252163611966736, 8.653077109634172, 8.65307710963417, 8.709277693971085, 8.709277693971083, 8.709811206260497, 8.760924451746558, 8.76092445174656, 8.82283041378858, 8.881250320273235, 8.888758552482528, 8.888758552482528, 8.888758552482527, 8.95297872984111, 8.985117118340703, 8.985117118340703, 8.985117118340703, 8.985117118340701]
# --- 0.49537110328674316 seconds ---
# Global_iteration:  15 b is  [0.007188869741900081, 0.015302119384807262]
# OBJOPT [[2.9484095031070225, 8.200538130772246], [2.9755704855169145, 7.993029506441622], (2.6433105169643656, 7.612433173921071), (2.4649909392946694, 7.8129437256536285), [2.3209629758412436, 8.24540426106693], (2.403855886621225, 7.541374597742248), [2.639764911144506, 8.46386235727821], [7.308242596888846, 7.025775351212462], (7.569496071592837, 6.831720355573781), [2.4974650681852615, 8.605414089948047], [7.3682772708923014, 7.597549130028304], [7.345940752307634, 7.257364033101638], [2.8036650480475256, 7.828505613793632], (7.613868185290283, 7.577967851858135), [2.3720620868714626, 7.975060896915066], (2.781859712744664, 8.359458757263381), (2.3882658963056422, 8.485601918189062), [2.6752050557166758, 8.09749454657754], [7.2809791414139395, 7.39115794411071], (7.5026467920952555, 7.138246890948082)]
# iteration 0
# [[-0.0042186915478812535, -0.004086666489066828, -0.004862329448381046, -0.005948491003020513, -0.004437956141243473, -0.0056020413074607525, -0.006692338262910945, -0.00459105077309382, -0.004767635450982356, -0.0058245662508509795, -0.005485827724504458, -0.0041806014877979495, -0.0062285601833933, -0.0043487628598113896, -0.0067989740501681085, -0.004818631380431379, -0.005067207460881079, -0.004474655013517764, -0.00440826677307927, -0.005988021426110676], [-0.014343403357774214, -0.01512474398533254, -0.009773086478056095, -0.003895734440119885, -0.012326150888164895, -0.005449733253714997, -0.0018979137778208847, -0.011195958208705961, -0.01002672460215101, -0.00439827342505792, -0.005943668991409783, -0.014680815329849755, -0.003083405333443438, -0.012933234456842236, -0.0012247059809050937, -0.009947292825122028, -0.00814473672732243, -0.012137332608534886, -0.012771406996948145, -0.0036798250180709816]]
# --- 0.0277712345123291 seconds ---
# objopt for global iteration  15  is ready
# b before boundchange:  [0.007188869741900081, 0.015302119384807262]
# b [0.007188869741900081, 0.015302119384807262]
# b after boundchange:  [0.006904909387095167, 0.014679323125845804]
# [[2.9444249442812294, 7.995941153855876], [2.9460546385355686, 8.21290644839292], [2.442542962440048, 8.038289115288068], [2.7813704034200244, 8.212118761955319], [2.8722363901436965, 8.143747588019291], [2.5529565949679855, 8.101367671484955], [2.9004127136317313, 8.195672281286834], [2.8846619623526446, 8.171436697460834], [2.7489541406534874, 8.117802088620733], [2.8048618766848907, 8.027568719575024], [2.3925157622397584, 8.094765830726129], [2.914631241288153, 8.072525114602072], [2.50429164696808, 8.208864172306864], [2.9553480766159854, 7.989374027217948], [2.6578156083466746, 8.080758964965028], [2.5865861832559713, 8.16268597362565], [2.8165084266289564, 8.08095905596112], [2.857326256031073, 8.081738333350291], [2.413044595878981, 8.017332074928785]]
#  and size of P is 19
# DIVOPT
# parameters for divopt [[2.9444249442812294, 7.995941153855876], [2.9460546385355686, 8.21290644839292], [2.442542962440048, 8.038289115288068], [2.7813704034200244, 8.212118761955319], [2.8722363901436965, 8.143747588019291], [2.5529565949679855, 8.101367671484955], [2.9004127136317313, 8.195672281286834], [2.8846619623526446, 8.171436697460834], [2.7489541406534874, 8.117802088620733], [2.8048618766848907, 8.027568719575024], [2.3925157622397584, 8.094765830726129], [2.914631241288153, 8.072525114602072], [2.50429164696808, 8.208864172306864], [2.9553480766159854, 7.989374027217948], [2.6578156083466746, 8.080758964965028], [2.5865861832559713, 8.16268597362565], [2.8165084266289564, 8.08095905596112], [2.857326256031073, 8.081738333350291], [2.413044595878981, 8.017332074928785]] 20 [0.006904909387095167, 0.014679323125845804] 3 10 10 5
# iteration 0
# GENERATION 0
# GENERATION 1
# GENERATION 2
# GENERATION 3
# GENERATION 4
# GENERATION 5
# GENERATION 6
# GENERATION 7
# GENERATION 8
# GENERATION 9
# GENERATION 10
# GENERATION 11
# GENERATION 12
# GENERATION 13
# GENERATION 14
# GENERATION 15
# GENERATION 16
# GENERATION 17
# GENERATION 18
# GENERATION 19
# GENERATION 20
# GENERATION 21
# GENERATION 22
# GENERATION 23
# GENERATION 24
# GENERATION 25
# GENERATION 26
# GENERATION 27
# GENERATION 28
# GENERATION 29
# GENERATION 30
# GENERATION 31
# GENERATION 32
# GENERATION 33
# GENERATION 34
# GENERATION 35
# GENERATION 36
# GENERATION 37
# GENERATION 38
# GENERATION 39
# GENERATION 40
# [[2.9460546385355686, 8.21290644839292], [2.9553480766159854, 7.989374027217948], [2.413044595878981, 8.017332074928785], (2.797000838683267, 7.86064173336774), (2.4322568968442346, 7.717572904051172), [2.8079047791015808, 8.427591325003393], (2.6582608549656874, 8.230014450373735), (7.2373877735943655, 7.33883446282924), [7.599053430490127, 6.527533605366941], [7.484850324951816, 7.439663119417524], [2.682489040818841, 7.651681174118874], [2.4203146494990446, 8.462696169824891], [7.450083743861992, 6.678773517539925], (7.440767847567605, 7.742635999589133), [7.545917416819031, 6.820651269404035], (7.5880998615471285, 7.646085278656647), [2.458210500453863, 7.614906545981953], (7.349761388949366, 7.0207088444129715), (2.373223130695728, 8.315964859368096), [7.50701684112078, 6.96419432029599]]
# all diversities [2.9453928236174116, 4.155922608241128, 4.64010756016811, 4.797319607262919, 5.050846525018463, 5.367230422856656, 5.915995019005997, 6.054213898744754, 6.062345893112067, 6.070139697725878, 6.26518961521967, 7.221786201840345, 7.223060260578315, 7.223060260578316, 7.2230950531028695, 7.267141804318008, 7.405483893750299, 7.406372768128646, 7.414037872233862, 7.479990790242049, 7.479990790242049, 7.711599993271799, 7.711599993271799, 7.758240311477426, 7.7582403114774285, 7.925440127558072, 7.925440127558073, 8.328668543857187, 8.328668543857189, 8.592088478255489, 8.815075607183632, 8.81507560718363, 8.815075607183632, 8.940790230630085, 9.004608519066014, 9.215929870822809, 9.225129046557027, 9.225129046557024, 9.253764724037923, 9.253764724037921, 9.253764724037921, 9.253764724037923]
# --- 0.21509408950805664 seconds ---
# [[[2.9460546385355686, 8.21290644839292],
#   [2.9553480766159854, 7.989374027217948],
#   [2.413044595878981, 8.017332074928785],
#   (2.797000838683267, 7.86064173336774),
#   (2.4322568968442346, 7.717572904051172),
#   [2.8079047791015808, 8.427591325003393],
#   (2.6582608549656874, 8.230014450373735),
#   (7.2373877735943655, 7.33883446282924),
#   [7.599053430490127, 6.527533605366941],
#   [7.484850324951816, 7.439663119417524],
#   [2.682489040818841, 7.651681174118874],
#   [2.4203146494990446, 8.462696169824891],
#   [7.450083743861992, 6.678773517539925],
#   (7.440767847567605, 7.742635999589133),
#   [7.545917416819031, 6.820651269404035],
#   (7.5880998615471285, 7.646085278656647),
#   [2.458210500453863, 7.614906545981953],
#   (7.349761388949366, 7.0207088444129715),
#   (2.373223130695728, 8.315964859368096),
#   [7.50701684112078, 6.96419432029599]],
#      SP diversity  Min-max diversity  S-energy diversity  \
#  0       1.289199           0.020000           44.586127
#  1       1.973023           0.778963            0.004891
#  2       1.934047           0.591284            0.009562
#  3       1.964552           0.770705            0.006204
#  4       1.961342           0.631241            0.006116
#  5       1.961505           0.602393            0.006139
#  6       1.736572           0.307280            0.038306
#  7       1.866692           0.497894            0.016889
#  8       1.767466           0.460666            0.029437
#  9       1.609628           0.244389            0.068746
#  10      1.430711           0.200864            0.126201
#  11      1.185081           0.137251            0.336917
#  12      0.997426           0.071558            1.264891
#  13      1.114725           0.142546            0.336726
#  14      1.070123           0.162795            0.370877
#  15      0.898512           0.148731            0.582733
#
#      Average Himmelblaus function (obj1)  Average x**2 function (obj1)
#  0                              0.011730                      0.106289
#  1                              0.009069                      0.035078
#  2                              0.008728                      0.024896
#  3                              0.009161                      0.028156
#  4                              0.010118                      0.026956
#  5                              0.009628                      0.025569
#  6                              0.008562                      0.015993
#  7                              0.008621                      0.015376
#  8                              0.008116                      0.016084
#  9                              0.007239                      0.014324
#  10                             0.006777                      0.013742
#  11                             0.006445                      0.011068
#  12                             0.006117                      0.009948
#  13                             0.006242                      0.010289
#  14                             0.006008                      0.011024
#  15                             0.005813                      0.009935  ,
#      Optimization  Diversity Optimization
#  0       7.682741                3.564088
#  1       7.723653                5.557819
#  2       7.851993                3.843443
#  3       8.146606                3.978247
#  4       8.217519                4.018085
#  5       7.999577                5.665657
#  6       7.950176                4.190687
#  7       8.445269                4.810368
#  8       8.326966                3.911981
#  9       8.419402                6.733978
#  10      8.382201                7.164751
#  11      8.512613                7.196891
#  12      8.510707                7.548880
#  13      8.643389                7.438706
#  14      8.531877                7.689401
#  15      8.535549                7.434560]

# %%
repeats = 50

random.seed(16)


# NOAH_SP_repeats(P_0, repeats, it, max_global_iteration, max_gen, pop_size, global_bound, b, r_number, c, mutation_rate, mutation_rate_div, box_border, theta)

# %%
plt.figure(figsize=(10, 6))

plt.plot(sp_diversity, label='Max-min NOAH', marker='o')
plt.plot(sp_diversity_2, label='s-Energy NOAH', marker='s')
plt.plot(sp_diversity_3, label='SP NOAH', marker='^')

# Adding titles and labels
plt.title('Comparison of SP Diversity Indicator', fontsize=18)
plt.xlabel('Iteration', fontsize=18)
plt.ylabel('SP', fontsize=18)
plt.legend(prop = { "size": 20 }, loc ="upper right")
plt.ylim(1.5, 2.1)
plt.grid(True)

plt.savefig('SPcomparison.png')
# Show the plot
plt.show()

# %%
plt.figure(figsize=(10, 6))

plt.plot(s_energy_diversity, label='Max-min NOAH', marker='o')
plt.plot(s_energy_diversity_2, label='s-Energy NOAH', marker='s')
plt.plot(s_energy_diversity_3, label='SP NOAH', marker='^')

# Adding titles and labels
plt.title('Comparison of s-Energy Diversity Indicator', fontsize=18)
plt.xlabel('Iteration', fontsize=18)
plt.ylabel('s-Energy', fontsize=18)
plt.legend(prop = { "size": 20 }, loc ="upper left")
plt.ylim(0, 100)
plt.grid(True)

plt.savefig('Senergycomparison.png')
# Show the plot
plt.show()

# %%
plt.figure(figsize=(10, 6))

plt.plot(min_max_diversity, label='Max-min NOAH', marker='o')
plt.plot(min_max_diversity_2, label='s-Energy NOAH', marker='s')
plt.plot(min_max_diversity_3, label='SP NOAH', marker='^')

# Adding titles and labels
plt.title('Comparison of Max-min Diversity Indicator', fontsize=18)
plt.xlabel('Iteration', fontsize=18)
plt.ylabel('Max-min', fontsize=18)
plt.legend(prop = { "size": 20 }, loc ="upper right")
plt.ylim(0, 1.4)
plt.grid(True)

plt.savefig('Minmaxcomparison.png')
# Show the plot
plt.show()

# %%
plt.figure(figsize=(10, 6))

plt.plot(diversity_optimization, label='Max-min NOAH', marker='o')
plt.plot(diversity_optimization_2, label='s-Energy NOAH', marker='s')
plt.plot(diversity_optimization_3, label='SP NOAH', marker='^')

# Adding titles and labels
plt.title('After diversity optimization', fontsize=18)
plt.xlabel('Iteration', fontsize=18)
plt.ylabel('Hausdorff distance', fontsize=18)
plt.legend(prop = { "size": 20 }, loc ="upper left")
plt.grid(True)

plt.savefig('Hausdorffcomparison_afterdiv.png')

# Show the plot
plt.show()

# %%
plt.figure(figsize=(10, 6))

plt.plot(optimization, label='Max-min NOAH', marker='o')
plt.plot(optimization_2, label='s-Energy NOAH', marker='s')
plt.plot(optimization_3, label='SP NOAH', marker='^')

# Adding titles and labels
plt.title('After normal optimization', fontsize=18)
plt.xlabel('Iteration', fontsize=18)
plt.ylabel('Hausdorff distance', fontsize=18)
plt.legend(prop = { "size": 20 }, loc ="upper left")
plt.grid(True)
plt.savefig('Hausdorffcomparison_beforediv.png')

# Show the plot
plt.show()

# %% [markdown]
# # Comparison of normal Max-min optimization and modified one

# %%
#WITH B and counter - РАБОТАЕТ ЛУЧШЕ, СТОИТ ОСТАВИТЬ


#c - параметр схождения, если c раз подряд значение diversity не меняется, значит, все
# На входе будет r элементов популяции, на выходе надо n = pop_size

def divOpt_simple_minmax(P, it, pop_size, b, c, mutation_rate, box_border):
    
    start_time = time.time()

    a_fp = open('./obj_div_simple_minmax_' + str(mutation_rate) + '.json', 'w')
    b_fp = open('./sol_div_simple_minmax_' + str(mutation_rate) + '.json', 'w')
    c_fp = open('./0.9statistic_div_simple_minmax_' + str(mutation_rate) + '.json', 'w')
    iteration = 0
    A = []
    B = []
    S = []
    for iteration in range(it):
        print("iteration", iteration)
        
        #Main program starts here

        #Initialization
        min_x=-55
        max_x=55
        A = defaultdict()
        C = defaultdict()
        solution = P
        diversity = []
        
        iteration_no_change = 0

        
        selec = SelectDiv_minmax(solution, len(solution))
        diversity.append(selec[0])

        gen_no=0
        
        while(len(solution)!=pop_size):
                
                #Поменяла на len(P)=r, было pop_size
                #здесь надо выбирать только из элементов с индексами solution
#                 a1 = random.randint(0,len(P)-1)
                 
    
            s = 0
            while s == 0:
                a1 = random.randint(0,len(P)-2)
                app = mutation(solution[a1], mutation_rate)
                if (app[0]<0) or (app[1]<0) or (app[0]>box_border) or (app[1]>box_border):
                    app = reflect_point(app[0], app[1], box_border)
                
                min_distance_from_new = 1000
                for z in range(len(solution)):
                    if my_distance(solution[z], app)<min_distance_from_new:
                        min_distance_from_new = my_distance(solution[z], app)
                            
                if (-obj1(app)<b[0]) and (-obj2(app)<b[1]) and (my_distance(app, solution[a1]) > epsilon) and (min_distance_from_new>=diversity[-1]) and (app[0]>=0) and (app[1]>=0) and (app[0]<=box_border) and (app[1]<=box_border) :
                    solution.append(app)
                    
                    s = 1
                else:
                    pass
        
        while (diversity[-1]<1.9):
#             print("GENERATION", gen_no)
            
            solution2 = solution[:]
            
            #Just printing
            
#             for i in range(len(solution)):
#                 print(-obj1(solution[i]), -obj2(solution[i]))
        
#             Generating offsprings
#             print("offsprings")

            while(len(solution2)!=pop_size+1):
                
                #Поменяла на len(P)=r, было pop_size
                #здесь надо выбирать только из элементов с индексами solution
#                 a1 = random.randint(0,len(P)-1)
                 
                s = 0
                counter = 0
                while (s == 0) and (counter < 700):
                    a1 = random.randint(0,len(P)-1)
                    app = mutation(solution[a1], mutation_rate)
                    if (app[0]<0) or (app[1]<0) or (app[0]>box_border) or (app[1]>box_border):
                        app = reflect_point(app[0], app[1], box_border)
                    min_distance_from_new = 1000
                    for z in range(len(solution)):
                        if my_distance(solution[z], app)<min_distance_from_new:
                            min_distance_from_new = my_distance(solution[z], app)
    #                 print(min_distance_from_new)    
    #УБРАЛА  (-obj1(app)<b[0]) and (-obj2(app)<b[1]) and
                    if (-obj1(app)<b[0]) and (-obj2(app)<b[1]) and (my_distance(app, solution[a1]) > epsilon) and (min_distance_from_new>=diversity[-1]) and (app[0]>=0) and (app[1]>=0) and (app[0]<=box_border) and (app[1]<=box_border) :
                        solution2.append(app)
#                         print(-obj1(app), -obj2(app))
                        s = 1
#             print("offsprings are ready")
            
            # When it is [0, 2, .., 9] it is not supposed to chenge, but it's getting lower
            
            solution = []
            
            select_div = SelectDiv_minmax(solution2, pop_size) 
#             print("select_div", select_div)
            #не забыть все нужные параметры вставить
    
    
    
    
            if np.abs(select_div[0]-diversity[-1])<epsilon:
                iteration_no_change+=1
            else:
                iteration_no_change = 0
#             print(iteration_no_change)
            diversity.append(select_div[0])  
            indices = select_div[1]
            
#             print(indices)
            
            for i in range(2*pop_size):
                if i in indices:
                    solution.append(solution2[i])
                         
#             print(heights)
            
#             save = select_div[0]
            
             
            
#             print("len solution", len(solution), len(solution[0]))
#             print(solution)
            C[gen_no] = solution
            gen_no = gen_no + 1
            max_reached_gen = gen_no
#             print(solution)
            
#         print(max_reached_gen)
        print("diversity", diversity[-1])
        S.append(max_reached_gen)
        B.append(C)
        iteration +=1  
#         print(solution)
        
    json.dump(B, b_fp, cls=NpEncoder)  
    json.dump(S, c_fp, cls=NpEncoder)            

    a_fp.close()
    b_fp.close()
    c_fp.close()

    print("--- %s seconds ---" % (time.time() - start_time))
    
    return solution

random.seed(400)
divOpt_simple_minmax(P_0, 1000, pop_size, b, 20, 10, 10)
# Out:
# iteration 0
# diversity 1.9070267820238744
# iteration 1
# diversity 1.9581210066924832
# iteration 2
# diversity 1.9033858403987158
# iteration 3
# diversity 1.915164804797338
# iteration 4
# diversity 1.9100070318143787
# iteration 5
# diversity 1.972549168639877
# iteration 6
# diversity 1.9531445660610578
# iteration 7
# diversity 1.926621281013103
# iteration 8
# diversity 1.9637717455086008
# iteration 9
# diversity 1.9454069618215013
# iteration 10
# diversity 1.9142158794192876
# iteration 11
# diversity 1.9198907854346918
# iteration 12
# diversity 1.9075259141032013
# iteration 13
# diversity 1.9059727193370288
# iteration 14
# diversity 1.9083557210054847
# iteration 15
# diversity 1.9153401173243938
# iteration 16
# diversity 1.90176798702512
# iteration 17
# diversity 1.9242210141204361
# iteration 18
# diversity 1.9130992691915263
# iteration 19
# diversity 2.116862035241425
# iteration 20
# diversity 1.9107095666943166
# iteration 21
# diversity 1.9441776393834704
# iteration 22
# diversity 1.9093136860809143
# iteration 23
# diversity 1.9000997412091145
# iteration 24
# diversity 1.9098657862124258
# iteration 25
# diversity 1.952037313333465
# iteration 26
# diversity 1.9439680600073503
# iteration 27
# diversity 1.9314613224125707
# iteration 28
# diversity 1.912971374876282
# iteration 29
# diversity 1.9136920996139124
# iteration 30
# diversity 1.9073086249992688
# iteration 31
# diversity 1.9010350317767735
# iteration 32
# diversity 1.9097614054597074
# iteration 33
# diversity 1.9008904137091471
# iteration 34
# diversity 1.909523647435001
# iteration 35
# diversity 1.91217283617515
# iteration 36
# diversity 1.9355228887130231
# iteration 37
# diversity 1.9026297590440449
# iteration 38
# diversity 1.916751073561034
# iteration 39
# diversity 1.9025414522793866
# iteration 40
# diversity 1.9178892455415006
# iteration 41
# diversity 1.9054072691314534
# iteration 42
# diversity 1.9536091266922422
# iteration 43
# diversity 1.902123888607457
# iteration 44
# diversity 1.9004738831448993
# iteration 45
# diversity 1.9756142932136975
# iteration 46
# diversity 1.904024561056627
# iteration 47
# diversity 1.9260889988244363
# iteration 48
# diversity 1.9178228843740872
# iteration 49
# diversity 1.9602295783912658
# iteration 50
# diversity 1.9026297590440449
# iteration 51
# diversity 1.9137987534477412
# iteration 52
# diversity 1.900368879282004
# iteration 53
# diversity 1.941639571331901
# iteration 54
# diversity 1.9301695166049055
# iteration 55
# diversity 1.915195131978895
# iteration 56
# diversity 1.9110132827856934
# iteration 57
# diversity 1.968612090040512
# iteration 58
# diversity 1.907466946464716
# iteration 59
# diversity 1.9475886410530259
# iteration 60
# diversity 1.9018137704115103
# iteration 61
# diversity 1.9154833908577453
# iteration 62
# diversity 1.91003748955708
# iteration 63
# diversity 1.9083056133852592
# iteration 64
# diversity 1.9121233167119949
# iteration 65
# diversity 1.9152516585654074
# iteration 66
# diversity 1.904164169132997
# iteration 67
# diversity 1.9401139013062445
# iteration 68
# diversity 1.9053637963736165
# iteration 69
# diversity 1.9736305869490107
# iteration 70
# diversity 1.9263274079489254
# iteration 71
# diversity 1.9608913533974208
# iteration 72
# diversity 1.915976812315136
# iteration 73
# diversity 1.9234698400029178
# iteration 74
# diversity 1.9083563994279247
# iteration 75
# diversity 1.908366365452676
# iteration 76
# diversity 1.914887170338166
# iteration 77
# diversity 1.9233503627530693
# iteration 78
# diversity 1.918706766054985
# iteration 79
# diversity 1.914580265030837
# iteration 80
# diversity 1.9139187496482786
# iteration 81
# diversity 1.9241791237088013
# iteration 82
# diversity 1.9110648343191943
# iteration 83
# diversity 1.9315402284994607
# iteration 84
# diversity 1.9742946609797771
# iteration 85
# diversity 1.902049884472235
# iteration 86
# diversity 1.9262348004035446
# iteration 87
# diversity 1.9367808656450276
# iteration 88
# diversity 1.9187984886242277
# iteration 89
# diversity 1.901142387014988
# iteration 90
# diversity 1.9006407483661685
# iteration 91
# diversity 1.9427025258212243
# iteration 92
# diversity 1.9080317399371307
# iteration 93
# diversity 1.902268529233717
# iteration 94
# diversity 1.9302086921574981
# iteration 95
# diversity 1.9372065790036037
# iteration 96
# diversity 1.9259368975961453
# iteration 97
# diversity 1.9211757277538084
# iteration 98
# diversity 1.9104856248099882
# iteration 99
# diversity 1.902913038462162
# iteration 100
# diversity 1.9289941501397034
# iteration 101
# diversity 1.966037237156334
# iteration 102
# diversity 1.9040024922182737
# iteration 103
# diversity 1.9280072389561862
# iteration 104
# diversity 1.9106951463832686
# iteration 105
# diversity 1.9147395183953662
# iteration 106
# diversity 1.9262734865868572
# iteration 107
# diversity 1.918597524098216
# iteration 108
# diversity 1.9130824587966901
# iteration 109
# diversity 1.9097731585011766
# iteration 110
# diversity 1.9135952293626508
# iteration 111
# diversity 1.943226339950208
# iteration 112
# diversity 1.9449096491420415
# iteration 113
# diversity 1.908501634647032
# iteration 114
# diversity 1.9163073238582815
# iteration 115
# diversity 1.9053383107819502
# iteration 116
# diversity 1.9384705670251376
# iteration 117
# diversity 1.9433020000070291
# iteration 118
# diversity 1.9029149627350141
# iteration 119
# diversity 1.9283469897603829
# iteration 120
# diversity 1.9192821626554966
# iteration 121
# diversity 1.9498432156850702
# iteration 122
# diversity 1.9114710978063592
# iteration 123
# diversity 1.9249509790549197
# iteration 124
# diversity 1.9016584236224683
# iteration 125
# diversity 1.9863182918833304
# iteration 126
# diversity 1.9179273690193943
# iteration 127
# diversity 1.9237258542325146
# iteration 128
# diversity 1.9062221260803136
# iteration 129
# diversity 1.9575136255979848
# iteration 130
# diversity 1.9589820601706853
# iteration 131
# diversity 1.9100869069917021
# iteration 132
# diversity 1.914138748069393
# iteration 133
# diversity 1.927428486578166
# iteration 134
# diversity 1.9394635992134275
# iteration 135
# diversity 1.9287977373761933
# iteration 136
# diversity 1.9037007837913917
# iteration 137
# diversity 1.9377325374273187
# iteration 138
# diversity 1.914091572319667
# iteration 139
# diversity 1.901285083906859
# iteration 140
# diversity 1.9330995484303752
# iteration 141
# diversity 1.9253633730413295
# iteration 142
# diversity 1.9376287488054516
# iteration 143
# diversity 1.9086713716195967
# iteration 144
# diversity 1.938483247584093
# iteration 145
# diversity 1.9029200931698536
# iteration 146
# diversity 1.9325543033826775
# iteration 147
# diversity 1.901972851283283
# iteration 148
# diversity 1.9170514278936281
# iteration 149
# diversity 1.9600588980924478
# iteration 150
# diversity 1.968763097664318
# iteration 151
# diversity 1.9240443070800102
# iteration 152
# diversity 1.9046607513951495
# iteration 153
# diversity 1.9496101527370937
# iteration 154
# diversity 1.9627335346569093
# iteration 155
# diversity 1.9796157217337518
# iteration 156
# diversity 1.9149863112117032
# iteration 157
# diversity 1.938177131081862
# iteration 158
# diversity 1.940531168531149
# iteration 159
# diversity 1.98413110276775
# iteration 160
# diversity 1.9439342230437548
# iteration 161
# diversity 1.9366684143178456
# iteration 162
# diversity 1.9454589908582332
# iteration 163
# diversity 1.9107229740948757
# iteration 164
# diversity 1.9044259326115287
# iteration 165
# diversity 1.9415413731138715
# iteration 166
# diversity 1.9341851672472383
# iteration 167
# diversity 1.90105112114067
# iteration 168
# diversity 1.9139460981270466
# iteration 169
# diversity 1.9317313829897134
# iteration 170
# diversity 1.9124563510394106
# iteration 171
# diversity 1.9697022482338888
# iteration 172
# diversity 1.9001693664396824
# iteration 173
# diversity 1.982770598570755
# iteration 174
# diversity 1.9088182621217693
# iteration 175
# diversity 1.9012890364171355
# iteration 176
# diversity 1.9128745450537195
# iteration 177
# diversity 1.917572364837737
# iteration 178
# diversity 1.911805732076656
# iteration 179
# diversity 1.9072044919602074
# iteration 180
# diversity 1.9024980528794548
# iteration 181
# diversity 1.9132413130826524
# iteration 182
# diversity 1.910863396934738
# iteration 183
# diversity 1.9087294491596665
# iteration 184
# diversity 1.9000797594440548
# iteration 185
# diversity 1.9049603722796622
# iteration 186
# diversity 1.9528548751820707
# iteration 187
# diversity 1.91768584812883
# iteration 188
# diversity 1.9190534061893643
# iteration 189
# diversity 1.9060613066566392
# iteration 190
# diversity 1.9166474414773818
# iteration 191
# diversity 1.9208182865615557
# iteration 192
# diversity 1.9198586118784435
# iteration 193
# diversity 2.0110342785084048
# iteration 194
# diversity 1.9187974139124115
# iteration 195
# diversity 1.978608764319663
# iteration 196
# diversity 1.9817047063197715
# iteration 197
# diversity 1.9205056195500831
# iteration 198
# diversity 1.9285813283413282
# iteration 199
# diversity 1.9284835422105775
# iteration 200
# diversity 1.9068771797967616
# iteration 201
# diversity 1.9128177850328185
# iteration 202
# diversity 1.9310159185372515
# iteration 203
# diversity 1.9545035851422348
# iteration 204
# diversity 1.912038161895146
# iteration 205
# diversity 1.9012890364171355
# iteration 206
# diversity 1.9341692445086425
# iteration 207
# diversity 1.9060227716043228
# iteration 208
# diversity 1.9206666413678726
# iteration 209
# diversity 1.9231006538674098
# iteration 210
# diversity 1.919593115797044
# iteration 211
# diversity 1.910383824661021
# iteration 212
# diversity 1.9013098498152892
# iteration 213
# diversity 1.9068828854932554
# iteration 214
# diversity 1.9086023757257302
# iteration 215
# diversity 1.9043139108779448
# iteration 216
# diversity 1.9433826692181477
# iteration 217
# diversity 1.9287565964469033
# iteration 218
# diversity 1.9536499613080418
# iteration 219
# diversity 1.9022907047208777
# iteration 220
# diversity 1.9075678832785499
# iteration 221
# diversity 1.9021308844337244
# iteration 222
# diversity 1.9101473565621587
# iteration 223
# diversity 1.929705183523441
# iteration 224
# diversity 2.0070698056998504
# iteration 225
# diversity 1.9204120837416359
# iteration 226
# diversity 1.9281256661691486
# iteration 227
# diversity 1.917283026374996
# iteration 228
# diversity 1.907545759568712
# iteration 229
# diversity 1.9014395821584524
# iteration 230
# diversity 1.9078373597874023
# iteration 231
# diversity 1.9097732309387179
# iteration 232
# diversity 1.9040991670554697
# iteration 233
# diversity 1.951643845363526
# iteration 234
# diversity 1.9348161659192382
# iteration 235
# diversity 1.9179657455142132
# iteration 236
# diversity 1.9105260806726043
# iteration 237
# diversity 1.9015484796671867
# iteration 238
# diversity 1.926695540525758
# iteration 239
# diversity 1.910129364491486
# iteration 240
# diversity 1.913021807349434
# iteration 241
# diversity 1.9208907720184314
# iteration 242
# diversity 1.9154051211155987
# iteration 243
# diversity 1.900960582535909
# iteration 244
# diversity 1.9104993422319219
# iteration 245
# diversity 1.9622308581659362
# iteration 246
# diversity 1.9355075028117217
# iteration 247
# diversity 1.9338688374875403
# iteration 248
# diversity 1.9026297590440449
# iteration 249
# diversity 1.9120190333130227
# iteration 250
# diversity 1.9081218568246041
# iteration 251
# diversity 1.908672094282844
# iteration 252
# diversity 1.9170776685279693
# iteration 253
# diversity 1.9058000551463137
# iteration 254
# diversity 1.9062596399661007
# iteration 255
# diversity 1.9174189475233945
# iteration 256
# diversity 1.9134057159388167
# iteration 257
# diversity 1.918125779884273
# iteration 258
# diversity 1.9028438324372623
# iteration 259
# diversity 1.9088113524481567
# iteration 260
# diversity 1.9546628897079579
# iteration 261
# diversity 2.0238666129019185
# iteration 262
# diversity 1.9706880436682435
# iteration 263
# diversity 1.9239696066886345
# iteration 264
# diversity 1.925268306115881
# iteration 265
# diversity 1.9061921988099693
# iteration 266
# diversity 1.9242043719624526
# iteration 267
# diversity 1.9009960748212713
# iteration 268
# diversity 1.9288077028839907
# iteration 269
# diversity 1.9555362024116285
# iteration 270
# diversity 1.9727946788938053
# iteration 271
# diversity 1.961688178036846
# iteration 272
# diversity 1.9198298622539212
# iteration 273
# diversity 1.9073723197976156
# iteration 274
# diversity 1.9998911533676782
# iteration 275
# diversity 1.9256298683125976
# iteration 276
# diversity 1.9306308738677653
# iteration 277
# diversity 1.9379926403662933
# iteration 278
# diversity 1.9134274507548694
# iteration 279
# diversity 1.9120257135112337
# iteration 280
# diversity 1.9067515222036098
# iteration 281
# diversity 1.900001555746445
# iteration 282
# diversity 1.92146366852704
# iteration 283
# diversity 1.9145724852649642
# iteration 284
# diversity 1.9124116869024341
# iteration 285
# diversity 1.9436519096947276
# iteration 286
# diversity 1.9344253544189296
# iteration 287
# diversity 1.9763002438884107
# iteration 288
# diversity 1.9718522844852104
# iteration 289
# diversity 1.9042171487475175
# iteration 290
# diversity 1.9204734195589066
# iteration 291
# diversity 1.9051336888690358
# iteration 292
# diversity 1.9012704170991692
# iteration 293
# diversity 1.945846056406777
# iteration 294
# diversity 1.96100682290654
# iteration 295
# diversity 1.908404924163065
# iteration 296
# diversity 1.9078999131307748
# iteration 297
# diversity 1.9043630329431593
# iteration 298
# diversity 1.9050987198524478
# iteration 299
# diversity 1.9045568357030263
# iteration 300
# diversity 1.9241898271582765
# iteration 301
# diversity 1.9121269265568936
# iteration 302
# diversity 1.9226724192838018
# iteration 303
# diversity 1.9038744825188534
# iteration 304
# diversity 1.9049968173163232
# iteration 305
# diversity 1.901342303700097
# iteration 306
# diversity 1.9380023151995702
# iteration 307
# diversity 1.9094205335135688
# iteration 308
# diversity 1.9689909687083003
# iteration 309
# diversity 1.9274353373126047
# iteration 310
# diversity 1.9346777408833356
# iteration 311
# diversity 1.9446130482653228
# iteration 312
# diversity 1.9396955907422906
# iteration 313
# diversity 1.9164826627958063
# iteration 314
# diversity 1.9205368005909795
# iteration 315
# diversity 1.939295756559349
# iteration 316
# diversity 1.9309140249657546
# iteration 317
# diversity 1.932977731313817
# iteration 318
# diversity 1.9244625182589918
# iteration 319
# diversity 1.9414413043404122
# iteration 320
# diversity 1.9049451939776547
# iteration 321
# diversity 1.9104670656868494
# iteration 322
# diversity 1.9253652497883647
# iteration 323
# diversity 1.9038207761183548
# iteration 324
# diversity 1.9379890650864875
# iteration 325
# diversity 1.9194651404681846
# iteration 326
# diversity 1.9114231858150539
# iteration 327
# diversity 1.9087744389308956
# iteration 328
# diversity 1.9315644843469932
# iteration 329
# diversity 1.9150841777255927
# iteration 330
# diversity 1.9070662810611165
# iteration 331
# diversity 1.9534773731649875
# iteration 332
# diversity 1.9328824267288496
# iteration 333
# diversity 1.9010553847900387
# iteration 334
# diversity 1.9230415991438652
# iteration 335
# diversity 1.9096195053348473
# iteration 336
# diversity 1.9031252883796217
# iteration 337
# diversity 1.9063051593000988
# iteration 338
# diversity 1.9080159160601589
# iteration 339
# diversity 1.9023240209271146
# iteration 340
# diversity 1.902853608107105
# iteration 341
# diversity 1.953189631261043
# iteration 342
# diversity 1.946668248785962
# iteration 343
# diversity 1.9328726608710793
# iteration 344
# diversity 1.9024750196813347
# iteration 345
# diversity 1.9035874937021993
# iteration 346
# diversity 1.9277514260130697
# iteration 347
# diversity 1.9573936768639113
# iteration 348
# diversity 1.9206258666453992
# iteration 349
# diversity 1.9165057935368472
# iteration 350
# diversity 1.9034911771783034
# iteration 351
# diversity 1.962113038457587
# iteration 352
# diversity 1.911512356183055
# iteration 353
# diversity 1.9088166166622644
# iteration 354
# diversity 1.9243249374980558
# iteration 355
# diversity 1.918226876984435
# iteration 356
# diversity 1.9263354476394532
# iteration 357
# diversity 1.9066959556803882
# iteration 358
# diversity 1.9345308213309977
# iteration 359
# diversity 1.9237612161180724
# iteration 360
# diversity 1.921043175977332
# iteration 361
# diversity 1.9070042011614567
# iteration 362
# diversity 1.916649288937922
# iteration 363
# diversity 1.9025844712148974
# iteration 364
# diversity 1.9161435924893553
# iteration 365
# diversity 1.9239738401220026
# iteration 366
# diversity 1.935738258218683
# iteration 367
# diversity 1.9169617320523944
# iteration 368
# diversity 1.9085312604175066
# iteration 369
# diversity 1.9219031932846131
# iteration 370
# diversity 1.930099203544037
# iteration 371
# diversity 1.919419847311695
# iteration 372
# diversity 1.9141740848057185
# iteration 373
# diversity 1.9602295783912658
# iteration 374
# diversity 1.9504122449599228
# iteration 375
# diversity 1.903400290452959
# iteration 376
# diversity 1.900610096340294
# iteration 377
# diversity 1.9037842588206466
# iteration 378
# diversity 1.9235862818967089
# iteration 379
# diversity 1.9047140129979372
# iteration 380
# diversity 1.9218792801549032
# iteration 381
# diversity 1.9585354494706928
# iteration 382
# diversity 1.9023248688672119
# iteration 383
# diversity 1.9341078341772875
# iteration 384
# diversity 1.9128529494226783
# iteration 385
# diversity 1.9004150148541128
# iteration 386
# diversity 1.938445036798056
# iteration 387
# diversity 1.9465990852415285
# iteration 388
# diversity 1.9150602343338778
# iteration 389
# diversity 1.9253426190367184
# iteration 390
# diversity 1.9355136518574154
# iteration 391
# diversity 1.9686497221331396
# iteration 392
# diversity 1.9074781636038738
# iteration 393
# diversity 1.926113477056145
# iteration 394
# diversity 1.970147071560156
# iteration 395
# diversity 1.9170110485796292
# iteration 396
# diversity 1.9456838183379084
# iteration 397
# diversity 1.9010606233749867
# iteration 398
# diversity 1.9150690052018975
# iteration 399
# diversity 1.9201723821555505
# iteration 400
# diversity 1.9077486846959764
# iteration 401
# diversity 1.9139257578322302
# iteration 402
# diversity 1.9305105011835593
# iteration 403
# diversity 1.9044839173026966
# iteration 404
# diversity 1.9226024388682332
# iteration 405
# diversity 1.9337477508342333
# iteration 406
# diversity 1.9446696896265094
# iteration 407
# diversity 1.9078722550211327
# iteration 408
# diversity 1.9051325539012771
# iteration 409
# diversity 1.9016013983068691
# iteration 410
# diversity 1.9034873468242108
# iteration 411
# diversity 1.9795334053861364
# iteration 412
# diversity 1.9290226790160647
# iteration 413
# diversity 1.934224941390973
# iteration 414
# diversity 1.9052333055636717
# iteration 415
# diversity 1.9030323460533576
# iteration 416
# diversity 1.903021002926505
# iteration 417
# diversity 1.9083864893067857
# iteration 418
# diversity 1.9052388829697922
# iteration 419
# diversity 1.907488817532598
# iteration 420
# diversity 1.963346857918883
# iteration 421
# diversity 1.9631160082514079
# iteration 422
# diversity 1.953187228508412
# iteration 423
# diversity 1.900060995563378
# iteration 424
# diversity 1.9012515708496391
# iteration 425
# diversity 1.9277626748325387
# iteration 426
# diversity 1.910632108717079
# iteration 427
# diversity 1.9374713531766252
# iteration 428
# diversity 1.927674086730171
# iteration 429
# diversity 1.9420644983442248
# iteration 430
# diversity 1.9099969888699093
# iteration 431
# diversity 1.9733217707819621
# iteration 432
# diversity 1.9100065325662594
# iteration 433
# diversity 1.9045058535632755
# iteration 434
# diversity 1.9138670630393524
# iteration 435
# diversity 1.9008219919402836
# iteration 436
# diversity 1.9942774708630315
# iteration 437
# diversity 1.9291966247101058
# iteration 438
# diversity 1.9076668959903316
# iteration 439
# diversity 1.9036329734499684
# iteration 440
# diversity 1.933585290230745
# iteration 441
# diversity 1.9040255885812056
# iteration 442
# diversity 1.9471121547376364
# iteration 443
# diversity 1.9436857595712342
# iteration 444
# diversity 1.9558507700741432
# iteration 445
# diversity 1.906610836158379
# iteration 446
# diversity 1.9089572017112661
# iteration 447
# diversity 1.9056058290460591
# iteration 448
# diversity 1.9238754859355107
# iteration 449
# diversity 1.900354497615898
# iteration 450
# diversity 1.905299115205599
# iteration 451
# diversity 1.9010229397677194
# iteration 452
# diversity 1.9445209883307224
# iteration 453
# diversity 1.9007034359328205
# iteration 454
# diversity 1.9012890364171355
# iteration 455
# diversity 1.9135014914791568
# iteration 456
# diversity 1.9159610444923774
# iteration 457
# diversity 1.9083357741942053
# iteration 458
# diversity 1.914349646890635
# iteration 459
# diversity 1.9023396411397657
# iteration 460
# diversity 1.9202825272257975
# iteration 461
# diversity 1.9167882544495587
# iteration 462
# diversity 1.9198271788274013
# iteration 463
# diversity 1.9244266376957946
# iteration 464
# diversity 1.9397488766458226
# iteration 465
# diversity 1.9315819535751553
# iteration 466
# diversity 1.9001511857156086
# iteration 467
# diversity 1.9313728798599195
# iteration 468
# diversity 1.9689078739159906
# iteration 469
# diversity 1.914195691940736
# iteration 470
# diversity 1.9098679344318938
# iteration 471
# diversity 1.9369753820160767
# iteration 472
# diversity 1.9018240840732201
# iteration 473
# diversity 1.9040902950464675
# iteration 474
# diversity 1.9197838012814146
# iteration 475
# diversity 1.9056057341059287
# iteration 476
# diversity 1.9275303694789507
# iteration 477
# diversity 1.9006031763303903
# iteration 478
# diversity 1.9376667794914173
# iteration 479
# diversity 1.9480631553733374
# iteration 480
# diversity 1.9303177642206693
# iteration 481
# diversity 1.933762546217788
# iteration 482
# diversity 1.901660294350936
# iteration 483
# diversity 1.9046520156440012
# iteration 484
# diversity 1.9040044195459906
# iteration 485
# diversity 1.9169234227388883
# iteration 486
# diversity 1.9967348931524822
# iteration 487
# diversity 1.9026297590440449
# iteration 488
# diversity 1.9005135469167036
# iteration 489
# diversity 1.9120584585975613
# iteration 490
# diversity 1.967098344495678
# iteration 491
# diversity 1.9277720543596277
# iteration 492
# diversity 1.9034052763535225
# iteration 493
# diversity 1.902796461393646
# iteration 494
# diversity 1.922915099566146
# iteration 495
# diversity 1.918110316455822
# iteration 496
# diversity 1.9523894886188071
# iteration 497
# diversity 1.9285288811133463
# iteration 498
# diversity 1.9695735877697793
# iteration 499
# diversity 1.917624232517892
# iteration 500
# diversity 1.9267184309333214
# iteration 501
# diversity 1.9716433477511854
# iteration 502
# diversity 1.9105127930337722
# iteration 503
# diversity 1.9031047170477462
# iteration 504
# diversity 1.9127917422577743
# iteration 505
# diversity 1.9437107399947355
# iteration 506
# diversity 1.9016041638240755
# iteration 507
# diversity 1.9026297590440449
# iteration 508
# diversity 1.9742267050722109
# iteration 509
# diversity 1.9148629852247439
# iteration 510
# diversity 1.9115817057702698
# iteration 511
# diversity 1.9018577342132381
# iteration 512
# diversity 1.9698368478162294
# iteration 513
# diversity 1.9096613648673304
# iteration 514
# diversity 1.9181050423825363
# iteration 515
# diversity 1.930643115426595
# iteration 516
# diversity 1.9167323082447858
# iteration 517
# diversity 1.9094267477362055
# iteration 518
# diversity 1.9233910426583558
# iteration 519
# diversity 1.9094944685298865
# iteration 520
# diversity 1.903225946695025
# iteration 521
# diversity 1.9047315169626176
# iteration 522
# diversity 1.9197442405416996
# iteration 523
# diversity 1.9267372306021335
# iteration 524
# diversity 1.9136238654243738
# iteration 525
# diversity 1.9044785389972343
# iteration 526
# diversity 1.9212930631580887
# iteration 527
# diversity 1.9134988658823036
# iteration 528
# diversity 1.9069332351278578
# iteration 529
# diversity 1.9100258646082942
# iteration 530
# diversity 1.9283963820413603
# iteration 531
# diversity 1.9199273922995543
# iteration 532
# diversity 1.9357864413411878
# iteration 533
# diversity 1.9017622900319042
# iteration 534
# diversity 1.956271324023729
# iteration 535
# diversity 1.915407521793676
# iteration 536
# diversity 1.9159493904605496
# iteration 537
# diversity 1.9106827457723574
# iteration 538
# diversity 1.9205985642573888
# iteration 539
# diversity 1.921194758859089
# iteration 540
# diversity 1.9295964011054918
# iteration 541
# diversity 1.96997945061533
# iteration 542
# diversity 1.9427090451888938
# iteration 543
# diversity 1.9159886717114836
# iteration 544
# diversity 1.9131041348240954
# iteration 545
# diversity 1.999515547565602
# iteration 546
# diversity 1.9248786379264875
# iteration 547
# diversity 1.9065738920474378
# iteration 548
# diversity 1.9598649262693157
# iteration 549
# diversity 1.9375521164668934
# iteration 550
# diversity 1.9025493009039847
# iteration 551
# diversity 1.932937065673975
# iteration 552
# diversity 1.902802352098289
# iteration 553
# diversity 1.9241613555677577
# iteration 554
# diversity 1.9069650374688027
# iteration 555
# diversity 1.914828109356153
# iteration 556
# diversity 1.9397725227649316
# iteration 557
# diversity 1.9274536238687792
# iteration 558
# diversity 1.9071395803235192
# iteration 559
# diversity 1.9110521744998725
# iteration 560
# diversity 1.9248100065385816
# iteration 561
# diversity 1.9167711072377198
# iteration 562
# diversity 1.92394442412407
# iteration 563
# diversity 1.9213980552009469
# iteration 564
# diversity 1.9136286121507935
# iteration 565
# diversity 1.9401860491737741
# iteration 566
# diversity 1.9308713174654482
# iteration 567
# diversity 1.954390917632621
# iteration 568
# diversity 1.949462754847
# iteration 569
# diversity 1.9064771997463068
# iteration 570
# diversity 1.9147653932482422
# iteration 571
# diversity 1.9083646946207808
# iteration 572
# diversity 1.9016117399786387
# iteration 573
# diversity 1.9842266585431003
# iteration 574
# diversity 1.9141046301067757
# iteration 575
# diversity 1.9035136526177214
# iteration 576
# diversity 1.9048745529355078
# iteration 577
# diversity 1.911122373894308
# iteration 578
# diversity 1.9292709663118068
# iteration 579
# diversity 1.9037140011763998
# iteration 580
# diversity 1.906717738153545
# iteration 581
# diversity 1.9420584292609986
# iteration 582
# diversity 1.9695206087276445
# iteration 583
# diversity 1.9836783057508633
# iteration 584
# diversity 1.9102269838033703
# iteration 585
# diversity 1.9204522445413004
# iteration 586
# diversity 1.9624407439396439
# iteration 587
# diversity 1.910026252586711
# iteration 588
# diversity 1.9104458510906412
# iteration 589
# diversity 1.900927073554291
# iteration 590
# diversity 1.9058725810593784
# iteration 591
# diversity 1.943496809701046
# iteration 592
# diversity 1.914546676055624
# iteration 593
# diversity 1.9589560544181783
# iteration 594
# diversity 1.9178256184630251
# iteration 595
# diversity 1.904348001101364
# iteration 596
# diversity 1.9997890887293492
# iteration 597
# diversity 1.9006839621794553
# iteration 598
# diversity 1.9026297590440449
# iteration 599
# diversity 1.9673841597419257
# iteration 600
# diversity 1.9001629962873061
# iteration 601
# diversity 1.925170774271085
# iteration 602
# diversity 1.9006673769041855
# iteration 603
# diversity 1.9059675479028306
# iteration 604
# diversity 1.9089862993066526
# iteration 605
# diversity 1.9099373867743852
# iteration 606
# diversity 1.9045507908237778
# iteration 607
# diversity 1.901699517217946
# iteration 608
# diversity 1.9420241617097596
# iteration 609
# diversity 1.912125478481553
# iteration 610
# diversity 1.907298143680492
# iteration 611
# diversity 2.0375973560521596
# iteration 612
# diversity 1.9012390109656943
# iteration 613
# diversity 1.903667281137599
# iteration 614
# diversity 1.9103310885962201
# iteration 615
# diversity 1.9147884117595064
# iteration 616
# diversity 1.9461044085105306
# iteration 617
# diversity 1.9339076982121675
# iteration 618
# diversity 1.903435939062071
# iteration 619
# diversity 1.903051751893472
# iteration 620
# diversity 1.912678909905411
# iteration 621
# diversity 1.9908508287981868
# iteration 622
# diversity 1.9085070608877523
# iteration 623
# diversity 1.910443667607642
# iteration 624
# diversity 1.9080591182587314
# iteration 625
# diversity 1.94158396080062
# iteration 626
# diversity 1.9116785470443225
# iteration 627
# diversity 1.9118700245701552
# iteration 628
# diversity 1.9889855706018382
# iteration 629
# diversity 1.913837656919816
# iteration 630
# diversity 1.9641573027286043
# iteration 631
# diversity 1.927024304628388
# iteration 632
# diversity 1.9101278634307628
# iteration 633
# diversity 1.9122786249037436
# iteration 634
# diversity 1.9013097879648262
# iteration 635
# diversity 1.9026297590440449
# iteration 636
# diversity 1.9007567446488982
# iteration 637
# diversity 1.91001877720493
# iteration 638
# diversity 1.9174401618777421
# iteration 639
# diversity 1.9115548962384346
# iteration 640
# diversity 1.9113202501968272
# iteration 641
# diversity 1.9267109151220134
# iteration 642
# diversity 1.9344223198787553
# iteration 643
# diversity 1.9062715561500763
# iteration 644
# diversity 1.953842859700971
# iteration 645
# diversity 1.918625051612923
# iteration 646
# diversity 1.9511421415205612
# iteration 647
# diversity 1.9234673490879175
# iteration 648
# diversity 1.971636395190326
# iteration 649
# diversity 1.9537173954899072
# iteration 650
# diversity 1.9142751997151515
# iteration 651
# diversity 1.9778557478834733
# iteration 652
# diversity 1.9240268481043767
# iteration 653
# diversity 1.9366325071228354
# iteration 654
# diversity 1.9345532140781394
# iteration 655
# diversity 1.9044355552790762
# iteration 656
# diversity 1.9068498925639255
# iteration 657
# diversity 1.9339476345855273
# iteration 658
# diversity 1.9170302300139184
# iteration 659
# diversity 1.9062144420060758
# iteration 660
# diversity 1.904963801497463
# iteration 661
# diversity 1.9132014496465708
# iteration 662
# diversity 1.9084254342989215
# iteration 663
# diversity 1.9942742940805611
# iteration 664
# diversity 1.9309086405737461
# iteration 665
# diversity 1.9262675343887758
# iteration 666
# diversity 1.9088167299964411
# iteration 667
# diversity 1.9010918581828635
# iteration 668
# diversity 1.900196424319126
# iteration 669
# diversity 1.9088787564263103
# iteration 670
# diversity 1.9075627729864342
# iteration 671
# diversity 1.983140826864719
# iteration 672
# diversity 1.9188785613372914
# iteration 673
# diversity 1.9458418528331287
# iteration 674
# diversity 1.9731641957473913
# iteration 675
# diversity 1.9286334559074285
# iteration 676
# diversity 1.9425351096948604
# iteration 677
# diversity 1.9073447172735243
# iteration 678
# diversity 1.9187151408923904
# iteration 679
# diversity 1.9255495678028944
# iteration 680
# diversity 1.9288723821391671
# iteration 681
# diversity 1.9026062237586097
# iteration 682
# diversity 1.9116460033206557
# iteration 683
# diversity 1.9743983833530458
# iteration 684
# diversity 1.9664869511125072
# iteration 685
# diversity 1.9423519017432864
# iteration 686
# diversity 1.9017232264893282
# iteration 687
# diversity 1.9024078071641437
# iteration 688
# diversity 1.9081473833625984
# iteration 689
# diversity 1.9151658801583682
# iteration 690
# diversity 1.916135672441798
# iteration 691
# diversity 1.9213083373597497
# iteration 692
# diversity 1.909927830334905
# iteration 693
# diversity 1.9136805568211215
# iteration 694
# diversity 1.917400975373925
# iteration 695
# diversity 1.9150903646646042
# iteration 696
# diversity 1.9049996379281862
# iteration 697
# diversity 1.9078782003328476
# iteration 698
# diversity 1.9059776046947874
# iteration 699
# diversity 1.9256244323387424
# iteration 700
# diversity 1.9811942541558358
# iteration 701
# diversity 1.9093174668459256
# iteration 702
# diversity 1.9030446576153055
# iteration 703
# diversity 1.9005191543489277
# iteration 704
# diversity 1.9182145740588852
# iteration 705
# diversity 1.9461886227237764
# iteration 706
# diversity 1.9571574124308555
# iteration 707
# diversity 1.9123202367356407
# iteration 708
# diversity 1.9007447060799716
# iteration 709
# diversity 1.9044100446992815
# iteration 710
# diversity 1.949890227958695
# iteration 711
# diversity 1.9438059493150586
# iteration 712
# diversity 1.9676156055299037
# iteration 713
# diversity 1.9004273004770322
# iteration 714
# diversity 1.9121266096542262
# iteration 715
# diversity 1.9033381061354973
# iteration 716
# diversity 1.912228797394762
# iteration 717
# diversity 1.9233063296871902
# iteration 718
# diversity 2.0056978335570617
# iteration 719
# diversity 1.9500604173633884
# iteration 720
# diversity 1.9013123225439563
# iteration 721
# diversity 1.9519947607468864
# iteration 722
# diversity 1.9045574375571377
# iteration 723
# diversity 1.9208119320704655
# iteration 724
# diversity 1.9452245384589761
# iteration 725
# diversity 1.9148113696325173
# iteration 726
# diversity 1.9492547021662086
# iteration 727
# diversity 1.9336030919768115
# iteration 728
# diversity 1.9276594733588734
# iteration 729
# diversity 1.919142636347784
# iteration 730
# diversity 1.9091734147325787
# iteration 731
# diversity 1.9028324302840096
# iteration 732
# diversity 1.909884419195348
# iteration 733
# diversity 1.9277572772414684
# iteration 734
# diversity 1.9226435962746562
# iteration 735
# diversity 1.9054627648041784
# iteration 736
# diversity 1.9031918659640945
# iteration 737
# diversity 1.9018951935009616
# iteration 738
# diversity 1.9110081925339726
# iteration 739
# diversity 1.9065005897755922
# iteration 740
# diversity 1.9028236148258126
# iteration 741
# diversity 1.9381789570670303
# iteration 742
# diversity 1.9015422889391769
# iteration 743
# diversity 1.9567318302704981
# iteration 744
# diversity 1.931081936111679
# iteration 745
# diversity 1.9666743768190125
# iteration 746
# diversity 1.9267654206468943
# iteration 747
# diversity 1.902293112121176
# iteration 748
# diversity 1.937485765100502
# iteration 749
# diversity 1.925720210472489
# iteration 750
# diversity 1.9141322643415322
# iteration 751
# diversity 1.9110503864991746
# iteration 752
# diversity 1.9034474016822163
# iteration 753
# diversity 1.9263415180965413
# iteration 754
# diversity 1.9772450837618596
# iteration 755
# diversity 1.9049879254554918
# iteration 756
# diversity 1.9346380214092984
# iteration 757
# diversity 1.9375044419002538
# iteration 758
# diversity 1.9204249748323388
# iteration 759
# diversity 1.9026297590440449
# iteration 760
# diversity 1.9249560383908138
# iteration 761
# diversity 1.9283721185407674
# iteration 762
# diversity 1.9366893330467023
# iteration 763
# diversity 1.9112528531532802
# iteration 764
# diversity 1.9030553379571897
# iteration 765
# diversity 1.9156737577074712
# iteration 766
# diversity 1.9046338033304562
# iteration 767
# diversity 1.913793719207145
# iteration 768
# diversity 1.9483625886859584
# iteration 769
# diversity 1.910947541465282
# iteration 770
# diversity 1.9027600869287813
# iteration 771
# diversity 1.9480263844388064
# iteration 772
# diversity 1.9560342850307162
# iteration 773
# diversity 1.9471313020344863
# iteration 774
# diversity 1.90603850039264
# iteration 775
# diversity 1.9425120059190113
# iteration 776
# diversity 1.902253544848801
# iteration 777
# diversity 1.9362836485043389
# iteration 778
# diversity 1.9804332736395107
# iteration 779
# diversity 1.9038256573894659
# iteration 780
# diversity 1.9445253186106621
# iteration 781
# diversity 1.9394482518414728
# iteration 782
# diversity 1.964153875821889
# iteration 783
# diversity 1.952261412776462
# iteration 784
# diversity 1.9241479367850534
# iteration 785
# diversity 1.9386488121894199
# iteration 786
# diversity 1.9220088546104297
# iteration 787
# diversity 1.9139596730022679
# iteration 788
# diversity 1.9356770797930987
# iteration 789
# diversity 1.9057685317200448
# iteration 790
# diversity 1.912650660831995
# iteration 791
# diversity 1.9138382914378196
# iteration 792
# diversity 1.9196303858196777
# iteration 793
# diversity 1.9089714135624092
# iteration 794
# diversity 1.9000964310873443
# iteration 795
# diversity 1.902641356067101
# iteration 796
# diversity 1.9046184180010124
# iteration 797
# diversity 1.9165213516536543
# iteration 798
# diversity 1.9435125222598086
# iteration 799
# diversity 1.9012765749602982
# iteration 800
# diversity 1.9083573675133791
# iteration 801
# diversity 1.9093399422392634
# iteration 802
# diversity 1.982990020779712
# iteration 803
# diversity 1.9162654968125015
# iteration 804
# diversity 1.9062668983704012
# iteration 805
# diversity 1.900891472227029
# iteration 806
# diversity 2.020222759994551
# iteration 807
# diversity 1.9043810962973202
# iteration 808
# diversity 1.9152441356256045
# iteration 809
# diversity 1.916223118888341
# iteration 810
# diversity 1.9068811851033503
# iteration 811
# diversity 1.9449774571752727
# iteration 812
# diversity 1.9001191909707862
# iteration 813
# diversity 1.916488391267041
# iteration 814
# diversity 1.9082588403613598
# iteration 815
# diversity 1.9097961470524027
# iteration 816
# diversity 1.9235793703269346
# iteration 817
# diversity 1.9329317632807546
# iteration 818
# diversity 1.9463942680384072
# iteration 819
# diversity 1.9023997479566521
# iteration 820
# diversity 1.9362685649391083
# iteration 821
# diversity 1.9048741888282084
# iteration 822
# diversity 1.9669923076470646
# iteration 823
# diversity 1.9333892198386653
# iteration 824
# diversity 1.9011040417715672
# iteration 825
# diversity 1.9060645053234382
# iteration 826
# diversity 1.9012890364171355
# iteration 827
# diversity 1.9312256838961257
# iteration 828
# diversity 1.9183675760419077
# iteration 829
# diversity 1.951069878150817
# iteration 830
# diversity 1.962857441261664
# iteration 831
# diversity 1.9208869924721843
# iteration 832
# diversity 1.9459600325228221
# iteration 833
# diversity 1.9871651967966468
# iteration 834
# diversity 1.9013479273590892
# iteration 835
# diversity 1.9248206630692548
# iteration 836
# diversity 1.9079093442999453
# iteration 837
# diversity 1.9446794698670797
# iteration 838
# diversity 1.9348049280031743
# iteration 839
# diversity 1.9132234432328792
# iteration 840
# diversity 1.9554775645180773
# iteration 841
# diversity 1.9119935756137907
# iteration 842
# diversity 1.9064130485833275
# iteration 843
# diversity 1.919339480411991
# iteration 844
# diversity 1.9238165784525034
# iteration 845
# diversity 1.9131744501958607
# iteration 846
# diversity 1.9171966248770091
# iteration 847
# diversity 1.916192756099242
# iteration 848
# diversity 1.91407314210126
# iteration 849
# diversity 1.9003588968803282
# iteration 850
# diversity 1.9450675463360776
# iteration 851
# diversity 1.9930940543778022
# iteration 852
# diversity 1.9012890364171355
# iteration 853
# diversity 1.96620305449892
# iteration 854
# diversity 1.9126450917115687
# iteration 855
# diversity 1.9538114334504215
# iteration 856
# diversity 1.9487133134105235
# iteration 857
# diversity 1.9055492081120708
# iteration 858
# diversity 1.9208894622579196
# iteration 859
# diversity 1.9131489006474136
# iteration 860
# diversity 1.9060359136024514
# iteration 861
# diversity 1.9168770618345599
# iteration 862
# diversity 1.9014163044948795
# iteration 863
# diversity 1.9109636262363852
# iteration 864
# diversity 1.9139263063409968
# iteration 865
# diversity 1.9104586349757422
# iteration 866
# diversity 1.9251735116491582
# iteration 867
# diversity 1.9071539496071421
# iteration 868
# diversity 1.9596721686510645
# iteration 869
# diversity 1.910298642229922
# iteration 870
# diversity 1.9065468693470067
# iteration 871
# diversity 1.9228819992552513
# iteration 872
# diversity 1.9442126012344154
# iteration 873
# diversity 1.9204903788633474
# iteration 874
# diversity 1.9206876012701515
# iteration 875
# diversity 1.9360647681779066
# iteration 876
# diversity 1.9284357850008755
# iteration 877
# diversity 1.9055506367428459
# iteration 878
# diversity 1.982028898518607
# iteration 879
# diversity 1.9750444386849177
# iteration 880
# diversity 1.9036850058716919
# iteration 881
# diversity 1.9138023391212151
# iteration 882
# diversity 1.919227093650019
# iteration 883
# diversity 1.9675004572864232
# iteration 884
# diversity 1.900030667352424
# iteration 885
# diversity 1.9058519959240077
# iteration 886
# diversity 1.920100282247321
# iteration 887
# diversity 1.9087262271740026
# iteration 888
# diversity 1.9014765660415316
# iteration 889
# diversity 1.9176636327845298
# iteration 890
# diversity 1.9398371121842204
# iteration 891
# diversity 1.9190608002975078
# iteration 892
# diversity 1.9032103082753713
# iteration 893
# diversity 1.9019718508155867
# iteration 894
# diversity 1.9309517940416765
# iteration 895
# diversity 1.904408074473766
# iteration 896
# diversity 1.9076109838507596
# iteration 897
# diversity 1.9662779660987268
# iteration 898
# diversity 1.9164402049885967
# iteration 899
# diversity 1.922543422687951
# iteration 900
# diversity 1.9454173571949784
# iteration 901
# diversity 1.941444806795305
# iteration 902
# diversity 1.927655425214934
# iteration 903
# diversity 1.9245555443047027
# iteration 904
# diversity 1.9218858349850307
# iteration 905
# diversity 1.9111892443085952
# iteration 906
# diversity 1.965381273505616
# iteration 907
# diversity 2.0006518412401078
# iteration 908
# diversity 1.9128980314275645
# iteration 909
# diversity 1.9041125158225425
# iteration 910
# diversity 1.9234348183828636
# iteration 911
# diversity 1.9378886300548175
# iteration 912
# diversity 1.9138131482298086
# iteration 913
# diversity 1.9448066650530502
# iteration 914
# diversity 1.912397409659904
# iteration 915
# diversity 1.9693012196677202
# iteration 916
# diversity 1.9004857867421694
# iteration 917
# diversity 1.9193167135251927
# iteration 918
# diversity 1.9140038448403351
# iteration 919
# diversity 1.9262914484093498
# iteration 920
# diversity 1.923021616879566
# iteration 921
# diversity 1.927595664426695
# iteration 922
# diversity 1.9404243738080689
# iteration 923
# diversity 1.9024875825185605
# iteration 924
# diversity 1.909551491216049
# iteration 925
# diversity 1.912858556876226
# iteration 926
# diversity 1.9101187143878342
# iteration 927
# diversity 1.90722307483059
# iteration 928
# diversity 1.9444874386127085
# iteration 929
# diversity 1.901433223539624
# iteration 930
# diversity 1.965692093077929
# iteration 931
# diversity 1.9531506785155797
# iteration 932
# diversity 1.9123843895681227
# iteration 933
# diversity 1.9011246411744476
# iteration 934
# diversity 1.9187479998464394
# iteration 935
# diversity 1.9233300762108216
# iteration 936
# diversity 1.9705983617673002
# iteration 937
# diversity 1.9138907198293398
# iteration 938
# diversity 1.9051526942896542
# iteration 939
# diversity 1.9009976705285294
# iteration 940
# diversity 1.942015644507595
# iteration 941
# diversity 1.901536170021151
# iteration 942
# diversity 1.9151123006679753
# iteration 943
# diversity 1.902737059618343
# iteration 944
# diversity 1.911909127200631
# iteration 945
# diversity 1.9101599060434613
# iteration 946
# diversity 1.9204593680357058
# iteration 947
# diversity 1.9682943588991488
# iteration 948
# diversity 1.9012890364171355
# iteration 949
# diversity 1.902770331998594
# iteration 950
# diversity 1.9306823283437469
# iteration 951
# diversity 1.9038582657395544
# iteration 952
# diversity 1.9099038059250655
# iteration 953
# diversity 1.9178274766340502
# iteration 954
# diversity 1.9441186104374615
# iteration 955
# diversity 1.9026297590440449
# iteration 956
# diversity 1.9416818157712203
# iteration 957
# diversity 1.9330998043882397
# iteration 958
# diversity 1.9061547804023153
# iteration 959
# diversity 1.9140725225705641
# iteration 960
# diversity 1.9254301594948562
# iteration 961
# diversity 1.9303669145094489
# iteration 962
# diversity 1.9724880172806192
# iteration 963
# diversity 1.9050867936603326
# iteration 964
# diversity 1.9448124081233171
# iteration 965
# diversity 1.925150925785193
# iteration 966
# diversity 1.9410904123126091
# iteration 967
# diversity 1.905632557795562
# iteration 968
# diversity 1.9358313010201502
# iteration 969
# diversity 1.94826823263128
# iteration 970
# diversity 1.9041258777627894
# iteration 971
# diversity 1.9074158424252252
# iteration 972
# diversity 1.9475092456679233
# iteration 973
# diversity 2.0016030423480586
# iteration 974
# diversity 1.937618868100206
# iteration 975
# diversity 1.9134931777287931
# iteration 976
# diversity 1.9230673511965064
# iteration 977
# diversity 1.9177454993849694
# iteration 978
# diversity 1.9014721107477555
# iteration 979
# diversity 1.9112683248306717
# iteration 980
# diversity 1.9161621982871277
# iteration 981
# diversity 1.924547888357049
# iteration 982
# diversity 1.9039225175262893
# iteration 983
# diversity 1.9388920681881863
# iteration 984
# diversity 1.9223123807101796
# iteration 985
# diversity 1.9071776681207322
# iteration 986
# diversity 1.9027544426013978
# iteration 987
# diversity 1.9156758997030845
# iteration 988
# diversity 1.9245222524146441
# iteration 989
# diversity 1.9813104467499663
# iteration 990
# diversity 1.9045334710250947
# iteration 991
# diversity 1.915024576113233
# iteration 992
# diversity 1.9021142218527083
# iteration 993
# diversity 1.9367481318672428
# iteration 994
# diversity 1.9225129197695778
# iteration 995
# diversity 1.9009383291444926
# iteration 996
# diversity 1.9483639372982902
# iteration 997
# diversity 1.9057212991830466
# iteration 998
# diversity 1.9029991979808265
# iteration 999
# diversity 1.9736208055232038
# --- 122.281494140625 seconds ---
# [[9, 4],
#  [9.03, 10],
#  [0, 6],
#  [0.1, 0.3],
#  [2, 1.98],
#  [7.26806569931307, 8.416282032153015],
#  (6.16666657598968, 5.453708823520189),
#  [4.982838762719405, 9.329044329275655],
#  (9.709965972267527, 0.07438506365325348),
#  (9.612834401310147, 6.887905161778974),
#  (2.7469818173257647, 6.652204882754987),
#  (0.7555835214432971, 3.872964869013316),
#  (5.72879886511647, 0.2552761114566764),
#  [0.35217679267587926, 8.121756272485543],
#  [2.7381340479602994, 0.11262824126203141],
#  [3.888080355026544, 3.0276374427793655],
#  [6.324131204448698, 3.3533963806730007],
#  (5.170767809314386, 7.255229103851596),
#  (1.761339727394703, 9.876330055104692),
#  [2.775658210441727, 4.678792419920134]]

# %%
#WITH B and counter - РАБОТАЕТ ЛУЧШЕ, СТОИТ ОСТАВИТЬ


#c - параметр схождения, если c раз подряд значение diversity не меняется, значит, все
# На входе будет r элементов популяции, на выходе надо n = pop_size

def divOpt_simple_minmax_nonzero(P, it, pop_size, b, c, mutation_rate, box_border, prob):
    
    start_time = time.time()

    a_fp = open('./obj_div_simple_minmax_nonzero_' + str(mutation_rate) + '.json', 'w')
    b_fp = open('./sol_div_simple_minmax_nonzero_' + str(mutation_rate) + '.json', 'w')
    c_fp = open('./0.9statistic_div_simple_minmax_nonzero_' + str(mutation_rate) + '.json', 'w')
    iteration = 0
    A = []
    B = []
    S = []
    for iteration in range(it):
        print("iteration", iteration)
        
        #Main program starts here

        #Initialization
        min_x=-55
        max_x=55
        A = defaultdict()
        C = defaultdict()
        solution = P
        diversity = []
        
        iteration_no_change = 0

        
        selec = SelectDiv_minmax(solution, len(solution))
        diversity.append(selec[0])
        non_zero_contributors = selec[3]
        select_div = [0, 0, 0, 0]

        gen_no=0
        
        while(len(solution)!=pop_size):
                
                #Поменяла на len(P)=r, было pop_size
                #здесь надо выбирать только из элементов с индексами solution
#                 a1 = random.randint(0,len(P)-1)
                 
    
            s = 0
            while s == 0:
                a1 = random.randint(0,len(P)-2)
                app = mutation(solution[a1], mutation_rate)
                if (app[0]<0) or (app[1]<0) or (app[0]>box_border) or (app[1]>box_border):
                    app = reflect_point(app[0], app[1], box_border)
                
                min_distance_from_new = 1000
                for z in range(len(solution)):
                    if my_distance(solution[z], app)<min_distance_from_new:
                        min_distance_from_new = my_distance(solution[z], app)
                            
                if (-obj1(app)<b[0]) and (-obj2(app)<b[1]) and (my_distance(app, solution[a1]) > epsilon) and (min_distance_from_new>=diversity[-1]) and (app[0]>=0) and (app[1]>=0) and (app[0]<=box_border) and (app[1]<=box_border) :
                    solution.append(app)
                    
                    s = 1
                else:
                    pass
                
        
        while (diversity[-1]<1.9):
#             print("GENERATION", gen_no)
            
            solution2 = solution[:]
            
            if len(non_zero_contributors)==0:
                flag = 0
            else:
                flag = 1

            while(len(solution2)!=pop_size+1):
                 
                if flag == 0:
                    a1 = random.randint(0,len(P)-1)
                    s = 0
                    while (s == 0):
                        a1 = random.randint(0,len(P)-1)
                        app = mutation(solution[a1], mutation_rate)
                        if (app[0]<0) or (app[1]<0) or (app[0]>box_border) or (app[1]>box_border):
                            app = reflect_point(app[0], app[1], box_border)
                            
                        min_distance_from_new = 1000
                        
                        for z in range(len(solution)):
                            if my_distance(solution[z], app)<min_distance_from_new:
                                min_distance_from_new = my_distance(solution[z], app)
   
                        if (-obj1(app)<b[0]) and (-obj2(app)<b[1]) and (my_distance(app, solution[a1]) > epsilon) and (min_distance_from_new>=diversity[-1]) and (app[0]>=0) and (app[1]>=0) and (app[0]<=box_border) and (app[1]<=box_border) :
                            solution2.append(app)
    #                         print(-obj1(app), -obj2(app))
                            s = 1
                        else:
                            counter += 1
                else: 
                    #ЗДЕСЬ С ВЕРОЯТНОСТЬЮ ПРОБ ВЫБИРАЛИСЬ ИМЕННО НЕНУЛЕВЫЕ ЭЛЕМЕНТЫ
                    if random.random() < prob:
                        a1 = random.choice(non_zero_contributors)
                    else:
                        a1 = random.choice([solution[i] for i in range(len(P_0))])
                        
                    s = 0
                    while (s == 0):
                        a1 = random.randint(0,len(P)-1)
                        app = mutation(solution[a1], mutation_rate)
                        if (app[0]<0) or (app[1]<0) or (app[0]>box_border) or (app[1]>box_border):
                            app = reflect_point(app[0], app[1], box_border)
                            
                        min_distance_from_new = 1000
                        
                        for z in range(len(solution)):
                            if my_distance(solution[z], app)<min_distance_from_new:
                                min_distance_from_new = my_distance(solution[z], app)
   
                        if (-obj1(app)<b[0]) and (-obj2(app)<b[1]) and (my_distance(app, solution[a1]) > epsilon) and (min_distance_from_new>=diversity[-1]) and (app[0]>=0) and (app[1]>=0) and (app[0]<=box_border) and (app[1]<=box_border) :
#                             print("flag = 1")
                            solution2.append(app)
    #                         print(-obj1(app), -obj2(app))
                            s = 1
#             print("offsprings are ready")
            
            # When it is [0, 2, .., 9] it is not supposed to chenge, but it's getting lower
            
            solution = []
            
            select_div = SelectDiv_minmax(solution2, pop_size) 
#             print("select_div", select_div)
            #не забыть все нужные параметры вставить
    
    
    
    
            if np.abs(select_div[0]-diversity[-1])<epsilon:
                iteration_no_change+=1
            else:
                iteration_no_change = 0
#             print(iteration_no_change)
            diversity.append(select_div[0])  
            indices = select_div[1]
            non_zero_contributors = select_div[3] 
            
            
            for i in range(2*pop_size):
                if i in indices:
                    solution.append(solution2[i])
            
    
            C[gen_no] = solution
            gen_no = gen_no + 1
            max_reached_gen = gen_no
#             print(solution)
            
#         print(max_reached_gen)
        print("diversity", diversity[-1])
        S.append(max_reached_gen)
        B.append(C)
        iteration +=1  
#         print(solution)
        
    json.dump(B, b_fp, cls=NpEncoder)  
    json.dump(S, c_fp, cls=NpEncoder)            

    a_fp.close()
    b_fp.close()
    c_fp.close()

    print("--- %s seconds ---" % (time.time() - start_time))
    
    return solution

random.seed(4)
divOpt_simple_minmax_nonzero(P_0, 1000, pop_size, b, 20, 10, 10, 0.9)
# Out:
# iteration 0
# diversity 1.9236899989550598
# iteration 1
# diversity 1.9629204453121598
# iteration 2
# diversity 1.9382468498568965
# iteration 3
# diversity 1.9743625301218912
# iteration 4
# diversity 1.9011194944171372
# iteration 5
# diversity 1.9011238360017264
# iteration 6
# diversity 1.935269803888639
# iteration 7
# diversity 1.922875315882615
# iteration 8
# diversity 1.9019370193944836
# iteration 9
# diversity 1.9079626039422513
# iteration 10
# diversity 1.9610352403179123
# iteration 11
# diversity 1.9104028690389963
# iteration 12
# diversity 1.9153747947049653
# iteration 13
# diversity 2.0401649664144017
# iteration 14
# diversity 1.916585811855337
# iteration 15
# diversity 1.9145199781966924
# iteration 16
# diversity 1.9018772899174405
# iteration 17
# diversity 1.9393747552007645
# iteration 18
# diversity 1.9127185499758443
# iteration 19
# diversity 1.918389987211058
# iteration 20
# diversity 1.9317979362959508
# iteration 21
# diversity 1.908827166233568
# iteration 22
# diversity 1.909177925494382
# iteration 23
# diversity 1.906247339911045
# iteration 24
# diversity 1.9425698889482734
# iteration 25
# diversity 1.9109176062619224
# iteration 26
# diversity 1.9170782509505633
# iteration 27
# diversity 1.9177071776490142
# iteration 28
# diversity 1.9003426212766306
# iteration 29
# diversity 1.924784038077355
# iteration 30
# diversity 1.9118577262054837
# iteration 31
# diversity 1.9860934629443434
# iteration 32
# diversity 1.9070125012392578
# iteration 33
# diversity 1.904383631126391
# iteration 34
# diversity 1.9288537374578618
# iteration 35
# diversity 1.9040612367865029
# iteration 36
# diversity 1.920173379674988
# iteration 37
# diversity 1.9471731249174462
# iteration 38
# diversity 1.9187645657793124
# iteration 39
# diversity 1.9357130930889794
# iteration 40
# diversity 1.902101573573123
# iteration 41
# diversity 1.913496402204364
# iteration 42
# diversity 1.9198316184599198
# iteration 43
# diversity 1.9093721508547339
# iteration 44
# diversity 1.9725429708941575
# iteration 45
# diversity 1.9006251302203125
# iteration 46
# diversity 1.9013086566784905
# iteration 47
# diversity 1.91268566454031
# iteration 48
# diversity 1.9235197682462741
# iteration 49
# diversity 1.9308467878858604
# iteration 50
# diversity 1.9542176992476534
# iteration 51
# diversity 1.9027927722730893
# iteration 52
# diversity 1.9147250211103706
# iteration 53
# diversity 1.9332096735581086
# iteration 54
# diversity 1.9138197422771246
# iteration 55
# diversity 1.9599905828092992
# iteration 56
# diversity 1.9233188418191145
# iteration 57
# diversity 1.9022687501383129
# iteration 58
# diversity 1.9087327133523435
# iteration 59
# diversity 1.9223691883904466
# iteration 60
# diversity 1.9356570507050361
# iteration 61
# diversity 1.913848592932904
# iteration 62
# diversity 1.9031442597969774
# iteration 63
# diversity 1.9391910228902514
# iteration 64
# diversity 1.9010158937119104
# iteration 65
# diversity 1.9011368405756435
# iteration 66
# diversity 1.9359458469548405
# iteration 67
# diversity 1.9166824658521409
# iteration 68
# diversity 1.9145186195525838
# iteration 69
# diversity 1.9228244231148572
# iteration 70
# diversity 1.9273941026546753
# iteration 71
# diversity 1.902816123935413
# iteration 72
# diversity 1.9420070343035307
# iteration 73
# diversity 1.9158896232877174
# iteration 74
# diversity 1.9141680314148666
# iteration 75
# diversity 1.9040145860009605
# iteration 76
# diversity 1.900739189140469
# iteration 77
# diversity 1.9037197165798314
# iteration 78
# diversity 1.9143137657098115
# iteration 79
# diversity 1.9170798558929207
# iteration 80
# diversity 1.9260632344294355
# iteration 81
# diversity 1.9042402777982337
# iteration 82
# diversity 1.9142796725850604
# iteration 83
# diversity 1.9099362183935624
# iteration 84
# diversity 1.9144911595049976
# iteration 85
# diversity 1.9587770689898276
# iteration 86
# diversity 1.9262385440058234
# iteration 87
# diversity 1.9105793284111392
# iteration 88
# diversity 1.966333328329137
# iteration 89
# diversity 1.9419018851352923
# iteration 90
# diversity 1.9501962867078988
# iteration 91
# diversity 1.9545362586743176
# iteration 92
# diversity 1.9110724905661138
# iteration 93
# diversity 1.9063609127081496
# iteration 94
# diversity 1.9106557621096458
# iteration 95
# diversity 1.9275496380021622
# iteration 96
# diversity 1.9072712400231373
# iteration 97
# diversity 1.9677328939278838
# iteration 98
# diversity 1.9116777455778784
# iteration 99
# diversity 1.9026297590440449
# iteration 100
# diversity 1.9786396760729847
# iteration 101
# diversity 1.9107328878719483
# iteration 102
# diversity 1.9756531677614928
# iteration 103
# diversity 1.905994731886475
# iteration 104
# diversity 1.9096289910375903
# iteration 105
# diversity 1.9437111328614727
# iteration 106
# diversity 1.9554589347745146
# iteration 107
# diversity 1.9253647609275693
# iteration 108
# diversity 1.9225476113959783
# iteration 109
# diversity 1.9056320341792612
# iteration 110
# diversity 1.9034050861986036
# iteration 111
# diversity 1.9018435798144888
# iteration 112
# diversity 1.9689430227663223
# iteration 113
# diversity 1.984733295781903
# iteration 114
# diversity 1.9082903530074002
# iteration 115
# diversity 1.9046560326554611
# iteration 116
# diversity 1.9071781830112686
# iteration 117
# diversity 1.9165798585540958
# iteration 118
# diversity 1.9593333015675338
# iteration 119
# diversity 1.917530486989701
# iteration 120
# diversity 1.9225598774054193
# iteration 121
# diversity 1.9263299004897532
# iteration 122
# diversity 1.9030663122688414
# iteration 123
# diversity 1.9468707565175927
# iteration 124
# diversity 1.907125415288848
# iteration 125
# diversity 1.9550742479523167
# iteration 126
# diversity 1.918252444544816
# iteration 127
# diversity 1.901328999563952
# iteration 128
# diversity 1.9246783935741338
# iteration 129
# diversity 1.9047602584273622
# iteration 130
# diversity 1.9754373033100723
# iteration 131
# diversity 1.9030392652126966
# iteration 132
# diversity 1.9128760797473525
# iteration 133
# diversity 1.9190044203757273
# iteration 134
# diversity 1.9405210215553588
# iteration 135
# diversity 1.9271051198858995
# iteration 136
# diversity 1.9068502991736862
# iteration 137
# diversity 1.997219555888687
# iteration 138
# diversity 1.9108090880643533
# iteration 139
# diversity 1.904588792810939
# iteration 140
# diversity 1.9241902352696774
# iteration 141
# diversity 1.9313568150533493
# iteration 142
# diversity 1.9042332062060168
# iteration 143
# diversity 1.9218940192099188
# iteration 144
# diversity 1.9965555390014846
# iteration 145
# diversity 1.9258339550926855
# iteration 146
# diversity 1.9354889025829265
# iteration 147
# diversity 1.9008363565053947
# iteration 148
# diversity 1.9690028849423948
# iteration 149
# diversity 1.9107684000910372
# iteration 150
# diversity 1.9006694980768184
# iteration 151
# diversity 1.904935871269304
# iteration 152
# diversity 1.914842028578896
# iteration 153
# diversity 1.9545108400818392
# iteration 154
# diversity 1.9275342183370427
# iteration 155
# diversity 1.9129339844789315
# iteration 156
# diversity 1.9232731438398571
# iteration 157
# diversity 1.9340838504153717
# iteration 158
# diversity 1.9007546589925837
# iteration 159
# diversity 1.9510880498408234
# iteration 160
# diversity 1.9255055314032368
# iteration 161
# diversity 1.9032995404032802
# iteration 162
# diversity 1.9203155519062591
# iteration 163
# diversity 1.9054883748031561
# iteration 164
# diversity 1.90085353974302
# iteration 165
# diversity 1.928380773239537
# iteration 166
# diversity 1.9393169409186761
# iteration 167
# diversity 1.9441088612708273
# iteration 168
# diversity 1.9244751053872537
# iteration 169
# diversity 1.9236721345660344
# iteration 170
# diversity 1.952261717669237
# iteration 171
# diversity 1.9072237572101414
# iteration 172
# diversity 1.9632705879048122
# iteration 173
# diversity 1.9554210903921272
# iteration 174
# diversity 1.9038539845773539
# iteration 175
# diversity 1.9100736428397038
# iteration 176
# diversity 1.9136256430483445
# iteration 177
# diversity 1.9120131962378146
# iteration 178
# diversity 1.9651393637492607
# iteration 179
# diversity 1.956324426454972
# iteration 180
# diversity 1.9250004608128113
# iteration 181
# diversity 1.9040389116088736
# iteration 182
# diversity 1.91648870602131
# iteration 183
# diversity 1.9136836502788281
# iteration 184
# diversity 1.9041739752328841
# iteration 185
# diversity 1.9328417703157614
# iteration 186
# diversity 1.9150693971890198
# iteration 187
# diversity 1.902126930050482
# iteration 188
# diversity 1.9019587821280677
# iteration 189
# diversity 1.9225471956623876
# iteration 190
# diversity 1.9403260794376203
# iteration 191
# diversity 1.904773713158799
# iteration 192
# diversity 1.9012748173222056
# iteration 193
# diversity 1.9381247716014554
# iteration 194
# diversity 1.921096454649406
# iteration 195
# diversity 1.9315477877320872
# iteration 196
# diversity 1.9033936228677824
# iteration 197
# diversity 1.9058754211140678
# iteration 198
# diversity 1.9044351882922679
# iteration 199
# diversity 1.9116042486078024
# iteration 200
# diversity 1.9429962045709652
# iteration 201
# diversity 1.9529889873630841
# iteration 202
# diversity 1.908994092128041
# iteration 203
# diversity 1.9018361406917983
# iteration 204
# diversity 1.9154819686025657
# iteration 205
# diversity 1.9218667503239162
# iteration 206
# diversity 1.9007715439412405
# iteration 207
# diversity 1.9122340765249173
# iteration 208
# diversity 1.9585410757564423
# iteration 209
# diversity 1.935358360034009
# iteration 210
# diversity 1.9582421672367234
# iteration 211
# diversity 1.9011249018796132
# iteration 212
# diversity 1.9053070128410754
# iteration 213
# diversity 1.9030163375439422
# iteration 214
# diversity 1.902288031066045
# iteration 215
# diversity 1.919646434647222
# iteration 216
# diversity 1.9155386733832185
# iteration 217
# diversity 1.9636750624821402
# iteration 218
# diversity 1.930909195326302
# iteration 219
# diversity 1.9072633533718861
# iteration 220
# diversity 1.904076484096199
# iteration 221
# diversity 1.9453712400836574
# iteration 222
# diversity 1.980356059015808
# iteration 223
# diversity 1.9192297601596966
# iteration 224
# diversity 1.9602295783912658
# iteration 225
# diversity 1.900472717159242
# iteration 226
# diversity 1.9024241900798893
# iteration 227
# diversity 1.9441175322695214
# iteration 228
# diversity 1.9250283461371007
# iteration 229
# diversity 1.903275180893651
# iteration 230
# diversity 1.9178055717261668
# iteration 231
# diversity 1.9159508175918347
# iteration 232
# diversity 1.9585779075445229
# iteration 233
# diversity 1.9315119549932342
# iteration 234
# diversity 1.9802772718871113
# iteration 235
# diversity 1.982131762040829
# iteration 236
# diversity 1.9486489266613316
# iteration 237
# diversity 1.9293278862262053
# iteration 238
# diversity 1.9138860700925475
# iteration 239
# diversity 1.9317954262268147
# iteration 240
# diversity 1.9075898400965634
# iteration 241
# diversity 1.9101428599244943
# iteration 242
# diversity 1.9093957677698994
# iteration 243
# diversity 1.917659610284029
# iteration 244
# diversity 1.9181076069233605
# iteration 245
# diversity 1.9050226718087846
# iteration 246
# diversity 1.979678664518264
# iteration 247
# diversity 1.9333287139253306
# iteration 248
# diversity 1.93273668122706
# iteration 249
# diversity 1.9128410435802063
# iteration 250
# diversity 1.9057492002140792
# iteration 251
# diversity 1.9278754776198062
# iteration 252
# diversity 1.9127133319765437
# iteration 253
# diversity 1.9103247417586895
# iteration 254
# diversity 1.9289809218557865
# iteration 255
# diversity 1.9052462373024275
# iteration 256
# diversity 1.9026297590440449
# iteration 257
# diversity 1.9910830315334596
# iteration 258
# diversity 1.9148948283135698
# iteration 259
# diversity 1.901055039543906
# iteration 260
# diversity 1.9481441922206522
# iteration 261
# diversity 1.9244744487041556
# iteration 262
# diversity 1.949214709130577
# iteration 263
# diversity 1.9133121060013596
# iteration 264
# diversity 1.9398182452975532
# iteration 265
# diversity 1.9273684419570665
# iteration 266
# diversity 1.943833780295639
# iteration 267
# diversity 1.9526319274843649
# iteration 268
# diversity 1.9101777990160465
# iteration 269
# diversity 1.9020599905630762
# iteration 270
# diversity 1.9012753996897322
# iteration 271
# diversity 1.904146821130856
# iteration 272
# diversity 1.9026528639667248
# iteration 273
# diversity 1.901253535758458
# iteration 274
# diversity 1.90408531314912
# iteration 275
# diversity 1.9022409834638294
# iteration 276
# diversity 1.9337830692669904
# iteration 277
# diversity 1.9545213064010902
# iteration 278
# diversity 1.9216678452591063
# iteration 279
# diversity 1.9172165267312977
# iteration 280
# diversity 1.961040610479176
# iteration 281
# diversity 1.9043011735875588
# iteration 282
# diversity 1.9193200912729076
# iteration 283
# diversity 1.9162125013807272
# iteration 284
# diversity 1.9056496030597372
# iteration 285
# diversity 1.9054711888136695
# iteration 286
# diversity 1.916960920077561
# iteration 287
# diversity 1.9004722091599962
# iteration 288
# diversity 1.9705892804603375
# iteration 289
# diversity 1.9450180746060797
# iteration 290
# diversity 2.001273947204663
# iteration 291
# diversity 1.966167285067879
# iteration 292
# diversity 1.962182546434128
# iteration 293
# diversity 1.9104030529891627
# iteration 294
# diversity 1.910955368301403
# iteration 295
# diversity 1.901902620583279
# iteration 296
# diversity 1.9810926452820186
# iteration 297
# diversity 1.9055210137518437
# iteration 298
# diversity 1.9296043314350282
# iteration 299
# diversity 1.9166753888519759
# iteration 300
# diversity 1.9174607200563045
# iteration 301
# diversity 1.915015893193326
# iteration 302
# diversity 1.9056984458962969
# iteration 303
# diversity 1.9015169136084533
# iteration 304
# diversity 1.904503370532013
# iteration 305
# diversity 2.0142011553799137
# iteration 306
# diversity 1.9430018372837399
# iteration 307
# diversity 1.9985156048029349
# iteration 308
# diversity 2.009360200592596
# iteration 309
# diversity 1.9181340074209856
# iteration 310
# diversity 1.9394008830750566
# iteration 311
# diversity 1.9026297590440449
# iteration 312
# diversity 1.915218809628383
# iteration 313
# diversity 1.9143786995359833
# iteration 314
# diversity 1.928771757821995
# iteration 315
# diversity 1.9251170511114521
# iteration 316
# diversity 1.9541100270792873
# iteration 317
# diversity 1.9133396775291123
# iteration 318
# diversity 1.9479174022979833
# iteration 319
# diversity 1.9200362228859984
# iteration 320
# diversity 1.9835274878044218
# iteration 321
# diversity 1.9692977443824162
# iteration 322
# diversity 1.9005013527313803
# iteration 323
# diversity 1.9126131804077564
# iteration 324
# diversity 1.9303719659765322
# iteration 325
# diversity 1.900089083524548
# iteration 326
# diversity 1.9337620150724528
# iteration 327
# diversity 1.908484198638163
# iteration 328
# diversity 1.9108543620010618
# iteration 329
# diversity 1.9602295783912658
# iteration 330
# diversity 1.9379804022733398
# iteration 331
# diversity 1.9316045695150315
# iteration 332
# diversity 1.9515006791591645
# iteration 333
# diversity 1.9015738094222536
# iteration 334
# diversity 1.9020916159392667
# iteration 335
# diversity 1.9011995429023312
# iteration 336
# diversity 1.9030063318795816
# iteration 337
# diversity 1.9027087794301074
# iteration 338
# diversity 1.9077799494973335
# iteration 339
# diversity 1.9018141618299604
# iteration 340
# diversity 1.9319269648577013
# iteration 341
# diversity 1.9348940702470967
# iteration 342
# diversity 1.904734625804089
# iteration 343
# diversity 1.9419226301445482
# iteration 344
# diversity 1.9041550018815216
# iteration 345
# diversity 1.9016148435006208
# iteration 346
# diversity 1.9060303545117885
# iteration 347
# diversity 1.9015874678433293
# iteration 348
# diversity 1.9256543180077208
# iteration 349
# diversity 1.9054919253620997
# iteration 350
# diversity 1.9340189040095612
# iteration 351
# diversity 1.901522499430427
# iteration 352
# diversity 1.9005415700841153
# iteration 353
# diversity 1.9639030227065055
# iteration 354
# diversity 1.9498749934607325
# iteration 355
# diversity 1.9462674426705184
# iteration 356
# diversity 1.921699850624963
# iteration 357
# diversity 1.906947438224902
# iteration 358
# diversity 1.905437209500223
# iteration 359
# diversity 1.9097280319633745
# iteration 360
# diversity 1.9253263919794081
# iteration 361
# diversity 1.9004284383076624
# iteration 362
# diversity 1.9076801429770558
# iteration 363
# diversity 1.9551019852843283
# iteration 364
# diversity 1.9014979270585877
# iteration 365
# diversity 1.9153724597456558
# iteration 366
# diversity 1.9387460102858114
# iteration 367
# diversity 1.9179811304557874
# iteration 368
# diversity 1.9131307999875962
# iteration 369
# diversity 1.9418336561291285
# iteration 370
# diversity 1.913524048143928
# iteration 371
# diversity 1.9219020424556823
# iteration 372
# diversity 1.9033839625573237
# iteration 373
# diversity 1.9175304597725118
# iteration 374
# diversity 1.9075120281797933
# iteration 375
# diversity 1.912807239098661
# iteration 376
# diversity 1.9900256431154064
# iteration 377
# diversity 1.9134226535206655
# iteration 378
# diversity 1.9095850979730487
# iteration 379
# diversity 1.9168515856846942
# iteration 380
# diversity 1.9327968628086563
# iteration 381
# diversity 1.9035911989379724
# iteration 382
# diversity 1.9189526254485416
# iteration 383
# diversity 1.9182233375003621
# iteration 384
# diversity 1.9331962085255192
# iteration 385
# diversity 1.9026322757238543
# iteration 386
# diversity 1.930035621633541
# iteration 387
# diversity 1.9001845879931165
# iteration 388
# diversity 1.947141827303367
# iteration 389
# diversity 1.9342751925484458
# iteration 390
# diversity 1.9509229029223907
# iteration 391
# diversity 1.9133057802763065
# iteration 392
# diversity 1.903034856102876
# iteration 393
# diversity 1.9124475974704371
# iteration 394
# diversity 1.9026297590440449
# iteration 395
# diversity 1.900622190087596
# iteration 396
# diversity 1.902915150298937
# iteration 397
# diversity 1.9062806078058494
# iteration 398
# diversity 1.9021152001512103
# iteration 399
# diversity 1.905948147356149
# iteration 400
# diversity 1.9022534810154377
# iteration 401
# diversity 1.9195322172836502
# iteration 402
# diversity 1.909254507151157
# iteration 403
# diversity 1.9142572784852099
# iteration 404
# diversity 1.9088610359675287
# iteration 405
# diversity 1.9416482710303382
# iteration 406
# diversity 1.9107082324522562
# iteration 407
# diversity 1.906299718056876
# iteration 408
# diversity 1.9000429696918164
# iteration 409
# diversity 1.9511103769355802
# iteration 410
# diversity 1.9260149483414242
# iteration 411
# diversity 1.90956066675398
# iteration 412
# diversity 1.9222655389181524
# iteration 413
# diversity 1.9133472539857197
# iteration 414
# diversity 1.9867033226619828
# iteration 415
# diversity 1.9207245956163561
# iteration 416
# diversity 1.90864986178522
# iteration 417
# diversity 1.9047137990459244
# iteration 418
# diversity 1.9023687537771419
# iteration 419
# diversity 1.9038305547594523
# iteration 420
# diversity 1.9012890364171355
# iteration 421
# diversity 2.0043668799816783
# iteration 422
# diversity 1.935318883733216
# iteration 423
# diversity 1.9391712697936307
# iteration 424
# diversity 1.9014004146254884
# iteration 425
# diversity 1.9129083189610776
# iteration 426
# diversity 1.907202888842469
# iteration 427
# diversity 1.9766532744934366
# iteration 428
# diversity 1.9288663807525552
# iteration 429
# diversity 1.9098218734708445
# iteration 430
# diversity 1.9998916788930257
# iteration 431
# diversity 1.9026297590440449
# iteration 432
# diversity 1.9076760866757088
# iteration 433
# diversity 1.9123204421515
# iteration 434
# diversity 1.9620549824555074
# iteration 435
# diversity 1.9041757098013739
# iteration 436
# diversity 1.9603851357792745
# iteration 437
# diversity 1.9259422606664371
# iteration 438
# diversity 1.9339241374566636
# iteration 439
# diversity 1.9061200919735277
# iteration 440
# diversity 1.920226359592461
# iteration 441
# diversity 1.9082512670404306
# iteration 442
# diversity 1.9023713900800772
# iteration 443
# diversity 1.9690788907890255
# iteration 444
# diversity 1.9225865827575024
# iteration 445
# diversity 1.9018970613297446
# iteration 446
# diversity 1.9006938121976324
# iteration 447
# diversity 1.9026297590440449
# iteration 448
# diversity 1.9006210261501175
# iteration 449
# diversity 1.93518124766358
# iteration 450
# diversity 1.9123650388137954
# iteration 451
# diversity 1.9042218380143212
# iteration 452
# diversity 1.9143763716397864
# iteration 453
# diversity 1.915759745360814
# iteration 454
# diversity 1.9026297590440449
# iteration 455
# diversity 1.907813577227555
# iteration 456
# diversity 1.9171676244209888
# iteration 457
# diversity 1.9026297590440449
# iteration 458
# diversity 1.9086917347680612
# iteration 459
# diversity 1.9171283520257825
# iteration 460
# diversity 1.9285575063761846
# iteration 461
# diversity 1.986856688029713
# iteration 462
# diversity 1.9165615270836602
# iteration 463
# diversity 1.921113457372691
# iteration 464
# diversity 1.9531138113652533
# iteration 465
# diversity 1.9001611279389463
# iteration 466
# diversity 1.9028172131646508
# iteration 467
# diversity 1.9078501401112204
# iteration 468
# diversity 1.9032168887696306
# iteration 469
# diversity 1.9163982603620247
# iteration 470
# diversity 1.9148696327548156
# iteration 471
# diversity 1.9076108268655496
# iteration 472
# diversity 1.9092910502280533
# iteration 473
# diversity 1.9046934864567162
# iteration 474
# diversity 1.94442452917394
# iteration 475
# diversity 1.9236271467028005
# iteration 476
# diversity 1.9020862050125409
# iteration 477
# diversity 1.9114865242403931
# iteration 478
# diversity 1.9042258709617252
# iteration 479
# diversity 1.9337492609609106
# iteration 480
# diversity 1.928320361246136
# iteration 481
# diversity 1.9262098228382671
# iteration 482
# diversity 1.9141160691605659
# iteration 483
# diversity 1.9831743363513714
# iteration 484
# diversity 1.9093458943929285
# iteration 485
# diversity 1.9026297590440449
# iteration 486
# diversity 1.914765867263164
# iteration 487
# diversity 1.914583330352438
# iteration 488
# diversity 1.926112502355573
# iteration 489
# diversity 1.911024113428694
# iteration 490
# diversity 1.9392805978260308
# iteration 491
# diversity 1.909916277603064
# iteration 492
# diversity 1.952272140936474
# iteration 493
# diversity 1.900780079721382
# iteration 494
# diversity 1.9054097215578472
# iteration 495
# diversity 1.9312015929717747
# iteration 496
# diversity 1.9384595935247284
# iteration 497
# diversity 1.9757622901744822
# iteration 498
# diversity 1.992042228091622
# iteration 499
# diversity 1.9185052256239936
# iteration 500
# diversity 1.9689847980047424
# iteration 501
# diversity 1.9505162436219385
# iteration 502
# diversity 1.9588208369564613
# iteration 503
# diversity 1.911939940184357
# iteration 504
# diversity 1.964963359170199
# iteration 505
# diversity 1.9266071781838354
# iteration 506
# diversity 1.9308647231341975
# iteration 507
# diversity 1.9399020839083554
# iteration 508
# diversity 1.9336875264098907
# iteration 509
# diversity 1.9679772182841753
# iteration 510
# diversity 1.9604456928171101
# iteration 511
# diversity 1.9869787859571024
# iteration 512
# diversity 1.9027005431363868
# iteration 513
# diversity 1.9147114507775491
# iteration 514
# diversity 1.936480620653665
# iteration 515
# diversity 1.9509241095916665
# iteration 516
# diversity 1.9500173368214961
# iteration 517
# diversity 1.902076057667175
# iteration 518
# diversity 1.9034794808401678
# iteration 519
# diversity 1.9356515487079031
# iteration 520
# diversity 1.9111807547983422
# iteration 521
# diversity 1.96380449595423
# iteration 522
# diversity 1.9531010452017081
# iteration 523
# diversity 1.933500340644961
# iteration 524
# diversity 1.9124527705511616
# iteration 525
# diversity 1.9009808040661706
# iteration 526
# diversity 1.911080049923478
# iteration 527
# diversity 1.9182795911262478
# iteration 528
# diversity 1.9537403554567288
# iteration 529
# diversity 1.9830813084451961
# iteration 530
# diversity 1.9039990260787387
# iteration 531
# diversity 1.9133323925649237
# iteration 532
# diversity 1.9399979696057543
# iteration 533
# diversity 1.9305301528156664
# iteration 534
# diversity 1.926589900248243
# iteration 535
# diversity 1.9557439567081305
# iteration 536
# diversity 1.9202872918018772
# iteration 537
# diversity 1.9196259206190487
# iteration 538
# diversity 1.9236834656584836
# iteration 539
# diversity 1.917559533095644
# iteration 540
# diversity 1.9198228026658284
# iteration 541
# diversity 1.9068653050500644
# iteration 542
# diversity 1.9235556185709792
# iteration 543
# diversity 1.9613027565000207
# iteration 544
# diversity 1.9255369083502911
# iteration 545
# diversity 1.9039202477594146
# iteration 546
# diversity 1.9007635063750028
# iteration 547
# diversity 1.940978238196279
# iteration 548
# diversity 1.9207151867297276
# iteration 549
# diversity 1.91247074101858
# iteration 550
# diversity 1.9134488087933847
# iteration 551
# diversity 1.9279209119435998
# iteration 552
# diversity 1.9289510146510085
# iteration 553
# diversity 1.965746350960947
# iteration 554
# diversity 1.931845779869861
# iteration 555
# diversity 1.9606405513285716
# iteration 556
# diversity 1.9142394340517686
# iteration 557
# diversity 1.9012890364171355
# iteration 558
# diversity 1.938126189577529
# iteration 559
# diversity 1.9135282736110746
# iteration 560
# diversity 1.9313162734719689
# iteration 561
# diversity 1.91311561033198
# iteration 562
# diversity 1.9562250559569547
# iteration 563
# diversity 1.968887107228364
# iteration 564
# diversity 1.9285518967433375
# iteration 565
# diversity 1.9120799132319237
# iteration 566
# diversity 1.9064936868884355
# iteration 567
# diversity 1.904177988230789
# iteration 568
# diversity 1.9311432398792885
# iteration 569
# diversity 1.9022968718474245
# iteration 570
# diversity 1.9199175789365286
# iteration 571
# diversity 1.903109097789184
# iteration 572
# diversity 1.9098614905698803
# iteration 573
# diversity 1.9011196468501994
# iteration 574
# diversity 1.9086397134479482
# iteration 575
# diversity 1.972934006857722
# iteration 576
# diversity 1.9528999239929772
# iteration 577
# diversity 1.9379564299790157
# iteration 578
# diversity 1.9292445278305035
# iteration 579
# diversity 1.9124524348388436
# iteration 580
# diversity 1.9672720120518041
# iteration 581
# diversity 1.9105806901946982
# iteration 582
# diversity 1.9123320106942878
# iteration 583
# diversity 1.9041195430712712
# iteration 584
# diversity 1.9265139322129279
# iteration 585
# diversity 1.901212443456595
# iteration 586
# diversity 1.9141261978843545
# iteration 587
# diversity 1.9198027726833746
# iteration 588
# diversity 1.9026297590440449
# iteration 589
# diversity 2.02322885381304
# iteration 590
# diversity 1.9041711690337586
# iteration 591
# diversity 1.921821929951317
# iteration 592
# diversity 1.9006270499431108
# iteration 593
# diversity 1.9549666755684176
# iteration 594
# diversity 1.9225151145901849
# iteration 595
# diversity 1.9484323991784416
# iteration 596
# diversity 1.9457841828023805
# iteration 597
# diversity 1.9810023566413462
# iteration 598
# diversity 1.9249678388080376
# iteration 599
# diversity 1.9509233097273873
# iteration 600
# diversity 1.9125061093066404
# iteration 601
# diversity 1.9258972621848072
# iteration 602
# diversity 1.9447893420448648
# iteration 603
# diversity 1.9279678206382866
# iteration 604
# diversity 1.9038026345047503
# iteration 605
# diversity 1.9147505381682075
# iteration 606
# diversity 1.9043775532053158
# iteration 607
# diversity 1.933641507578026
# iteration 608
# diversity 1.905835792425832
# iteration 609
# diversity 1.9033916795195103
# iteration 610
# diversity 1.9245752016747664
# iteration 611
# diversity 1.9330391379777312
# iteration 612
# diversity 1.9267749305662938
# iteration 613
# diversity 1.9301124340204887
# iteration 614
# diversity 1.9219809182077214
# iteration 615
# diversity 1.9139390189551515
# iteration 616
# diversity 1.9306441986712284
# iteration 617
# diversity 1.9044575521214893
# iteration 618
# diversity 1.900138288336136
# iteration 619
# diversity 1.914593472604224
# iteration 620
# diversity 1.9198715713083543
# iteration 621
# diversity 1.9364197342784972
# iteration 622
# diversity 1.954228042306261
# iteration 623
# diversity 1.9335567221240584
# iteration 624
# diversity 1.9168140459416925
# iteration 625
# diversity 1.9188863713972548
# iteration 626
# diversity 1.947267770062719
# iteration 627
# diversity 1.92607365877885
# iteration 628
# diversity 1.9014598055567258
# iteration 629
# diversity 1.9215274352764642
# iteration 630
# diversity 1.9007401444127612
# iteration 631
# diversity 1.9664725373976055
# iteration 632
# diversity 1.9368214043712815
# iteration 633
# diversity 1.976199609804736
# iteration 634
# diversity 1.9458436978117137
# iteration 635
# diversity 1.9022841749122503
# iteration 636
# diversity 1.9099397460571859
# iteration 637
# diversity 1.9150077071764882
# iteration 638
# diversity 1.9033827886889139
# iteration 639
# diversity 1.9150196914226179
# iteration 640
# diversity 1.9017386499066222
# iteration 641
# diversity 1.9398399326621658
# iteration 642
# diversity 1.9762665513690687
# iteration 643
# diversity 1.923721777715094
# iteration 644
# diversity 1.91315689778237
# iteration 645
# diversity 1.9104648753501632
# iteration 646
# diversity 1.9298528022375006
# iteration 647
# diversity 1.9218622548690891
# iteration 648
# diversity 1.9216942939914956
# iteration 649
# diversity 1.965145952132677
# iteration 650
# diversity 1.9269435236287509
# iteration 651
# diversity 1.9047331958066789
# iteration 652
# diversity 1.9026297590440449
# iteration 653
# diversity 1.9646732175667223
# iteration 654
# diversity 1.9304097128019648
# iteration 655
# diversity 1.95138577995982
# iteration 656
# diversity 1.915975158561986
# iteration 657
# diversity 1.9073216999808273
# iteration 658
# diversity 1.9586463756714085
# iteration 659
# diversity 1.9188046407870785
# iteration 660
# diversity 1.903031094189797
# iteration 661
# diversity 1.9143273710503041
# iteration 662
# diversity 1.951121194524423
# iteration 663
# diversity 1.9323662317247419
# iteration 664
# diversity 1.9243989197113718
# iteration 665
# diversity 1.9708691728624979
# iteration 666
# diversity 1.943766678366849
# iteration 667
# diversity 1.906342314120646
# iteration 668
# diversity 1.9211512970757574
# iteration 669
# diversity 1.9138528556332426
# iteration 670
# diversity 1.9024838854504038
# iteration 671
# diversity 1.9000236350229873
# iteration 672
# diversity 1.9897527852840466
# iteration 673
# diversity 1.9189003210263202
# iteration 674
# diversity 1.9298522122194828
# iteration 675
# diversity 1.909083723129901
# iteration 676
# diversity 1.9023176164646431
# iteration 677
# diversity 1.9206978849675627
# iteration 678
# diversity 1.938394987309239
# iteration 679
# diversity 1.9565666828886477
# iteration 680
# diversity 1.924481342691711
# iteration 681
# diversity 1.9175422778784184
# iteration 682
# diversity 1.9003183325514452
# iteration 683
# diversity 1.9373052988571537
# iteration 684
# diversity 1.9373931624045642
# iteration 685
# diversity 1.9602295783912658
# iteration 686
# diversity 1.9038524281836953
# iteration 687
# diversity 1.9094725422536591
# iteration 688
# diversity 1.9558036458222254
# iteration 689
# diversity 1.9120763810968522
# iteration 690
# diversity 1.9247179871153095
# iteration 691
# diversity 1.913742841853052
# iteration 692
# diversity 1.9864486480065486
# iteration 693
# diversity 1.9049125987691866
# iteration 694
# diversity 1.9050599463608549
# iteration 695
# diversity 1.9729830438934413
# iteration 696
# diversity 1.9077760467959999
# iteration 697
# diversity 1.902959938999022
# iteration 698
# diversity 1.9363494975675895
# iteration 699
# diversity 1.9208548267254542
# iteration 700
# diversity 1.905396292894202
# iteration 701
# diversity 1.9013520625027724
# iteration 702
# diversity 1.9048195775837045
# iteration 703
# diversity 1.9970561974018488
# iteration 704
# diversity 1.934996501856628
# iteration 705
# diversity 1.980226060160662
# iteration 706
# diversity 1.901896593284967
# iteration 707
# diversity 1.9041983449717899
# iteration 708
# diversity 1.9098432033660424
# iteration 709
# diversity 1.9214698432903636
# iteration 710
# diversity 1.9177148639729429
# iteration 711
# diversity 1.9074177908006318
# iteration 712
# diversity 1.9228804556567196
# iteration 713
# diversity 1.9573111222500168
# iteration 714
# diversity 1.903635278211531
# iteration 715
# diversity 1.9114365515825253
# iteration 716
# diversity 1.942479643002193
# iteration 717
# diversity 1.9407874911294098
# iteration 718
# diversity 1.917882724980735
# iteration 719
# diversity 1.9355908475486878
# iteration 720
# diversity 1.9251043113512618
# iteration 721
# diversity 1.9004788343745824
# iteration 722
# diversity 1.9630539480098
# iteration 723
# diversity 1.9297056835131405
# iteration 724
# diversity 1.9280530934459008
# iteration 725
# diversity 1.9404498781725
# iteration 726
# diversity 1.9024661803888252
# iteration 727
# diversity 1.9012890364171355
# iteration 728
# diversity 1.93911552868917
# iteration 729
# diversity 1.9857220375438205
# iteration 730
# diversity 1.9047399237584872
# iteration 731
# diversity 1.909879435596379
# iteration 732
# diversity 1.9729360902528783
# iteration 733
# diversity 1.905541269892113
# iteration 734
# diversity 1.9168375199492251
# iteration 735
# diversity 1.9185003370161817
# iteration 736
# diversity 1.9473508616080646
# iteration 737
# diversity 1.9132372359156198
# iteration 738
# diversity 1.9259103035604903
# iteration 739
# diversity 1.9500410960791084
# iteration 740
# diversity 1.9121244572489966
# iteration 741
# diversity 1.9557171247573983
# iteration 742
# diversity 1.9012890364171355
# iteration 743
# diversity 1.9258683186224101
# iteration 744
# diversity 1.9094574427301647
# iteration 745
# diversity 1.9450833510300927
# iteration 746
# diversity 1.9190173130008386
# iteration 747
# diversity 1.9111692984338953
# iteration 748
# diversity 1.9251382799393355
# iteration 749
# diversity 1.912517219933406
# iteration 750
# diversity 1.9094705976295676
# iteration 751
# diversity 1.903957538595814
# iteration 752
# diversity 1.9048414223960215
# iteration 753
# diversity 1.9297665219476963
# iteration 754
# diversity 1.920621499346663
# iteration 755
# diversity 1.9061398472009043
# iteration 756
# diversity 1.9416320513583738
# iteration 757
# diversity 2.0079909312346707
# iteration 758
# diversity 1.9222966662070649
# iteration 759
# diversity 1.9426614010558332
# iteration 760
# diversity 1.9043875152061995
# iteration 761
# diversity 1.910331156550434
# iteration 762
# diversity 1.9677644733804853
# iteration 763
# diversity 1.9433676045485502
# iteration 764
# diversity 1.9012431028800907
# iteration 765
# diversity 1.919234785954603
# iteration 766
# diversity 1.916239063974245
# iteration 767
# diversity 1.9052943321488345
# iteration 768
# diversity 1.941340188368739
# iteration 769
# diversity 1.903465657331934
# iteration 770
# diversity 1.907781043596142
# iteration 771
# diversity 1.9090568896127618
# iteration 772
# diversity 1.9408866352618594
# iteration 773
# diversity 1.9005993128110303
# iteration 774
# diversity 1.914677700321796
# iteration 775
# diversity 1.9191972792952519
# iteration 776
# diversity 1.9276674475886395
# iteration 777
# diversity 1.9274015219803025
# iteration 778
# diversity 2.001381671361159
# iteration 779
# diversity 1.9059000187527555
# iteration 780
# diversity 1.9142415255670369
# iteration 781
# diversity 1.915812195282315
# iteration 782
# diversity 1.938834301340463
# iteration 783
# diversity 1.9150719355097257
# iteration 784
# diversity 1.9110296278298864
# iteration 785
# diversity 1.9616083292225694
# iteration 786
# diversity 1.9295594050964562
# iteration 787
# diversity 1.970356869068064
# iteration 788
# diversity 1.9274730381868876
# iteration 789
# diversity 1.9136127708926167
# iteration 790
# diversity 1.9188895267752575
# iteration 791
# diversity 1.9085450911045059
# iteration 792
# diversity 1.9023885748484313
# iteration 793
# diversity 1.96201611974252
# iteration 794
# diversity 1.9158002295555339
# iteration 795
# diversity 1.907325003688597
# iteration 796
# diversity 1.9164985126310934
# iteration 797
# diversity 1.9512960080838009
# iteration 798
# diversity 1.9641791728950977
# iteration 799
# diversity 1.9294270340272355
# iteration 800
# diversity 1.926820063359537
# iteration 801
# diversity 1.9052807965731007
# iteration 802
# diversity 1.9185634119563884
# iteration 803
# diversity 1.9140813852567102
# iteration 804
# diversity 1.9173384579287265
# iteration 805
# diversity 1.9177876597701078
# iteration 806
# diversity 1.9009721897770597
# iteration 807
# diversity 1.936938323077929
# iteration 808
# diversity 1.9222843838367332
# iteration 809
# diversity 1.9118030064354943
# iteration 810
# diversity 1.9145878180681857
# iteration 811
# diversity 1.9170892013712728
# iteration 812
# diversity 1.9132025948385483
# iteration 813
# diversity 1.9086346253202777
# iteration 814
# diversity 1.9270172722863874
# iteration 815
# diversity 1.919064168098034
# iteration 816
# diversity 1.9126866984466953
# iteration 817
# diversity 1.9318461517518728
# iteration 818
# diversity 1.9098680057761632
# iteration 819
# diversity 1.9057220520134253
# iteration 820
# diversity 1.9175455746625734
# iteration 821
# diversity 1.9130812524597405
# iteration 822
# diversity 1.9242237897262235
# iteration 823
# diversity 1.9158803190266949
# iteration 824
# diversity 1.9142655701349007
# iteration 825
# diversity 1.945642038500237
# iteration 826
# diversity 1.9022979188698483
# iteration 827
# diversity 1.904031135332088
# iteration 828
# diversity 1.9081293002905226
# iteration 829
# diversity 1.904669110749229
# iteration 830
# diversity 1.9050385836947887
# iteration 831
# diversity 1.9098192572594264
# iteration 832
# diversity 1.9075789556057672
# iteration 833
# diversity 1.9114045738318526
# iteration 834
# diversity 1.9258056473200797
# iteration 835
# diversity 1.928551107588775
# iteration 836
# diversity 1.9522619854525778
# iteration 837
# diversity 1.963698496784892
# iteration 838
# diversity 1.937224523158988
# iteration 839
# diversity 2.0033230627854883
# iteration 840
# diversity 1.9167640417741396
# iteration 841
# diversity 1.9177813254729954
# iteration 842
# diversity 1.937486131001271
# iteration 843
# diversity 1.9700210786312629
# iteration 844
# diversity 1.9156572091988544
# iteration 845
# diversity 1.919051019228527
# iteration 846
# diversity 1.9830517688335931
# iteration 847
# diversity 1.910171069973661
# iteration 848
# diversity 1.914211581842863
# iteration 849
# diversity 1.9022923970026664
# iteration 850
# diversity 1.917408496981382
# iteration 851
# diversity 1.9074359226048083
# iteration 852
# diversity 1.944771042210297
# iteration 853
# diversity 1.957968810262674
# iteration 854
# diversity 1.9026297590440449
# iteration 855
# diversity 2.000590691332387
# iteration 856
# diversity 1.9138235347579415
# iteration 857
# diversity 1.9183654051553487
# iteration 858
# diversity 1.9072872747284997
# iteration 859
# diversity 1.9241814676886404
# iteration 860
# diversity 1.9141388591464823
# iteration 861
# diversity 1.9037556313140698
# iteration 862
# diversity 1.9050049762908754
# iteration 863
# diversity 1.930251399353771
# iteration 864
# diversity 1.9211963563804308
# iteration 865
# diversity 1.9296241910217447
# iteration 866
# diversity 1.9266804044627814
# iteration 867
# diversity 1.9032803535822544
# iteration 868
# diversity 1.9012052804068023
# iteration 869
# diversity 1.9243406430787173
# iteration 870
# diversity 1.90204914593343
# iteration 871
# diversity 1.9116773453082092
# iteration 872
# diversity 1.9108080592397207
# iteration 873
# diversity 1.9047044529687946
# iteration 874
# diversity 1.940210462564834
# iteration 875
# diversity 1.9125320016925649
# iteration 876
# diversity 1.9165465814335536
# iteration 877
# diversity 1.9411971192390882
# iteration 878
# diversity 1.9018829502259158
# iteration 879
# diversity 2.036181146646454
# iteration 880
# diversity 1.9354171733559464
# iteration 881
# diversity 1.9494634716313015
# iteration 882
# diversity 1.9080108231039121
# iteration 883
# diversity 1.9653958012058614
# iteration 884
# diversity 1.9309303525750363
# iteration 885
# diversity 1.9218898673244906
# iteration 886
# diversity 1.9313241695290755
# iteration 887
# diversity 1.9074939738303147
# iteration 888
# diversity 1.9318725853516883
# iteration 889
# diversity 1.9202838023194129
# iteration 890
# diversity 1.929273518857742
# iteration 891
# diversity 1.9037443995099512
# iteration 892
# diversity 1.9305139681807455
# iteration 893
# diversity 1.9659427811958843
# iteration 894
# diversity 1.9213889697633888
# iteration 895
# diversity 1.9073155265138697
# iteration 896
# diversity 1.9389908729485485
# iteration 897
# diversity 1.9002408059784628
# iteration 898
# diversity 1.9159752473038993
# iteration 899
# diversity 1.9189932386688537
# iteration 900
# diversity 1.9726472385360816
# iteration 901
# diversity 1.9495782848336245
# iteration 902
# diversity 1.915125844571601
# iteration 903
# diversity 1.9115604995354858
# iteration 904
# diversity 1.9128705171346652
# iteration 905
# diversity 1.916199158496841
# iteration 906
# diversity 1.9221328885257212
# iteration 907
# diversity 1.9294877616208508
# iteration 908
# diversity 1.9028087173554984
# iteration 909
# diversity 1.9127951028868597
# iteration 910
# diversity 1.9130187041645135
# iteration 911
# diversity 1.9102599463946255
# iteration 912
# diversity 1.9066228624724166
# iteration 913
# diversity 1.9367133380029065
# iteration 914
# diversity 1.9023478150042066
# iteration 915
# diversity 1.9565858649077323
# iteration 916
# diversity 1.9405958090607476
# iteration 917
# diversity 1.9675504131076145
# iteration 918
# diversity 1.9179910223567682
# iteration 919
# diversity 1.9517599463086666
# iteration 920
# diversity 1.9080351967806157
# iteration 921
# diversity 1.9082267614845612
# iteration 922
# diversity 1.9495712799344194
# iteration 923
# diversity 1.9492535360272645
# iteration 924
# diversity 1.9110584703997704
# iteration 925
# diversity 1.9300225062742502
# iteration 926
# diversity 1.9217174235974712
# iteration 927
# diversity 1.9099147028585501
# iteration 928
# diversity 1.9224252478083588
# iteration 929
# diversity 1.9424589568117503
# iteration 930
# diversity 1.913231399982781
# iteration 931
# diversity 1.9023728828682624
# iteration 932
# diversity 1.942476752145214
# iteration 933
# diversity 1.9215847141527698
# iteration 934
# diversity 1.9225502292116712
# iteration 935
# diversity 1.9160343122610006
# iteration 936
# diversity 1.9246784007665432
# iteration 937
# diversity 1.9484179074019017
# iteration 938
# diversity 1.9004180096406007
# iteration 939
# diversity 1.921338681858124
# iteration 940
# diversity 1.900302740833294
# iteration 941
# diversity 1.9024358350826247
# iteration 942
# diversity 1.9373411096399298
# iteration 943
# diversity 1.9260570013055645
# iteration 944
# diversity 1.9095048255738443
# iteration 945
# diversity 1.9343712510040256
# iteration 946
# diversity 1.972120978280026
# iteration 947
# diversity 1.9373441268303084
# iteration 948
# diversity 1.9091657377398217
# iteration 949
# diversity 1.9049546811253912
# iteration 950
# diversity 1.9089028698614865
# iteration 951
# diversity 1.9032153142558343
# iteration 952
# diversity 1.9223652487114398
# iteration 953
# diversity 2.0607492969007817
# iteration 954
# diversity 1.9308620886946717
# iteration 955
# diversity 1.9099425915575152
# iteration 956
# diversity 1.9233780296402034
# iteration 957
# diversity 1.9261743354567777
# iteration 958
# diversity 1.9157619718306997
# iteration 959
# diversity 1.920582373737763
# iteration 960
# diversity 1.9026297590440449
# iteration 961
# diversity 1.948006579653799
# iteration 962
# diversity 1.9157866245635846
# iteration 963
# diversity 1.917808801524003
# iteration 964
# diversity 1.9202444011260156
# iteration 965
# diversity 1.9228603870665082
# iteration 966
# diversity 1.9108206456007808
# iteration 967
# diversity 1.9149463810473106
# iteration 968
# diversity 1.92020867828587
# iteration 969
# diversity 1.9558432585806522
# iteration 970
# diversity 1.9366689733839717
# iteration 971
# diversity 1.9168133680345176
# iteration 972
# diversity 1.9185261004037433
# iteration 973
# diversity 1.974353063850617
# iteration 974
# diversity 1.921606790943801
# iteration 975
# diversity 1.9124749027174726
# iteration 976
# diversity 1.9515368111892901
# iteration 977
# diversity 1.9638772987174395
# iteration 978
# diversity 1.9190213909473612
# iteration 979
# diversity 1.9220771545639102
# iteration 980
# diversity 1.9194503568213137
# iteration 981
# diversity 1.9025470362813863
# iteration 982
# diversity 1.9174318912201933
# iteration 983
# diversity 1.9521056534225247
# iteration 984
# diversity 1.936528484199794
# iteration 985
# diversity 1.915787935407976
# iteration 986
# diversity 1.903793022133369
# iteration 987
# diversity 1.9096614945278971
# iteration 988
# diversity 1.909054776312522
# iteration 989
# diversity 1.9282756002708321
# iteration 990
# diversity 1.9273510319827083
# iteration 991
# diversity 1.9002178355399288
# iteration 992
# diversity 1.9036348655233493
# iteration 993
# diversity 1.9089549152139316
# iteration 994
# diversity 2.005396207768632
# iteration 995
# diversity 1.9375321144498079
# iteration 996
# diversity 1.9402420147939052
# iteration 997
# diversity 1.92902748446713
# iteration 998
# diversity 1.901256956039635
# iteration 999
# diversity 1.9300751559910843
# --- 117.94787216186523 seconds ---
# [[2, 4.2],
#  [9.05, 1],
#  [9.03, 10],
#  [0, 6],
#  [0.1, 0.3],
#  [2, 1.98],
#  (7.865466813960886, 6.195178539883711),
#  (7.2813128027650365, 4.355625822787023),
#  (3.9774653535403846, 7.303836041828346),
#  (3.3608876565047305, 9.60901205006789),
#  [0.6696952850374691, 8.32870770806139],
#  [0.054773945797206736, 3.60622861537762],
#  [5.854392904923275, 9.8567184759374],
#  [4.466888690210178, 1.9369704284131921],
#  (5.88752436751612, 6.710553010669821),
#  [9.668495555860412, 4.303584821194358],
#  (2.1708425790094354, 6.255253164924383),
#  (6.451199584421619, 1.544956298522564),
#  [9.240806164196782, 7.738168404631345],
#  [4.024592367620489, 4.5876297319307175]]

# %%
def statistical_comparison(js1, js2):
    
    with open(js1, 'r') as f:
        list_non_zero = ast.literal_eval(f.readlines()[0])
    with open(js2, 'r') as f:
        list_with_zero = ast.literal_eval(f.readlines()[0])
    
    print(statistics.mean(list_non_zero), statistics.stdev(list_non_zero), statistics.mean(list_with_zero), statistics.stdev(list_with_zero))
    
    # Two-Sample t-test
    t_stat, t_p_value = scipy.stats.ttest_ind(list_non_zero, list_with_zero)
    print(t_stat, t_p_value)
    
statistical_comparison('0.9statistic_div_simple_minmax_nonzero_10.json', '0.9statistic_div_simple_minmax_10.json')
# Out:
# 31.844 4.442679529450825 32.24 4.129097897779786
# -2.0646615981985788 0.03908380512861559

# %% [markdown]
# # Paired comparison of all results (not included in the paper)

# %%
def compare_two_lists(list1, list2):
    t_stat, t_p_value = scipy.stats.ttest_rel(list1, list2)
    print(statistics.mean(list1), statistics.mean(list2))
    return [t_stat, t_p_value]

# %%
#Не знаю как сравнить зависимые 3 выборки
def compare_three_lists(list1, list2, list3):
    k_stat, k_p_value = scipy.stats.kruskal(list1, list2, list3)
    print(statistics.mean(list1), statistics.mean(list2), statistics.mean(list3))
    return [k_stat, k_p_value]

# %%
# Minmax

sp_diversity = [
    1.289199, 1.992752, 1.984671, 1.978791, 1.969326, 
    1.948743, 1.940491, 1.917006, 1.892472, 1.869275, 
    1.839718, 1.798662, 1.772763, 1.730658, 1.664272, 
    1.587330
]

# Min-Max Diversity
min_max_diversity = [
    0.020000, 1.155057, 1.076923, 1.017851, 0.956182, 
    0.896359, 0.864250, 0.814980, 0.763097, 0.730958, 
    0.683252, 0.641958, 0.607719, 0.564796, 0.510914, 
    0.453903
]

# S-Energy Diversity (divided by 100)
s_energy_diversity = np.array([
    4458.612694, 0.264910, 0.366218, 0.437088, 0.557592, 
    0.887322, 1.003750, 1.478514, 2.227013, 2.804378, 
    4.013549, 5.346665, 7.400823, 8.685858, 10.206573, 
    16.005764
])

# Average Himmelblau's function (obj1)
average_himmelblaus_obj1 = [
    0.011730, 0.009366, 0.009402, 0.009419, 0.009403, 
    0.009408, 0.009580, 0.009557, 0.009550, 0.009475, 
    0.009450, 0.009377, 0.009359, 0.009238, 0.008956, 
    0.008852
]

# Average x² function (obj1)
average_x2_obj1 = [
    0.106289, 0.043626, 0.038726, 0.035411, 0.031480, 
    0.028532, 0.026705, 0.024218, 0.021740, 0.020261, 
    0.018588, 0.016948, 0.015813, 0.014355, 0.012922, 
    0.011714
]

# Optimization
optimization = [
    7.451326, 7.855854, 7.836587, 7.958636, 7.958332, 
    7.925209, 8.045178, 8.171637, 8.130771, 8.164983, 
    8.142607, 8.169197, 8.304763, 8.319354, 8.333976, 
    8.414887
]

# Diversity Optimization
diversity_optimization = [
    3.538180, 3.717981, 3.740359, 3.818768, 3.927783, 
    3.987598, 4.103164, 4.201240, 4.263009, 4.363165, 
    4.556143, 4.579950, 4.638799, 4.880286, 5.050622, 
    5.412182
]

# %%
# S-Energy Diversity


sp_diversity_2 = [
    1.289199, 1.996073, 1.991996, 1.987945, 1.981956, 
    1.967903, 1.951544, 1.932737, 1.895963, 1.874545, 
    1.827847, 1.784486, 1.702311, 1.624896, 1.556300, 
    1.480062
]

# Min-Max Diversity
min_max_diversity_2 = [
    0.020000, 1.221061, 1.138655, 1.076242, 1.031588, 
    0.942658, 0.909607, 0.838863, 0.767845, 0.698749, 
    0.663497, 0.607038, 0.535997, 0.486068, 0.429293, 
    0.379392
]

s_energy_diversity_2 = np.array([
    445.861269, 0.019368, 0.025308, 0.030822, 0.038321, 
    0.056873, 0.081425, 0.118431, 0.228517, 0.297233, 
    0.522955, 0.646044, 1.074184, 2.085269, 3.569676, 
    4.610993
])*10

# Average Himmelblau's function (obj1)
average_himmelblaus_obj1_2 = [
    0.011730, 0.009600, 0.009608, 0.009532, 0.009616, 
    0.009601, 0.009599, 0.009561, 0.009561, 0.009461, 
    0.009287, 0.009163, 0.009011, 0.008784, 0.008641, 
    0.008437
]

# Average x² function (obj1)
average_x2_obj1_2 = [
    0.106289, 0.055352, 0.049133, 0.044683, 0.040917, 
    0.036637, 0.033793, 0.030192, 0.026679, 0.023562, 
    0.021241, 0.019300, 0.017019, 0.015214, 0.014057, 
    0.012782
]

# Optimization
optimization_2 = [
    7.497427, 7.796311, 7.855045, 7.926001, 7.993331, 
    7.977684, 8.045780, 8.046087, 8.211405, 8.315027, 
    8.233245, 8.198871, 8.186490, 8.445689, 8.387225, 
    8.489354
]

# Diversity Optimization
diversity_optimization_2 = [
    3.362746, 3.422245, 3.559312, 3.678381, 3.826344, 
    3.949061, 4.028183, 4.122715, 4.191066, 4.390973, 
    4.588962, 4.826460, 5.011662, 5.239017, 5.409667, 
    5.608053
]

# %%
# SP diversity
sp_diversity_3 = [
    1.289199, 1.960487, 1.945357, 1.937804, 1.924560, 
    1.909342, 1.869035, 1.837104, 1.797108, 1.744152, 
    1.739766, 1.702741, 1.622240, 1.572711, 1.494850, 
    1.417844
]

# Min-Max Diversity
min_max_diversity_3 = [
    0.020000, 0.724326, 0.677254, 0.628711, 0.622938, 
    0.600469, 0.529807, 0.496154, 0.447991, 0.423633, 
    0.412592, 0.389407, 0.344460, 0.311957, 0.279708, 
    0.245256
]

# S-Energy Diversity
s_energy_diversity_3 = np.array([
    44.586127, 0.006602, 0.008349, 0.009297, 0.010976, 
    0.014109, 0.021526, 0.863826, 0.061337, 0.082194, 
    0.097439, 0.336245, 0.197754, 0.621770, 0.696143, 
    2.926403
])*100

# Average Himmelblau's function (obj1)
average_himmelblaus_obj1_3 = [
    0.011730, 0.008437, 0.008432, 0.008630, 0.008870, 
    0.008912, 0.008896, 0.008877, 0.008940, 0.008881, 
    0.009055, 0.008936, 0.008793, 0.008705, 0.008598, 
    0.008348
]

# Average x² function (obj1)
average_x2_obj1_3 = [
    0.106289, 0.036426, 0.032597, 0.030453, 0.027351, 
    0.025033, 0.022691, 0.021111, 0.019045, 0.017011, 
    0.015413, 0.014264, 0.012799, 0.011787, 0.011149, 
    0.010127
]

# Optimization
optimization_3 = [
    7.400528, 7.843852, 7.977254, 7.995594, 8.007154, 
    7.991656, 8.119319, 8.088134, 8.080141, 8.279104, 
    8.262833, 8.340878, 8.348617, 8.411689, 8.420187, 
    8.404809
]

# Diversity Optimization
diversity_optimization_3 = [
    4.085698, 4.089746, 3.945617, 4.098771, 4.222704, 
    4.338337, 4.443570, 4.567530, 4.694627, 4.801443, 
    4.832356, 5.114050, 5.195214, 5.410029, 5.526543, 
    5.585083
]

# %%
compare_three_lists(sp_diversity, sp_diversity_2, sp_diversity_3)
# Out:
# 1.9408131874999999 1.8028601874999999 1.73526875
# [15.127256011507344, 0.0005189889293522805]

# %%
compare_three_lists(s_energy_diversity, s_energy_diversity_2, s_energy_diversity_3)
# Out:
# 347.67658124999997 282.91497625 282.5186694375
# [16.98278061224488, 0.0002052277323032883]

# %%
compare_three_lists(min_max_diversity, min_max_diversity_2, min_max_diversity_3)
# Out:
# 0.295665 0.7290605625 0.7348874375
# [23.15808903365906, 9.360194228054647e-06]

# %%
compare_three_lists(optimization, optimization_2, optimization_3)
# Out:
# 8.09795375 8.06144825 8.0739560625
# [0.1938775510203925, 0.90761157248771]

# %%
compare_three_lists(diversity_optimization, diversity_optimization_2, diversity_optimization_3)
# Out:
# 4.73556875 4.315893375 4.2987018125
# [6.21875, 0.04462883965030139]

# %% [markdown]
# ## NSGA-II, mutation rate 0.7

# %%
mutation_rate = 0.7
pop_size = 50
it = 30
max_gen = 30

# %%
def NSGA2_simple(P_0, mutation_rate, it, pop_size, max_gen):
    
    start_time = time.time()

    a_fp = open('./obj1evolution_simple_' + str(mutation_rate) + '.json', 'w')
    b_fp = open('./sol1evolution_simple_' + str(mutation_rate) + '.json', 'w')
    iteration = 0
    B = []
    D = []
    for iteration in range(it):
        print("iteration", iteration)
        
        #Main program starts here

        #Initialization
        min_x=-55
        max_x=55
        A = defaultdict()
        C = defaultdict()
        solution = P_0

        gen_no=0
        while(gen_no<max_gen):
            print("GENERATION", gen_no)
            function1_values = [obj1(solution[i]) for i in range(0,pop_size)]
            function2_values = [obj2(solution[i]) for i in range(0,pop_size)]
            non_dominated_sorted_solution = fast_non_dominated_sort(function1_values[:],function2_values[:])
#             crowding_distance_values=[]

#             for i in range(0,len(non_dominated_sorted_solution)):
#                 crowding_distance_values.append(crowding_distance(function1_values[:],function2_values[:],non_dominated_sorted_solution[i][:]))

            solution2 = solution[:]

            #Generating offsprings
            while(len(solution2)!=2*pop_size):
                a1 = random.randint(0,pop_size-1)
                s = 0
                app = mutation(solution[a1], mutation_rate)
                solution2.append(app)
#                 print("app", app, obj1(app), obj2(app))    
            
            function1_values2 = [obj1(solution2[i]) for i in range(0,2*pop_size)]
            function2_values2 = [obj2(solution2[i]) for i in range(0,2*pop_size)]
            
#             print(function1_values2, function2_values2)

            A[gen_no] = [function1_values, function2_values]
            non_dominated_sorted_solution2 = fast_non_dominated_sort(function1_values2[:],function2_values2[:])
            crowding_distance_values2=[]

            for i in range(0,len(non_dominated_sorted_solution2)):
                crowding_distance_values2.append(crowding_distance(function1_values2[:],function2_values2[:],non_dominated_sorted_solution2[i][:]))

            
            
            new_solution= []
            for i in range(0,len(non_dominated_sorted_solution2)):
                non_dominated_sorted_solution2_1 = [index_of(non_dominated_sorted_solution2[i][j],non_dominated_sorted_solution2[i] ) for j in range(0,len(non_dominated_sorted_solution2[i]))]
                front22 = sort_by_values(non_dominated_sorted_solution2_1[:], crowding_distance_values2[i][:])
                front = [non_dominated_sorted_solution2[i][front22[j]] for j in range(0,len(non_dominated_sorted_solution2[i]))]
                front.reverse()
                for value in front:
                    new_solution.append(value)
                    if(len(new_solution)==pop_size):
                        break
                if (len(new_solution) == pop_size):
                    break
            solution = [solution2[i] for i in new_solution] 
            
#             print("solution", solution)
            
            C[gen_no] = solution
            gen_no = gen_no + 1
        B.append(A)   
        D.append(C)
        
#         print("B, D", B)
        iteration +=1  
        vis_plot(solution)
    json.dump(B, a_fp)
    json.dump(D, b_fp, cls=NpEncoder)            
    a_fp.close()
    b_fp.close()

    print("--- %s seconds ---" % (time.time() - start_time))
    
    return 0

# %%
NSGA2_simple(P_0, mutation_rate, it, pop_size, max_gen)

# %%
def non_domin(objjs, it, max_gen):
    pareto_fronts(objjs, it, max_gen)
    return one_pareto_front(objjs, it, max_gen)

non_domin("obj1evolution_simple_0.7.json", 30, 0)

# %%
# mutation_rate = 0.99
# pop_size = 50
# it = 1
# max_gen = 10000
# eps = 10

# %%
# NSGA2_simple_eps(P_0, mutation_rate, it, pop_size, max_gen, eps)

# %%
# a = sol("obj1evolution_simple_eps_0.7.json", 30).values.tolist()
print(a)
# pairs = []
# # Iterate over the length of the lists
# for i in range(50):
#     # Create a pair [first coordinate, second coordinate] and append it to the pairs list
#     pair = [a[0][i], a[1][i]]
#     pairs.append(pair)

# # Print the list of pairs
# vis_plot(pairs)

# %%
# def non_domin_eps(objjs, it, max_gen, eps):
#     pareto_fronts_eps(objjs, it, max_gen, eps)
#     return one_pareto_front_eps(objjs, it, max_gen, eps)

# non_domin_eps("obj1evolution_simple_eps_0.7.json", 30, 30, 10)

# %%
def knee_point(objjs, soljs, it, max_gen, mutation_rate, pop_size):
    minim = 100000
    nondom = non_domin(objjs, it, max_gen)
    print(nondom)
    sols = sol(soljs, it)
    for i in range(len(nondom[0])):
        if np.abs(nondom[0][i] - nondom[1][i]) < minim:
            minim = np.abs(nondom[0][i] - nondom[1][i])
            minim_arg = i
#     print(minim, minim_arg)
    for i in range(it):
        print(i)
        for j in range(max_gen):
            for d in range(pop_size):
#                 print(obj1(sols[i][j][d], heights), obj2(sols[i][j][d], heights))
#                 print(sols[i][j][d])
                if (np.abs(-obj1(sols[i][j][d]) - nondom[0][minim_arg]) < epsilon) and (np.abs(-obj2(sols[i][j][d]) - nondom[1][minim_arg]) < epsilon):
#                   
                    return sols[i][j][d]
    
knee_point("obj1evolution_simple_0.7.json", 'sol1evolution_simple_0.7.json', 30, 30, mutation_rate, pop_size)

# %%
def min_obj1(objjs, soljs, it, max_gen, mutation_rate, pop_size):
    min1 = 100000
    nondom = non_domin(objjs, it, max_gen)
    sols = sol(soljs, it)
    for i in range(len(nondom[0])):
        if np.abs(nondom[0][i]) < min1:
            min1 = np.abs(nondom[0][i])
            min_arg1 = i
#     print(min1, min_arg1)
    for i in range(it):
        print(i)
        for j in range(max_gen):
            
            for d in range(pop_size):
                    
#                 print(sols[i][j][d])
    #             print(obj1(sol099[i][j][d], heights), obj2(sol099[i][j][d], heights))
                
                if (np.abs(-obj1(sols[i][j][d]) - nondom[0][min_arg1]) < epsilon) and (np.abs(-obj2(sols[i][j][d]) - nondom[1][min_arg1]) < epsilon):
#                     print ([i, j, d])
                    return sols[i][j][d]
min_obj1("obj1evolution_simple_0.7.json", 'sol1evolution_simple_0.7.json', 30, 30, mutation_rate, pop_size)

# %%
def min_obj2(objjs, soljs, it, max_gen, mutation_rate, pop_size):
    min2 = 100000
    nondom = non_domin(objjs, it, max_gen)
    sols = sol(soljs, it)
    for i in range(len(nondom[0])):
        if np.abs(nondom[1][i]) < min2:
            min2 = np.abs(nondom[1][i])
            min_arg2 = i
    print(min2, min_arg2)
    for i in range(it):
        print(i)
        for j in range(max_gen):
            for d in range(pop_size):
    #             print(obj1(sol099[i][j][d], heights), obj2(sol099[i][j][d], heights))
                if (np.abs(-obj1(sols[i][j][d]) - nondom[0][min_arg2]) < epsilon) and (np.abs(-obj2(sols[i][j][d]) - nondom[1][min_arg2]) < epsilon):
                    print ([i, j, d])
                    return sols[i][j][d]
min_obj2("obj1evolution_simple_0.7.json", 'sol1evolution_simple_0.7.json', 30, 30, mutation_rate, pop_size)

# %%
# def results(it, max_gen, mutation_rate):
#     df = df_correct_to_Andre('./objevolution' + str(mutation_rate) + '.json', it)
#     res = []
#     for k in range(it):
#         A = []
#         for i in range(max_gen):
#             A.append([df[k][i][0], df[k][i][1]])
#         res.append(A)
#     E = []
#     for q in range(it):
#         B = []
#         C = non_dominated([x for y in [res[q][t][0] for t in range(1, max_gen)] for x in y], [x for y in [res[q][t][1] for t in range(1, max_gen)] for x in y])
#         for p in range(max_gen):
#             B.append([C[0][p], C[1][p]])
#         E.append(B)
#     with open('./results' + str(mutation_rate) + '.txt', "w") as txt_file:
#         txt_file.write(str(E))
#     return 0
# # results(it, max_gen, mutation_rate)
